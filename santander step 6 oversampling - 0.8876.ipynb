# %% [markdown]
# # Santander

# %% [markdown]
# # 1. Import libs
# [top](#Contents)

# %%
# pandas and numpy imports
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

import warnings
# Suppress the specific warning
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn.metrics')

# %%
# pip install -U imbalanced-learn

# %% [markdown]
# # 2. Get data
# [top](#Contents)

# %% [markdown]
# #### Read data
# [top](#Contents)

# %%
bank_ds = pd.read_csv('train.csv')

# %%
bank_test_ds = pd.read_csv('test.csv')

# %% [markdown]
# #### Drop an unneeded column

# %%
# Assuming 'column_to_drop' is the name of the column you want to drop
column_to_drop = 'ID_code'

# Drop the column from bank_ds
bank_ds.drop(column_to_drop, axis=1, inplace=True)

# %% [markdown]
# ### Split 70/30 (stratified sampling)

# %%
target = bank_ds['target']

# %%
# separate dataset into train and test

X_train, X_test, y_train, y_test = train_test_split(
    bank_ds.drop(labels=['target'], axis=1),  # drop the target
    bank_ds['target'],  # just the target
    test_size=0.3,
    stratify=target,
    random_state=42)

X_train.shape, X_test.shape
# Out:
# ((140000, 200), (60000, 200))

# %% [markdown]
# ### Scaling

# %% [markdown]
# Models like Logistic Regression require scaling for better performance. Tree-based models like Random Forest, XGBoost, and LightGBM do not inherently require scaling but scaling can still be beneficial (can improve performance and convergence in some cases).

# %%
from sklearn.preprocessing import MinMaxScaler
# we put the variables in the same scale
scaler = MinMaxScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Oversampling

# %%
from imblearn.over_sampling import (
    RandomOverSampler,
    SMOTE,
    ADASYN,
    BorderlineSMOTE,
    SVMSMOTE,
)
from sklearn.svm import SVC

# %%
oversampler_dict = {
    'random': RandomOverSampler(sampling_strategy='auto', random_state=0),
    'smote': SMOTE(sampling_strategy='auto', random_state=0, k_neighbors=5, n_jobs=4),
    'adasyn': ADASYN(sampling_strategy='auto', random_state=0, n_neighbors=5, n_jobs=4),
    'border1': BorderlineSMOTE(sampling_strategy='auto', random_state=0, k_neighbors=5, m_neighbors=10, kind='borderline-1', n_jobs=4),
    'border2': BorderlineSMOTE(sampling_strategy='auto', random_state=0, k_neighbors=5, m_neighbors=10, kind='borderline-2', n_jobs=4)
}

# %%
# oversampler_dict = {
    'random': RandomOverSampler(sampling_strategy='auto', random_state=0),
    'smote': SMOTE(sampling_strategy='auto', random_state=0, k_neighbors=5, n_jobs=4),
    'adasyn': ADASYN(sampling_strategy='auto', random_state=0, n_neighbors=5, n_jobs=4),
    'border1': BorderlineSMOTE(sampling_strategy='auto', random_state=0, k_neighbors=5, m_neighbors=10, kind='borderline-1', n_jobs=4),
    'border2': BorderlineSMOTE(sampling_strategy='auto', random_state=0, k_neighbors=5, m_neighbors=10, kind='borderline-2', n_jobs=4),
    'svm': SVMSMOTE(sampling_strategy='auto', random_state=0, k_neighbors=5, m_neighbors=10, n_jobs=4, svm_estimator=SVC(kernel='linear'))
}

# %% [markdown]
# ## Evaluation

# %% [markdown]
# #### Metrics which require predict method

# %% [markdown]
# #### Confusion matrix, Recall, Precision, F1-score, G-mean, etc

# %%
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    recall_score,
    precision_score,
    f1_score,
    classification_report,
    confusion_matrix
)

# require scaling
from imblearn.metrics import (
    geometric_mean_score,
    make_index_balanced_accuracy,
)

def dominance(y_true, y_pred):
    tpr = recall_score(y_test, y_pred, pos_label=1)
    tnr = recall_score(y_test, y_pred, pos_label=0)
    return tpr - tnr

# Function to get classification metrics
def get_classification_metrics(y_true, y_pred):
    report = classification_report(y_true, y_pred, output_dict=True)
    accuracy          = accuracy_score(y_test, y_pred)
    balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
    
    # Adding possible averages to recall, precision, and f1-score calculations
    # Default average is None - scores are returned for each class individually rather than being averaged
    recall_weighted    = recall_score(y_test, y_pred, average='weighted')
    precision_weighted = precision_score(y_test, y_pred, average='weighted') 
    f1_weighted        = f1_score(y_test, y_pred, average='weighted')

    recall_micro       = recall_score(y_test, y_pred, average='micro')
    precision_micro    = precision_score(y_test, y_pred, average='micro')
    f1_micro           = f1_score(y_test, y_pred, average='micro')
    
    recall_macro       = recall_score(y_test, y_pred, average='macro')
    precision_macro    = precision_score(y_test, y_pred, average='macro')
    f1_macro           = f1_score(y_test, y_pred, average='macro')

    # Adding possible averages to G-mean
    # If the average parameter is not specified, it defaults to average='binary'.
    g_mean_binary      = geometric_mean_score(y_test, y_pred, average='binary')
    g_mean_weighted    = geometric_mean_score(y_test, y_pred, average='weighted')
    g_mean_micro       = geometric_mean_score(y_test, y_pred, average='micro')
    g_mean_macro       = geometric_mean_score(y_test, y_pred, average='macro')

    # A lower alpha gives more weight to sensitivity (TPR), while a higher alpha gives more weight to specificity (TNR). 
    # In other words,in case of a lower alpha more emphasis is placed on correctly identifying positive instances
    gmean = make_index_balanced_accuracy(alpha=0.5, squared=True)(geometric_mean_score) 
    corrected_g_mean  = gmean(y_test, y_pred)
    # specifying an average might not be necessary or meaningful. Leaving for the time being
    corrected_g_mean_binary  = gmean(y_test, y_pred,average='binary')
    corrected_g_mean_weighted  = gmean(y_test, y_pred,average='weighted')
    corrected_g_mean_micro  = gmean(y_test, y_pred,average='micro')
    corrected_g_mean_macro  = gmean(y_test, y_pred,average='macro')
    
    dominance_score   = dominance(y_test, y_pred) 

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
    FPR = fp / (tn + fp)
    FNR = fn / (tp + fn)
    # TPR = tp / (tp + fn) # recallminority
    # TNR = tn / (tn + fp) # recall majority
    
    return {
        'Accuracy': accuracy,
        'Recall Majority (TNR)': report['0']['recall'],
        'Recall Minority (TPR)': report['1']['recall'],
        'Balanced Accuracy': balanced_accuracy,
        'FPR': FPR,
        'FNR': FNR,
        
        'Precision Majority': report['0']['precision'],
        'Precision Minority': report['1']['precision'],
        'F1-Score Majority': report['0']['f1-score'],
        'F1-Score Minority': report['1']['f1-score'], 
        
        # Weighted average (Use 'weighted' if you want to take class imbalance into account)
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,

        # Micro average (Use 'micro' if you want a metric that gives equal weight to every individual prediction)
        'Micro Precision': precision_micro,
        'Micro Recall': recall_micro,
        'Micro F1-Score': f1_micro,
        
        # Macro average (Use 'macro' if you want to treat each class equally)
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,

        # Geometric average (a suitable metric when you want to balance the trade-off between detecting the minority class 
        # and avoiding false positives from the majority class)
        'G-mean-binary': g_mean_binary, # (compute two geometric means for each class, then the arithmetic mean of these G-means)
        'G-mean-weighted': g_mean_weighted, # calculates the geometric mean for each class and then computes the weighted arithmetic mean of these G-means
        'G-mean-micro': g_mean_micro, # treats all classes equally, regardless of their size
        'G-mean-macro': g_mean_macro, # use when you want to weight each instance equally, regardless of their class

        # Corrected G-means
        'Corrected G-mean': corrected_g_mean,
        'Corrected G-mean-binary': corrected_g_mean_binary,
        'Corrected G-mean-weighted': corrected_g_mean_weighted,
        'Corrected G-mean-micro': corrected_g_mean_micro,
        'Corrected G-mean-macro': corrected_g_mean_macro,
        
        'Dominance': dominance_score
    }

# Dictionary to hold the models
models_dict = {
    #'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(random_state=42),
    #'XGBoost': XGBClassifier(random_state=42),
    'LightGBM': LGBMClassifier(random_state=42),
    'CatBoost': CatBoostClassifier(random_state=42)
}
# Collecting results
results = []
confusion_matrices = []

# Iterate over each oversampling technique
for name, oversampler in oversampler_dict.items():
    print(f"Applying undersampling technique: {name}")
    
    # Apply oversampling to the training data
    X_resampled, y_resampled = oversampler.fit_resample(X_train, y_train)
    
    # Iterate over each model
    for model_name, model in models_dict.items():
        print(f"Training model: {model_name} with oversampling technique: {name}")
        
        # Train the model
        model.fit(X_resampled, y_resampled)
        
        # Make predictions on the test set
        y_pred = model.predict(X_test)
        
        # Calculate metrics
        metrics = get_classification_metrics(y_test, y_pred)
        
        # Append the results
        results.append({
            'Oversampling Technique': name,
            'Model': model_name,
            **metrics
        })

# Create a DataFrame from the results
df_results_1 = pd.DataFrame(results)

# Print the DataFrame as a table
print(df_results_1)
# Out:
# Applying undersampling technique: random
# Training model: Logistic Regression with oversampling technique: random
# Training model: LightGBM with oversampling technique: random
# [LightGBM] [Info] Number of positive: 125931, number of negative: 125931
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.644267 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 251862, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Applying undersampling technique: smote
# C:\Users\dziya\anaconda3\Lib\site-packages\imblearn\over_sampling\_smote\base.py:363: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# Training model: Logistic Regression with oversampling technique: smote
# Training model: LightGBM with oversampling technique: smote
# [LightGBM] [Info] Number of positive: 125931, number of negative: 125931
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.615931 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 251862, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Applying undersampling technique: adasyn
# C:\Users\dziya\anaconda3\Lib\site-packages\imblearn\over_sampling\_adasyn.py:156: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# Training model: Logistic Regression with oversampling technique: adasyn
# Training model: LightGBM with oversampling technique: adasyn
# [LightGBM] [Info] Number of positive: 123202, number of negative: 125931
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.618503 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 249133, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.494523 -> initscore=-0.021909
# [LightGBM] [Info] Start training from score -0.021909
# Applying undersampling technique: border1
# C:\Users\dziya\anaconda3\Lib\site-packages\imblearn\over_sampling\_smote\filter.py:197: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# Training model: Logistic Regression with oversampling technique: border1
# Training model: LightGBM with oversampling technique: border1
# [LightGBM] [Info] Number of positive: 125931, number of negative: 125931
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.542396 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 251862, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Applying undersampling technique: border2
# C:\Users\dziya\anaconda3\Lib\site-packages\imblearn\over_sampling\_smote\filter.py:197: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(
# Training model: Logistic Regression with oversampling technique: border2
# Training model: LightGBM with oversampling technique: border2
# [LightGBM] [Info] Number of positive: 125931, number of negative: 125931
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.651417 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 251862, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#   Oversampling Technique                Model  Accuracy  \
# 0                 random  Logistic Regression  0.782117
# 1                 random             LightGBM  0.815500
# 2                  smote  Logistic Regression  0.787783
# 3                  smote             LightGBM  0.858667
# 4                 adasyn  Logistic Regression  0.789567
# 5                 adasyn             LightGBM  0.860033
# 6                border1  Logistic Regression  0.807250
# 7                border1             LightGBM  0.862183
# 8                border2  Logistic Regression  0.797517
# 9                border2             LightGBM  0.836700
#
#    Recall Majority (TNR)  Recall Minority (TPR)  Balanced Accuracy       FPR  \
# 0               0.783217               0.772267           0.777742  0.216783
# 1               0.824183               0.737767           0.780975  0.175817
# 2               0.790795               0.760823           0.775809  0.209205
# 3               0.925682               0.258749           0.592216  0.074318
# 4               0.793167               0.757340           0.775253  0.206833
# 5               0.927887               0.252612           0.590250  0.072113
# 6               0.816198               0.727152           0.771675  0.183802
# 7               0.929017               0.263891           0.596454  0.070983
# 8               0.803543               0.743573           0.773558  0.196457
# 9               0.875248               0.491624           0.683436  0.124752
#
#         FNR  Precision Majority  Precision Minority  ...  G-mean-binary  \
# 0  0.227733            0.968541            0.284666  ...       0.777723
# 1  0.262233            0.965677            0.319150  ...       0.779779
# 2  0.239177            0.967318            0.288890  ...       0.775664
# 3  0.741251            0.917893            0.280022  ...       0.489408
# 4  0.242660            0.966954            0.290292  ...       0.775046
# 5  0.747388            0.917450            0.281256  ...       0.484144
# 6  0.272848            0.964001            0.306488  ...       0.770389
# 7  0.736109            0.918685            0.293434  ...       0.495136
# 8  0.256427            0.965579            0.297163  ...       0.772976
# 9  0.508376            0.939069            0.305662  ...       0.655967
#
#    G-mean-weighted  G-mean-micro  G-mean-macro  Corrected G-mean  \
# 0         0.777730      0.782117      0.777742          0.604853
# 1         0.780212      0.815500      0.780975          0.608056
# 2         0.775716      0.787783      0.775809          0.601655
# 3         0.528889      0.858667      0.592216          0.239520
# 4         0.775121      0.789567      0.775253          0.600696
# 5         0.524987      0.860033      0.590250          0.234396
# 6         0.770854      0.807250      0.771675          0.593500
# 7         0.533990      0.862183      0.596454          0.245160
# 8         0.773187      0.797517      0.773558          0.597492
# 9         0.666029      0.836700      0.683436          0.430293
#
#    Corrected G-mean-binary  Corrected G-mean-weighted  Corrected G-mean-micro  \
# 0                 0.601541                   0.607510                0.611706
# 1                 0.581783                   0.629747                0.665040
# 2                 0.592638                   0.608941                0.620603
# 3                 0.159648                   0.354256                0.737308
# 4                 0.589936                   0.609412                0.623416
# 5                 0.155255                   0.349967                0.739657
# 6                 0.567076                   0.615356                0.651653
# 7                 0.163629                   0.360917                0.743360
# 8                 0.579577                   0.612141                0.636033
# 9                 0.347757                   0.511582                0.700067
#
#    Corrected G-mean-macro  Dominance
# 0                0.604883  -0.010950
# 1                0.609923  -0.086416
# 2                0.601879  -0.029972
# 3                0.350720  -0.666933
# 4                0.601017  -0.035827
# 5                0.348395  -0.675275
# 6                0.595482  -0.089045
# 7                0.355758  -0.665126
# 8                0.598391  -0.059970
# 9                0.467085  -0.383624
#
# [10 rows x 31 columns]

# %% [markdown]
# #### Metrics which require predict_proba method
# The ROC AUC score is calculated based on the predicted probabilities for each class, which are obtained using the predict_proba method. This method provides the probability estimates for each class, which are necessary to compute the ROC curve and subsequently the AUC (Area Under the Curve).

# %%
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score
)

# Dictionary to hold the models
models_dict = {
    #'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(random_state=42),
    #'XGBoost': XGBClassifier(random_state=42),
    'LightGBM': LGBMClassifier(random_state=42),
    'CatBoost': CatBoostClassifier(random_state=42)
}

# Collecting results
results = []
# Iterate over each undersampling technique
for name, oversampler in oversampler_dict.items():
    print(f"Applying oversampling technique: {name}")
    
    # Apply oversampling to the training data
    X_resampled, y_resampled = oversampler.fit_resample(X_train, y_train)
    
    # Iterate over each model
    for model_name, model in models_dict.items():
        print(f"Training model: {model_name} with oversampling technique: {name}")

        # Train the model
        model.fit(X_resampled, y_resampled)
        
        # Make predictions on the test set
        y_pred_proba = model.predict_proba(X_test)[:, 1]  
        
        # Calculate metrics
        roc_auc = roc_auc_score(y_test, y_pred_proba)
        pr_auc = average_precision_score(y_test, y_pred_proba)
        
        # Append the results
        results.append({
            'Undersampling Technique': name,
            'Model': model_name,
            'ROC-AUC': roc_auc,
            'PR-AUC': pr_auc
        })

# Create a DataFrame from the results
df_results_2 = pd.DataFrame(results)

# Print the DataFrame as a table
print(df_results_2)
# Out:
# Applying oversampling technique: random
# Training model: CatBoost with oversampling technique: random
# Learning rate set to 0.109202
# 0:	learn: 0.6849325	total: 356ms	remaining: 5m 55s
# 1:	learn: 0.6771810	total: 498ms	remaining: 4m 8s
# 2:	learn: 0.6709826	total: 637ms	remaining: 3m 31s
# 3:	learn: 0.6649726	total: 781ms	remaining: 3m 14s
# 4:	learn: 0.6595633	total: 921ms	remaining: 3m 3s
# 5:	learn: 0.6546803	total: 1.06s	remaining: 2m 56s
# 6:	learn: 0.6499906	total: 1.2s	remaining: 2m 50s
# 7:	learn: 0.6454376	total: 1.33s	remaining: 2m 45s
# 8:	learn: 0.6411991	total: 1.5s	remaining: 2m 45s
# 9:	learn: 0.6370973	total: 1.68s	remaining: 2m 46s
# 10:	learn: 0.6331012	total: 1.83s	remaining: 2m 44s
# 11:	learn: 0.6292891	total: 1.96s	remaining: 2m 41s
# 12:	learn: 0.6256999	total: 2.1s	remaining: 2m 39s
# 13:	learn: 0.6221606	total: 2.24s	remaining: 2m 37s
# 14:	learn: 0.6188819	total: 2.38s	remaining: 2m 36s
# 15:	learn: 0.6157070	total: 2.53s	remaining: 2m 35s
# 16:	learn: 0.6124670	total: 2.65s	remaining: 2m 33s
# 17:	learn: 0.6093699	total: 2.79s	remaining: 2m 32s
# 18:	learn: 0.6064312	total: 2.92s	remaining: 2m 30s
# 19:	learn: 0.6036143	total: 3.09s	remaining: 2m 31s
# 20:	learn: 0.6008431	total: 3.23s	remaining: 2m 30s
# 21:	learn: 0.5983385	total: 3.37s	remaining: 2m 29s
# 22:	learn: 0.5957782	total: 3.52s	remaining: 2m 29s
# 23:	learn: 0.5932371	total: 3.64s	remaining: 2m 28s
# 24:	learn: 0.5906782	total: 3.79s	remaining: 2m 27s
# 25:	learn: 0.5882550	total: 3.91s	remaining: 2m 26s
# 26:	learn: 0.5859009	total: 4.04s	remaining: 2m 25s
# 27:	learn: 0.5835862	total: 4.18s	remaining: 2m 25s
# 28:	learn: 0.5813990	total: 4.33s	remaining: 2m 24s
# 29:	learn: 0.5791403	total: 4.47s	remaining: 2m 24s
# 30:	learn: 0.5768933	total: 4.62s	remaining: 2m 24s
# 31:	learn: 0.5747623	total: 4.76s	remaining: 2m 24s
# 32:	learn: 0.5726777	total: 4.9s	remaining: 2m 23s
# 33:	learn: 0.5706400	total: 5.05s	remaining: 2m 23s
# 34:	learn: 0.5686452	total: 5.2s	remaining: 2m 23s
# 35:	learn: 0.5667688	total: 5.35s	remaining: 2m 23s
# 36:	learn: 0.5648954	total: 5.5s	remaining: 2m 23s
# 37:	learn: 0.5630777	total: 5.65s	remaining: 2m 22s
# 38:	learn: 0.5612740	total: 5.78s	remaining: 2m 22s
# 39:	learn: 0.5594133	total: 5.91s	remaining: 2m 21s
# 40:	learn: 0.5575682	total: 6.04s	remaining: 2m 21s
# 41:	learn: 0.5557724	total: 6.17s	remaining: 2m 20s
# 42:	learn: 0.5540026	total: 6.3s	remaining: 2m 20s
# 43:	learn: 0.5523500	total: 6.44s	remaining: 2m 19s
# 44:	learn: 0.5507039	total: 6.59s	remaining: 2m 19s
# 45:	learn: 0.5491353	total: 6.74s	remaining: 2m 19s
# 46:	learn: 0.5474479	total: 6.91s	remaining: 2m 20s
# 47:	learn: 0.5458887	total: 7.05s	remaining: 2m 19s
# 48:	learn: 0.5443869	total: 7.22s	remaining: 2m 20s
# 49:	learn: 0.5428456	total: 7.36s	remaining: 2m 19s
# 50:	learn: 0.5413387	total: 7.54s	remaining: 2m 20s
# 51:	learn: 0.5398370	total: 7.69s	remaining: 2m 20s
# 52:	learn: 0.5383797	total: 7.84s	remaining: 2m 20s
# 53:	learn: 0.5369439	total: 7.97s	remaining: 2m 19s
# 54:	learn: 0.5355636	total: 8.15s	remaining: 2m 20s
# 55:	learn: 0.5341337	total: 8.29s	remaining: 2m 19s
# 56:	learn: 0.5327627	total: 8.44s	remaining: 2m 19s
# 57:	learn: 0.5313543	total: 8.59s	remaining: 2m 19s
# 58:	learn: 0.5300427	total: 8.76s	remaining: 2m 19s
# 59:	learn: 0.5287572	total: 8.9s	remaining: 2m 19s
# 60:	learn: 0.5274742	total: 9.06s	remaining: 2m 19s
# 61:	learn: 0.5261599	total: 9.21s	remaining: 2m 19s
# 62:	learn: 0.5248859	total: 9.41s	remaining: 2m 19s
# 63:	learn: 0.5236272	total: 9.55s	remaining: 2m 19s
# 64:	learn: 0.5223930	total: 9.74s	remaining: 2m 20s
# 65:	learn: 0.5211434	total: 9.9s	remaining: 2m 20s
# 66:	learn: 0.5198263	total: 10.1s	remaining: 2m 19s
# 67:	learn: 0.5186916	total: 10.2s	remaining: 2m 19s
# 68:	learn: 0.5174616	total: 10.3s	remaining: 2m 19s
# 69:	learn: 0.5162738	total: 10.5s	remaining: 2m 19s
# 70:	learn: 0.5151330	total: 10.6s	remaining: 2m 19s
# 71:	learn: 0.5140194	total: 10.8s	remaining: 2m 18s
# 72:	learn: 0.5128950	total: 10.9s	remaining: 2m 18s
# 73:	learn: 0.5117636	total: 11.1s	remaining: 2m 18s
# 74:	learn: 0.5106113	total: 11.2s	remaining: 2m 18s
# 75:	learn: 0.5095092	total: 11.4s	remaining: 2m 18s
# 76:	learn: 0.5084902	total: 11.5s	remaining: 2m 17s
# 77:	learn: 0.5074687	total: 11.6s	remaining: 2m 17s
# 78:	learn: 0.5064371	total: 11.8s	remaining: 2m 17s
# 79:	learn: 0.5054019	total: 11.9s	remaining: 2m 16s
# 80:	learn: 0.5044637	total: 12s	remaining: 2m 16s
# 81:	learn: 0.5033775	total: 12.2s	remaining: 2m 16s
# 82:	learn: 0.5024223	total: 12.3s	remaining: 2m 16s
# 83:	learn: 0.5013794	total: 12.5s	remaining: 2m 16s
# 84:	learn: 0.5003633	total: 12.6s	remaining: 2m 15s
# 85:	learn: 0.4992969	total: 12.7s	remaining: 2m 15s
# 86:	learn: 0.4983163	total: 12.9s	remaining: 2m 15s
# 87:	learn: 0.4973527	total: 13s	remaining: 2m 14s
# 88:	learn: 0.4964427	total: 13.2s	remaining: 2m 14s
# 89:	learn: 0.4954693	total: 13.3s	remaining: 2m 14s
# 90:	learn: 0.4945410	total: 13.4s	remaining: 2m 14s
# 91:	learn: 0.4936158	total: 13.6s	remaining: 2m 14s
# 92:	learn: 0.4927165	total: 13.7s	remaining: 2m 13s
# 93:	learn: 0.4918227	total: 13.9s	remaining: 2m 13s
# 94:	learn: 0.4909630	total: 14s	remaining: 2m 13s
# 95:	learn: 0.4900495	total: 14.1s	remaining: 2m 13s
# 96:	learn: 0.4891688	total: 14.3s	remaining: 2m 12s
# 97:	learn: 0.4882500	total: 14.4s	remaining: 2m 12s
# 98:	learn: 0.4873613	total: 14.5s	remaining: 2m 12s
# 99:	learn: 0.4865459	total: 14.6s	remaining: 2m 11s
# 100:	learn: 0.4856731	total: 14.8s	remaining: 2m 11s
# 101:	learn: 0.4848288	total: 14.9s	remaining: 2m 11s
# 102:	learn: 0.4839828	total: 15s	remaining: 2m 10s
# 103:	learn: 0.4831448	total: 15.1s	remaining: 2m 10s
# 104:	learn: 0.4823110	total: 15.3s	remaining: 2m 10s
# 105:	learn: 0.4814780	total: 15.4s	remaining: 2m 10s
# 106:	learn: 0.4806426	total: 15.6s	remaining: 2m 10s
# 107:	learn: 0.4798394	total: 15.8s	remaining: 2m 10s
# 108:	learn: 0.4789920	total: 15.9s	remaining: 2m 10s
# 109:	learn: 0.4781436	total: 16.1s	remaining: 2m 9s
# 110:	learn: 0.4773381	total: 16.2s	remaining: 2m 9s
# 111:	learn: 0.4765345	total: 16.3s	remaining: 2m 9s
# 112:	learn: 0.4757734	total: 16.5s	remaining: 2m 9s
# 113:	learn: 0.4750013	total: 16.6s	remaining: 2m 9s
# 114:	learn: 0.4742223	total: 16.8s	remaining: 2m 9s
# 115:	learn: 0.4734125	total: 16.9s	remaining: 2m 8s
# 116:	learn: 0.4726386	total: 17.1s	remaining: 2m 8s
# 117:	learn: 0.4718427	total: 17.2s	remaining: 2m 8s
# 118:	learn: 0.4710268	total: 17.4s	remaining: 2m 8s
# 119:	learn: 0.4702891	total: 17.5s	remaining: 2m 8s
# 120:	learn: 0.4695597	total: 17.6s	remaining: 2m 8s
# 121:	learn: 0.4688162	total: 17.7s	remaining: 2m 7s
# 122:	learn: 0.4680302	total: 17.9s	remaining: 2m 7s
# 123:	learn: 0.4672722	total: 18.1s	remaining: 2m 7s
# 124:	learn: 0.4665325	total: 18.2s	remaining: 2m 7s
# 125:	learn: 0.4657857	total: 18.3s	remaining: 2m 7s
# 126:	learn: 0.4650512	total: 18.5s	remaining: 2m 7s
# 127:	learn: 0.4642643	total: 18.6s	remaining: 2m 6s
# 128:	learn: 0.4634950	total: 18.8s	remaining: 2m 6s
# 129:	learn: 0.4627939	total: 18.9s	remaining: 2m 6s
# 130:	learn: 0.4620562	total: 19.1s	remaining: 2m 6s
# 131:	learn: 0.4613325	total: 19.2s	remaining: 2m 6s
# 132:	learn: 0.4605644	total: 19.4s	remaining: 2m 6s
# 133:	learn: 0.4598649	total: 19.5s	remaining: 2m 6s
# 134:	learn: 0.4591516	total: 19.6s	remaining: 2m 5s
# 135:	learn: 0.4584189	total: 19.8s	remaining: 2m 5s
# 136:	learn: 0.4577121	total: 19.9s	remaining: 2m 5s
# 137:	learn: 0.4569706	total: 20.1s	remaining: 2m 5s
# 138:	learn: 0.4562598	total: 20.3s	remaining: 2m 5s
# 139:	learn: 0.4555619	total: 20.4s	remaining: 2m 5s
# 140:	learn: 0.4548345	total: 20.6s	remaining: 2m 5s
# 141:	learn: 0.4541837	total: 20.7s	remaining: 2m 5s
# 142:	learn: 0.4535080	total: 20.8s	remaining: 2m 4s
# 143:	learn: 0.4527924	total: 21s	remaining: 2m 4s
# 144:	learn: 0.4521241	total: 21.1s	remaining: 2m 4s
# 145:	learn: 0.4514514	total: 21.3s	remaining: 2m 4s
# 146:	learn: 0.4507939	total: 21.4s	remaining: 2m 4s
# 147:	learn: 0.4501408	total: 21.5s	remaining: 2m 4s
# 148:	learn: 0.4494912	total: 21.7s	remaining: 2m 3s
# 149:	learn: 0.4488172	total: 21.8s	remaining: 2m 3s
# 150:	learn: 0.4481574	total: 21.9s	remaining: 2m 3s
# 151:	learn: 0.4475228	total: 22.1s	remaining: 2m 3s
# 152:	learn: 0.4468899	total: 22.2s	remaining: 2m 3s
# 153:	learn: 0.4462663	total: 22.4s	remaining: 2m 2s
# 154:	learn: 0.4456136	total: 22.5s	remaining: 2m 2s
# 155:	learn: 0.4449387	total: 22.6s	remaining: 2m 2s
# 156:	learn: 0.4443317	total: 22.8s	remaining: 2m 2s
# 157:	learn: 0.4436968	total: 22.9s	remaining: 2m 2s
# 158:	learn: 0.4430945	total: 23s	remaining: 2m 1s
# 159:	learn: 0.4425226	total: 23.2s	remaining: 2m 1s
# 160:	learn: 0.4419237	total: 23.3s	remaining: 2m 1s
# 161:	learn: 0.4413130	total: 23.4s	remaining: 2m 1s
# 162:	learn: 0.4406919	total: 23.6s	remaining: 2m 1s
# 163:	learn: 0.4400561	total: 23.7s	remaining: 2m
# 164:	learn: 0.4394593	total: 23.9s	remaining: 2m
# 165:	learn: 0.4388558	total: 24s	remaining: 2m
# 166:	learn: 0.4382265	total: 24.1s	remaining: 2m
# 167:	learn: 0.4376388	total: 24.3s	remaining: 2m
# 168:	learn: 0.4370700	total: 24.4s	remaining: 1m 59s
# 169:	learn: 0.4364996	total: 24.5s	remaining: 1m 59s
# 170:	learn: 0.4359424	total: 24.7s	remaining: 1m 59s
# 171:	learn: 0.4353612	total: 24.8s	remaining: 1m 59s
# 172:	learn: 0.4347895	total: 25s	remaining: 1m 59s
# 173:	learn: 0.4341916	total: 25.2s	remaining: 1m 59s
# 174:	learn: 0.4336327	total: 25.3s	remaining: 1m 59s
# 175:	learn: 0.4330705	total: 25.5s	remaining: 1m 59s
# 176:	learn: 0.4325252	total: 25.6s	remaining: 1m 59s
# 177:	learn: 0.4319842	total: 25.8s	remaining: 1m 59s
# 178:	learn: 0.4314394	total: 25.9s	remaining: 1m 58s
# 179:	learn: 0.4308540	total: 26.1s	remaining: 1m 58s
# 180:	learn: 0.4303143	total: 26.2s	remaining: 1m 58s
# 181:	learn: 0.4297469	total: 26.4s	remaining: 1m 58s
# 182:	learn: 0.4292015	total: 26.6s	remaining: 1m 58s
# 183:	learn: 0.4286578	total: 26.7s	remaining: 1m 58s
# 184:	learn: 0.4281521	total: 26.9s	remaining: 1m 58s
# 185:	learn: 0.4276065	total: 27.1s	remaining: 1m 58s
# 186:	learn: 0.4270751	total: 27.3s	remaining: 1m 58s
# 187:	learn: 0.4265345	total: 27.5s	remaining: 1m 58s
# 188:	learn: 0.4259783	total: 27.6s	remaining: 1m 58s
# 189:	learn: 0.4254489	total: 27.8s	remaining: 1m 58s
# 190:	learn: 0.4248706	total: 27.9s	remaining: 1m 58s
# 191:	learn: 0.4243538	total: 28.1s	remaining: 1m 58s
# 192:	learn: 0.4238460	total: 28.2s	remaining: 1m 58s
# 193:	learn: 0.4233584	total: 28.4s	remaining: 1m 57s
# 194:	learn: 0.4228470	total: 28.5s	remaining: 1m 57s
# 195:	learn: 0.4223041	total: 28.8s	remaining: 1m 57s
# 196:	learn: 0.4218158	total: 28.9s	remaining: 1m 57s
# 197:	learn: 0.4212995	total: 29.1s	remaining: 1m 57s
# 198:	learn: 0.4207840	total: 29.2s	remaining: 1m 57s
# 199:	learn: 0.4202827	total: 29.4s	remaining: 1m 57s
# 200:	learn: 0.4198042	total: 29.6s	remaining: 1m 57s
# 201:	learn: 0.4193410	total: 29.7s	remaining: 1m 57s
# 202:	learn: 0.4188413	total: 29.9s	remaining: 1m 57s
# 203:	learn: 0.4183075	total: 30s	remaining: 1m 57s
# 204:	learn: 0.4178272	total: 30.2s	remaining: 1m 57s
# 205:	learn: 0.4173525	total: 30.3s	remaining: 1m 56s
# 206:	learn: 0.4168820	total: 30.5s	remaining: 1m 56s
# 207:	learn: 0.4164272	total: 30.6s	remaining: 1m 56s
# 208:	learn: 0.4159177	total: 30.8s	remaining: 1m 56s
# 209:	learn: 0.4154151	total: 30.9s	remaining: 1m 56s
# 210:	learn: 0.4149369	total: 31.1s	remaining: 1m 56s
# 211:	learn: 0.4144477	total: 31.4s	remaining: 1m 56s
# 212:	learn: 0.4139213	total: 31.6s	remaining: 1m 56s
# 213:	learn: 0.4134445	total: 31.7s	remaining: 1m 56s
# 214:	learn: 0.4129446	total: 31.9s	remaining: 1m 56s
# 215:	learn: 0.4124883	total: 32s	remaining: 1m 56s
# 216:	learn: 0.4120119	total: 32.2s	remaining: 1m 56s
# 217:	learn: 0.4115922	total: 32.3s	remaining: 1m 55s
# 218:	learn: 0.4111263	total: 32.4s	remaining: 1m 55s
# 219:	learn: 0.4106356	total: 32.6s	remaining: 1m 55s
# 220:	learn: 0.4101790	total: 32.8s	remaining: 1m 55s
# 221:	learn: 0.4097115	total: 32.9s	remaining: 1m 55s
# 222:	learn: 0.4092705	total: 33s	remaining: 1m 55s
# 223:	learn: 0.4088058	total: 33.2s	remaining: 1m 55s
# 224:	learn: 0.4083786	total: 33.3s	remaining: 1m 54s
# 225:	learn: 0.4079494	total: 33.5s	remaining: 1m 54s
# 226:	learn: 0.4075172	total: 33.6s	remaining: 1m 54s
# 227:	learn: 0.4070811	total: 33.7s	remaining: 1m 54s
# 228:	learn: 0.4066609	total: 33.9s	remaining: 1m 54s
# 229:	learn: 0.4062107	total: 34s	remaining: 1m 53s
# 230:	learn: 0.4057967	total: 34.1s	remaining: 1m 53s
# 231:	learn: 0.4053516	total: 34.3s	remaining: 1m 53s
# 232:	learn: 0.4049005	total: 34.4s	remaining: 1m 53s
# 233:	learn: 0.4044479	total: 34.6s	remaining: 1m 53s
# 234:	learn: 0.4040302	total: 34.7s	remaining: 1m 53s
# 235:	learn: 0.4035577	total: 34.9s	remaining: 1m 53s
# 236:	learn: 0.4031168	total: 35.1s	remaining: 1m 52s
# 237:	learn: 0.4026928	total: 35.2s	remaining: 1m 52s
# 238:	learn: 0.4022653	total: 35.3s	remaining: 1m 52s
# 239:	learn: 0.4018242	total: 35.5s	remaining: 1m 52s
# 240:	learn: 0.4014004	total: 35.7s	remaining: 1m 52s
# 241:	learn: 0.4009814	total: 35.8s	remaining: 1m 52s
# 242:	learn: 0.4005465	total: 35.9s	remaining: 1m 51s
# 243:	learn: 0.4000732	total: 36.1s	remaining: 1m 51s
# 244:	learn: 0.3996526	total: 36.3s	remaining: 1m 51s
# 245:	learn: 0.3992427	total: 36.4s	remaining: 1m 51s
# 246:	learn: 0.3988239	total: 36.6s	remaining: 1m 51s
# 247:	learn: 0.3984167	total: 36.7s	remaining: 1m 51s
# 248:	learn: 0.3979731	total: 36.9s	remaining: 1m 51s
# 249:	learn: 0.3975154	total: 37.1s	remaining: 1m 51s
# 250:	learn: 0.3971032	total: 37.2s	remaining: 1m 51s
# 251:	learn: 0.3967044	total: 37.3s	remaining: 1m 50s
# 252:	learn: 0.3962572	total: 37.5s	remaining: 1m 50s
# 253:	learn: 0.3958488	total: 37.7s	remaining: 1m 50s
# 254:	learn: 0.3954130	total: 37.8s	remaining: 1m 50s
# 255:	learn: 0.3949976	total: 38s	remaining: 1m 50s
# 256:	learn: 0.3945838	total: 38.1s	remaining: 1m 50s
# 257:	learn: 0.3942209	total: 38.3s	remaining: 1m 50s
# 258:	learn: 0.3938314	total: 38.4s	remaining: 1m 49s
# 259:	learn: 0.3934376	total: 38.5s	remaining: 1m 49s
# 260:	learn: 0.3930425	total: 38.7s	remaining: 1m 49s
# 261:	learn: 0.3926401	total: 38.9s	remaining: 1m 49s
# 262:	learn: 0.3922211	total: 39s	remaining: 1m 49s
# 263:	learn: 0.3918061	total: 39.2s	remaining: 1m 49s
# 264:	learn: 0.3914232	total: 39.3s	remaining: 1m 49s
# 265:	learn: 0.3910432	total: 39.5s	remaining: 1m 49s
# 266:	learn: 0.3906739	total: 39.6s	remaining: 1m 48s
# 267:	learn: 0.3902697	total: 39.8s	remaining: 1m 48s
# 268:	learn: 0.3898640	total: 39.9s	remaining: 1m 48s
# 269:	learn: 0.3894324	total: 40.1s	remaining: 1m 48s
# 270:	learn: 0.3890229	total: 40.3s	remaining: 1m 48s
# 271:	learn: 0.3886620	total: 40.4s	remaining: 1m 48s
# 272:	learn: 0.3882697	total: 40.6s	remaining: 1m 48s
# 273:	learn: 0.3879089	total: 40.7s	remaining: 1m 47s
# 274:	learn: 0.3875555	total: 40.9s	remaining: 1m 47s
# 275:	learn: 0.3871714	total: 41s	remaining: 1m 47s
# 276:	learn: 0.3867798	total: 41.1s	remaining: 1m 47s
# 277:	learn: 0.3864006	total: 41.3s	remaining: 1m 47s
# 278:	learn: 0.3860138	total: 41.5s	remaining: 1m 47s
# 279:	learn: 0.3856681	total: 41.6s	remaining: 1m 46s
# 280:	learn: 0.3852801	total: 41.8s	remaining: 1m 46s
# 281:	learn: 0.3849119	total: 41.9s	remaining: 1m 46s
# 282:	learn: 0.3845592	total: 42.1s	remaining: 1m 46s
# 283:	learn: 0.3842014	total: 42.2s	remaining: 1m 46s
# 284:	learn: 0.3838631	total: 42.4s	remaining: 1m 46s
# 285:	learn: 0.3834735	total: 42.5s	remaining: 1m 46s
# 286:	learn: 0.3830889	total: 42.7s	remaining: 1m 46s
# 287:	learn: 0.3827221	total: 42.9s	remaining: 1m 46s
# 288:	learn: 0.3823269	total: 43.1s	remaining: 1m 46s
# 289:	learn: 0.3819781	total: 43.2s	remaining: 1m 45s
# 290:	learn: 0.3815444	total: 43.4s	remaining: 1m 45s
# 291:	learn: 0.3811338	total: 43.5s	remaining: 1m 45s
# 292:	learn: 0.3807372	total: 43.7s	remaining: 1m 45s
# 293:	learn: 0.3803720	total: 43.8s	remaining: 1m 45s
# 294:	learn: 0.3800297	total: 44s	remaining: 1m 45s
# 295:	learn: 0.3796610	total: 44.1s	remaining: 1m 44s
# 296:	learn: 0.3792927	total: 44.3s	remaining: 1m 44s
# 297:	learn: 0.3789300	total: 44.4s	remaining: 1m 44s
# 298:	learn: 0.3785963	total: 44.6s	remaining: 1m 44s
# 299:	learn: 0.3782723	total: 44.7s	remaining: 1m 44s
# 300:	learn: 0.3779052	total: 44.8s	remaining: 1m 44s
# 301:	learn: 0.3775648	total: 45s	remaining: 1m 43s
# 302:	learn: 0.3771650	total: 45.1s	remaining: 1m 43s
# 303:	learn: 0.3768070	total: 45.3s	remaining: 1m 43s
# 304:	learn: 0.3764364	total: 45.4s	remaining: 1m 43s
# 305:	learn: 0.3760855	total: 45.5s	remaining: 1m 43s
# 306:	learn: 0.3757258	total: 45.7s	remaining: 1m 43s
# 307:	learn: 0.3753566	total: 45.8s	remaining: 1m 42s
# 308:	learn: 0.3749679	total: 46s	remaining: 1m 42s
# 309:	learn: 0.3746152	total: 46.1s	remaining: 1m 42s
# 310:	learn: 0.3742527	total: 46.3s	remaining: 1m 42s
# 311:	learn: 0.3739167	total: 46.4s	remaining: 1m 42s
# 312:	learn: 0.3735838	total: 46.6s	remaining: 1m 42s
# 313:	learn: 0.3732000	total: 46.7s	remaining: 1m 42s
# 314:	learn: 0.3728519	total: 46.9s	remaining: 1m 41s
# 315:	learn: 0.3724978	total: 47s	remaining: 1m 41s
# 316:	learn: 0.3721619	total: 47.2s	remaining: 1m 41s
# 317:	learn: 0.3718041	total: 47.3s	remaining: 1m 41s
# 318:	learn: 0.3714427	total: 47.5s	remaining: 1m 41s
# 319:	learn: 0.3711301	total: 47.6s	remaining: 1m 41s
# 320:	learn: 0.3707666	total: 47.7s	remaining: 1m 40s
# 321:	learn: 0.3704011	total: 47.9s	remaining: 1m 40s
# 322:	learn: 0.3700212	total: 48s	remaining: 1m 40s
# 323:	learn: 0.3696841	total: 48.1s	remaining: 1m 40s
# 324:	learn: 0.3693456	total: 48.3s	remaining: 1m 40s
# 325:	learn: 0.3689935	total: 48.4s	remaining: 1m 40s
# 326:	learn: 0.3686411	total: 48.6s	remaining: 1m 39s
# 327:	learn: 0.3683010	total: 48.7s	remaining: 1m 39s
# 328:	learn: 0.3679610	total: 48.9s	remaining: 1m 39s
# 329:	learn: 0.3676474	total: 49s	remaining: 1m 39s
# 330:	learn: 0.3673376	total: 49.2s	remaining: 1m 39s
# 331:	learn: 0.3669979	total: 49.3s	remaining: 1m 39s
# 332:	learn: 0.3666609	total: 49.5s	remaining: 1m 39s
# 333:	learn: 0.3663116	total: 49.7s	remaining: 1m 39s
# 334:	learn: 0.3659640	total: 49.8s	remaining: 1m 38s
# 335:	learn: 0.3656449	total: 50s	remaining: 1m 38s
# 336:	learn: 0.3653162	total: 50.1s	remaining: 1m 38s
# 337:	learn: 0.3649917	total: 50.2s	remaining: 1m 38s
# 338:	learn: 0.3646747	total: 50.4s	remaining: 1m 38s
# 339:	learn: 0.3643215	total: 50.5s	remaining: 1m 38s
# 340:	learn: 0.3640046	total: 50.7s	remaining: 1m 37s
# 341:	learn: 0.3636777	total: 50.8s	remaining: 1m 37s
# 342:	learn: 0.3633238	total: 51s	remaining: 1m 37s
# 343:	learn: 0.3629893	total: 51.2s	remaining: 1m 37s
# 344:	learn: 0.3626538	total: 51.3s	remaining: 1m 37s
# 345:	learn: 0.3623199	total: 51.5s	remaining: 1m 37s
# 346:	learn: 0.3620182	total: 51.7s	remaining: 1m 37s
# 347:	learn: 0.3616342	total: 51.8s	remaining: 1m 37s
# 348:	learn: 0.3613147	total: 52s	remaining: 1m 36s
# 349:	learn: 0.3609616	total: 52.3s	remaining: 1m 37s
# 350:	learn: 0.3606352	total: 52.5s	remaining: 1m 37s
# 351:	learn: 0.3603233	total: 52.6s	remaining: 1m 36s
# 352:	learn: 0.3599995	total: 52.8s	remaining: 1m 36s
# 353:	learn: 0.3596713	total: 53s	remaining: 1m 36s
# 354:	learn: 0.3593419	total: 53.1s	remaining: 1m 36s
# 355:	learn: 0.3590413	total: 53.3s	remaining: 1m 36s
# 356:	learn: 0.3587245	total: 53.5s	remaining: 1m 36s
# 357:	learn: 0.3583844	total: 53.6s	remaining: 1m 36s
# 358:	learn: 0.3580869	total: 53.8s	remaining: 1m 36s
# 359:	learn: 0.3577635	total: 53.9s	remaining: 1m 35s
# 360:	learn: 0.3574314	total: 54.1s	remaining: 1m 35s
# 361:	learn: 0.3571265	total: 54.2s	remaining: 1m 35s
# 362:	learn: 0.3568279	total: 54.4s	remaining: 1m 35s
# 363:	learn: 0.3565143	total: 54.5s	remaining: 1m 35s
# 364:	learn: 0.3561708	total: 54.7s	remaining: 1m 35s
# 365:	learn: 0.3558520	total: 54.9s	remaining: 1m 35s
# 366:	learn: 0.3555904	total: 55s	remaining: 1m 34s
# 367:	learn: 0.3552998	total: 55.1s	remaining: 1m 34s
# 368:	learn: 0.3550183	total: 55.3s	remaining: 1m 34s
# 369:	learn: 0.3547256	total: 55.5s	remaining: 1m 34s
# 370:	learn: 0.3544136	total: 55.7s	remaining: 1m 34s
# 371:	learn: 0.3541164	total: 55.9s	remaining: 1m 34s
# 372:	learn: 0.3537924	total: 56s	remaining: 1m 34s
# 373:	learn: 0.3535080	total: 56.2s	remaining: 1m 34s
# 374:	learn: 0.3531912	total: 56.4s	remaining: 1m 33s
# 375:	learn: 0.3528906	total: 56.5s	remaining: 1m 33s
# 376:	learn: 0.3526020	total: 56.7s	remaining: 1m 33s
# 377:	learn: 0.3523187	total: 56.8s	remaining: 1m 33s
# 378:	learn: 0.3520303	total: 57s	remaining: 1m 33s
# 379:	learn: 0.3517574	total: 57.2s	remaining: 1m 33s
# 380:	learn: 0.3514369	total: 57.4s	remaining: 1m 33s
# 381:	learn: 0.3511367	total: 57.5s	remaining: 1m 33s
# 382:	learn: 0.3508473	total: 57.7s	remaining: 1m 32s
# 383:	learn: 0.3505619	total: 57.9s	remaining: 1m 32s
# 384:	learn: 0.3502226	total: 58s	remaining: 1m 32s
# 385:	learn: 0.3499105	total: 58.2s	remaining: 1m 32s
# 386:	learn: 0.3496257	total: 58.3s	remaining: 1m 32s
# 387:	learn: 0.3493127	total: 58.5s	remaining: 1m 32s
# 388:	learn: 0.3490248	total: 58.7s	remaining: 1m 32s
# 389:	learn: 0.3487213	total: 58.8s	remaining: 1m 32s
# 390:	learn: 0.3484128	total: 59s	remaining: 1m 31s
# 391:	learn: 0.3481155	total: 59.2s	remaining: 1m 31s
# 392:	learn: 0.3478435	total: 59.4s	remaining: 1m 31s
# 393:	learn: 0.3475620	total: 59.5s	remaining: 1m 31s
# 394:	learn: 0.3472589	total: 59.6s	remaining: 1m 31s
# 395:	learn: 0.3469406	total: 59.8s	remaining: 1m 31s
# 396:	learn: 0.3466562	total: 59.9s	remaining: 1m 31s
# 397:	learn: 0.3463799	total: 1m	remaining: 1m 30s
# 398:	learn: 0.3460652	total: 1m	remaining: 1m 30s
# 399:	learn: 0.3457965	total: 1m	remaining: 1m 30s
# 400:	learn: 0.3455136	total: 1m	remaining: 1m 30s
# 401:	learn: 0.3452122	total: 1m	remaining: 1m 30s
# 402:	learn: 0.3448891	total: 1m 1s	remaining: 1m 30s
# 403:	learn: 0.3445876	total: 1m 1s	remaining: 1m 30s
# 404:	learn: 0.3442841	total: 1m 1s	remaining: 1m 30s
# 405:	learn: 0.3439780	total: 1m 1s	remaining: 1m 30s
# 406:	learn: 0.3437175	total: 1m 1s	remaining: 1m 30s
# 407:	learn: 0.3434472	total: 1m 1s	remaining: 1m 29s
# 408:	learn: 0.3431713	total: 1m 2s	remaining: 1m 29s
# 409:	learn: 0.3428928	total: 1m 2s	remaining: 1m 29s
# 410:	learn: 0.3425933	total: 1m 2s	remaining: 1m 29s
# 411:	learn: 0.3423130	total: 1m 2s	remaining: 1m 29s
# 412:	learn: 0.3420065	total: 1m 2s	remaining: 1m 29s
# 413:	learn: 0.3417330	total: 1m 2s	remaining: 1m 29s
# 414:	learn: 0.3414376	total: 1m 3s	remaining: 1m 28s
# 415:	learn: 0.3411322	total: 1m 3s	remaining: 1m 28s
# 416:	learn: 0.3408832	total: 1m 3s	remaining: 1m 28s
# 417:	learn: 0.3405826	total: 1m 3s	remaining: 1m 28s
# 418:	learn: 0.3403187	total: 1m 3s	remaining: 1m 28s
# 419:	learn: 0.3400301	total: 1m 3s	remaining: 1m 28s
# 420:	learn: 0.3397835	total: 1m 3s	remaining: 1m 27s
# 421:	learn: 0.3395252	total: 1m 4s	remaining: 1m 27s
# 422:	learn: 0.3392370	total: 1m 4s	remaining: 1m 27s
# 423:	learn: 0.3389796	total: 1m 4s	remaining: 1m 27s
# 424:	learn: 0.3386605	total: 1m 4s	remaining: 1m 27s
# 425:	learn: 0.3383669	total: 1m 4s	remaining: 1m 27s
# 426:	learn: 0.3381261	total: 1m 4s	remaining: 1m 26s
# 427:	learn: 0.3378313	total: 1m 4s	remaining: 1m 26s
# 428:	learn: 0.3375512	total: 1m 4s	remaining: 1m 26s
# 429:	learn: 0.3372747	total: 1m 5s	remaining: 1m 26s
# 430:	learn: 0.3369828	total: 1m 5s	remaining: 1m 26s
# 431:	learn: 0.3367341	total: 1m 5s	remaining: 1m 25s
# 432:	learn: 0.3364468	total: 1m 5s	remaining: 1m 25s
# 433:	learn: 0.3361605	total: 1m 5s	remaining: 1m 25s
# 434:	learn: 0.3359074	total: 1m 5s	remaining: 1m 25s
# 435:	learn: 0.3356786	total: 1m 5s	remaining: 1m 25s
# 436:	learn: 0.3354027	total: 1m 6s	remaining: 1m 25s
# 437:	learn: 0.3351353	total: 1m 6s	remaining: 1m 24s
# 438:	learn: 0.3348634	total: 1m 6s	remaining: 1m 24s
# 439:	learn: 0.3345861	total: 1m 6s	remaining: 1m 24s
# 440:	learn: 0.3343059	total: 1m 6s	remaining: 1m 24s
# 441:	learn: 0.3340292	total: 1m 6s	remaining: 1m 24s
# 442:	learn: 0.3337388	total: 1m 7s	remaining: 1m 24s
# 443:	learn: 0.3334518	total: 1m 7s	remaining: 1m 24s
# 444:	learn: 0.3331949	total: 1m 7s	remaining: 1m 24s
# 445:	learn: 0.3329007	total: 1m 7s	remaining: 1m 24s
# 446:	learn: 0.3326625	total: 1m 7s	remaining: 1m 23s
# 447:	learn: 0.3323925	total: 1m 7s	remaining: 1m 23s
# 448:	learn: 0.3321364	total: 1m 8s	remaining: 1m 23s
# 449:	learn: 0.3319147	total: 1m 8s	remaining: 1m 23s
# 450:	learn: 0.3316375	total: 1m 8s	remaining: 1m 23s
# 451:	learn: 0.3313708	total: 1m 8s	remaining: 1m 23s
# 452:	learn: 0.3310886	total: 1m 8s	remaining: 1m 23s
# 453:	learn: 0.3308406	total: 1m 8s	remaining: 1m 22s
# 454:	learn: 0.3305592	total: 1m 9s	remaining: 1m 22s
# 455:	learn: 0.3302742	total: 1m 9s	remaining: 1m 22s
# 456:	learn: 0.3299887	total: 1m 9s	remaining: 1m 22s
# 457:	learn: 0.3297239	total: 1m 9s	remaining: 1m 22s
# 458:	learn: 0.3294882	total: 1m 9s	remaining: 1m 22s
# 459:	learn: 0.3292301	total: 1m 9s	remaining: 1m 22s
# 460:	learn: 0.3289475	total: 1m 10s	remaining: 1m 22s
# 461:	learn: 0.3287190	total: 1m 10s	remaining: 1m 21s
# 462:	learn: 0.3284410	total: 1m 10s	remaining: 1m 21s
# 463:	learn: 0.3281923	total: 1m 10s	remaining: 1m 21s
# 464:	learn: 0.3279417	total: 1m 10s	remaining: 1m 21s
# 465:	learn: 0.3276819	total: 1m 11s	remaining: 1m 21s
# 466:	learn: 0.3274558	total: 1m 11s	remaining: 1m 21s
# 467:	learn: 0.3272293	total: 1m 11s	remaining: 1m 21s
# 468:	learn: 0.3269869	total: 1m 11s	remaining: 1m 20s
# 469:	learn: 0.3267242	total: 1m 11s	remaining: 1m 20s
# 470:	learn: 0.3264591	total: 1m 11s	remaining: 1m 20s
# 471:	learn: 0.3261691	total: 1m 11s	remaining: 1m 20s
# 472:	learn: 0.3258957	total: 1m 12s	remaining: 1m 20s
# 473:	learn: 0.3256280	total: 1m 12s	remaining: 1m 20s
# 474:	learn: 0.3253435	total: 1m 12s	remaining: 1m 20s
# 475:	learn: 0.3250358	total: 1m 12s	remaining: 1m 20s
# 476:	learn: 0.3247745	total: 1m 12s	remaining: 1m 19s
# 477:	learn: 0.3245061	total: 1m 13s	remaining: 1m 19s
# 478:	learn: 0.3242643	total: 1m 13s	remaining: 1m 19s
# 479:	learn: 0.3239873	total: 1m 13s	remaining: 1m 19s
# 480:	learn: 0.3237501	total: 1m 13s	remaining: 1m 19s
# 481:	learn: 0.3234784	total: 1m 13s	remaining: 1m 19s
# 482:	learn: 0.3232564	total: 1m 13s	remaining: 1m 19s
# 483:	learn: 0.3230061	total: 1m 14s	remaining: 1m 18s
# 484:	learn: 0.3227537	total: 1m 14s	remaining: 1m 18s
# 485:	learn: 0.3224754	total: 1m 14s	remaining: 1m 18s
# 486:	learn: 0.3222220	total: 1m 14s	remaining: 1m 18s
# 487:	learn: 0.3219644	total: 1m 14s	remaining: 1m 18s
# 488:	learn: 0.3217284	total: 1m 14s	remaining: 1m 18s
# 489:	learn: 0.3214899	total: 1m 15s	remaining: 1m 18s
# 490:	learn: 0.3212508	total: 1m 15s	remaining: 1m 17s
# 491:	learn: 0.3210027	total: 1m 15s	remaining: 1m 17s
# 492:	learn: 0.3207996	total: 1m 15s	remaining: 1m 17s
# 493:	learn: 0.3205709	total: 1m 15s	remaining: 1m 17s
# 494:	learn: 0.3203156	total: 1m 15s	remaining: 1m 17s
# 495:	learn: 0.3200369	total: 1m 15s	remaining: 1m 17s
# 496:	learn: 0.3197850	total: 1m 16s	remaining: 1m 17s
# 497:	learn: 0.3195438	total: 1m 16s	remaining: 1m 16s
# 498:	learn: 0.3192738	total: 1m 16s	remaining: 1m 16s
# 499:	learn: 0.3190350	total: 1m 16s	remaining: 1m 16s
# 500:	learn: 0.3187994	total: 1m 16s	remaining: 1m 16s
# 501:	learn: 0.3185362	total: 1m 16s	remaining: 1m 16s
# 502:	learn: 0.3182946	total: 1m 17s	remaining: 1m 16s
# 503:	learn: 0.3180693	total: 1m 17s	remaining: 1m 15s
# 504:	learn: 0.3178330	total: 1m 17s	remaining: 1m 15s
# 505:	learn: 0.3176065	total: 1m 17s	remaining: 1m 15s
# 506:	learn: 0.3173376	total: 1m 17s	remaining: 1m 15s
# 507:	learn: 0.3171249	total: 1m 17s	remaining: 1m 15s
# 508:	learn: 0.3168622	total: 1m 17s	remaining: 1m 15s
# 509:	learn: 0.3166094	total: 1m 18s	remaining: 1m 15s
# 510:	learn: 0.3163425	total: 1m 18s	remaining: 1m 14s
# 511:	learn: 0.3161124	total: 1m 18s	remaining: 1m 14s
# 512:	learn: 0.3158658	total: 1m 18s	remaining: 1m 14s
# 513:	learn: 0.3156360	total: 1m 18s	remaining: 1m 14s
# 514:	learn: 0.3153854	total: 1m 18s	remaining: 1m 14s
# 515:	learn: 0.3151072	total: 1m 19s	remaining: 1m 14s
# 516:	learn: 0.3148445	total: 1m 19s	remaining: 1m 14s
# 517:	learn: 0.3146137	total: 1m 19s	remaining: 1m 13s
# 518:	learn: 0.3143801	total: 1m 19s	remaining: 1m 13s
# 519:	learn: 0.3141628	total: 1m 19s	remaining: 1m 13s
# 520:	learn: 0.3139188	total: 1m 19s	remaining: 1m 13s
# 521:	learn: 0.3136963	total: 1m 20s	remaining: 1m 13s
# 522:	learn: 0.3134500	total: 1m 20s	remaining: 1m 13s
# 523:	learn: 0.3132229	total: 1m 20s	remaining: 1m 13s
# 524:	learn: 0.3129695	total: 1m 20s	remaining: 1m 12s
# 525:	learn: 0.3127597	total: 1m 20s	remaining: 1m 12s
# 526:	learn: 0.3125232	total: 1m 20s	remaining: 1m 12s
# 527:	learn: 0.3122958	total: 1m 21s	remaining: 1m 12s
# 528:	learn: 0.3121090	total: 1m 21s	remaining: 1m 12s
# 529:	learn: 0.3118333	total: 1m 21s	remaining: 1m 12s
# 530:	learn: 0.3115700	total: 1m 21s	remaining: 1m 12s
# 531:	learn: 0.3113293	total: 1m 21s	remaining: 1m 11s
# 532:	learn: 0.3111017	total: 1m 21s	remaining: 1m 11s
# 533:	learn: 0.3108643	total: 1m 22s	remaining: 1m 11s
# 534:	learn: 0.3106269	total: 1m 22s	remaining: 1m 11s
# 535:	learn: 0.3103845	total: 1m 22s	remaining: 1m 11s
# 536:	learn: 0.3101276	total: 1m 22s	remaining: 1m 11s
# 537:	learn: 0.3098939	total: 1m 22s	remaining: 1m 11s
# 538:	learn: 0.3096727	total: 1m 23s	remaining: 1m 11s
# 539:	learn: 0.3094267	total: 1m 23s	remaining: 1m 10s
# 540:	learn: 0.3091612	total: 1m 23s	remaining: 1m 10s
# 541:	learn: 0.3089044	total: 1m 23s	remaining: 1m 10s
# 542:	learn: 0.3086586	total: 1m 23s	remaining: 1m 10s
# 543:	learn: 0.3083956	total: 1m 23s	remaining: 1m 10s
# 544:	learn: 0.3081878	total: 1m 24s	remaining: 1m 10s
# 545:	learn: 0.3079521	total: 1m 24s	remaining: 1m 10s
# 546:	learn: 0.3076910	total: 1m 24s	remaining: 1m 9s
# 547:	learn: 0.3074501	total: 1m 24s	remaining: 1m 9s
# 548:	learn: 0.3072557	total: 1m 24s	remaining: 1m 9s
# 549:	learn: 0.3070351	total: 1m 24s	remaining: 1m 9s
# 550:	learn: 0.3067749	total: 1m 25s	remaining: 1m 9s
# 551:	learn: 0.3065427	total: 1m 25s	remaining: 1m 9s
# 552:	learn: 0.3063057	total: 1m 25s	remaining: 1m 9s
# 553:	learn: 0.3060705	total: 1m 25s	remaining: 1m 8s
# 554:	learn: 0.3058627	total: 1m 25s	remaining: 1m 8s
# 555:	learn: 0.3056642	total: 1m 25s	remaining: 1m 8s
# 556:	learn: 0.3054264	total: 1m 26s	remaining: 1m 8s
# 557:	learn: 0.3051967	total: 1m 26s	remaining: 1m 8s
# 558:	learn: 0.3049864	total: 1m 26s	remaining: 1m 8s
# 559:	learn: 0.3047803	total: 1m 26s	remaining: 1m 8s
# 560:	learn: 0.3045771	total: 1m 26s	remaining: 1m 7s
# 561:	learn: 0.3043344	total: 1m 26s	remaining: 1m 7s
# 562:	learn: 0.3041059	total: 1m 27s	remaining: 1m 7s
# 563:	learn: 0.3038579	total: 1m 27s	remaining: 1m 7s
# 564:	learn: 0.3036065	total: 1m 27s	remaining: 1m 7s
# 565:	learn: 0.3033953	total: 1m 27s	remaining: 1m 7s
# 566:	learn: 0.3031506	total: 1m 27s	remaining: 1m 6s
# 567:	learn: 0.3029251	total: 1m 27s	remaining: 1m 6s
# 568:	learn: 0.3026763	total: 1m 28s	remaining: 1m 6s
# 569:	learn: 0.3024610	total: 1m 28s	remaining: 1m 6s
# 570:	learn: 0.3022368	total: 1m 28s	remaining: 1m 6s
# 571:	learn: 0.3020034	total: 1m 28s	remaining: 1m 6s
# 572:	learn: 0.3017675	total: 1m 28s	remaining: 1m 6s
# 573:	learn: 0.3015222	total: 1m 28s	remaining: 1m 5s
# 574:	learn: 0.3012574	total: 1m 29s	remaining: 1m 5s
# 575:	learn: 0.3010340	total: 1m 29s	remaining: 1m 5s
# 576:	learn: 0.3007920	total: 1m 29s	remaining: 1m 5s
# 577:	learn: 0.3005879	total: 1m 29s	remaining: 1m 5s
# 578:	learn: 0.3003818	total: 1m 29s	remaining: 1m 5s
# 579:	learn: 0.3001753	total: 1m 29s	remaining: 1m 5s
# 580:	learn: 0.2999351	total: 1m 30s	remaining: 1m 4s
# 581:	learn: 0.2996852	total: 1m 30s	remaining: 1m 4s
# 582:	learn: 0.2994754	total: 1m 30s	remaining: 1m 4s
# 583:	learn: 0.2992555	total: 1m 30s	remaining: 1m 4s
# 584:	learn: 0.2990367	total: 1m 30s	remaining: 1m 4s
# 585:	learn: 0.2988377	total: 1m 30s	remaining: 1m 4s
# 586:	learn: 0.2986096	total: 1m 31s	remaining: 1m 4s
# 587:	learn: 0.2983868	total: 1m 31s	remaining: 1m 3s
# 588:	learn: 0.2981790	total: 1m 31s	remaining: 1m 3s
# 589:	learn: 0.2979546	total: 1m 31s	remaining: 1m 3s
# 590:	learn: 0.2977314	total: 1m 31s	remaining: 1m 3s
# 591:	learn: 0.2975102	total: 1m 32s	remaining: 1m 3s
# 592:	learn: 0.2972748	total: 1m 32s	remaining: 1m 3s
# 593:	learn: 0.2970568	total: 1m 32s	remaining: 1m 3s
# 594:	learn: 0.2968265	total: 1m 32s	remaining: 1m 2s
# 595:	learn: 0.2965868	total: 1m 32s	remaining: 1m 2s
# 596:	learn: 0.2963640	total: 1m 32s	remaining: 1m 2s
# 597:	learn: 0.2961442	total: 1m 32s	remaining: 1m 2s
# 598:	learn: 0.2959063	total: 1m 33s	remaining: 1m 2s
# 599:	learn: 0.2956957	total: 1m 33s	remaining: 1m 2s
# 600:	learn: 0.2954687	total: 1m 33s	remaining: 1m 2s
# 601:	learn: 0.2952393	total: 1m 33s	remaining: 1m 1s
# 602:	learn: 0.2950186	total: 1m 33s	remaining: 1m 1s
# 603:	learn: 0.2947968	total: 1m 33s	remaining: 1m 1s
# 604:	learn: 0.2945856	total: 1m 34s	remaining: 1m 1s
# 605:	learn: 0.2943758	total: 1m 34s	remaining: 1m 1s
# 606:	learn: 0.2941451	total: 1m 34s	remaining: 1m 1s
# 607:	learn: 0.2939256	total: 1m 34s	remaining: 1m
# 608:	learn: 0.2937142	total: 1m 34s	remaining: 1m
# 609:	learn: 0.2935165	total: 1m 34s	remaining: 1m
# 610:	learn: 0.2932756	total: 1m 35s	remaining: 1m
# 611:	learn: 0.2930386	total: 1m 35s	remaining: 1m
# 612:	learn: 0.2928163	total: 1m 35s	remaining: 1m
# 613:	learn: 0.2926261	total: 1m 35s	remaining: 1m
# 614:	learn: 0.2923937	total: 1m 35s	remaining: 59.9s
# 615:	learn: 0.2922166	total: 1m 35s	remaining: 59.8s
# 616:	learn: 0.2919800	total: 1m 36s	remaining: 59.6s
# 617:	learn: 0.2917784	total: 1m 36s	remaining: 59.5s
# 618:	learn: 0.2915775	total: 1m 36s	remaining: 59.3s
# 619:	learn: 0.2913787	total: 1m 36s	remaining: 59.1s
# 620:	learn: 0.2911482	total: 1m 36s	remaining: 59s
# 621:	learn: 0.2909576	total: 1m 36s	remaining: 58.8s
# 622:	learn: 0.2907492	total: 1m 36s	remaining: 58.7s
# 623:	learn: 0.2905436	total: 1m 37s	remaining: 58.5s
# 624:	learn: 0.2902995	total: 1m 37s	remaining: 58.4s
# 625:	learn: 0.2900974	total: 1m 37s	remaining: 58.2s
# 626:	learn: 0.2899142	total: 1m 37s	remaining: 58s
# 627:	learn: 0.2896954	total: 1m 37s	remaining: 57.9s
# 628:	learn: 0.2894879	total: 1m 37s	remaining: 57.8s
# 629:	learn: 0.2892714	total: 1m 38s	remaining: 57.6s
# 630:	learn: 0.2890654	total: 1m 38s	remaining: 57.4s
# 631:	learn: 0.2888400	total: 1m 38s	remaining: 57.3s
# 632:	learn: 0.2886359	total: 1m 38s	remaining: 57.1s
# 633:	learn: 0.2884290	total: 1m 38s	remaining: 57s
# 634:	learn: 0.2882078	total: 1m 38s	remaining: 56.8s
# 635:	learn: 0.2879738	total: 1m 39s	remaining: 56.7s
# 636:	learn: 0.2877599	total: 1m 39s	remaining: 56.5s
# 637:	learn: 0.2875465	total: 1m 39s	remaining: 56.4s
# 638:	learn: 0.2873227	total: 1m 39s	remaining: 56.2s
# 639:	learn: 0.2870999	total: 1m 39s	remaining: 56.1s
# 640:	learn: 0.2869183	total: 1m 39s	remaining: 55.9s
# 641:	learn: 0.2867281	total: 1m 39s	remaining: 55.8s
# 642:	learn: 0.2865240	total: 1m 40s	remaining: 55.6s
# 643:	learn: 0.2863164	total: 1m 40s	remaining: 55.5s
# 644:	learn: 0.2860797	total: 1m 40s	remaining: 55.3s
# 645:	learn: 0.2858410	total: 1m 40s	remaining: 55.2s
# 646:	learn: 0.2856252	total: 1m 40s	remaining: 55s
# 647:	learn: 0.2854127	total: 1m 41s	remaining: 54.9s
# 648:	learn: 0.2851932	total: 1m 41s	remaining: 54.7s
# 649:	learn: 0.2849974	total: 1m 41s	remaining: 54.6s
# 650:	learn: 0.2848272	total: 1m 41s	remaining: 54.4s
# 651:	learn: 0.2846179	total: 1m 41s	remaining: 54.3s
# 652:	learn: 0.2844208	total: 1m 41s	remaining: 54.1s
# 653:	learn: 0.2842411	total: 1m 41s	remaining: 54s
# 654:	learn: 0.2840406	total: 1m 42s	remaining: 53.8s
# 655:	learn: 0.2838284	total: 1m 42s	remaining: 53.7s
# 656:	learn: 0.2836204	total: 1m 42s	remaining: 53.5s
# 657:	learn: 0.2833786	total: 1m 42s	remaining: 53.4s
# 658:	learn: 0.2831448	total: 1m 42s	remaining: 53.2s
# 659:	learn: 0.2829235	total: 1m 42s	remaining: 53.1s
# 660:	learn: 0.2827332	total: 1m 43s	remaining: 52.9s
# 661:	learn: 0.2825323	total: 1m 43s	remaining: 52.8s
# 662:	learn: 0.2823460	total: 1m 43s	remaining: 52.6s
# 663:	learn: 0.2821431	total: 1m 43s	remaining: 52.4s
# 664:	learn: 0.2819483	total: 1m 43s	remaining: 52.3s
# 665:	learn: 0.2817638	total: 1m 43s	remaining: 52.1s
# 666:	learn: 0.2815806	total: 1m 44s	remaining: 52s
# 667:	learn: 0.2813565	total: 1m 44s	remaining: 51.8s
# 668:	learn: 0.2811838	total: 1m 44s	remaining: 51.7s
# 669:	learn: 0.2810275	total: 1m 44s	remaining: 51.5s
# 670:	learn: 0.2808426	total: 1m 44s	remaining: 51.3s
# 671:	learn: 0.2806431	total: 1m 44s	remaining: 51.2s
# 672:	learn: 0.2804113	total: 1m 45s	remaining: 51s
# 673:	learn: 0.2802144	total: 1m 45s	remaining: 50.9s
# 674:	learn: 0.2799822	total: 1m 45s	remaining: 50.7s
# 675:	learn: 0.2797857	total: 1m 45s	remaining: 50.6s
# 676:	learn: 0.2795809	total: 1m 45s	remaining: 50.4s
# 677:	learn: 0.2793991	total: 1m 45s	remaining: 50.3s
# 678:	learn: 0.2791961	total: 1m 45s	remaining: 50.1s
# 679:	learn: 0.2790002	total: 1m 46s	remaining: 49.9s
# 680:	learn: 0.2788155	total: 1m 46s	remaining: 49.8s
# 681:	learn: 0.2786269	total: 1m 46s	remaining: 49.6s
# 682:	learn: 0.2784196	total: 1m 46s	remaining: 49.5s
# 683:	learn: 0.2782222	total: 1m 46s	remaining: 49.3s
# 684:	learn: 0.2780174	total: 1m 46s	remaining: 49.2s
# 685:	learn: 0.2778214	total: 1m 47s	remaining: 49s
# 686:	learn: 0.2776097	total: 1m 47s	remaining: 48.9s
# 687:	learn: 0.2773930	total: 1m 47s	remaining: 48.8s
# 688:	learn: 0.2772046	total: 1m 47s	remaining: 48.6s
# 689:	learn: 0.2770265	total: 1m 47s	remaining: 48.5s
# 690:	learn: 0.2768214	total: 1m 48s	remaining: 48.3s
# 691:	learn: 0.2766326	total: 1m 48s	remaining: 48.2s
# 692:	learn: 0.2764300	total: 1m 48s	remaining: 48s
# 693:	learn: 0.2762560	total: 1m 48s	remaining: 47.9s
# 694:	learn: 0.2760721	total: 1m 48s	remaining: 47.7s
# 695:	learn: 0.2758480	total: 1m 48s	remaining: 47.6s
# 696:	learn: 0.2756610	total: 1m 49s	remaining: 47.4s
# 697:	learn: 0.2755077	total: 1m 49s	remaining: 47.3s
# 698:	learn: 0.2753095	total: 1m 49s	remaining: 47.2s
# 699:	learn: 0.2750879	total: 1m 49s	remaining: 47s
# 700:	learn: 0.2749031	total: 1m 49s	remaining: 46.9s
# 701:	learn: 0.2746913	total: 1m 50s	remaining: 46.7s
# 702:	learn: 0.2744842	total: 1m 50s	remaining: 46.6s
# 703:	learn: 0.2742812	total: 1m 50s	remaining: 46.5s
# 704:	learn: 0.2741050	total: 1m 50s	remaining: 46.3s
# 705:	learn: 0.2739156	total: 1m 50s	remaining: 46.2s
# 706:	learn: 0.2737304	total: 1m 51s	remaining: 46s
# 707:	learn: 0.2735373	total: 1m 51s	remaining: 45.9s
# 708:	learn: 0.2733648	total: 1m 51s	remaining: 45.8s
# 709:	learn: 0.2731724	total: 1m 51s	remaining: 45.7s
# 710:	learn: 0.2729462	total: 1m 51s	remaining: 45.5s
# 711:	learn: 0.2727728	total: 1m 52s	remaining: 45.4s
# 712:	learn: 0.2726026	total: 1m 52s	remaining: 45.2s
# 713:	learn: 0.2724234	total: 1m 52s	remaining: 45.1s
# 714:	learn: 0.2722403	total: 1m 52s	remaining: 44.9s
# 715:	learn: 0.2720562	total: 1m 52s	remaining: 44.8s
# 716:	learn: 0.2718717	total: 1m 52s	remaining: 44.6s
# 717:	learn: 0.2716814	total: 1m 53s	remaining: 44.4s
# 718:	learn: 0.2714791	total: 1m 53s	remaining: 44.3s
# 719:	learn: 0.2713002	total: 1m 53s	remaining: 44.1s
# 720:	learn: 0.2710895	total: 1m 53s	remaining: 44s
# 721:	learn: 0.2709032	total: 1m 53s	remaining: 43.8s
# 722:	learn: 0.2707328	total: 1m 53s	remaining: 43.7s
# 723:	learn: 0.2705336	total: 1m 54s	remaining: 43.5s
# 724:	learn: 0.2703522	total: 1m 54s	remaining: 43.4s
# 725:	learn: 0.2701839	total: 1m 54s	remaining: 43.2s
# 726:	learn: 0.2699875	total: 1m 54s	remaining: 43.1s
# 727:	learn: 0.2697818	total: 1m 54s	remaining: 42.9s
# 728:	learn: 0.2696122	total: 1m 54s	remaining: 42.7s
# 729:	learn: 0.2694256	total: 1m 55s	remaining: 42.6s
# 730:	learn: 0.2692364	total: 1m 55s	remaining: 42.4s
# 731:	learn: 0.2690486	total: 1m 55s	remaining: 42.3s
# 732:	learn: 0.2688520	total: 1m 55s	remaining: 42.1s
# 733:	learn: 0.2686603	total: 1m 55s	remaining: 42s
# 734:	learn: 0.2684795	total: 1m 55s	remaining: 41.8s
# 735:	learn: 0.2683249	total: 1m 56s	remaining: 41.6s
# 736:	learn: 0.2681238	total: 1m 56s	remaining: 41.5s
# 737:	learn: 0.2679363	total: 1m 56s	remaining: 41.3s
# 738:	learn: 0.2677893	total: 1m 56s	remaining: 41.2s
# 739:	learn: 0.2676111	total: 1m 56s	remaining: 41s
# 740:	learn: 0.2674371	total: 1m 56s	remaining: 40.9s
# 741:	learn: 0.2672173	total: 1m 57s	remaining: 40.7s
# 742:	learn: 0.2670307	total: 1m 57s	remaining: 40.5s
# 743:	learn: 0.2668304	total: 1m 57s	remaining: 40.4s
# 744:	learn: 0.2666406	total: 1m 57s	remaining: 40.2s
# 745:	learn: 0.2664379	total: 1m 57s	remaining: 40.1s
# 746:	learn: 0.2662297	total: 1m 57s	remaining: 39.9s
# 747:	learn: 0.2660544	total: 1m 57s	remaining: 39.8s
# 748:	learn: 0.2658584	total: 1m 58s	remaining: 39.6s
# 749:	learn: 0.2656547	total: 1m 58s	remaining: 39.4s
# 750:	learn: 0.2654562	total: 1m 58s	remaining: 39.3s
# 751:	learn: 0.2652424	total: 1m 58s	remaining: 39.1s
# 752:	learn: 0.2650526	total: 1m 58s	remaining: 39s
# 753:	learn: 0.2648421	total: 1m 59s	remaining: 38.9s
# 754:	learn: 0.2646683	total: 1m 59s	remaining: 38.7s
# 755:	learn: 0.2644984	total: 1m 59s	remaining: 38.5s
# 756:	learn: 0.2642802	total: 1m 59s	remaining: 38.4s
# 757:	learn: 0.2641091	total: 1m 59s	remaining: 38.2s
# 758:	learn: 0.2639259	total: 1m 59s	remaining: 38.1s
# 759:	learn: 0.2637510	total: 2m	remaining: 37.9s
# 760:	learn: 0.2635547	total: 2m	remaining: 37.8s
# 761:	learn: 0.2633709	total: 2m	remaining: 37.6s
# 762:	learn: 0.2632244	total: 2m	remaining: 37.5s
# 763:	learn: 0.2630217	total: 2m	remaining: 37.3s
# 764:	learn: 0.2628437	total: 2m 1s	remaining: 37.2s
# 765:	learn: 0.2626861	total: 2m 1s	remaining: 37s
# 766:	learn: 0.2624968	total: 2m 1s	remaining: 36.9s
# 767:	learn: 0.2623216	total: 2m 1s	remaining: 36.7s
# 768:	learn: 0.2621369	total: 2m 1s	remaining: 36.6s
# 769:	learn: 0.2619353	total: 2m 1s	remaining: 36.4s
# 770:	learn: 0.2617552	total: 2m 2s	remaining: 36.2s
# 771:	learn: 0.2615894	total: 2m 2s	remaining: 36.1s
# 772:	learn: 0.2613915	total: 2m 2s	remaining: 36s
# 773:	learn: 0.2612016	total: 2m 2s	remaining: 35.8s
# 774:	learn: 0.2610229	total: 2m 2s	remaining: 35.6s
# 775:	learn: 0.2608418	total: 2m 2s	remaining: 35.5s
# 776:	learn: 0.2606706	total: 2m 3s	remaining: 35.3s
# 777:	learn: 0.2604826	total: 2m 3s	remaining: 35.2s
# 778:	learn: 0.2603061	total: 2m 3s	remaining: 35s
# 779:	learn: 0.2601327	total: 2m 3s	remaining: 34.9s
# 780:	learn: 0.2599721	total: 2m 3s	remaining: 34.7s
# 781:	learn: 0.2598103	total: 2m 4s	remaining: 34.6s
# 782:	learn: 0.2596539	total: 2m 4s	remaining: 34.4s
# 783:	learn: 0.2594894	total: 2m 4s	remaining: 34.3s
# 784:	learn: 0.2593162	total: 2m 4s	remaining: 34.1s
# 785:	learn: 0.2591401	total: 2m 4s	remaining: 34s
# 786:	learn: 0.2589466	total: 2m 5s	remaining: 33.8s
# 787:	learn: 0.2587670	total: 2m 5s	remaining: 33.7s
# 788:	learn: 0.2585653	total: 2m 5s	remaining: 33.5s
# 789:	learn: 0.2584019	total: 2m 5s	remaining: 33.4s
# 790:	learn: 0.2582401	total: 2m 5s	remaining: 33.2s
# 791:	learn: 0.2580409	total: 2m 5s	remaining: 33.1s
# 792:	learn: 0.2578573	total: 2m 6s	remaining: 32.9s
# 793:	learn: 0.2576689	total: 2m 6s	remaining: 32.7s
# 794:	learn: 0.2574767	total: 2m 6s	remaining: 32.6s
# 795:	learn: 0.2572738	total: 2m 6s	remaining: 32.4s
# 796:	learn: 0.2570811	total: 2m 6s	remaining: 32.3s
# 797:	learn: 0.2568761	total: 2m 6s	remaining: 32.1s
# 798:	learn: 0.2566989	total: 2m 7s	remaining: 32s
# 799:	learn: 0.2565110	total: 2m 7s	remaining: 31.8s
# 800:	learn: 0.2563616	total: 2m 7s	remaining: 31.7s
# 801:	learn: 0.2561681	total: 2m 7s	remaining: 31.5s
# 802:	learn: 0.2560031	total: 2m 7s	remaining: 31.4s
# 803:	learn: 0.2558044	total: 2m 7s	remaining: 31.2s
# 804:	learn: 0.2556389	total: 2m 8s	remaining: 31s
# 805:	learn: 0.2554501	total: 2m 8s	remaining: 30.9s
# 806:	learn: 0.2552527	total: 2m 8s	remaining: 30.7s
# 807:	learn: 0.2550998	total: 2m 8s	remaining: 30.6s
# 808:	learn: 0.2549387	total: 2m 8s	remaining: 30.4s
# 809:	learn: 0.2547220	total: 2m 8s	remaining: 30.2s
# 810:	learn: 0.2545609	total: 2m 9s	remaining: 30.1s
# 811:	learn: 0.2543777	total: 2m 9s	remaining: 29.9s
# 812:	learn: 0.2542326	total: 2m 9s	remaining: 29.8s
# 813:	learn: 0.2540471	total: 2m 9s	remaining: 29.6s
# 814:	learn: 0.2538669	total: 2m 9s	remaining: 29.5s
# 815:	learn: 0.2536738	total: 2m 9s	remaining: 29.3s
# 816:	learn: 0.2535267	total: 2m 10s	remaining: 29.1s
# 817:	learn: 0.2533923	total: 2m 10s	remaining: 29s
# 818:	learn: 0.2532080	total: 2m 10s	remaining: 28.8s
# 819:	learn: 0.2529944	total: 2m 10s	remaining: 28.7s
# 820:	learn: 0.2528421	total: 2m 10s	remaining: 28.5s
# 821:	learn: 0.2526910	total: 2m 10s	remaining: 28.4s
# 822:	learn: 0.2525379	total: 2m 11s	remaining: 28.2s
# 823:	learn: 0.2523651	total: 2m 11s	remaining: 28s
# 824:	learn: 0.2522215	total: 2m 11s	remaining: 27.9s
# 825:	learn: 0.2520690	total: 2m 11s	remaining: 27.7s
# 826:	learn: 0.2519200	total: 2m 11s	remaining: 27.6s
# 827:	learn: 0.2517365	total: 2m 11s	remaining: 27.4s
# 828:	learn: 0.2515876	total: 2m 12s	remaining: 27.2s
# 829:	learn: 0.2514503	total: 2m 12s	remaining: 27.1s
# 830:	learn: 0.2512903	total: 2m 12s	remaining: 26.9s
# 831:	learn: 0.2511219	total: 2m 12s	remaining: 26.8s
# 832:	learn: 0.2509400	total: 2m 12s	remaining: 26.6s
# 833:	learn: 0.2507471	total: 2m 12s	remaining: 26.5s
# 834:	learn: 0.2506223	total: 2m 13s	remaining: 26.3s
# 835:	learn: 0.2504529	total: 2m 13s	remaining: 26.1s
# 836:	learn: 0.2503060	total: 2m 13s	remaining: 26s
# 837:	learn: 0.2501276	total: 2m 13s	remaining: 25.8s
# 838:	learn: 0.2499224	total: 2m 13s	remaining: 25.7s
# 839:	learn: 0.2497502	total: 2m 13s	remaining: 25.5s
# 840:	learn: 0.2495749	total: 2m 14s	remaining: 25.4s
# 841:	learn: 0.2494349	total: 2m 14s	remaining: 25.2s
# 842:	learn: 0.2492432	total: 2m 14s	remaining: 25s
# 843:	learn: 0.2490698	total: 2m 14s	remaining: 24.9s
# 844:	learn: 0.2489111	total: 2m 14s	remaining: 24.7s
# 845:	learn: 0.2487365	total: 2m 14s	remaining: 24.6s
# 846:	learn: 0.2485571	total: 2m 15s	remaining: 24.4s
# 847:	learn: 0.2483792	total: 2m 15s	remaining: 24.2s
# 848:	learn: 0.2482295	total: 2m 15s	remaining: 24.1s
# 849:	learn: 0.2480937	total: 2m 15s	remaining: 23.9s
# 850:	learn: 0.2479198	total: 2m 15s	remaining: 23.8s
# 851:	learn: 0.2477668	total: 2m 15s	remaining: 23.6s
# 852:	learn: 0.2475929	total: 2m 16s	remaining: 23.4s
# 853:	learn: 0.2474167	total: 2m 16s	remaining: 23.3s
# 854:	learn: 0.2472215	total: 2m 16s	remaining: 23.1s
# 855:	learn: 0.2470649	total: 2m 16s	remaining: 23s
# 856:	learn: 0.2468945	total: 2m 16s	remaining: 22.8s
# 857:	learn: 0.2467266	total: 2m 16s	remaining: 22.6s
# 858:	learn: 0.2465397	total: 2m 17s	remaining: 22.5s
# 859:	learn: 0.2463837	total: 2m 17s	remaining: 22.3s
# 860:	learn: 0.2462123	total: 2m 17s	remaining: 22.2s
# 861:	learn: 0.2460489	total: 2m 17s	remaining: 22s
# 862:	learn: 0.2458891	total: 2m 17s	remaining: 21.9s
# 863:	learn: 0.2457104	total: 2m 17s	remaining: 21.7s
# 864:	learn: 0.2455539	total: 2m 18s	remaining: 21.6s
# 865:	learn: 0.2453932	total: 2m 18s	remaining: 21.4s
# 866:	learn: 0.2452040	total: 2m 18s	remaining: 21.3s
# 867:	learn: 0.2450237	total: 2m 18s	remaining: 21.1s
# 868:	learn: 0.2448657	total: 2m 18s	remaining: 20.9s
# 869:	learn: 0.2446927	total: 2m 19s	remaining: 20.8s
# 870:	learn: 0.2445220	total: 2m 19s	remaining: 20.6s
# 871:	learn: 0.2443615	total: 2m 19s	remaining: 20.5s
# 872:	learn: 0.2441647	total: 2m 19s	remaining: 20.3s
# 873:	learn: 0.2439847	total: 2m 19s	remaining: 20.1s
# 874:	learn: 0.2438181	total: 2m 19s	remaining: 20s
# 875:	learn: 0.2436861	total: 2m 20s	remaining: 19.8s
# 876:	learn: 0.2435550	total: 2m 20s	remaining: 19.7s
# 877:	learn: 0.2433628	total: 2m 20s	remaining: 19.5s
# 878:	learn: 0.2432359	total: 2m 20s	remaining: 19.3s
# 879:	learn: 0.2430564	total: 2m 20s	remaining: 19.2s
# 880:	learn: 0.2428868	total: 2m 20s	remaining: 19s
# 881:	learn: 0.2427133	total: 2m 21s	remaining: 18.9s
# 882:	learn: 0.2425559	total: 2m 21s	remaining: 18.7s
# 883:	learn: 0.2423700	total: 2m 21s	remaining: 18.5s
# 884:	learn: 0.2422331	total: 2m 21s	remaining: 18.4s
# 885:	learn: 0.2420992	total: 2m 21s	remaining: 18.2s
# 886:	learn: 0.2419283	total: 2m 21s	remaining: 18.1s
# 887:	learn: 0.2417569	total: 2m 21s	remaining: 17.9s
# 888:	learn: 0.2415814	total: 2m 22s	remaining: 17.7s
# 889:	learn: 0.2413993	total: 2m 22s	remaining: 17.6s
# 890:	learn: 0.2412483	total: 2m 22s	remaining: 17.4s
# 891:	learn: 0.2411104	total: 2m 22s	remaining: 17.3s
# 892:	learn: 0.2409410	total: 2m 22s	remaining: 17.1s
# 893:	learn: 0.2407625	total: 2m 22s	remaining: 17s
# 894:	learn: 0.2405982	total: 2m 23s	remaining: 16.8s
# 895:	learn: 0.2404562	total: 2m 23s	remaining: 16.6s
# 896:	learn: 0.2402919	total: 2m 23s	remaining: 16.5s
# 897:	learn: 0.2401318	total: 2m 23s	remaining: 16.3s
# 898:	learn: 0.2399650	total: 2m 23s	remaining: 16.1s
# 899:	learn: 0.2398051	total: 2m 23s	remaining: 16s
# 900:	learn: 0.2396131	total: 2m 24s	remaining: 15.8s
# 901:	learn: 0.2394546	total: 2m 24s	remaining: 15.7s
# 902:	learn: 0.2393200	total: 2m 24s	remaining: 15.5s
# 903:	learn: 0.2391550	total: 2m 24s	remaining: 15.3s
# 904:	learn: 0.2389705	total: 2m 24s	remaining: 15.2s
# 905:	learn: 0.2387979	total: 2m 24s	remaining: 15s
# 906:	learn: 0.2386485	total: 2m 25s	remaining: 14.9s
# 907:	learn: 0.2385095	total: 2m 25s	remaining: 14.7s
# 908:	learn: 0.2383594	total: 2m 25s	remaining: 14.5s
# ...
# 702:	learn: 0.2317325	total: 1m 48s	remaining: 45.7s
# 703:	learn: 0.2315609	total: 1m 48s	remaining: 45.6s
# 704:	learn: 0.2313667	total: 1m 48s	remaining: 45.4s
# 705:	learn: 0.2311944	total: 1m 48s	remaining: 45.3s
# 706:	learn: 0.2310229	total: 1m 48s	remaining: 45.2s
# 707:	learn: 0.2308376	total: 1m 49s	remaining: 45s
# 708:	learn: 0.2306505	total: 1m 49s	remaining: 44.9s
# 709:	learn: 0.2304923	total: 1m 49s	remaining: 44.7s
# 710:	learn: 0.2303368	total: 1m 49s	remaining: 44.6s
# 711:	learn: 0.2301855	total: 1m 49s	remaining: 44.4s
# 712:	learn: 0.2300181	total: 1m 50s	remaining: 44.3s
# 713:	learn: 0.2298226	total: 1m 50s	remaining: 44.1s
# 714:	learn: 0.2296336	total: 1m 50s	remaining: 44s
# 715:	learn: 0.2294910	total: 1m 50s	remaining: 43.8s
# 716:	learn: 0.2292829	total: 1m 50s	remaining: 43.7s
# 717:	learn: 0.2291073	total: 1m 50s	remaining: 43.5s
# 718:	learn: 0.2289568	total: 1m 50s	remaining: 43.4s
# 719:	learn: 0.2288001	total: 1m 51s	remaining: 43.2s
# 720:	learn: 0.2286398	total: 1m 51s	remaining: 43s
# 721:	learn: 0.2284665	total: 1m 51s	remaining: 42.9s
# 722:	learn: 0.2283086	total: 1m 51s	remaining: 42.7s
# 723:	learn: 0.2281566	total: 1m 51s	remaining: 42.6s
# 724:	learn: 0.2279803	total: 1m 51s	remaining: 42.4s
# 725:	learn: 0.2278287	total: 1m 51s	remaining: 42.2s
# 726:	learn: 0.2276768	total: 1m 52s	remaining: 42.1s
# 727:	learn: 0.2275050	total: 1m 52s	remaining: 42s
# 728:	learn: 0.2273146	total: 1m 52s	remaining: 41.8s
# 729:	learn: 0.2271162	total: 1m 52s	remaining: 41.7s
# 730:	learn: 0.2269750	total: 1m 52s	remaining: 41.5s
# 731:	learn: 0.2268176	total: 1m 52s	remaining: 41.3s
# 732:	learn: 0.2266869	total: 1m 53s	remaining: 41.2s
# 733:	learn: 0.2265081	total: 1m 53s	remaining: 41s
# 734:	learn: 0.2263383	total: 1m 53s	remaining: 40.9s
# 735:	learn: 0.2261384	total: 1m 53s	remaining: 40.7s
# 736:	learn: 0.2259639	total: 1m 53s	remaining: 40.6s
# 737:	learn: 0.2257889	total: 1m 53s	remaining: 40.4s
# 738:	learn: 0.2256061	total: 1m 53s	remaining: 40.3s
# 739:	learn: 0.2254590	total: 1m 54s	remaining: 40.1s
# 740:	learn: 0.2252810	total: 1m 54s	remaining: 40s
# 741:	learn: 0.2251319	total: 1m 54s	remaining: 39.8s
# 742:	learn: 0.2249908	total: 1m 54s	remaining: 39.6s
# 743:	learn: 0.2247938	total: 1m 54s	remaining: 39.5s
# 744:	learn: 0.2246406	total: 1m 54s	remaining: 39.3s
# 745:	learn: 0.2244687	total: 1m 55s	remaining: 39.2s
# 746:	learn: 0.2242923	total: 1m 55s	remaining: 39s
# 747:	learn: 0.2241342	total: 1m 55s	remaining: 38.9s
# 748:	learn: 0.2239588	total: 1m 55s	remaining: 38.7s
# 749:	learn: 0.2237727	total: 1m 55s	remaining: 38.6s
# 750:	learn: 0.2236307	total: 1m 55s	remaining: 38.4s
# 751:	learn: 0.2234576	total: 1m 55s	remaining: 38.2s
# 752:	learn: 0.2233027	total: 1m 56s	remaining: 38.1s
# 753:	learn: 0.2231580	total: 1m 56s	remaining: 37.9s
# 754:	learn: 0.2229957	total: 1m 56s	remaining: 37.8s
# 755:	learn: 0.2228370	total: 1m 56s	remaining: 37.6s
# 756:	learn: 0.2226845	total: 1m 56s	remaining: 37.5s
# 757:	learn: 0.2225262	total: 1m 56s	remaining: 37.3s
# 758:	learn: 0.2223696	total: 1m 56s	remaining: 37.1s
# 759:	learn: 0.2221924	total: 1m 57s	remaining: 37s
# 760:	learn: 0.2220348	total: 1m 57s	remaining: 36.8s
# 761:	learn: 0.2218986	total: 1m 57s	remaining: 36.7s
# 762:	learn: 0.2217346	total: 1m 57s	remaining: 36.5s
# 763:	learn: 0.2215911	total: 1m 57s	remaining: 36.4s
# 764:	learn: 0.2214330	total: 1m 57s	remaining: 36.2s
# 765:	learn: 0.2212778	total: 1m 58s	remaining: 36.1s
# 766:	learn: 0.2211405	total: 1m 58s	remaining: 35.9s
# 767:	learn: 0.2209564	total: 1m 58s	remaining: 35.8s
# 768:	learn: 0.2207936	total: 1m 58s	remaining: 35.6s
# 769:	learn: 0.2206117	total: 1m 58s	remaining: 35.5s
# 770:	learn: 0.2204595	total: 1m 58s	remaining: 35.3s
# 771:	learn: 0.2203138	total: 1m 59s	remaining: 35.2s
# 772:	learn: 0.2201508	total: 1m 59s	remaining: 35s
# 773:	learn: 0.2199947	total: 1m 59s	remaining: 34.9s
# 774:	learn: 0.2198388	total: 1m 59s	remaining: 34.7s
# 775:	learn: 0.2196743	total: 1m 59s	remaining: 34.6s
# 776:	learn: 0.2195144	total: 1m 59s	remaining: 34.4s
# 777:	learn: 0.2193595	total: 2m	remaining: 34.3s
# 778:	learn: 0.2191879	total: 2m	remaining: 34.1s
# 779:	learn: 0.2190470	total: 2m	remaining: 33.9s
# 780:	learn: 0.2188806	total: 2m	remaining: 33.8s
# 781:	learn: 0.2187301	total: 2m	remaining: 33.7s
# 782:	learn: 0.2185536	total: 2m	remaining: 33.5s
# 783:	learn: 0.2184113	total: 2m 1s	remaining: 33.4s
# 784:	learn: 0.2182479	total: 2m 1s	remaining: 33.2s
# 785:	learn: 0.2180909	total: 2m 1s	remaining: 33.1s
# 786:	learn: 0.2179155	total: 2m 1s	remaining: 32.9s
# 787:	learn: 0.2177511	total: 2m 1s	remaining: 32.8s
# 788:	learn: 0.2176422	total: 2m 1s	remaining: 32.6s
# 789:	learn: 0.2174811	total: 2m 2s	remaining: 32.5s
# 790:	learn: 0.2173189	total: 2m 2s	remaining: 32.3s
# 791:	learn: 0.2171545	total: 2m 2s	remaining: 32.1s
# 792:	learn: 0.2170168	total: 2m 2s	remaining: 32s
# 793:	learn: 0.2168539	total: 2m 2s	remaining: 31.8s
# 794:	learn: 0.2167090	total: 2m 2s	remaining: 31.7s
# 795:	learn: 0.2165618	total: 2m 3s	remaining: 31.5s
# 796:	learn: 0.2164131	total: 2m 3s	remaining: 31.4s
# 797:	learn: 0.2162553	total: 2m 3s	remaining: 31.2s
# 798:	learn: 0.2160815	total: 2m 3s	remaining: 31.1s
# 799:	learn: 0.2159395	total: 2m 3s	remaining: 30.9s
# 800:	learn: 0.2158094	total: 2m 3s	remaining: 30.8s
# 801:	learn: 0.2156676	total: 2m 3s	remaining: 30.6s
# 802:	learn: 0.2155204	total: 2m 4s	remaining: 30.4s
# 803:	learn: 0.2153822	total: 2m 4s	remaining: 30.3s
# 804:	learn: 0.2152341	total: 2m 4s	remaining: 30.1s
# 805:	learn: 0.2150730	total: 2m 4s	remaining: 30s
# 806:	learn: 0.2149188	total: 2m 4s	remaining: 29.8s
# 807:	learn: 0.2147772	total: 2m 4s	remaining: 29.7s
# 808:	learn: 0.2146316	total: 2m 4s	remaining: 29.5s
# 809:	learn: 0.2145183	total: 2m 5s	remaining: 29.4s
# 810:	learn: 0.2143808	total: 2m 5s	remaining: 29.2s
# 811:	learn: 0.2142225	total: 2m 5s	remaining: 29s
# 812:	learn: 0.2140679	total: 2m 5s	remaining: 28.9s
# 813:	learn: 0.2139018	total: 2m 5s	remaining: 28.7s
# 814:	learn: 0.2137571	total: 2m 6s	remaining: 28.6s
# 815:	learn: 0.2136367	total: 2m 6s	remaining: 28.5s
# 816:	learn: 0.2134989	total: 2m 6s	remaining: 28.3s
# 817:	learn: 0.2133479	total: 2m 6s	remaining: 28.2s
# 818:	learn: 0.2132144	total: 2m 6s	remaining: 28s
# 819:	learn: 0.2130415	total: 2m 7s	remaining: 27.9s
# 820:	learn: 0.2128903	total: 2m 7s	remaining: 27.7s
# 821:	learn: 0.2127371	total: 2m 7s	remaining: 27.6s
# 822:	learn: 0.2126056	total: 2m 7s	remaining: 27.4s
# 823:	learn: 0.2124715	total: 2m 7s	remaining: 27.3s
# 824:	learn: 0.2123378	total: 2m 8s	remaining: 27.2s
# 825:	learn: 0.2121702	total: 2m 8s	remaining: 27s
# 826:	learn: 0.2120319	total: 2m 8s	remaining: 26.9s
# 827:	learn: 0.2118774	total: 2m 8s	remaining: 26.7s
# 828:	learn: 0.2117403	total: 2m 8s	remaining: 26.6s
# 829:	learn: 0.2115803	total: 2m 9s	remaining: 26.4s
# 830:	learn: 0.2114154	total: 2m 9s	remaining: 26.3s
# 831:	learn: 0.2112585	total: 2m 9s	remaining: 26.1s
# 832:	learn: 0.2111276	total: 2m 9s	remaining: 26s
# 833:	learn: 0.2109712	total: 2m 10s	remaining: 25.9s
# 834:	learn: 0.2108544	total: 2m 10s	remaining: 25.7s
# 835:	learn: 0.2107025	total: 2m 10s	remaining: 25.6s
# 836:	learn: 0.2105550	total: 2m 10s	remaining: 25.4s
# 837:	learn: 0.2104215	total: 2m 10s	remaining: 25.3s
# 838:	learn: 0.2102605	total: 2m 10s	remaining: 25.1s
# 839:	learn: 0.2101026	total: 2m 11s	remaining: 25s
# 840:	learn: 0.2099698	total: 2m 11s	remaining: 24.8s
# 841:	learn: 0.2098266	total: 2m 11s	remaining: 24.6s
# 842:	learn: 0.2096791	total: 2m 11s	remaining: 24.5s
# 843:	learn: 0.2095407	total: 2m 11s	remaining: 24.4s
# 844:	learn: 0.2093773	total: 2m 11s	remaining: 24.2s
# 845:	learn: 0.2092443	total: 2m 12s	remaining: 24.1s
# 846:	learn: 0.2090877	total: 2m 12s	remaining: 23.9s
# 847:	learn: 0.2089602	total: 2m 12s	remaining: 23.8s
# 848:	learn: 0.2088131	total: 2m 12s	remaining: 23.6s
# 849:	learn: 0.2086743	total: 2m 12s	remaining: 23.5s
# 850:	learn: 0.2085072	total: 2m 13s	remaining: 23.3s
# 851:	learn: 0.2083495	total: 2m 13s	remaining: 23.2s
# 852:	learn: 0.2082365	total: 2m 13s	remaining: 23s
# 853:	learn: 0.2080222	total: 2m 13s	remaining: 22.9s
# 854:	learn: 0.2079054	total: 2m 13s	remaining: 22.7s
# 855:	learn: 0.2077795	total: 2m 14s	remaining: 22.6s
# 856:	learn: 0.2076474	total: 2m 14s	remaining: 22.4s
# 857:	learn: 0.2075006	total: 2m 14s	remaining: 22.2s
# 858:	learn: 0.2073708	total: 2m 14s	remaining: 22.1s
# 859:	learn: 0.2072417	total: 2m 14s	remaining: 21.9s
# 860:	learn: 0.2071139	total: 2m 14s	remaining: 21.8s
# 861:	learn: 0.2069857	total: 2m 15s	remaining: 21.6s
# 862:	learn: 0.2068535	total: 2m 15s	remaining: 21.5s
# 863:	learn: 0.2067090	total: 2m 15s	remaining: 21.3s
# 864:	learn: 0.2065768	total: 2m 15s	remaining: 21.1s
# 865:	learn: 0.2064575	total: 2m 15s	remaining: 21s
# 866:	learn: 0.2063337	total: 2m 15s	remaining: 20.8s
# 867:	learn: 0.2061814	total: 2m 16s	remaining: 20.7s
# 868:	learn: 0.2060515	total: 2m 16s	remaining: 20.5s
# 869:	learn: 0.2058997	total: 2m 16s	remaining: 20.4s
# 870:	learn: 0.2057586	total: 2m 16s	remaining: 20.2s
# 871:	learn: 0.2056045	total: 2m 16s	remaining: 20.1s
# 872:	learn: 0.2054668	total: 2m 17s	remaining: 19.9s
# 873:	learn: 0.2053131	total: 2m 17s	remaining: 19.8s
# 874:	learn: 0.2051681	total: 2m 17s	remaining: 19.6s
# 875:	learn: 0.2050644	total: 2m 17s	remaining: 19.5s
# 876:	learn: 0.2049187	total: 2m 17s	remaining: 19.3s
# 877:	learn: 0.2047597	total: 2m 17s	remaining: 19.1s
# 878:	learn: 0.2046405	total: 2m 17s	remaining: 19s
# 879:	learn: 0.2045175	total: 2m 18s	remaining: 18.8s
# 880:	learn: 0.2044150	total: 2m 18s	remaining: 18.7s
# 881:	learn: 0.2042719	total: 2m 18s	remaining: 18.5s
# 882:	learn: 0.2041628	total: 2m 18s	remaining: 18.3s
# 883:	learn: 0.2040499	total: 2m 18s	remaining: 18.2s
# 884:	learn: 0.2039436	total: 2m 18s	remaining: 18s
# 885:	learn: 0.2038236	total: 2m 18s	remaining: 17.9s
# 886:	learn: 0.2036951	total: 2m 19s	remaining: 17.7s
# 887:	learn: 0.2035509	total: 2m 19s	remaining: 17.6s
# 888:	learn: 0.2034331	total: 2m 19s	remaining: 17.4s
# 889:	learn: 0.2032808	total: 2m 19s	remaining: 17.3s
# 890:	learn: 0.2031078	total: 2m 19s	remaining: 17.1s
# 891:	learn: 0.2029721	total: 2m 19s	remaining: 16.9s
# 892:	learn: 0.2028312	total: 2m 20s	remaining: 16.8s
# 893:	learn: 0.2026891	total: 2m 20s	remaining: 16.7s
# 894:	learn: 0.2025648	total: 2m 20s	remaining: 16.5s
# 895:	learn: 0.2024361	total: 2m 20s	remaining: 16.3s
# 896:	learn: 0.2023139	total: 2m 20s	remaining: 16.2s
# 897:	learn: 0.2021731	total: 2m 21s	remaining: 16s
# 898:	learn: 0.2020556	total: 2m 21s	remaining: 15.9s
# 899:	learn: 0.2019162	total: 2m 21s	remaining: 15.7s
# 900:	learn: 0.2017759	total: 2m 21s	remaining: 15.6s
# 901:	learn: 0.2016414	total: 2m 21s	remaining: 15.4s
# 902:	learn: 0.2015194	total: 2m 21s	remaining: 15.2s
# 903:	learn: 0.2013746	total: 2m 22s	remaining: 15.1s
# 904:	learn: 0.2012536	total: 2m 22s	remaining: 14.9s
# 905:	learn: 0.2011194	total: 2m 22s	remaining: 14.8s
# 906:	learn: 0.2009820	total: 2m 22s	remaining: 14.6s
# 907:	learn: 0.2008648	total: 2m 22s	remaining: 14.4s
# 908:	learn: 0.2007465	total: 2m 22s	remaining: 14.3s
# 909:	learn: 0.2006042	total: 2m 22s	remaining: 14.1s
# 910:	learn: 0.2004810	total: 2m 23s	remaining: 14s
# 911:	learn: 0.2003763	total: 2m 23s	remaining: 13.8s
# 912:	learn: 0.2002652	total: 2m 23s	remaining: 13.7s
# 913:	learn: 0.2001294	total: 2m 23s	remaining: 13.5s
# 914:	learn: 0.2000075	total: 2m 23s	remaining: 13.3s
# 915:	learn: 0.1998852	total: 2m 23s	remaining: 13.2s
# 916:	learn: 0.1997475	total: 2m 23s	remaining: 13s
# 917:	learn: 0.1996107	total: 2m 24s	remaining: 12.9s
# 918:	learn: 0.1994897	total: 2m 24s	remaining: 12.7s
# 919:	learn: 0.1993798	total: 2m 24s	remaining: 12.6s
# 920:	learn: 0.1992687	total: 2m 24s	remaining: 12.4s
# 921:	learn: 0.1991531	total: 2m 24s	remaining: 12.2s
# 922:	learn: 0.1990006	total: 2m 24s	remaining: 12.1s
# 923:	learn: 0.1988514	total: 2m 25s	remaining: 11.9s
# 924:	learn: 0.1987264	total: 2m 25s	remaining: 11.8s
# 925:	learn: 0.1985911	total: 2m 25s	remaining: 11.6s
# 926:	learn: 0.1984529	total: 2m 25s	remaining: 11.5s
# 927:	learn: 0.1983279	total: 2m 25s	remaining: 11.3s
# 928:	learn: 0.1981815	total: 2m 25s	remaining: 11.1s
# 929:	learn: 0.1980659	total: 2m 25s	remaining: 11s
# 930:	learn: 0.1979223	total: 2m 26s	remaining: 10.8s
# 931:	learn: 0.1977959	total: 2m 26s	remaining: 10.7s
# 932:	learn: 0.1976811	total: 2m 26s	remaining: 10.5s
# 933:	learn: 0.1975416	total: 2m 26s	remaining: 10.4s
# 934:	learn: 0.1974355	total: 2m 26s	remaining: 10.2s
# 935:	learn: 0.1972966	total: 2m 26s	remaining: 10s
# 936:	learn: 0.1971518	total: 2m 27s	remaining: 9.88s
# 937:	learn: 0.1970265	total: 2m 27s	remaining: 9.73s
# 938:	learn: 0.1968939	total: 2m 27s	remaining: 9.58s
# 939:	learn: 0.1967625	total: 2m 27s	remaining: 9.42s
# 940:	learn: 0.1966515	total: 2m 27s	remaining: 9.26s
# 941:	learn: 0.1965245	total: 2m 27s	remaining: 9.11s
# 942:	learn: 0.1964167	total: 2m 28s	remaining: 8.95s
# 943:	learn: 0.1962927	total: 2m 28s	remaining: 8.79s
# 944:	learn: 0.1961640	total: 2m 28s	remaining: 8.63s
# 945:	learn: 0.1960342	total: 2m 28s	remaining: 8.47s
# 946:	learn: 0.1958992	total: 2m 28s	remaining: 8.32s
# 947:	learn: 0.1957836	total: 2m 28s	remaining: 8.16s
# 948:	learn: 0.1956618	total: 2m 28s	remaining: 8s
# 949:	learn: 0.1955244	total: 2m 29s	remaining: 7.85s
# 950:	learn: 0.1953903	total: 2m 29s	remaining: 7.69s
# 951:	learn: 0.1952648	total: 2m 29s	remaining: 7.53s
# 952:	learn: 0.1951237	total: 2m 29s	remaining: 7.38s
# 953:	learn: 0.1949940	total: 2m 29s	remaining: 7.22s
# 954:	learn: 0.1948521	total: 2m 29s	remaining: 7.06s
# 955:	learn: 0.1947116	total: 2m 30s	remaining: 6.91s
# 956:	learn: 0.1946018	total: 2m 30s	remaining: 6.75s
# 957:	learn: 0.1944543	total: 2m 30s	remaining: 6.59s
# 958:	learn: 0.1943332	total: 2m 30s	remaining: 6.44s
# 959:	learn: 0.1941957	total: 2m 30s	remaining: 6.28s
# 960:	learn: 0.1940756	total: 2m 30s	remaining: 6.12s
# 961:	learn: 0.1939422	total: 2m 31s	remaining: 5.97s
# 962:	learn: 0.1937853	total: 2m 31s	remaining: 5.82s
# 963:	learn: 0.1936543	total: 2m 31s	remaining: 5.66s
# 964:	learn: 0.1935128	total: 2m 31s	remaining: 5.5s
# 965:	learn: 0.1933889	total: 2m 31s	remaining: 5.35s
# 966:	learn: 0.1932747	total: 2m 32s	remaining: 5.19s
# 967:	learn: 0.1931601	total: 2m 32s	remaining: 5.03s
# 968:	learn: 0.1930293	total: 2m 32s	remaining: 4.88s
# 969:	learn: 0.1928932	total: 2m 32s	remaining: 4.72s
# 970:	learn: 0.1927781	total: 2m 32s	remaining: 4.56s
# 971:	learn: 0.1926370	total: 2m 32s	remaining: 4.41s
# 972:	learn: 0.1925322	total: 2m 33s	remaining: 4.25s
# 973:	learn: 0.1924150	total: 2m 33s	remaining: 4.09s
# 974:	learn: 0.1922971	total: 2m 33s	remaining: 3.93s
# 975:	learn: 0.1921625	total: 2m 33s	remaining: 3.78s
# 976:	learn: 0.1920549	total: 2m 33s	remaining: 3.62s
# 977:	learn: 0.1919453	total: 2m 33s	remaining: 3.46s
# 978:	learn: 0.1917868	total: 2m 34s	remaining: 3.3s
# 979:	learn: 0.1916951	total: 2m 34s	remaining: 3.15s
# 980:	learn: 0.1915519	total: 2m 34s	remaining: 2.99s
# 981:	learn: 0.1914200	total: 2m 34s	remaining: 2.83s
# 982:	learn: 0.1912925	total: 2m 34s	remaining: 2.68s
# 983:	learn: 0.1911625	total: 2m 35s	remaining: 2.52s
# 984:	learn: 0.1910501	total: 2m 35s	remaining: 2.37s
# 985:	learn: 0.1909226	total: 2m 35s	remaining: 2.21s
# 986:	learn: 0.1907934	total: 2m 35s	remaining: 2.05s
# 987:	learn: 0.1906904	total: 2m 35s	remaining: 1.89s
# 988:	learn: 0.1905560	total: 2m 36s	remaining: 1.74s
# 989:	learn: 0.1904227	total: 2m 36s	remaining: 1.58s
# 990:	learn: 0.1903005	total: 2m 36s	remaining: 1.42s
# 991:	learn: 0.1901762	total: 2m 36s	remaining: 1.26s
# 992:	learn: 0.1900741	total: 2m 36s	remaining: 1.1s
# 993:	learn: 0.1899513	total: 2m 36s	remaining: 946ms
# 994:	learn: 0.1898321	total: 2m 36s	remaining: 789ms
# 995:	learn: 0.1897093	total: 2m 37s	remaining: 631ms
# 996:	learn: 0.1895772	total: 2m 37s	remaining: 473ms
# 997:	learn: 0.1894844	total: 2m 37s	remaining: 315ms
# 998:	learn: 0.1893657	total: 2m 37s	remaining: 158ms
# 999:	learn: 0.1892456	total: 2m 37s	remaining: 0us
#   Undersampling Technique     Model   ROC-AUC    PR-AUC
# 0                  random  CatBoost  0.887633  0.572914
# 1                   smote  CatBoost  0.780618  0.339093
# 2                  adasyn  CatBoost  0.780315  0.340419
# 3                 border1  CatBoost  0.793785  0.364244
# 4                 border2  CatBoost  0.814447  0.408506

# %% [markdown]
# ### Export classification metrics

# %%
# Concatenate df_results_1 and df_results_2 horisontally
df_combined_results = pd.concat([df_results_2, df_results_1], axis=1)

# Export results to CSV files
df_combined_results.to_csv('6_evaluation_results_oversampling.csv', index=False)
