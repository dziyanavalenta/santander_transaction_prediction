# %% [markdown]
# # Santander

# %% [markdown]
# #### Contents
#  - [Readme](#Readme)
#  - [1. Import libs](#1.-Import-libs)
#  - [2. Get data](#2.-Get-data)
#      - [Read data](#Read-data)

# %% [markdown]
# ### Readme
# [top](#Contents)

# %% [markdown]
# # 1. Import libs
# [top](#Contents)

# %%
# pandas and numpy imports
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

import warnings
# Suppress the specific warning
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn.metrics')

# %%
# pip install -U imbalanced-learn

# %% [markdown]
# # 2. Get data
# [top](#Contents)

# %% [markdown]
# #### Read data
# [top](#Contents)

# %%
bank_ds = pd.read_csv('train.csv')

# %%
bank_test_ds = pd.read_csv('test.csv')

# %% [markdown]
# #### Drop an unneeded column

# %%
# Assuming 'column_to_drop' is the name of the column you want to drop
column_to_drop = 'ID_code'

# Drop the column from bank_ds
bank_ds.drop(column_to_drop, axis=1, inplace=True)

# %% [markdown]
# ### Split 70/30 (stratified sampling)

# %%
target = bank_ds['target']

# %%
# separate dataset into train and test

X_train, X_test, y_train, y_test = train_test_split(
    bank_ds.drop(labels=['target'], axis=1),  # drop the target
    bank_ds['target'],  # just the target
    test_size=0.3,
    stratify=target,
    random_state=42)

X_train.shape, X_test.shape
# Out:
# ((140000, 200), (60000, 200))

# %% [markdown]
# ### Scaling

# %% [markdown]
# Models like Logistic Regression require scaling for better performance. Tree-based models like Random Forest, XGBoost, and LightGBM do not inherently require scaling but scaling can still be beneficial (can improve performance and convergence in some cases).

# %%
from sklearn.preprocessing import MinMaxScaler
# we put the variables in the same scale
scaler = MinMaxScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Undersampling

# %%
from imblearn.under_sampling import (
    RandomUnderSampler,
    TomekLinks,
    OneSidedSelection,
    EditedNearestNeighbours,
    RepeatedEditedNearestNeighbours,
    NeighbourhoodCleaningRule,
    NearMiss
)

# %%
# sampling_strategy='auto' undersamples only majority class
undersampler_dict = {
    'random': RandomUnderSampler(sampling_strategy='auto', random_state=0, replacement=False),
    'ncr':    NeighbourhoodCleaningRule(sampling_strategy='auto', n_neighbors=3, kind_sel='all', n_jobs=4, threshold_cleaning=0.5),
    'enn':    EditedNearestNeighbours(sampling_strategy='auto', n_neighbors=3, kind_sel='all', n_jobs=4),
    'renn':   RepeatedEditedNearestNeighbours(sampling_strategy='auto', n_neighbors=3, kind_sel='all', n_jobs=4, max_iter=100),   
    'nm1':    NearMiss(sampling_strategy='auto', version=1, n_neighbors=3, n_jobs=4),
    'tomek':  TomekLinks(sampling_strategy='auto', n_jobs=4),
    'oss':    OneSidedSelection(sampling_strategy='auto', random_state=0, n_neighbors=1, n_jobs=4)
}

# %%
# from imblearn.under_sampling import (
    CondensedNearestNeighbour,
    AllKNN,
    InstanceHardnessThreshold
)

# %%
# sampling_strategy='auto' undersamples only majority class
undersampler_dict = {
    'random': RandomUnderSampler(sampling_strategy='auto', random_state=0, replacement=False),
    'ncr':    NeighbourhoodCleaningRule(sampling_strategy='auto', n_neighbors=3, kind_sel='all', n_jobs=4, threshold_cleaning=0.5),
    'tomek':  TomekLinks(sampling_strategy='auto', n_jobs=4),
    'oss':    OneSidedSelection(sampling_strategy='auto', random_state=0, n_neighbors=1, n_jobs=4),
    'enn':    EditedNearestNeighbours(sampling_strategy='auto', n_neighbors=3, kind_sel='all', n_jobs=4),
    'renn':   RepeatedEditedNearestNeighbours(sampling_strategy='auto', n_neighbors=3, kind_sel='all', n_jobs=4, max_iter=100),   
    'nm1':    NearMiss(sampling_strategy='auto', version=1, n_neighbors=3, n_jobs=4),

    'allknn': AllKNN(sampling_strategy='auto', n_neighbors=3, kind_sel='all', n_jobs=4),
    'cnn':    CondensedNearestNeighbour(sampling_strategy='auto', random_state=0, n_neighbors=1, n_jobs=4),
    'nm2':    NearMiss(sampling_strategy='auto', version=2, n_neighbors=3, n_jobs=4)
}

# %% [markdown]
# ## Evaluation

# %% [markdown]
# #### Metrics which require predict method

# %% [markdown]
# #### Confusion matrix, Recall, Precision, F1-score, G-mean, etc

# %%
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    recall_score,
    precision_score,
    f1_score,
    classification_report,
    confusion_matrix
)

# require scaling
from imblearn.metrics import (
    geometric_mean_score,
    make_index_balanced_accuracy,
)

def dominance(y_true, y_pred):
    tpr = recall_score(y_test, y_pred, pos_label=1)
    tnr = recall_score(y_test, y_pred, pos_label=0)
    return tpr - tnr

# Function to get classification metrics
def get_classification_metrics(y_true, y_pred):
    report = classification_report(y_true, y_pred, output_dict=True)
    accuracy          = accuracy_score(y_test, y_pred)
    balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
    
    # Adding possible averages to recall, precision, and f1-score calculations
    # Default average is None - scores are returned for each class individually rather than being averaged
    recall_weighted    = recall_score(y_test, y_pred, average='weighted')
    precision_weighted = precision_score(y_test, y_pred, average='weighted') 
    f1_weighted        = f1_score(y_test, y_pred, average='weighted')

    recall_micro       = recall_score(y_test, y_pred, average='micro')
    precision_micro    = precision_score(y_test, y_pred, average='micro')
    f1_micro           = f1_score(y_test, y_pred, average='micro')
    
    recall_macro       = recall_score(y_test, y_pred, average='macro')
    precision_macro    = precision_score(y_test, y_pred, average='macro')
    f1_macro           = f1_score(y_test, y_pred, average='macro')

    # Adding possible averages to G-mean
    # If the average parameter is not specified, it defaults to average='binary'.
    g_mean_binary      = geometric_mean_score(y_test, y_pred, average='binary')
    g_mean_weighted    = geometric_mean_score(y_test, y_pred, average='weighted')
    g_mean_micro       = geometric_mean_score(y_test, y_pred, average='micro')
    g_mean_macro       = geometric_mean_score(y_test, y_pred, average='macro')

    # A lower alpha gives more weight to sensitivity (TPR), while a higher alpha gives more weight to specificity (TNR). 
    # In other words,in case of a lower alpha more emphasis is placed on correctly identifying positive instances
    gmean = make_index_balanced_accuracy(alpha=0.5, squared=True)(geometric_mean_score) 
    corrected_g_mean  = gmean(y_test, y_pred)
    # specifying an average might not be necessary or meaningful. Leaving for the time being
    corrected_g_mean_binary  = gmean(y_test, y_pred,average='binary')
    corrected_g_mean_weighted  = gmean(y_test, y_pred,average='weighted')
    corrected_g_mean_micro  = gmean(y_test, y_pred,average='micro')
    corrected_g_mean_macro  = gmean(y_test, y_pred,average='macro')
    
    dominance_score   = dominance(y_test, y_pred) 

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
    FPR = fp / (tn + fp)
    FNR = fn / (tp + fn)
    # TPR = tp / (tp + fn) # recallminority
    # TNR = tn / (tn + fp) # recall majority
    
    return {
        'Accuracy': accuracy,
        'Recall Majority (TNR)': report['0']['recall'],
        'Recall Minority (TPR)': report['1']['recall'],
        'Balanced Accuracy': balanced_accuracy,
        'FPR': FPR,
        'FNR': FNR,
        
        'Precision Majority': report['0']['precision'],
        'Precision Minority': report['1']['precision'],
        'F1-Score Majority': report['0']['f1-score'],
        'F1-Score Minority': report['1']['f1-score'], 
        
        # Weighted average (Use 'weighted' if you want to take class imbalance into account)
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,

        # Micro average (Use 'micro' if you want a metric that gives equal weight to every individual prediction)
        'Micro Precision': precision_micro,
        'Micro Recall': recall_micro,
        'Micro F1-Score': f1_micro,
        
        # Macro average (Use 'macro' if you want to treat each class equally)
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,

        # Geometric average (a suitable metric when you want to balance the trade-off between detecting the minority class 
        # and avoiding false positives from the majority class)
        'G-mean-binary': g_mean_binary, # (compute two geometric means for each class, then the arithmetic mean of these G-means)
        'G-mean-weighted': g_mean_weighted, # calculates the geometric mean for each class and then computes the weighted arithmetic mean of these G-means
        'G-mean-micro': g_mean_micro, # treats all classes equally, regardless of their size
        'G-mean-macro': g_mean_macro, # use when you want to weight each instance equally, regardless of their class

        # Corrected G-means
        'Corrected G-mean': corrected_g_mean,
        'Corrected G-mean-binary': corrected_g_mean_binary,
        'Corrected G-mean-weighted': corrected_g_mean_weighted,
        'Corrected G-mean-micro': corrected_g_mean_micro,
        'Corrected G-mean-macro': corrected_g_mean_macro,
        
        'Dominance': dominance_score
    }

# Dictionary to hold the models
models_dict = {
    #'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(random_state=42),
    #'XGBoost': XGBClassifier(random_state=42),
    'LightGBM': LGBMClassifier(random_state=42),
    'CatBoost': CatBoostClassifier(random_state=42, verbose=False) # Disable logging
}
# Collecting results
results = []
confusion_matrices = []

# Iterate over each undersampling technique
for name, undersampler in undersampler_dict.items():
    print(f"Applying undersampling technique: {name}")
    
    # Apply undersampling to the training data
    X_resampled, y_resampled = undersampler.fit_resample(X_train, y_train)
    
    # Iterate over each model
    for model_name, model in models_dict.items():
        print(f"Training model: {model_name} with undersampling technique: {name}")
        
        # Train the model
        model.fit(X_resampled, y_resampled)
        
        # Make predictions on the test set
        y_pred = model.predict(X_test)
        
        # Calculate metrics
        metrics = get_classification_metrics(y_test, y_pred)
        
        # Append the results
        results.append({
            'Undersampling Technique': name,
            'Model': model_name,
            **metrics
        })

# Create a DataFrame from the results
df_results_1 = pd.DataFrame(results)

# Print the DataFrame as a table
print(df_results_1)
# Out:
# Applying undersampling technique: random
# Training model: Logistic Regression with undersampling technique: random
# Training model: LightGBM with undersampling technique: random
# [LightGBM] [Info] Number of positive: 14069, number of negative: 14069
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049050 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 28138, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Applying undersampling technique: ncr
# C:\Users\dziya\anaconda3\Lib\site-packages\imblearn\under_sampling\_prototype_selection\_neighbourhood_cleaning_rule.py:201: FutureWarning: `kind_sel` is deprecated in 0.12 and will be removed in 0.14. It already has not effect and corresponds to the `'all'` option.
#   warnings.warn(
# Training model: Logistic Regression with undersampling technique: ncr
# Training model: LightGBM with undersampling technique: ncr
# [LightGBM] [Info] Number of positive: 14069, number of negative: 106100
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.210969 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 120169, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.117077 -> initscore=-2.020408
# [LightGBM] [Info] Start training from score -2.020408
# Applying undersampling technique: enn
# Training model: Logistic Regression with undersampling technique: enn
# Training model: LightGBM with undersampling technique: enn
# [LightGBM] [Info] Number of positive: 14069, number of negative: 117372
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.239032 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 131441, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.107037 -> initscore=-2.121375
# [LightGBM] [Info] Start training from score -2.121375
# Applying undersampling technique: renn
# Training model: Logistic Regression with undersampling technique: renn
# Training model: LightGBM with undersampling technique: renn
# [LightGBM] [Info] Number of positive: 14069, number of negative: 116828
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.230120 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 130897, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.107481 -> initscore=-2.116729
# [LightGBM] [Info] Start training from score -2.116729
# Applying undersampling technique: nm1
# Training model: Logistic Regression with undersampling technique: nm1
# Training model: LightGBM with undersampling technique: nm1
# [LightGBM] [Info] Number of positive: 14069, number of negative: 14069
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051188 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 28138, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Applying undersampling technique: tomek
# Training model: Logistic Regression with undersampling technique: tomek
# Training model: LightGBM with undersampling technique: tomek
# [LightGBM] [Info] Number of positive: 14069, number of negative: 125364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.236662 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 139433, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.100902 -> initscore=-2.187248
# [LightGBM] [Info] Start training from score -2.187248
# Applying undersampling technique: oss
# Training model: Logistic Regression with undersampling technique: oss
# Training model: LightGBM with undersampling technique: oss
# [LightGBM] [Info] Number of positive: 14069, number of negative: 125327
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.229265 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 139396, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.100928 -> initscore=-2.186953
# [LightGBM] [Info] Start training from score -2.186953
#    Undersampling Technique                Model  Accuracy  \
# 0                   random  Logistic Regression  0.779217
# 1                   random             LightGBM  0.772617
# 2                      ncr  Logistic Regression  0.912683
# 3                      ncr             LightGBM  0.908267
# 4                      enn  Logistic Regression  0.913283
# 5                      enn             LightGBM  0.908583
# 6                     renn  Logistic Regression  0.913300
# 7                     renn             LightGBM  0.909067
# 8                      nm1  Logistic Regression  0.797967
# 9                      nm1             LightGBM  0.675917
# 10                   tomek  Logistic Regression  0.913533
# 11                   tomek             LightGBM  0.907450
# 12                     oss  Logistic Regression  0.913517
# 13                     oss             LightGBM  0.907667
#
#     Recall Majority (TNR)  Recall Minority (TPR)  Balanced Accuracy       FPR  \
# 0                0.780104               0.771272           0.775688  0.219896
# 1                0.770414               0.792337           0.781375  0.229586
# 2                0.980212               0.308177           0.644194  0.019788
# 3                0.997684               0.107812           0.552748  0.002316
# 4                0.982750               0.291425           0.637087  0.017250
# 5                0.997628               0.111461           0.554545  0.002372
# 6                0.982546               0.293415           0.637981  0.017454
# 7                0.997573               0.116769           0.557171  0.002427
# 8                0.804191               0.742246           0.773218  0.195809
# 9                0.652795               0.882899           0.767847  0.347205
# 10               0.985900               0.265716           0.625808  0.014100
# 11               0.998351               0.093714           0.546032  0.001649
# 12               0.985881               0.265716           0.625799  0.014119
# 13               0.998073               0.098358           0.548215  0.001927
#
#          FNR  Precision Majority  Precision Minority  ...  G-mean-binary  \
# 0   0.228728            0.968286            0.281511  ...       0.775676
# 1   0.207663            0.970770            0.278250  ...       0.781298
# 2   0.691823            0.926919            0.634997  ...       0.549617
# 3   0.892188            0.909177            0.838710  ...       0.327967
# 4   0.708575            0.925461            0.653646  ...       0.535161
# 5   0.888539            0.909510            0.840000  ...       0.333462
# 6   0.706585            0.925640            0.652527  ...       0.536930
# 7   0.883231            0.909997            0.843114  ...       0.341300
# 8   0.257754            0.965434            0.297481  ...       0.772598
# 9   0.117101            0.980355            0.221220  ...       0.759179
# 10  0.734284            0.923192            0.677952  ...       0.511829
# 11  0.906286            0.907930            0.863914  ...       0.305874
# 12  0.734284            0.923190            0.677665  ...       0.511824
# 13  0.901642            0.908335            0.850789  ...       0.313318
#
#     G-mean-weighted  G-mean-micro  G-mean-macro  Corrected G-mean  \
# 0          0.775680      0.779217      0.775688          0.601673
# 1          0.781326      0.772617      0.781375          0.610427
# 2          0.585577      0.912683      0.644194          0.302079
# 3          0.423246      0.908267      0.552748          0.107563
# 4          0.574105      0.913283      0.637087          0.286398
# 5          0.426822      0.908583      0.554545          0.111197
# 6          0.575516      0.913300      0.637981          0.288294
# 7          0.431982      0.909067      0.557171          0.116486
# 8          0.772822      0.797967      0.773218          0.596908
# 9          0.762324      0.675917      0.767847          0.576352
# 10         0.555742      0.913533      0.625808          0.261969
# 11         0.409303      0.907450      0.546032          0.093559
# 12         0.555736      0.913517      0.625799          0.261964
# 13         0.413926      0.907667      0.548215          0.098168
#
#     Corrected G-mean-binary  Corrected G-mean-weighted  \
# 0                  0.599016                   0.603803
# 1                  0.617119                   0.605124
# 2                  0.200575                   0.434965
# 3                  0.059704                   0.242824
# 4                  0.187401                   0.420629
# 5                  0.061927                   0.246674
# 6                  0.188958                   0.422409
# 7                  0.065185                   0.252276
# 8                  0.578420                   0.612035
# 9                  0.642663                   0.527714
# 10                 0.167636                   0.397713
# 11                 0.051241                   0.228076
# 12                 0.167635                   0.397701
# 13                 0.054007                   0.232922
#
#     Corrected G-mean-micro  Corrected G-mean-macro  Dominance
# 0                 0.607179                0.601692  -0.008832
# 1                 0.596937                0.610547   0.021923
# 2                 0.832991                0.414986  -0.672034
# 3                 0.824948                0.305530  -0.889872
# 4                 0.834086                0.405880  -0.691325
# 5                 0.825524                0.307520  -0.886167
# 6                 0.834117                0.407019  -0.689131
# 7                 0.826402                0.310439  -0.880804
# 8                 0.636751                0.597867  -0.061945
# 9                 0.456863                0.589589   0.230104
# 10                0.834543                0.391635  -0.720184
# 11                0.823466                0.298151  -0.904637
# 12                0.834513                0.391624  -0.720166
# 13                0.823859                0.300540  -0.899715
#
# [14 rows x 31 columns]

# %% [markdown]
# #### Metrics which require predict_proba method
# The ROC AUC score is calculated based on the predicted probabilities for each class, which are obtained using the predict_proba method. This method provides the probability estimates for each class, which are necessary to compute the ROC curve and subsequently the AUC (Area Under the Curve).

# %%
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score
)

# Dictionary to hold the models
models_dict = {
    #'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(random_state=42),
    #'XGBoost': XGBClassifier(random_state=42),
    'LightGBM': LGBMClassifier(random_state=42),
    'CatBoost': CatBoostClassifier(random_state=42, verbose=False) # Disable logging
}

# Collecting results
results = []
# Iterate over each undersampling technique
for name, undersampler in undersampler_dict.items():
    print(f"Applying undersampling technique: {name}")
    
    # Apply undersampling to the training data
    X_resampled, y_resampled = undersampler.fit_resample(X_train, y_train)
    
    # Iterate over each model
    for model_name, model in models_dict.items():
        print(f"Training model: {model_name} with undersampling technique: {name}")

        # Train the model
        model.fit(X_resampled, y_resampled)
        
        # Make predictions on the test set
        y_pred_proba = model.predict_proba(X_test)[:, 1]  
        
        # Calculate metrics
        roc_auc = roc_auc_score(y_test, y_pred_proba)
        pr_auc = average_precision_score(y_test, y_pred_proba)
        
        # Append the results
        results.append({
            'Undersampling Technique': name,
            'Model': model_name,
            'ROC-AUC': roc_auc,
            'PR-AUC': pr_auc
        })

# Create a DataFrame from the results
df_results_2 = pd.DataFrame(results)

# Print the DataFrame as a table
print(df_results_2)
# Out:
# Applying undersampling technique: random
# Training model: Logistic Regression with undersampling technique: random
# Training model: LightGBM with undersampling technique: random
# [LightGBM] [Info] Number of positive: 14069, number of negative: 14069
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049135 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 28138, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training model: CatBoost with undersampling technique: random
# Learning rate set to 0.042833
# 0:	learn: 0.6896089	total: 248ms	remaining: 4m 7s
# 1:	learn: 0.6865107	total: 292ms	remaining: 2m 25s
# 2:	learn: 0.6835010	total: 338ms	remaining: 1m 52s
# 3:	learn: 0.6806626	total: 383ms	remaining: 1m 35s
# 4:	learn: 0.6775753	total: 430ms	remaining: 1m 25s
# 5:	learn: 0.6748614	total: 478ms	remaining: 1m 19s
# 6:	learn: 0.6722514	total: 526ms	remaining: 1m 14s
# 7:	learn: 0.6700669	total: 572ms	remaining: 1m 10s
# 8:	learn: 0.6678494	total: 620ms	remaining: 1m 8s
# 9:	learn: 0.6655291	total: 668ms	remaining: 1m 6s
# 10:	learn: 0.6632604	total: 714ms	remaining: 1m 4s
# 11:	learn: 0.6612618	total: 758ms	remaining: 1m 2s
# 12:	learn: 0.6590120	total: 809ms	remaining: 1m 1s
# 13:	learn: 0.6570630	total: 855ms	remaining: 1m
# 14:	learn: 0.6550019	total: 901ms	remaining: 59.2s
# 15:	learn: 0.6532705	total: 945ms	remaining: 58.1s
# 16:	learn: 0.6514535	total: 992ms	remaining: 57.3s
# 17:	learn: 0.6496770	total: 1.03s	remaining: 56.4s
# 18:	learn: 0.6476815	total: 1.08s	remaining: 55.6s
# 19:	learn: 0.6459736	total: 1.12s	remaining: 55.1s
# 20:	learn: 0.6441781	total: 1.18s	remaining: 54.9s
# 21:	learn: 0.6424871	total: 1.22s	remaining: 54.4s
# 22:	learn: 0.6408145	total: 1.27s	remaining: 54.1s
# 23:	learn: 0.6390902	total: 1.32s	remaining: 53.8s
# 24:	learn: 0.6374981	total: 1.37s	remaining: 53.6s
# 25:	learn: 0.6360022	total: 1.43s	remaining: 53.6s
# 26:	learn: 0.6343650	total: 1.48s	remaining: 53.2s
# 27:	learn: 0.6327105	total: 1.53s	remaining: 53.1s
# 28:	learn: 0.6311782	total: 1.58s	remaining: 53s
# 29:	learn: 0.6297465	total: 1.63s	remaining: 52.7s
# 30:	learn: 0.6281873	total: 1.68s	remaining: 52.4s
# 31:	learn: 0.6266891	total: 1.72s	remaining: 52.1s
# 32:	learn: 0.6251807	total: 1.77s	remaining: 51.8s
# 33:	learn: 0.6238280	total: 1.81s	remaining: 51.4s
# 34:	learn: 0.6223560	total: 1.85s	remaining: 51.1s
# 35:	learn: 0.6210121	total: 1.9s	remaining: 50.8s
# 36:	learn: 0.6197080	total: 1.94s	remaining: 50.6s
# 37:	learn: 0.6183124	total: 1.99s	remaining: 50.3s
# 38:	learn: 0.6169728	total: 2.04s	remaining: 50.2s
# 39:	learn: 0.6156607	total: 2.09s	remaining: 50.1s
# 40:	learn: 0.6144774	total: 2.14s	remaining: 50s
# 41:	learn: 0.6132571	total: 2.2s	remaining: 50.1s
# 42:	learn: 0.6121490	total: 2.24s	remaining: 49.9s
# 43:	learn: 0.6109222	total: 2.29s	remaining: 49.7s
# 44:	learn: 0.6097151	total: 2.34s	remaining: 49.7s
# 45:	learn: 0.6085027	total: 2.4s	remaining: 49.7s
# 46:	learn: 0.6072728	total: 2.44s	remaining: 49.5s
# 47:	learn: 0.6060422	total: 2.49s	remaining: 49.4s
# 48:	learn: 0.6048829	total: 2.54s	remaining: 49.3s
# 49:	learn: 0.6039708	total: 2.58s	remaining: 49.1s
# 50:	learn: 0.6028220	total: 2.64s	remaining: 49.1s
# 51:	learn: 0.6017938	total: 2.69s	remaining: 49s
# 52:	learn: 0.6006829	total: 2.74s	remaining: 48.9s
# 53:	learn: 0.5994975	total: 2.79s	remaining: 48.9s
# 54:	learn: 0.5984899	total: 2.84s	remaining: 48.8s
# 55:	learn: 0.5974348	total: 2.89s	remaining: 48.7s
# 56:	learn: 0.5963010	total: 2.94s	remaining: 48.7s
# 57:	learn: 0.5952012	total: 2.99s	remaining: 48.6s
# 58:	learn: 0.5942087	total: 3.04s	remaining: 48.4s
# 59:	learn: 0.5932140	total: 3.08s	remaining: 48.3s
# 60:	learn: 0.5922460	total: 3.13s	remaining: 48.1s
# 61:	learn: 0.5912299	total: 3.17s	remaining: 48s
# 62:	learn: 0.5902369	total: 3.21s	remaining: 47.8s
# 63:	learn: 0.5893807	total: 3.26s	remaining: 47.7s
# 64:	learn: 0.5883758	total: 3.31s	remaining: 47.6s
# 65:	learn: 0.5873730	total: 3.37s	remaining: 47.7s
# 66:	learn: 0.5863254	total: 3.42s	remaining: 47.6s
# 67:	learn: 0.5853380	total: 3.47s	remaining: 47.6s
# 68:	learn: 0.5843978	total: 3.52s	remaining: 47.5s
# 69:	learn: 0.5833767	total: 3.58s	remaining: 47.5s
# 70:	learn: 0.5824254	total: 3.63s	remaining: 47.4s
# 71:	learn: 0.5815186	total: 3.67s	remaining: 47.4s
# 72:	learn: 0.5806474	total: 3.73s	remaining: 47.4s
# 73:	learn: 0.5797421	total: 3.78s	remaining: 47.3s
# 74:	learn: 0.5787891	total: 3.83s	remaining: 47.2s
# 75:	learn: 0.5778361	total: 3.88s	remaining: 47.2s
# 76:	learn: 0.5770259	total: 3.93s	remaining: 47.1s
# 77:	learn: 0.5762120	total: 3.98s	remaining: 47.1s
# 78:	learn: 0.5753189	total: 4.03s	remaining: 47s
# 79:	learn: 0.5743952	total: 4.09s	remaining: 47s
# 80:	learn: 0.5734959	total: 4.13s	remaining: 46.9s
# 81:	learn: 0.5725740	total: 4.19s	remaining: 46.9s
# 82:	learn: 0.5717203	total: 4.23s	remaining: 46.8s
# 83:	learn: 0.5709164	total: 4.29s	remaining: 46.7s
# 84:	learn: 0.5700676	total: 4.34s	remaining: 46.7s
# 85:	learn: 0.5692349	total: 4.38s	remaining: 46.6s
# 86:	learn: 0.5684196	total: 4.43s	remaining: 46.5s
# 87:	learn: 0.5675629	total: 4.48s	remaining: 46.4s
# 88:	learn: 0.5667360	total: 4.53s	remaining: 46.4s
# 89:	learn: 0.5659491	total: 4.58s	remaining: 46.3s
# 90:	learn: 0.5651112	total: 4.63s	remaining: 46.2s
# 91:	learn: 0.5643165	total: 4.68s	remaining: 46.2s
# 92:	learn: 0.5635299	total: 4.72s	remaining: 46.1s
# 93:	learn: 0.5627802	total: 4.77s	remaining: 46s
# 94:	learn: 0.5619939	total: 4.82s	remaining: 46s
# 95:	learn: 0.5612154	total: 4.87s	remaining: 45.9s
# 96:	learn: 0.5603971	total: 5s	remaining: 46.5s
# 97:	learn: 0.5596445	total: 5.12s	remaining: 47.1s
# 98:	learn: 0.5588309	total: 5.19s	remaining: 47.2s
# 99:	learn: 0.5579991	total: 5.24s	remaining: 47.2s
# 100:	learn: 0.5573126	total: 5.29s	remaining: 47.1s
# 101:	learn: 0.5566721	total: 5.34s	remaining: 47s
# 102:	learn: 0.5559333	total: 5.39s	remaining: 46.9s
# 103:	learn: 0.5551766	total: 5.44s	remaining: 46.9s
# 104:	learn: 0.5543567	total: 5.49s	remaining: 46.8s
# 105:	learn: 0.5536353	total: 5.54s	remaining: 46.7s
# 106:	learn: 0.5529639	total: 5.6s	remaining: 46.7s
# 107:	learn: 0.5522633	total: 5.82s	remaining: 48s
# 108:	learn: 0.5514790	total: 5.94s	remaining: 48.6s
# 109:	learn: 0.5508127	total: 5.99s	remaining: 48.5s
# 110:	learn: 0.5500894	total: 6.04s	remaining: 48.4s
# 111:	learn: 0.5493570	total: 6.08s	remaining: 48.2s
# 112:	learn: 0.5486170	total: 6.13s	remaining: 48.1s
# 113:	learn: 0.5479343	total: 6.18s	remaining: 48s
# 114:	learn: 0.5472804	total: 6.23s	remaining: 47.9s
# 115:	learn: 0.5465995	total: 6.28s	remaining: 47.9s
# 116:	learn: 0.5459151	total: 6.32s	remaining: 47.7s
# 117:	learn: 0.5452826	total: 6.37s	remaining: 47.6s
# 118:	learn: 0.5447002	total: 6.42s	remaining: 47.5s
# 119:	learn: 0.5440533	total: 6.47s	remaining: 47.4s
# 120:	learn: 0.5433630	total: 6.51s	remaining: 47.3s
# 121:	learn: 0.5426872	total: 6.56s	remaining: 47.2s
# 122:	learn: 0.5420422	total: 6.61s	remaining: 47.1s
# 123:	learn: 0.5413958	total: 6.66s	remaining: 47.1s
# 124:	learn: 0.5407582	total: 6.71s	remaining: 47s
# 125:	learn: 0.5401688	total: 6.76s	remaining: 46.9s
# 126:	learn: 0.5395870	total: 6.81s	remaining: 46.8s
# 127:	learn: 0.5389293	total: 6.86s	remaining: 46.7s
# 128:	learn: 0.5383094	total: 6.91s	remaining: 46.7s
# 129:	learn: 0.5377130	total: 6.96s	remaining: 46.6s
# 130:	learn: 0.5370660	total: 7.01s	remaining: 46.5s
# 131:	learn: 0.5364552	total: 7.05s	remaining: 46.4s
# 132:	learn: 0.5358730	total: 7.1s	remaining: 46.3s
# 133:	learn: 0.5352600	total: 7.14s	remaining: 46.2s
# 134:	learn: 0.5346769	total: 7.19s	remaining: 46.1s
# 135:	learn: 0.5341066	total: 7.24s	remaining: 46s
# 136:	learn: 0.5334930	total: 7.29s	remaining: 45.9s
# 137:	learn: 0.5329642	total: 7.33s	remaining: 45.8s
# 138:	learn: 0.5323847	total: 7.38s	remaining: 45.7s
# 139:	learn: 0.5317414	total: 7.42s	remaining: 45.6s
# 140:	learn: 0.5312379	total: 7.48s	remaining: 45.5s
# 141:	learn: 0.5306770	total: 7.53s	remaining: 45.5s
# 142:	learn: 0.5300661	total: 7.58s	remaining: 45.4s
# 143:	learn: 0.5295699	total: 7.63s	remaining: 45.3s
# 144:	learn: 0.5290554	total: 7.67s	remaining: 45.2s
# 145:	learn: 0.5285186	total: 7.72s	remaining: 45.2s
# 146:	learn: 0.5279710	total: 7.76s	remaining: 45.1s
# 147:	learn: 0.5273697	total: 7.81s	remaining: 45s
# 148:	learn: 0.5267798	total: 7.86s	remaining: 44.9s
# 149:	learn: 0.5262142	total: 7.91s	remaining: 44.8s
# 150:	learn: 0.5256628	total: 7.96s	remaining: 44.7s
# 151:	learn: 0.5251149	total: 8s	remaining: 44.7s
# 152:	learn: 0.5245737	total: 8.05s	remaining: 44.6s
# 153:	learn: 0.5240087	total: 8.1s	remaining: 44.5s
# 154:	learn: 0.5234734	total: 8.14s	remaining: 44.4s
# 155:	learn: 0.5229652	total: 8.2s	remaining: 44.4s
# 156:	learn: 0.5223847	total: 8.25s	remaining: 44.3s
# 157:	learn: 0.5218928	total: 8.3s	remaining: 44.2s
# 158:	learn: 0.5213600	total: 8.35s	remaining: 44.1s
# 159:	learn: 0.5208316	total: 8.41s	remaining: 44.1s
# 160:	learn: 0.5203172	total: 8.46s	remaining: 44.1s
# 161:	learn: 0.5198057	total: 8.52s	remaining: 44.1s
# 162:	learn: 0.5193433	total: 8.57s	remaining: 44s
# 163:	learn: 0.5188285	total: 8.62s	remaining: 44s
# 164:	learn: 0.5182739	total: 8.67s	remaining: 43.9s
# 165:	learn: 0.5177635	total: 8.73s	remaining: 43.9s
# 166:	learn: 0.5172521	total: 8.79s	remaining: 43.8s
# 167:	learn: 0.5167628	total: 8.84s	remaining: 43.8s
# 168:	learn: 0.5162769	total: 8.9s	remaining: 43.8s
# 169:	learn: 0.5157894	total: 8.96s	remaining: 43.8s
# 170:	learn: 0.5152893	total: 9.04s	remaining: 43.8s
# 171:	learn: 0.5147945	total: 9.09s	remaining: 43.7s
# 172:	learn: 0.5142957	total: 9.15s	remaining: 43.7s
# 173:	learn: 0.5137635	total: 9.19s	remaining: 43.6s
# 174:	learn: 0.5132508	total: 9.24s	remaining: 43.6s
# 175:	learn: 0.5128059	total: 9.33s	remaining: 43.7s
# 176:	learn: 0.5122934	total: 9.41s	remaining: 43.7s
# 177:	learn: 0.5117889	total: 9.48s	remaining: 43.8s
# 178:	learn: 0.5112869	total: 9.54s	remaining: 43.8s
# 179:	learn: 0.5108022	total: 9.6s	remaining: 43.7s
# 180:	learn: 0.5103215	total: 9.66s	remaining: 43.7s
# 181:	learn: 0.5098281	total: 9.71s	remaining: 43.6s
# 182:	learn: 0.5093498	total: 9.77s	remaining: 43.6s
# 183:	learn: 0.5088566	total: 9.82s	remaining: 43.5s
# 184:	learn: 0.5084249	total: 9.88s	remaining: 43.5s
# 185:	learn: 0.5079325	total: 9.93s	remaining: 43.5s
# 186:	learn: 0.5074603	total: 9.99s	remaining: 43.4s
# 187:	learn: 0.5069590	total: 10s	remaining: 43.4s
# 188:	learn: 0.5065149	total: 10.1s	remaining: 43.3s
# 189:	learn: 0.5060603	total: 10.2s	remaining: 43.3s
# 190:	learn: 0.5056051	total: 10.2s	remaining: 43.2s
# 191:	learn: 0.5051814	total: 10.3s	remaining: 43.2s
# 192:	learn: 0.5047460	total: 10.3s	remaining: 43.1s
# 193:	learn: 0.5042887	total: 10.4s	remaining: 43s
# 194:	learn: 0.5038107	total: 10.4s	remaining: 43s
# 195:	learn: 0.5033695	total: 10.5s	remaining: 42.9s
# 196:	learn: 0.5029328	total: 10.5s	remaining: 42.8s
# 197:	learn: 0.5024826	total: 10.6s	remaining: 42.7s
# 198:	learn: 0.5020693	total: 10.6s	remaining: 42.7s
# 199:	learn: 0.5016769	total: 10.7s	remaining: 42.6s
# 200:	learn: 0.5012346	total: 10.7s	remaining: 42.6s
# 201:	learn: 0.5008266	total: 10.8s	remaining: 42.5s
# 202:	learn: 0.5003312	total: 10.8s	remaining: 42.4s
# 203:	learn: 0.4999142	total: 10.9s	remaining: 42.4s
# 204:	learn: 0.4995057	total: 10.9s	remaining: 42.3s
# 205:	learn: 0.4990656	total: 11s	remaining: 42.2s
# 206:	learn: 0.4986425	total: 11s	remaining: 42.2s
# 207:	learn: 0.4982238	total: 11.1s	remaining: 42.1s
# 208:	learn: 0.4977678	total: 11.1s	remaining: 42.1s
# 209:	learn: 0.4973248	total: 11.2s	remaining: 42s
# 210:	learn: 0.4968721	total: 11.2s	remaining: 41.9s
# 211:	learn: 0.4964243	total: 11.3s	remaining: 41.9s
# 212:	learn: 0.4959865	total: 11.3s	remaining: 41.8s
# 213:	learn: 0.4955302	total: 11.4s	remaining: 41.8s
# 214:	learn: 0.4950748	total: 11.4s	remaining: 41.7s
# 215:	learn: 0.4946335	total: 11.5s	remaining: 41.7s
# 216:	learn: 0.4942135	total: 11.5s	remaining: 41.6s
# 217:	learn: 0.4938020	total: 11.6s	remaining: 41.6s
# 218:	learn: 0.4934098	total: 11.6s	remaining: 41.5s
# 219:	learn: 0.4929616	total: 11.7s	remaining: 41.5s
# 220:	learn: 0.4925502	total: 11.7s	remaining: 41.4s
# 221:	learn: 0.4921257	total: 11.8s	remaining: 41.3s
# 222:	learn: 0.4917681	total: 11.8s	remaining: 41.2s
# 223:	learn: 0.4913585	total: 11.9s	remaining: 41.2s
# 224:	learn: 0.4909264	total: 11.9s	remaining: 41.1s
# 225:	learn: 0.4904923	total: 12s	remaining: 41s
# 226:	learn: 0.4901056	total: 12s	remaining: 41s
# 227:	learn: 0.4896591	total: 12.1s	remaining: 40.9s
# 228:	learn: 0.4892481	total: 12.1s	remaining: 40.9s
# 229:	learn: 0.4888156	total: 12.2s	remaining: 40.8s
# 230:	learn: 0.4883942	total: 12.2s	remaining: 40.8s
# 231:	learn: 0.4879791	total: 12.3s	remaining: 40.7s
# 232:	learn: 0.4875812	total: 12.3s	remaining: 40.6s
# 233:	learn: 0.4871774	total: 12.4s	remaining: 40.5s
# 234:	learn: 0.4867906	total: 12.4s	remaining: 40.5s
# 235:	learn: 0.4863895	total: 12.5s	remaining: 40.4s
# 236:	learn: 0.4859741	total: 12.5s	remaining: 40.3s
# 237:	learn: 0.4856012	total: 12.6s	remaining: 40.3s
# 238:	learn: 0.4851939	total: 12.6s	remaining: 40.2s
# 239:	learn: 0.4848043	total: 12.7s	remaining: 40.2s
# 240:	learn: 0.4843819	total: 12.7s	remaining: 40.1s
# 241:	learn: 0.4839751	total: 12.8s	remaining: 40s
# 242:	learn: 0.4836095	total: 12.8s	remaining: 40s
# 243:	learn: 0.4831962	total: 12.9s	remaining: 39.9s
# 244:	learn: 0.4827842	total: 12.9s	remaining: 39.8s
# 245:	learn: 0.4824053	total: 13s	remaining: 39.8s
# 246:	learn: 0.4820045	total: 13s	remaining: 39.7s
# 247:	learn: 0.4815960	total: 13.1s	remaining: 39.7s
# 248:	learn: 0.4812195	total: 13.1s	remaining: 39.6s
# 249:	learn: 0.4808526	total: 13.2s	remaining: 39.6s
# 250:	learn: 0.4804764	total: 13.2s	remaining: 39.5s
# 251:	learn: 0.4800822	total: 13.3s	remaining: 39.5s
# 252:	learn: 0.4797107	total: 13.3s	remaining: 39.4s
# 253:	learn: 0.4792908	total: 13.4s	remaining: 39.3s
# 254:	learn: 0.4789423	total: 13.4s	remaining: 39.3s
# 255:	learn: 0.4785520	total: 13.5s	remaining: 39.2s
# 256:	learn: 0.4781321	total: 13.6s	remaining: 39.2s
# 257:	learn: 0.4777371	total: 13.6s	remaining: 39.1s
# 258:	learn: 0.4773386	total: 13.7s	remaining: 39.1s
# 259:	learn: 0.4769627	total: 13.7s	remaining: 39s
# 260:	learn: 0.4765614	total: 13.8s	remaining: 39s
# 261:	learn: 0.4761608	total: 13.8s	remaining: 38.9s
# 262:	learn: 0.4757585	total: 13.9s	remaining: 38.9s
# 263:	learn: 0.4753978	total: 13.9s	remaining: 38.8s
# 264:	learn: 0.4750318	total: 14s	remaining: 38.8s
# 265:	learn: 0.4746449	total: 14s	remaining: 38.7s
# 266:	learn: 0.4742600	total: 14.1s	remaining: 38.6s
# 267:	learn: 0.4738778	total: 14.1s	remaining: 38.6s
# 268:	learn: 0.4734627	total: 14.2s	remaining: 38.5s
# 269:	learn: 0.4730720	total: 14.2s	remaining: 38.4s
# 270:	learn: 0.4726899	total: 14.2s	remaining: 38.3s
# 271:	learn: 0.4722548	total: 14.3s	remaining: 38.3s
# 272:	learn: 0.4718417	total: 14.3s	remaining: 38.2s
# 273:	learn: 0.4714558	total: 14.4s	remaining: 38.1s
# 274:	learn: 0.4710443	total: 14.4s	remaining: 38s
# 275:	learn: 0.4706403	total: 14.5s	remaining: 38s
# 276:	learn: 0.4702669	total: 14.5s	remaining: 37.9s
# 277:	learn: 0.4698768	total: 14.6s	remaining: 37.8s
# 278:	learn: 0.4694831	total: 14.6s	remaining: 37.8s
# 279:	learn: 0.4690869	total: 14.7s	remaining: 37.7s
# 280:	learn: 0.4687137	total: 14.7s	remaining: 37.6s
# 281:	learn: 0.4683081	total: 14.7s	remaining: 37.5s
# 282:	learn: 0.4679330	total: 14.8s	remaining: 37.5s
# 283:	learn: 0.4675580	total: 14.8s	remaining: 37.4s
# 284:	learn: 0.4671663	total: 14.9s	remaining: 37.3s
# 285:	learn: 0.4668009	total: 14.9s	remaining: 37.3s
# 286:	learn: 0.4664044	total: 15s	remaining: 37.2s
# 287:	learn: 0.4659917	total: 15s	remaining: 37.2s
# 288:	learn: 0.4655850	total: 15.1s	remaining: 37.1s
# 289:	learn: 0.4652181	total: 15.1s	remaining: 37.1s
# 290:	learn: 0.4648244	total: 15.2s	remaining: 37s
# 291:	learn: 0.4644512	total: 15.2s	remaining: 37s
# 292:	learn: 0.4640638	total: 15.3s	remaining: 36.9s
# 293:	learn: 0.4636664	total: 15.3s	remaining: 36.8s
# 294:	learn: 0.4633042	total: 15.4s	remaining: 36.8s
# 295:	learn: 0.4628979	total: 15.4s	remaining: 36.7s
# 296:	learn: 0.4625142	total: 15.5s	remaining: 36.7s
# 297:	learn: 0.4621222	total: 15.5s	remaining: 36.6s
# 298:	learn: 0.4617457	total: 15.6s	remaining: 36.5s
# 299:	learn: 0.4613996	total: 15.6s	remaining: 36.5s
# 300:	learn: 0.4610349	total: 15.7s	remaining: 36.4s
# 301:	learn: 0.4606447	total: 15.7s	remaining: 36.3s
# 302:	learn: 0.4602818	total: 15.8s	remaining: 36.3s
# 303:	learn: 0.4599267	total: 15.8s	remaining: 36.2s
# 304:	learn: 0.4595330	total: 15.9s	remaining: 36.2s
# 305:	learn: 0.4591725	total: 15.9s	remaining: 36.1s
# 306:	learn: 0.4588119	total: 16s	remaining: 36.2s
# 307:	learn: 0.4584354	total: 16.2s	remaining: 36.4s
# 308:	learn: 0.4580789	total: 16.3s	remaining: 36.5s
# 309:	learn: 0.4576852	total: 16.4s	remaining: 36.6s
# 310:	learn: 0.4573028	total: 16.5s	remaining: 36.5s
# 311:	learn: 0.4569103	total: 16.5s	remaining: 36.5s
# 312:	learn: 0.4565559	total: 16.6s	remaining: 36.4s
# 313:	learn: 0.4561913	total: 16.6s	remaining: 36.3s
# 314:	learn: 0.4558116	total: 16.7s	remaining: 36.3s
# 315:	learn: 0.4554739	total: 16.7s	remaining: 36.2s
# 316:	learn: 0.4550969	total: 16.8s	remaining: 36.2s
# 317:	learn: 0.4547351	total: 16.8s	remaining: 36.1s
# 318:	learn: 0.4543846	total: 16.9s	remaining: 36.1s
# 319:	learn: 0.4540310	total: 17s	remaining: 36s
# 320:	learn: 0.4536923	total: 17s	remaining: 36s
# 321:	learn: 0.4533551	total: 17s	remaining: 35.9s
# 322:	learn: 0.4530016	total: 17.1s	remaining: 35.8s
# 323:	learn: 0.4526346	total: 17.2s	remaining: 35.8s
# 324:	learn: 0.4522589	total: 17.2s	remaining: 35.7s
# 325:	learn: 0.4519110	total: 17.3s	remaining: 35.7s
# 326:	learn: 0.4515711	total: 17.3s	remaining: 35.6s
# 327:	learn: 0.4512334	total: 17.4s	remaining: 35.6s
# 328:	learn: 0.4508673	total: 17.4s	remaining: 35.5s
# 329:	learn: 0.4505253	total: 17.5s	remaining: 35.5s
# 330:	learn: 0.4501572	total: 17.5s	remaining: 35.4s
# 331:	learn: 0.4497967	total: 17.6s	remaining: 35.3s
# 332:	learn: 0.4494444	total: 17.6s	remaining: 35.3s
# 333:	learn: 0.4491178	total: 17.7s	remaining: 35.3s
# 334:	learn: 0.4487359	total: 17.8s	remaining: 35.3s
# 335:	learn: 0.4483872	total: 17.9s	remaining: 35.3s
# 336:	learn: 0.4480301	total: 17.9s	remaining: 35.3s
# 337:	learn: 0.4476849	total: 18s	remaining: 35.2s
# 338:	learn: 0.4473120	total: 18.1s	remaining: 35.2s
# 339:	learn: 0.4469805	total: 18.1s	remaining: 35.2s
# 340:	learn: 0.4466360	total: 18.2s	remaining: 35.2s
# 341:	learn: 0.4462771	total: 18.3s	remaining: 35.2s
# 342:	learn: 0.4459237	total: 18.4s	remaining: 35.2s
# 343:	learn: 0.4455798	total: 18.5s	remaining: 35.2s
# 344:	learn: 0.4452262	total: 18.6s	remaining: 35.3s
# 345:	learn: 0.4449004	total: 18.6s	remaining: 35.2s
# 346:	learn: 0.4445787	total: 18.7s	remaining: 35.2s
# 347:	learn: 0.4442324	total: 18.8s	remaining: 35.2s
# 348:	learn: 0.4438720	total: 18.8s	remaining: 35.1s
# 349:	learn: 0.4435465	total: 18.9s	remaining: 35.1s
# 350:	learn: 0.4432185	total: 19s	remaining: 35s
# 351:	learn: 0.4428847	total: 19s	remaining: 35s
# 352:	learn: 0.4425439	total: 19.1s	remaining: 34.9s
# 353:	learn: 0.4422274	total: 19.1s	remaining: 34.9s
# 354:	learn: 0.4419092	total: 19.2s	remaining: 34.8s
# 355:	learn: 0.4415975	total: 19.3s	remaining: 34.8s
# 356:	learn: 0.4412516	total: 19.3s	remaining: 34.8s
# 357:	learn: 0.4409028	total: 19.4s	remaining: 34.7s
# 358:	learn: 0.4405848	total: 19.4s	remaining: 34.7s
# 359:	learn: 0.4402443	total: 19.5s	remaining: 34.6s
# 360:	learn: 0.4399178	total: 19.5s	remaining: 34.6s
# 361:	learn: 0.4396054	total: 19.6s	remaining: 34.5s
# 362:	learn: 0.4392774	total: 19.6s	remaining: 34.5s
# 363:	learn: 0.4389351	total: 19.7s	remaining: 34.4s
# 364:	learn: 0.4386147	total: 19.7s	remaining: 34.4s
# 365:	learn: 0.4383062	total: 19.8s	remaining: 34.3s
# 366:	learn: 0.4379890	total: 19.9s	remaining: 34.2s
# 367:	learn: 0.4376576	total: 19.9s	remaining: 34.2s
# 368:	learn: 0.4373488	total: 20s	remaining: 34.2s
# 369:	learn: 0.4369909	total: 20.1s	remaining: 34.3s
# 370:	learn: 0.4366637	total: 20.2s	remaining: 34.3s
# 371:	learn: 0.4363508	total: 20.3s	remaining: 34.3s
# 372:	learn: 0.4360375	total: 20.4s	remaining: 34.3s
# 373:	learn: 0.4357277	total: 20.5s	remaining: 34.2s
# 374:	learn: 0.4354227	total: 20.5s	remaining: 34.2s
# 375:	learn: 0.4351026	total: 20.6s	remaining: 34.2s
# 376:	learn: 0.4347743	total: 20.7s	remaining: 34.1s
# 377:	learn: 0.4344512	total: 20.7s	remaining: 34.1s
# 378:	learn: 0.4341452	total: 20.8s	remaining: 34.1s
# 379:	learn: 0.4338158	total: 20.9s	remaining: 34s
# 380:	learn: 0.4334922	total: 20.9s	remaining: 34s
# 381:	learn: 0.4331748	total: 21s	remaining: 34s
# 382:	learn: 0.4328683	total: 21.1s	remaining: 33.9s
# 383:	learn: 0.4325272	total: 21.1s	remaining: 33.9s
# 384:	learn: 0.4322221	total: 21.2s	remaining: 33.9s
# 385:	learn: 0.4318946	total: 21.3s	remaining: 33.8s
# 386:	learn: 0.4315902	total: 21.3s	remaining: 33.8s
# 387:	learn: 0.4312457	total: 21.4s	remaining: 33.7s
# 388:	learn: 0.4309474	total: 21.4s	remaining: 33.7s
# 389:	learn: 0.4306334	total: 21.5s	remaining: 33.6s
# 390:	learn: 0.4303258	total: 21.6s	remaining: 33.6s
# 391:	learn: 0.4300346	total: 21.6s	remaining: 33.5s
# 392:	learn: 0.4297598	total: 21.7s	remaining: 33.5s
# 393:	learn: 0.4294530	total: 21.7s	remaining: 33.4s
# 394:	learn: 0.4291667	total: 21.8s	remaining: 33.4s
# 395:	learn: 0.4288368	total: 21.9s	remaining: 33.3s
# 396:	learn: 0.4285114	total: 21.9s	remaining: 33.3s
# 397:	learn: 0.4281910	total: 22s	remaining: 33.3s
# 398:	learn: 0.4279151	total: 22.1s	remaining: 33.2s
# 399:	learn: 0.4275814	total: 22.2s	remaining: 33.2s
# 400:	learn: 0.4273284	total: 22.2s	remaining: 33.2s
# 401:	learn: 0.4270624	total: 22.3s	remaining: 33.1s
# 402:	learn: 0.4267720	total: 22.3s	remaining: 33.1s
# 403:	learn: 0.4264722	total: 22.4s	remaining: 33s
# 404:	learn: 0.4261916	total: 22.4s	remaining: 33s
# 405:	learn: 0.4258828	total: 22.5s	remaining: 32.9s
# 406:	learn: 0.4255973	total: 22.6s	remaining: 32.9s
# 407:	learn: 0.4252958	total: 22.6s	remaining: 32.8s
# 408:	learn: 0.4250085	total: 22.7s	remaining: 32.8s
# 409:	learn: 0.4247149	total: 22.8s	remaining: 32.8s
# 410:	learn: 0.4244118	total: 22.8s	remaining: 32.7s
# 411:	learn: 0.4241038	total: 22.9s	remaining: 32.7s
# 412:	learn: 0.4237870	total: 23s	remaining: 32.6s
# 413:	learn: 0.4234827	total: 23s	remaining: 32.6s
# 414:	learn: 0.4231710	total: 23.1s	remaining: 32.6s
# 415:	learn: 0.4228900	total: 23.2s	remaining: 32.5s
# 416:	learn: 0.4225975	total: 23.2s	remaining: 32.5s
# 417:	learn: 0.4222990	total: 23.3s	remaining: 32.4s
# 418:	learn: 0.4220166	total: 23.4s	remaining: 32.4s
# 419:	learn: 0.4217411	total: 23.4s	remaining: 32.3s
# 420:	learn: 0.4214674	total: 23.5s	remaining: 32.3s
# 421:	learn: 0.4211481	total: 23.6s	remaining: 32.3s
# 422:	learn: 0.4208470	total: 23.6s	remaining: 32.2s
# 423:	learn: 0.4205885	total: 23.7s	remaining: 32.2s
# 424:	learn: 0.4203144	total: 23.8s	remaining: 32.2s
# 425:	learn: 0.4200159	total: 23.8s	remaining: 32.1s
# 426:	learn: 0.4197378	total: 23.9s	remaining: 32s
# 427:	learn: 0.4194599	total: 24s	remaining: 32s
# 428:	learn: 0.4191740	total: 24s	remaining: 32s
# 429:	learn: 0.4188764	total: 24.1s	remaining: 31.9s
# 430:	learn: 0.4185960	total: 24.1s	remaining: 31.9s
# 431:	learn: 0.4183147	total: 24.2s	remaining: 31.8s
# 432:	learn: 0.4180379	total: 24.2s	remaining: 31.7s
# 433:	learn: 0.4177400	total: 24.3s	remaining: 31.7s
# 434:	learn: 0.4174521	total: 24.4s	remaining: 31.6s
# 435:	learn: 0.4171851	total: 24.4s	remaining: 31.6s
# 436:	learn: 0.4168926	total: 24.5s	remaining: 31.5s
# 437:	learn: 0.4166053	total: 24.5s	remaining: 31.5s
# 438:	learn: 0.4163440	total: 24.6s	remaining: 31.4s
# 439:	learn: 0.4160464	total: 24.7s	remaining: 31.4s
# 440:	learn: 0.4157219	total: 24.7s	remaining: 31.3s
# 441:	learn: 0.4154451	total: 24.8s	remaining: 31.3s
# 442:	learn: 0.4151746	total: 24.8s	remaining: 31.2s
# 443:	learn: 0.4149045	total: 24.9s	remaining: 31.2s
# 444:	learn: 0.4146078	total: 24.9s	remaining: 31.1s
# 445:	learn: 0.4143481	total: 25s	remaining: 31.1s
# 446:	learn: 0.4140928	total: 25.1s	remaining: 31s
# 447:	learn: 0.4138082	total: 25.1s	remaining: 30.9s
# 448:	learn: 0.4135238	total: 25.2s	remaining: 30.9s
# 449:	learn: 0.4132421	total: 25.2s	remaining: 30.8s
# 450:	learn: 0.4129551	total: 25.3s	remaining: 30.8s
# 451:	learn: 0.4126694	total: 25.4s	remaining: 30.7s
# 452:	learn: 0.4124028	total: 25.4s	remaining: 30.7s
# 453:	learn: 0.4121371	total: 25.5s	remaining: 30.6s
# 454:	learn: 0.4118476	total: 25.5s	remaining: 30.5s
# 455:	learn: 0.4115933	total: 25.6s	remaining: 30.5s
# 456:	learn: 0.4113350	total: 25.6s	remaining: 30.4s
# 457:	learn: 0.4110431	total: 25.7s	remaining: 30.4s
# 458:	learn: 0.4107638	total: 25.7s	remaining: 30.3s
# 459:	learn: 0.4104715	total: 25.8s	remaining: 30.3s
# 460:	learn: 0.4102043	total: 25.8s	remaining: 30.2s
# 461:	learn: 0.4099298	total: 25.9s	remaining: 30.1s
# 462:	learn: 0.4096629	total: 25.9s	remaining: 30.1s
# 463:	learn: 0.4094104	total: 26s	remaining: 30s
# 464:	learn: 0.4091654	total: 26s	remaining: 30s
# 465:	learn: 0.4088650	total: 26.1s	remaining: 29.9s
# 466:	learn: 0.4086092	total: 26.1s	remaining: 29.8s
# 467:	learn: 0.4083303	total: 26.2s	remaining: 29.8s
# 468:	learn: 0.4080885	total: 26.2s	remaining: 29.7s
# 469:	learn: 0.4078357	total: 26.3s	remaining: 29.7s
# 470:	learn: 0.4075787	total: 26.4s	remaining: 29.6s
# 471:	learn: 0.4073163	total: 26.4s	remaining: 29.5s
# 472:	learn: 0.4070533	total: 26.5s	remaining: 29.5s
# 473:	learn: 0.4068025	total: 26.5s	remaining: 29.4s
# 474:	learn: 0.4065332	total: 26.6s	remaining: 29.4s
# 475:	learn: 0.4062610	total: 26.6s	remaining: 29.3s
# 476:	learn: 0.4060086	total: 26.7s	remaining: 29.2s
# 477:	learn: 0.4057287	total: 26.7s	remaining: 29.2s
# 478:	learn: 0.4054968	total: 26.8s	remaining: 29.1s
# 479:	learn: 0.4052453	total: 26.8s	remaining: 29s
# 480:	learn: 0.4049790	total: 26.9s	remaining: 29s
# 481:	learn: 0.4047136	total: 26.9s	remaining: 28.9s
# 482:	learn: 0.4044385	total: 27s	remaining: 28.9s
# 483:	learn: 0.4041714	total: 27s	remaining: 28.8s
# 484:	learn: 0.4039012	total: 27.1s	remaining: 28.7s
# 485:	learn: 0.4036416	total: 27.1s	remaining: 28.7s
# 486:	learn: 0.4033760	total: 27.2s	remaining: 28.6s
# 487:	learn: 0.4031318	total: 27.2s	remaining: 28.6s
# 488:	learn: 0.4028893	total: 27.3s	remaining: 28.5s
# 489:	learn: 0.4025923	total: 27.3s	remaining: 28.4s
# 490:	learn: 0.4023406	total: 27.4s	remaining: 28.4s
# 491:	learn: 0.4020787	total: 27.4s	remaining: 28.3s
# 492:	learn: 0.4018209	total: 27.5s	remaining: 28.3s
# 493:	learn: 0.4015819	total: 27.5s	remaining: 28.2s
# 494:	learn: 0.4013226	total: 27.6s	remaining: 28.1s
# 495:	learn: 0.4010670	total: 27.6s	remaining: 28.1s
# 496:	learn: 0.4008243	total: 27.7s	remaining: 28s
# 497:	learn: 0.4005767	total: 27.8s	remaining: 28s
# 498:	learn: 0.4003403	total: 27.8s	remaining: 27.9s
# 499:	learn: 0.4000809	total: 27.9s	remaining: 27.9s
# 500:	learn: 0.3998153	total: 27.9s	remaining: 27.8s
# 501:	learn: 0.3995538	total: 28s	remaining: 27.7s
# 502:	learn: 0.3992957	total: 28s	remaining: 27.7s
# 503:	learn: 0.3990421	total: 28.1s	remaining: 27.6s
# 504:	learn: 0.3988023	total: 28.1s	remaining: 27.6s
# 505:	learn: 0.3985574	total: 28.2s	remaining: 27.5s
# 506:	learn: 0.3982928	total: 28.2s	remaining: 27.5s
# 507:	learn: 0.3980468	total: 28.3s	remaining: 27.4s
# 508:	learn: 0.3977958	total: 28.3s	remaining: 27.3s
# 509:	learn: 0.3975556	total: 28.4s	remaining: 27.3s
# 510:	learn: 0.3973012	total: 28.5s	remaining: 27.2s
# 511:	learn: 0.3970278	total: 28.5s	remaining: 27.2s
# 512:	learn: 0.3967512	total: 28.6s	remaining: 27.1s
# 513:	learn: 0.3964863	total: 28.6s	remaining: 27.1s
# 514:	learn: 0.3962439	total: 28.7s	remaining: 27s
# 515:	learn: 0.3960157	total: 28.8s	remaining: 27s
# 516:	learn: 0.3957689	total: 28.8s	remaining: 26.9s
# 517:	learn: 0.3954905	total: 28.9s	remaining: 26.9s
# 518:	learn: 0.3952572	total: 28.9s	remaining: 26.8s
# 519:	learn: 0.3950258	total: 29s	remaining: 26.7s
# 520:	learn: 0.3948192	total: 29s	remaining: 26.7s
# 521:	learn: 0.3945331	total: 29.1s	remaining: 26.6s
# 522:	learn: 0.3942822	total: 29.1s	remaining: 26.6s
# 523:	learn: 0.3940363	total: 29.2s	remaining: 26.5s
# 524:	learn: 0.3937927	total: 29.3s	remaining: 26.5s
# 525:	learn: 0.3935437	total: 29.3s	remaining: 26.4s
# 526:	learn: 0.3932954	total: 29.4s	remaining: 26.4s
# 527:	learn: 0.3930630	total: 29.4s	remaining: 26.3s
# 528:	learn: 0.3928163	total: 29.5s	remaining: 26.3s
# 529:	learn: 0.3925713	total: 29.6s	remaining: 26.2s
# 530:	learn: 0.3923192	total: 29.6s	remaining: 26.2s
# 531:	learn: 0.3920737	total: 29.7s	remaining: 26.1s
# 532:	learn: 0.3918223	total: 29.7s	remaining: 26s
# 533:	learn: 0.3915784	total: 29.8s	remaining: 26s
# 534:	learn: 0.3913450	total: 29.9s	remaining: 25.9s
# 535:	learn: 0.3910982	total: 29.9s	remaining: 25.9s
# 536:	learn: 0.3908714	total: 30s	remaining: 25.8s
# 537:	learn: 0.3906381	total: 30s	remaining: 25.8s
# 538:	learn: 0.3903862	total: 30.1s	remaining: 25.7s
# 539:	learn: 0.3901474	total: 30.1s	remaining: 25.7s
# 540:	learn: 0.3899052	total: 30.2s	remaining: 25.6s
# 541:	learn: 0.3896543	total: 30.2s	remaining: 25.6s
# 542:	learn: 0.3894158	total: 30.3s	remaining: 25.5s
# 543:	learn: 0.3891759	total: 30.4s	remaining: 25.5s
# 544:	learn: 0.3889141	total: 30.4s	remaining: 25.4s
# 545:	learn: 0.3886879	total: 30.5s	remaining: 25.4s
# 546:	learn: 0.3884520	total: 30.5s	remaining: 25.3s
# 547:	learn: 0.3882327	total: 30.6s	remaining: 25.2s
# 548:	learn: 0.3879799	total: 30.7s	remaining: 25.2s
# 549:	learn: 0.3877541	total: 30.7s	remaining: 25.1s
# 550:	learn: 0.3875172	total: 30.8s	remaining: 25.1s
# 551:	learn: 0.3872931	total: 30.8s	remaining: 25s
# 552:	learn: 0.3870546	total: 30.9s	remaining: 25s
# 553:	learn: 0.3867959	total: 30.9s	remaining: 24.9s
# 554:	learn: 0.3865577	total: 31s	remaining: 24.9s
# 555:	learn: 0.3863377	total: 31.1s	remaining: 24.8s
# 556:	learn: 0.3860794	total: 31.1s	remaining: 24.7s
# 557:	learn: 0.3858484	total: 31.2s	remaining: 24.7s
# 558:	learn: 0.3856070	total: 31.2s	remaining: 24.6s
# 559:	learn: 0.3853715	total: 31.3s	remaining: 24.6s
# 560:	learn: 0.3851160	total: 31.3s	remaining: 24.5s
# 561:	learn: 0.3848484	total: 31.4s	remaining: 24.5s
# 562:	learn: 0.3846096	total: 31.5s	remaining: 24.4s
# 563:	learn: 0.3843712	total: 31.5s	remaining: 24.4s
# 564:	learn: 0.3841188	total: 31.6s	remaining: 24.3s
# 565:	learn: 0.3838899	total: 31.6s	remaining: 24.3s
# 566:	learn: 0.3836512	total: 31.7s	remaining: 24.2s
# 567:	learn: 0.3834235	total: 31.7s	remaining: 24.1s
# 568:	learn: 0.3831966	total: 31.8s	remaining: 24.1s
# 569:	learn: 0.3829668	total: 31.9s	remaining: 24s
# 570:	learn: 0.3827465	total: 31.9s	remaining: 24s
# 571:	learn: 0.3824945	total: 32s	remaining: 23.9s
# 572:	learn: 0.3822678	total: 32s	remaining: 23.9s
# 573:	learn: 0.3820388	total: 32.1s	remaining: 23.8s
# 574:	learn: 0.3818072	total: 32.1s	remaining: 23.8s
# 575:	learn: 0.3815635	total: 32.2s	remaining: 23.7s
# 576:	learn: 0.3813456	total: 32.3s	remaining: 23.6s
# 577:	learn: 0.3811300	total: 32.3s	remaining: 23.6s
# 578:	learn: 0.3808840	total: 32.4s	remaining: 23.5s
# 579:	learn: 0.3806456	total: 32.4s	remaining: 23.5s
# 580:	learn: 0.3804513	total: 32.5s	remaining: 23.4s
# 581:	learn: 0.3802344	total: 32.5s	remaining: 23.4s
# 582:	learn: 0.3799911	total: 32.6s	remaining: 23.3s
# 583:	learn: 0.3797310	total: 32.7s	remaining: 23.3s
# 584:	learn: 0.3794717	total: 32.7s	remaining: 23.2s
# 585:	learn: 0.3792294	total: 32.8s	remaining: 23.2s
# 586:	learn: 0.3790051	total: 32.9s	remaining: 23.1s
# 587:	learn: 0.3788076	total: 32.9s	remaining: 23.1s
# 588:	learn: 0.3785698	total: 33s	remaining: 23s
# 589:	learn: 0.3783285	total: 33s	remaining: 22.9s
# 590:	learn: 0.3781179	total: 33.1s	remaining: 22.9s
# 591:	learn: 0.3779093	total: 33.1s	remaining: 22.8s
# 592:	learn: 0.3776643	total: 33.2s	remaining: 22.8s
# 593:	learn: 0.3774286	total: 33.3s	remaining: 22.7s
# 594:	learn: 0.3772059	total: 33.3s	remaining: 22.7s
# 595:	learn: 0.3769934	total: 33.4s	remaining: 22.6s
# 596:	learn: 0.3767556	total: 33.4s	remaining: 22.6s
# 597:	learn: 0.3765555	total: 33.5s	remaining: 22.5s
# 598:	learn: 0.3763351	total: 33.6s	remaining: 22.5s
# 599:	learn: 0.3761072	total: 33.6s	remaining: 22.4s
# 600:	learn: 0.3758845	total: 33.7s	remaining: 22.4s
# 601:	learn: 0.3756531	total: 33.8s	remaining: 22.3s
# 602:	learn: 0.3754144	total: 33.8s	remaining: 22.3s
# 603:	learn: 0.3751996	total: 33.9s	remaining: 22.2s
# 604:	learn: 0.3749712	total: 34s	remaining: 22.2s
# 605:	learn: 0.3747468	total: 34s	remaining: 22.1s
# 606:	learn: 0.3745425	total: 34.1s	remaining: 22.1s
# 607:	learn: 0.3743309	total: 34.1s	remaining: 22s
# 608:	learn: 0.3741270	total: 34.2s	remaining: 22s
# 609:	learn: 0.3738945	total: 34.3s	remaining: 21.9s
# 610:	learn: 0.3736644	total: 34.3s	remaining: 21.8s
# 611:	learn: 0.3734226	total: 34.4s	remaining: 21.8s
# 612:	learn: 0.3732151	total: 34.4s	remaining: 21.7s
# 613:	learn: 0.3730262	total: 34.5s	remaining: 21.7s
# 614:	learn: 0.3727992	total: 34.5s	remaining: 21.6s
# 615:	learn: 0.3725748	total: 34.6s	remaining: 21.6s
# 616:	learn: 0.3723594	total: 34.6s	remaining: 21.5s
# 617:	learn: 0.3721507	total: 34.7s	remaining: 21.4s
# 618:	learn: 0.3719126	total: 34.7s	remaining: 21.4s
# 619:	learn: 0.3717194	total: 34.8s	remaining: 21.3s
# 620:	learn: 0.3715102	total: 34.8s	remaining: 21.3s
# 621:	learn: 0.3712917	total: 34.9s	remaining: 21.2s
# 622:	learn: 0.3710605	total: 34.9s	remaining: 21.1s
# 623:	learn: 0.3708128	total: 35s	remaining: 21.1s
# 624:	learn: 0.3705847	total: 35s	remaining: 21s
# 625:	learn: 0.3703620	total: 35.1s	remaining: 21s
# 626:	learn: 0.3701342	total: 35.1s	remaining: 20.9s
# 627:	learn: 0.3699197	total: 35.2s	remaining: 20.9s
# 628:	learn: 0.3697077	total: 35.3s	remaining: 20.8s
# 629:	learn: 0.3694895	total: 35.3s	remaining: 20.7s
# 630:	learn: 0.3692961	total: 35.4s	remaining: 20.7s
# 631:	learn: 0.3690814	total: 35.4s	remaining: 20.6s
# 632:	learn: 0.3688763	total: 35.5s	remaining: 20.6s
# 633:	learn: 0.3686424	total: 35.5s	remaining: 20.5s
# 634:	learn: 0.3684420	total: 35.6s	remaining: 20.4s
# 635:	learn: 0.3682264	total: 35.6s	remaining: 20.4s
# 636:	learn: 0.3680345	total: 35.7s	remaining: 20.3s
# 637:	learn: 0.3678063	total: 35.7s	remaining: 20.3s
# 638:	learn: 0.3676115	total: 35.8s	remaining: 20.2s
# 639:	learn: 0.3674055	total: 35.8s	remaining: 20.2s
# 640:	learn: 0.3671956	total: 35.9s	remaining: 20.1s
# 641:	learn: 0.3670058	total: 36s	remaining: 20.1s
# 642:	learn: 0.3668024	total: 36s	remaining: 20s
# 643:	learn: 0.3665820	total: 36.1s	remaining: 19.9s
# 644:	learn: 0.3663589	total: 36.1s	remaining: 19.9s
# 645:	learn: 0.3661668	total: 36.2s	remaining: 19.8s
# 646:	learn: 0.3659641	total: 36.2s	remaining: 19.8s
# 647:	learn: 0.3657365	total: 36.3s	remaining: 19.7s
# 648:	learn: 0.3655084	total: 36.4s	remaining: 19.7s
# 649:	learn: 0.3653148	total: 36.5s	remaining: 19.6s
# 650:	learn: 0.3651229	total: 36.5s	remaining: 19.6s
# 651:	learn: 0.3648987	total: 36.6s	remaining: 19.5s
# 652:	learn: 0.3646851	total: 36.6s	remaining: 19.5s
# 653:	learn: 0.3644967	total: 36.7s	remaining: 19.4s
# 654:	learn: 0.3643035	total: 36.7s	remaining: 19.4s
# 655:	learn: 0.3640772	total: 36.8s	remaining: 19.3s
# 656:	learn: 0.3638529	total: 36.9s	remaining: 19.2s
# 657:	learn: 0.3636274	total: 36.9s	remaining: 19.2s
# 658:	learn: 0.3634478	total: 37s	remaining: 19.1s
# 659:	learn: 0.3632303	total: 37s	remaining: 19.1s
# 660:	learn: 0.3630309	total: 37.1s	remaining: 19s
# 661:	learn: 0.3628068	total: 37.1s	remaining: 19s
# 662:	learn: 0.3625979	total: 37.2s	remaining: 18.9s
# 663:	learn: 0.3623796	total: 37.3s	remaining: 18.9s
# 664:	learn: 0.3621692	total: 37.3s	remaining: 18.8s
# 665:	learn: 0.3619496	total: 37.4s	remaining: 18.7s
# 666:	learn: 0.3617428	total: 37.4s	remaining: 18.7s
# 667:	learn: 0.3615511	total: 37.5s	remaining: 18.6s
# 668:	learn: 0.3613469	total: 37.5s	remaining: 18.6s
# 669:	learn: 0.3611401	total: 37.6s	remaining: 18.5s
# 670:	learn: 0.3609355	total: 37.6s	remaining: 18.4s
# 671:	learn: 0.3607142	total: 37.7s	remaining: 18.4s
# 672:	learn: 0.3604914	total: 37.7s	remaining: 18.3s
# 673:	learn: 0.3602764	total: 37.8s	remaining: 18.3s
# 674:	learn: 0.3600666	total: 37.8s	remaining: 18.2s
# 675:	learn: 0.3598313	total: 37.9s	remaining: 18.2s
# 676:	learn: 0.3596342	total: 38s	remaining: 18.1s
# 677:	learn: 0.3594516	total: 38s	remaining: 18s
# 678:	learn: 0.3592800	total: 38.1s	remaining: 18s
# 679:	learn: 0.3590718	total: 38.1s	remaining: 17.9s
# 680:	learn: 0.3588789	total: 38.2s	remaining: 17.9s
# 681:	learn: 0.3586420	total: 38.2s	remaining: 17.8s
# 682:	learn: 0.3584511	total: 38.3s	remaining: 17.8s
# 683:	learn: 0.3582492	total: 38.3s	remaining: 17.7s
# 684:	learn: 0.3580428	total: 38.4s	remaining: 17.7s
# 685:	learn: 0.3578303	total: 38.5s	remaining: 17.6s
# 686:	learn: 0.3576156	total: 38.5s	remaining: 17.5s
# 687:	learn: 0.3573988	total: 38.6s	remaining: 17.5s
# 688:	learn: 0.3571965	total: 38.6s	remaining: 17.4s
# 689:	learn: 0.3569850	total: 38.7s	remaining: 17.4s
# 690:	learn: 0.3567958	total: 38.7s	remaining: 17.3s
# 691:	learn: 0.3566000	total: 38.8s	remaining: 17.3s
# 692:	learn: 0.3564238	total: 38.8s	remaining: 17.2s
# 693:	learn: 0.3562095	total: 38.9s	remaining: 17.1s
# 694:	learn: 0.3560150	total: 38.9s	remaining: 17.1s
# 695:	learn: 0.3558377	total: 39s	remaining: 17s
# 696:	learn: 0.3556300	total: 39s	remaining: 17s
# 697:	learn: 0.3554463	total: 39.1s	remaining: 16.9s
# 698:	learn: 0.3552527	total: 39.1s	remaining: 16.9s
# 699:	learn: 0.3550275	total: 39.2s	remaining: 16.8s
# 700:	learn: 0.3548324	total: 39.2s	remaining: 16.7s
# 701:	learn: 0.3546227	total: 39.3s	remaining: 16.7s
# 702:	learn: 0.3544657	total: 39.3s	remaining: 16.6s
# 703:	learn: 0.3542574	total: 39.4s	remaining: 16.6s
# 704:	learn: 0.3540376	total: 39.4s	remaining: 16.5s
# 705:	learn: 0.3538522	total: 39.5s	remaining: 16.5s
# 706:	learn: 0.3536384	total: 39.6s	remaining: 16.4s
# 707:	learn: 0.3534521	total: 39.6s	remaining: 16.3s
# 708:	learn: 0.3532410	total: 39.7s	remaining: 16.3s
# 709:	learn: 0.3530328	total: 39.7s	remaining: 16.2s
# 710:	learn: 0.3528385	total: 39.8s	remaining: 16.2s
# 711:	learn: 0.3526545	total: 39.8s	remaining: 16.1s
# 712:	learn: 0.3524623	total: 39.9s	remaining: 16.1s
# 713:	learn: 0.3522470	total: 40s	remaining: 16s
# 714:	learn: 0.3520133	total: 40s	remaining: 15.9s
# 715:	learn: 0.3518210	total: 40.1s	remaining: 15.9s
# 716:	learn: 0.3516037	total: 40.1s	remaining: 15.8s
# 717:	learn: 0.3514207	total: 40.2s	remaining: 15.8s
# 718:	learn: 0.3512398	total: 40.2s	remaining: 15.7s
# 719:	learn: 0.3510362	total: 40.3s	remaining: 15.7s
# 720:	learn: 0.3508303	total: 40.4s	remaining: 15.6s
# 721:	learn: 0.3506453	total: 40.4s	remaining: 15.6s
# 722:	learn: 0.3504410	total: 40.5s	remaining: 15.5s
# 723:	learn: 0.3502577	total: 40.5s	remaining: 15.4s
# 724:	learn: 0.3500653	total: 40.6s	remaining: 15.4s
# 725:	learn: 0.3498614	total: 40.6s	remaining: 15.3s
# 726:	learn: 0.3496475	total: 40.7s	remaining: 15.3s
# 727:	learn: 0.3494546	total: 40.7s	remaining: 15.2s
# 728:	learn: 0.3492714	total: 40.8s	remaining: 15.2s
# 729:	learn: 0.3490899	total: 40.8s	remaining: 15.1s
# 730:	learn: 0.3489109	total: 40.9s	remaining: 15s
# 731:	learn: 0.3487311	total: 40.9s	remaining: 15s
# 732:	learn: 0.3485195	total: 41s	remaining: 14.9s
# 733:	learn: 0.3483453	total: 41.1s	remaining: 14.9s
# 734:	learn: 0.3481512	total: 41.1s	remaining: 14.8s
# 735:	learn: 0.3479766	total: 41.2s	remaining: 14.8s
# 736:	learn: 0.3477600	total: 41.2s	remaining: 14.7s
# 737:	learn: 0.3475646	total: 41.3s	remaining: 14.7s
# 738:	learn: 0.3473668	total: 41.3s	remaining: 14.6s
# 739:	learn: 0.3471801	total: 41.4s	remaining: 14.5s
# 740:	learn: 0.3469620	total: 41.5s	remaining: 14.5s
# 741:	learn: 0.3467803	total: 41.5s	remaining: 14.4s
# 742:	learn: 0.3465695	total: 41.6s	remaining: 14.4s
# 743:	learn: 0.3463955	total: 41.6s	remaining: 14.3s
# 744:	learn: 0.3462012	total: 41.7s	remaining: 14.3s
# 745:	learn: 0.3460068	total: 41.8s	remaining: 14.2s
# 746:	learn: 0.3458424	total: 41.8s	remaining: 14.2s
# 747:	learn: 0.3456731	total: 41.9s	remaining: 14.1s
# 748:	learn: 0.3454662	total: 41.9s	remaining: 14.1s
# 749:	learn: 0.3452519	total: 42s	remaining: 14s
# 750:	learn: 0.3450726	total: 42s	remaining: 13.9s
# 751:	learn: 0.3448765	total: 42.1s	remaining: 13.9s
# 752:	learn: 0.3447020	total: 42.2s	remaining: 13.8s
# 753:	learn: 0.3445281	total: 42.2s	remaining: 13.8s
# 754:	learn: 0.3443313	total: 42.3s	remaining: 13.7s
# 755:	learn: 0.3441538	total: 42.3s	remaining: 13.7s
# 756:	learn: 0.3439675	total: 42.4s	remaining: 13.6s
# 757:	learn: 0.3437563	total: 42.5s	remaining: 13.6s
# 758:	learn: 0.3435582	total: 42.5s	remaining: 13.5s
# 759:	learn: 0.3433429	total: 42.6s	remaining: 13.4s
# 760:	learn: 0.3431400	total: 42.6s	remaining: 13.4s
# 761:	learn: 0.3429507	total: 42.7s	remaining: 13.3s
# 762:	learn: 0.3427741	total: 42.8s	remaining: 13.3s
# 763:	learn: 0.3425818	total: 42.8s	remaining: 13.2s
# 764:	learn: 0.3423842	total: 42.9s	remaining: 13.2s
# 765:	learn: 0.3422264	total: 43s	remaining: 13.1s
# 766:	learn: 0.3420346	total: 43s	remaining: 13.1s
# 767:	learn: 0.3418725	total: 43.1s	remaining: 13s
# 768:	learn: 0.3416532	total: 43.2s	remaining: 13s
# 769:	learn: 0.3414837	total: 43.2s	remaining: 12.9s
# 770:	learn: 0.3413076	total: 43.3s	remaining: 12.9s
# 771:	learn: 0.3411212	total: 43.4s	remaining: 12.8s
# 772:	learn: 0.3409373	total: 43.4s	remaining: 12.7s
# 773:	learn: 0.3407642	total: 43.5s	remaining: 12.7s
# 774:	learn: 0.3405853	total: 43.5s	remaining: 12.6s
# 775:	learn: 0.3404013	total: 43.6s	remaining: 12.6s
# 776:	learn: 0.3402309	total: 43.6s	remaining: 12.5s
# 777:	learn: 0.3400418	total: 43.7s	remaining: 12.5s
# 778:	learn: 0.3398566	total: 43.8s	remaining: 12.4s
# 779:	learn: 0.3396829	total: 43.8s	remaining: 12.4s
# 780:	learn: 0.3395205	total: 43.9s	remaining: 12.3s
# 781:	learn: 0.3393191	total: 43.9s	remaining: 12.2s
# 782:	learn: 0.3391358	total: 44s	remaining: 12.2s
# 783:	learn: 0.3389547	total: 44s	remaining: 12.1s
# 784:	learn: 0.3387622	total: 44.1s	remaining: 12.1s
# 785:	learn: 0.3385640	total: 44.1s	remaining: 12s
# 786:	learn: 0.3383913	total: 44.1s	remaining: 11.9s
# 787:	learn: 0.3382319	total: 44.2s	remaining: 11.9s
# 788:	learn: 0.3380531	total: 44.3s	remaining: 11.8s
# 789:	learn: 0.3378843	total: 44.3s	remaining: 11.8s
# 790:	learn: 0.3376870	total: 44.4s	remaining: 11.7s
# 791:	learn: 0.3374928	total: 44.4s	remaining: 11.7s
# 792:	learn: 0.3373359	total: 44.5s	remaining: 11.6s
# 793:	learn: 0.3371572	total: 44.6s	remaining: 11.6s
# 794:	learn: 0.3369778	total: 44.6s	remaining: 11.5s
# 795:	learn: 0.3367760	total: 44.7s	remaining: 11.5s
# 796:	learn: 0.3365979	total: 44.8s	remaining: 11.4s
# 797:	learn: 0.3364134	total: 44.8s	remaining: 11.3s
# 798:	learn: 0.3362421	total: 44.9s	remaining: 11.3s
# 799:	learn: 0.3360598	total: 45s	remaining: 11.2s
# 800:	learn: 0.3358966	total: 45s	remaining: 11.2s
# 801:	learn: 0.3356987	total: 45.1s	remaining: 11.1s
# 802:	learn: 0.3355327	total: 45.2s	remaining: 11.1s
# 803:	learn: 0.3353536	total: 45.2s	remaining: 11s
# 804:	learn: 0.3351790	total: 45.3s	remaining: 11s
# 805:	learn: 0.3350122	total: 45.4s	remaining: 10.9s
# 806:	learn: 0.3348434	total: 45.4s	remaining: 10.9s
# 807:	learn: 0.3346473	total: 45.5s	remaining: 10.8s
# 808:	learn: 0.3344711	total: 45.5s	remaining: 10.8s
# 809:	learn: 0.3343012	total: 45.6s	remaining: 10.7s
# 810:	learn: 0.3341249	total: 45.7s	remaining: 10.6s
# 811:	learn: 0.3339360	total: 45.7s	remaining: 10.6s
# 812:	learn: 0.3337637	total: 45.8s	remaining: 10.5s
# 813:	learn: 0.3335908	total: 45.9s	remaining: 10.5s
# 814:	learn: 0.3333799	total: 45.9s	remaining: 10.4s
# 815:	learn: 0.3332025	total: 46s	remaining: 10.4s
# 816:	learn: 0.3330182	total: 46s	remaining: 10.3s
# 817:	learn: 0.3328311	total: 46.1s	remaining: 10.3s
# 818:	learn: 0.3326666	total: 46.1s	remaining: 10.2s
# 819:	learn: 0.3324914	total: 46.2s	remaining: 10.1s
# 820:	learn: 0.3323035	total: 46.3s	remaining: 10.1s
# 821:	learn: 0.3321161	total: 46.3s	remaining: 10s
# 822:	learn: 0.3319317	total: 46.4s	remaining: 9.97s
# 823:	learn: 0.3317699	total: 46.4s	remaining: 9.92s
# 824:	learn: 0.3315672	total: 46.5s	remaining: 9.86s
# 825:	learn: 0.3313864	total: 46.5s	remaining: 9.81s
# 826:	learn: 0.3311900	total: 46.6s	remaining: 9.75s
# 827:	learn: 0.3309919	total: 46.7s	remaining: 9.69s
# 828:	learn: 0.3308030	total: 46.7s	remaining: 9.64s
# 829:	learn: 0.3305987	total: 46.8s	remaining: 9.58s
# 830:	learn: 0.3304288	total: 46.8s	remaining: 9.53s
# 831:	learn: 0.3302745	total: 46.9s	remaining: 9.47s
# 832:	learn: 0.3300805	total: 47s	remaining: 9.41s
# 833:	learn: 0.3299048	total: 47s	remaining: 9.36s
# 834:	learn: 0.3297372	total: 47.1s	remaining: 9.3s
# 835:	learn: 0.3295886	total: 47.1s	remaining: 9.25s
# 836:	learn: 0.3294020	total: 47.2s	remaining: 9.19s
# 837:	learn: 0.3292161	total: 47.3s	remaining: 9.14s
# 838:	learn: 0.3290476	total: 47.3s	remaining: 9.08s
# 839:	learn: 0.3288491	total: 47.4s	remaining: 9.03s
# 840:	learn: 0.3286768	total: 47.5s	remaining: 8.97s
# 841:	learn: 0.3284884	total: 47.5s	remaining: 8.92s
# 842:	learn: 0.3283013	total: 47.6s	remaining: 8.86s
# 843:	learn: 0.3281104	total: 47.6s	remaining: 8.81s
# 844:	learn: 0.3279320	total: 47.7s	remaining: 8.75s
# 845:	learn: 0.3277544	total: 47.8s	remaining: 8.7s
# 846:	learn: 0.3275697	total: 47.8s	remaining: 8.64s
# 847:	learn: 0.3274168	total: 47.9s	remaining: 8.59s
# 848:	learn: 0.3272474	total: 48s	remaining: 8.53s
# 849:	learn: 0.3270622	total: 48s	remaining: 8.47s
# 850:	learn: 0.3268773	total: 48.1s	remaining: 8.42s
# 851:	learn: 0.3266820	total: 48.1s	remaining: 8.36s
# 852:	learn: 0.3264790	total: 48.2s	remaining: 8.31s
# 853:	learn: 0.3263242	total: 48.3s	remaining: 8.25s
# 854:	learn: 0.3261584	total: 48.3s	remaining: 8.2s
# 855:	learn: 0.3259853	total: 48.4s	remaining: 8.14s
# 856:	learn: 0.3258293	total: 48.4s	remaining: 8.08s
# 857:	learn: 0.3256606	total: 48.5s	remaining: 8.03s
# 858:	learn: 0.3254720	total: 48.6s	remaining: 7.97s
# 859:	learn: 0.3252929	total: 48.6s	remaining: 7.91s
# 860:	learn: 0.3251373	total: 48.7s	remaining: 7.86s
# 861:	learn: 0.3249665	total: 48.7s	remaining: 7.8s
# 862:	learn: 0.3247969	total: 48.8s	remaining: 7.75s
# 863:	learn: 0.3246210	total: 48.8s	remaining: 7.69s
# 864:	learn: 0.3244561	total: 48.9s	remaining: 7.63s
# 865:	learn: 0.3243035	total: 49s	remaining: 7.58s
# 866:	learn: 0.3241205	total: 49s	remaining: 7.52s
# 867:	learn: 0.3239636	total: 49.1s	remaining: 7.46s
# 868:	learn: 0.3237982	total: 49.2s	remaining: 7.41s
# 869:	learn: 0.3236385	total: 49.2s	remaining: 7.35s
# 870:	learn: 0.3234879	total: 49.3s	remaining: 7.3s
# 871:	learn: 0.3233019	total: 49.3s	remaining: 7.24s
# 872:	learn: 0.3231229	total: 49.4s	remaining: 7.19s
# 873:	learn: 0.3229540	total: 49.5s	remaining: 7.13s
# 874:	learn: 0.3227753	total: 49.6s	remaining: 7.08s
# 875:	learn: 0.3226055	total: 49.6s	remaining: 7.02s
# 876:	learn: 0.3224223	total: 49.7s	remaining: 6.97s
# 877:	learn: 0.3222489	total: 49.7s	remaining: 6.91s
# 878:	learn: 0.3220703	total: 49.8s	remaining: 6.85s
# 879:	learn: 0.3218834	total: 49.9s	remaining: 6.8s
# 880:	learn: 0.3217139	total: 49.9s	remaining: 6.74s
# 881:	learn: 0.3215199	total: 50s	remaining: 6.69s
# 882:	learn: 0.3213564	total: 50.1s	remaining: 6.63s
# 883:	learn: 0.3211809	total: 50.1s	remaining: 6.58s
# 884:	learn: 0.3210130	total: 50.2s	remaining: 6.52s
# 885:	learn: 0.3208449	total: 50.3s	remaining: 6.47s
# 886:	learn: 0.3206709	total: 50.3s	remaining: 6.41s
# 887:	learn: 0.3205237	total: 50.4s	remaining: 6.36s
# 888:	learn: 0.3203520	total: 50.5s	remaining: 6.3s
# 889:	learn: 0.3201963	total: 50.6s	remaining: 6.25s
# 890:	learn: 0.3200670	total: 50.6s	remaining: 6.2s
# 891:	learn: 0.3198977	total: 50.7s	remaining: 6.14s
# 892:	learn: 0.3197526	total: 50.8s	remaining: 6.08s
# 893:	learn: 0.3195764	total: 50.9s	remaining: 6.03s
# 894:	learn: 0.3194116	total: 50.9s	remaining: 5.97s
# 895:	learn: 0.3192540	total: 51s	remaining: 5.92s
# 896:	learn: 0.3190745	total: 51s	remaining: 5.86s
# 897:	learn: 0.3189002	total: 51.1s	remaining: 5.8s
# 898:	learn: 0.3187496	total: 51.2s	remaining: 5.75s
# 899:	learn: 0.3185944	total: 51.2s	remaining: 5.69s
# 900:	learn: 0.3183981	total: 51.3s	remaining: 5.63s
# 901:	learn: 0.3182266	total: 51.4s	remaining: 5.58s
# 902:	learn: 0.3180342	total: 51.4s	remaining: 5.52s
# 903:	learn: 0.3178572	total: 51.5s	remaining: 5.47s
# 904:	learn: 0.3177047	total: 51.5s	remaining: 5.41s
# 905:	learn: 0.3175592	total: 51.6s	remaining: 5.35s
# 906:	learn: 0.3173911	total: 51.7s	remaining: 5.3s
# 907:	learn: 0.3172002	total: 51.7s	remaining: 5.24s
# 908:	learn: 0.3170451	total: 51.8s	remaining: 5.18s
# 909:	learn: 0.3168859	total: 51.9s	remaining: 5.13s
# 910:	learn: 0.3167128	total: 51.9s	remaining: 5.07s
# 911:	learn: 0.3165527	total: 52s	remaining: 5.02s
# 912:	learn: 0.3163822	total: 52.1s	remaining: 4.96s
# 913:	learn: 0.3162073	total: 52.1s	remaining: 4.9s
# 914:	learn: 0.3160469	total: 52.2s	remaining: 4.85s
# 915:	learn: 0.3159088	total: 52.2s	remaining: 4.79s
# 916:	learn: 0.3157561	total: 52.3s	remaining: 4.74s
# ...
# 726:	learn: 0.1676217	total: 1m 23s	remaining: 31.2s
# 727:	learn: 0.1675560	total: 1m 23s	remaining: 31.1s
# 728:	learn: 0.1674815	total: 1m 23s	remaining: 31s
# 729:	learn: 0.1674154	total: 1m 23s	remaining: 30.9s
# 730:	learn: 0.1673459	total: 1m 23s	remaining: 30.8s
# 731:	learn: 0.1672701	total: 1m 23s	remaining: 30.7s
# 732:	learn: 0.1671955	total: 1m 24s	remaining: 30.6s
# 733:	learn: 0.1671356	total: 1m 24s	remaining: 30.5s
# 734:	learn: 0.1670658	total: 1m 24s	remaining: 30.4s
# 735:	learn: 0.1669937	total: 1m 24s	remaining: 30.2s
# 736:	learn: 0.1669143	total: 1m 24s	remaining: 30.1s
# 737:	learn: 0.1668454	total: 1m 24s	remaining: 30s
# 738:	learn: 0.1667714	total: 1m 24s	remaining: 29.9s
# 739:	learn: 0.1666961	total: 1m 24s	remaining: 29.8s
# 740:	learn: 0.1666246	total: 1m 24s	remaining: 29.7s
# 741:	learn: 0.1665767	total: 1m 24s	remaining: 29.5s
# 742:	learn: 0.1664965	total: 1m 25s	remaining: 29.4s
# 743:	learn: 0.1664204	total: 1m 25s	remaining: 29.3s
# 744:	learn: 0.1663423	total: 1m 25s	remaining: 29.2s
# 745:	learn: 0.1662810	total: 1m 25s	remaining: 29.1s
# 746:	learn: 0.1662187	total: 1m 25s	remaining: 28.9s
# 747:	learn: 0.1661411	total: 1m 25s	remaining: 28.8s
# 748:	learn: 0.1660693	total: 1m 25s	remaining: 28.7s
# 749:	learn: 0.1660071	total: 1m 25s	remaining: 28.6s
# 750:	learn: 0.1659437	total: 1m 25s	remaining: 28.5s
# 751:	learn: 0.1658824	total: 1m 25s	remaining: 28.4s
# 752:	learn: 0.1658102	total: 1m 26s	remaining: 28.3s
# 753:	learn: 0.1657440	total: 1m 26s	remaining: 28.2s
# 754:	learn: 0.1656749	total: 1m 26s	remaining: 28.1s
# 755:	learn: 0.1656062	total: 1m 26s	remaining: 28s
# 756:	learn: 0.1655358	total: 1m 26s	remaining: 27.8s
# 757:	learn: 0.1654728	total: 1m 26s	remaining: 27.7s
# 758:	learn: 0.1654114	total: 1m 26s	remaining: 27.6s
# 759:	learn: 0.1653365	total: 1m 27s	remaining: 27.5s
# 760:	learn: 0.1652668	total: 1m 27s	remaining: 27.4s
# 761:	learn: 0.1652077	total: 1m 27s	remaining: 27.3s
# 762:	learn: 0.1651541	total: 1m 27s	remaining: 27.2s
# 763:	learn: 0.1650854	total: 1m 27s	remaining: 27s
# 764:	learn: 0.1650167	total: 1m 27s	remaining: 26.9s
# 765:	learn: 0.1649552	total: 1m 27s	remaining: 26.8s
# 766:	learn: 0.1648783	total: 1m 27s	remaining: 26.7s
# 767:	learn: 0.1648119	total: 1m 27s	remaining: 26.6s
# 768:	learn: 0.1647587	total: 1m 28s	remaining: 26.5s
# 769:	learn: 0.1646970	total: 1m 28s	remaining: 26.3s
# 770:	learn: 0.1646292	total: 1m 28s	remaining: 26.2s
# 771:	learn: 0.1645545	total: 1m 28s	remaining: 26.2s
# 772:	learn: 0.1644924	total: 1m 28s	remaining: 26.1s
# 773:	learn: 0.1644282	total: 1m 28s	remaining: 26s
# 774:	learn: 0.1643665	total: 1m 29s	remaining: 25.8s
# 775:	learn: 0.1643009	total: 1m 29s	remaining: 25.7s
# 776:	learn: 0.1642349	total: 1m 29s	remaining: 25.6s
# 777:	learn: 0.1641694	total: 1m 29s	remaining: 25.5s
# 778:	learn: 0.1640998	total: 1m 29s	remaining: 25.4s
# 779:	learn: 0.1640310	total: 1m 29s	remaining: 25.3s
# 780:	learn: 0.1639652	total: 1m 29s	remaining: 25.2s
# 781:	learn: 0.1638982	total: 1m 29s	remaining: 25s
# 782:	learn: 0.1638309	total: 1m 29s	remaining: 24.9s
# 783:	learn: 0.1637649	total: 1m 30s	remaining: 24.8s
# 784:	learn: 0.1636859	total: 1m 30s	remaining: 24.7s
# 785:	learn: 0.1636120	total: 1m 30s	remaining: 24.6s
# 786:	learn: 0.1635324	total: 1m 30s	remaining: 24.5s
# 787:	learn: 0.1634758	total: 1m 30s	remaining: 24.3s
# 788:	learn: 0.1634089	total: 1m 30s	remaining: 24.2s
# 789:	learn: 0.1633397	total: 1m 30s	remaining: 24.2s
# 790:	learn: 0.1632737	total: 1m 31s	remaining: 24.1s
# 791:	learn: 0.1632132	total: 1m 31s	remaining: 23.9s
# 792:	learn: 0.1631370	total: 1m 31s	remaining: 23.8s
# 793:	learn: 0.1630641	total: 1m 31s	remaining: 23.7s
# 794:	learn: 0.1629880	total: 1m 31s	remaining: 23.6s
# 795:	learn: 0.1629293	total: 1m 31s	remaining: 23.5s
# 796:	learn: 0.1628565	total: 1m 31s	remaining: 23.4s
# 797:	learn: 0.1627942	total: 1m 31s	remaining: 23.2s
# 798:	learn: 0.1627380	total: 1m 31s	remaining: 23.1s
# 799:	learn: 0.1626657	total: 1m 32s	remaining: 23s
# 800:	learn: 0.1626151	total: 1m 32s	remaining: 22.9s
# 801:	learn: 0.1625506	total: 1m 32s	remaining: 22.8s
# 802:	learn: 0.1624785	total: 1m 32s	remaining: 22.7s
# 803:	learn: 0.1624232	total: 1m 32s	remaining: 22.5s
# 804:	learn: 0.1623650	total: 1m 32s	remaining: 22.4s
# 805:	learn: 0.1622902	total: 1m 32s	remaining: 22.3s
# 806:	learn: 0.1622310	total: 1m 32s	remaining: 22.2s
# 807:	learn: 0.1621635	total: 1m 32s	remaining: 22.1s
# 808:	learn: 0.1620964	total: 1m 33s	remaining: 22s
# 809:	learn: 0.1620257	total: 1m 33s	remaining: 21.9s
# 810:	learn: 0.1619564	total: 1m 33s	remaining: 21.8s
# 811:	learn: 0.1619043	total: 1m 33s	remaining: 21.7s
# 812:	learn: 0.1618440	total: 1m 33s	remaining: 21.5s
# 813:	learn: 0.1617825	total: 1m 33s	remaining: 21.4s
# 814:	learn: 0.1617188	total: 1m 33s	remaining: 21.3s
# 815:	learn: 0.1616585	total: 1m 34s	remaining: 21.2s
# 816:	learn: 0.1615922	total: 1m 34s	remaining: 21.1s
# 817:	learn: 0.1615204	total: 1m 34s	remaining: 21s
# 818:	learn: 0.1614590	total: 1m 34s	remaining: 20.8s
# 819:	learn: 0.1614054	total: 1m 34s	remaining: 20.7s
# 820:	learn: 0.1613360	total: 1m 34s	remaining: 20.6s
# 821:	learn: 0.1612641	total: 1m 34s	remaining: 20.5s
# 822:	learn: 0.1612076	total: 1m 34s	remaining: 20.4s
# 823:	learn: 0.1611515	total: 1m 34s	remaining: 20.3s
# 824:	learn: 0.1610824	total: 1m 35s	remaining: 20.2s
# 825:	learn: 0.1610290	total: 1m 35s	remaining: 20.1s
# 826:	learn: 0.1609631	total: 1m 35s	remaining: 19.9s
# 827:	learn: 0.1608932	total: 1m 35s	remaining: 19.8s
# 828:	learn: 0.1608261	total: 1m 35s	remaining: 19.7s
# 829:	learn: 0.1607668	total: 1m 35s	remaining: 19.6s
# 830:	learn: 0.1606902	total: 1m 35s	remaining: 19.5s
# 831:	learn: 0.1606213	total: 1m 35s	remaining: 19.3s
# 832:	learn: 0.1605692	total: 1m 35s	remaining: 19.2s
# 833:	learn: 0.1605018	total: 1m 36s	remaining: 19.1s
# 834:	learn: 0.1604441	total: 1m 36s	remaining: 19s
# 835:	learn: 0.1603795	total: 1m 36s	remaining: 18.9s
# 836:	learn: 0.1603143	total: 1m 36s	remaining: 18.8s
# 837:	learn: 0.1602504	total: 1m 36s	remaining: 18.6s
# 838:	learn: 0.1601943	total: 1m 36s	remaining: 18.5s
# 839:	learn: 0.1601360	total: 1m 36s	remaining: 18.4s
# 840:	learn: 0.1600761	total: 1m 36s	remaining: 18.3s
# 841:	learn: 0.1600324	total: 1m 36s	remaining: 18.2s
# 842:	learn: 0.1599696	total: 1m 36s	remaining: 18.1s
# 843:	learn: 0.1599181	total: 1m 37s	remaining: 17.9s
# 844:	learn: 0.1598556	total: 1m 37s	remaining: 17.8s
# 845:	learn: 0.1597994	total: 1m 37s	remaining: 17.7s
# 846:	learn: 0.1597325	total: 1m 37s	remaining: 17.6s
# 847:	learn: 0.1596815	total: 1m 37s	remaining: 17.5s
# 848:	learn: 0.1596393	total: 1m 37s	remaining: 17.4s
# 849:	learn: 0.1595857	total: 1m 37s	remaining: 17.3s
# 850:	learn: 0.1595304	total: 1m 37s	remaining: 17.1s
# 851:	learn: 0.1594604	total: 1m 37s	remaining: 17s
# 852:	learn: 0.1594009	total: 1m 38s	remaining: 16.9s
# 853:	learn: 0.1593343	total: 1m 38s	remaining: 16.8s
# 854:	learn: 0.1592645	total: 1m 38s	remaining: 16.7s
# 855:	learn: 0.1591942	total: 1m 38s	remaining: 16.6s
# 856:	learn: 0.1591373	total: 1m 38s	remaining: 16.4s
# 857:	learn: 0.1590757	total: 1m 38s	remaining: 16.3s
# 858:	learn: 0.1590194	total: 1m 38s	remaining: 16.2s
# 859:	learn: 0.1589389	total: 1m 38s	remaining: 16.1s
# 860:	learn: 0.1588760	total: 1m 38s	remaining: 16s
# 861:	learn: 0.1588169	total: 1m 39s	remaining: 15.9s
# 862:	learn: 0.1587511	total: 1m 39s	remaining: 15.7s
# 863:	learn: 0.1586820	total: 1m 39s	remaining: 15.6s
# 864:	learn: 0.1586165	total: 1m 39s	remaining: 15.5s
# 865:	learn: 0.1585672	total: 1m 39s	remaining: 15.4s
# 866:	learn: 0.1585103	total: 1m 39s	remaining: 15.3s
# 867:	learn: 0.1584574	total: 1m 39s	remaining: 15.2s
# 868:	learn: 0.1584059	total: 1m 39s	remaining: 15.1s
# 869:	learn: 0.1583576	total: 1m 40s	remaining: 15s
# 870:	learn: 0.1582991	total: 1m 40s	remaining: 14.8s
# 871:	learn: 0.1582403	total: 1m 40s	remaining: 14.7s
# 872:	learn: 0.1581786	total: 1m 40s	remaining: 14.6s
# 873:	learn: 0.1581192	total: 1m 40s	remaining: 14.5s
# 874:	learn: 0.1580505	total: 1m 40s	remaining: 14.4s
# 875:	learn: 0.1580028	total: 1m 40s	remaining: 14.3s
# 876:	learn: 0.1579477	total: 1m 40s	remaining: 14.1s
# 877:	learn: 0.1578908	total: 1m 40s	remaining: 14s
# 878:	learn: 0.1578303	total: 1m 41s	remaining: 13.9s
# 879:	learn: 0.1577719	total: 1m 41s	remaining: 13.8s
# 880:	learn: 0.1577199	total: 1m 41s	remaining: 13.7s
# 881:	learn: 0.1576562	total: 1m 41s	remaining: 13.6s
# 882:	learn: 0.1576021	total: 1m 41s	remaining: 13.4s
# 883:	learn: 0.1575586	total: 1m 41s	remaining: 13.3s
# 884:	learn: 0.1574930	total: 1m 41s	remaining: 13.2s
# 885:	learn: 0.1574435	total: 1m 41s	remaining: 13.1s
# 886:	learn: 0.1573805	total: 1m 41s	remaining: 13s
# 887:	learn: 0.1573299	total: 1m 42s	remaining: 12.9s
# 888:	learn: 0.1572712	total: 1m 42s	remaining: 12.8s
# 889:	learn: 0.1572070	total: 1m 42s	remaining: 12.6s
# 890:	learn: 0.1571554	total: 1m 42s	remaining: 12.5s
# 891:	learn: 0.1570949	total: 1m 42s	remaining: 12.4s
# 892:	learn: 0.1570261	total: 1m 42s	remaining: 12.3s
# 893:	learn: 0.1569553	total: 1m 42s	remaining: 12.2s
# 894:	learn: 0.1569007	total: 1m 42s	remaining: 12.1s
# 895:	learn: 0.1568429	total: 1m 42s	remaining: 11.9s
# 896:	learn: 0.1567859	total: 1m 43s	remaining: 11.8s
# 897:	learn: 0.1567337	total: 1m 43s	remaining: 11.7s
# 898:	learn: 0.1566648	total: 1m 43s	remaining: 11.6s
# 899:	learn: 0.1565895	total: 1m 43s	remaining: 11.5s
# 900:	learn: 0.1565345	total: 1m 43s	remaining: 11.4s
# 901:	learn: 0.1564749	total: 1m 43s	remaining: 11.3s
# 902:	learn: 0.1564239	total: 1m 43s	remaining: 11.1s
# 903:	learn: 0.1563742	total: 1m 43s	remaining: 11s
# 904:	learn: 0.1563208	total: 1m 43s	remaining: 10.9s
# 905:	learn: 0.1562609	total: 1m 44s	remaining: 10.8s
# 906:	learn: 0.1562011	total: 1m 44s	remaining: 10.7s
# 907:	learn: 0.1561328	total: 1m 44s	remaining: 10.6s
# 908:	learn: 0.1560907	total: 1m 44s	remaining: 10.5s
# 909:	learn: 0.1560272	total: 1m 44s	remaining: 10.3s
# 910:	learn: 0.1559549	total: 1m 44s	remaining: 10.2s
# 911:	learn: 0.1558847	total: 1m 44s	remaining: 10.1s
# 912:	learn: 0.1558255	total: 1m 45s	remaining: 10s
# 913:	learn: 0.1557576	total: 1m 45s	remaining: 9.9s
# 914:	learn: 0.1557008	total: 1m 45s	remaining: 9.79s
# 915:	learn: 0.1556544	total: 1m 45s	remaining: 9.67s
# 916:	learn: 0.1555808	total: 1m 45s	remaining: 9.56s
# 917:	learn: 0.1555171	total: 1m 45s	remaining: 9.44s
# 918:	learn: 0.1554530	total: 1m 45s	remaining: 9.32s
# 919:	learn: 0.1553803	total: 1m 45s	remaining: 9.21s
# 920:	learn: 0.1553233	total: 1m 46s	remaining: 9.1s
# 921:	learn: 0.1552657	total: 1m 46s	remaining: 8.98s
# 922:	learn: 0.1551952	total: 1m 46s	remaining: 8.87s
# 923:	learn: 0.1551423	total: 1m 46s	remaining: 8.76s
# 924:	learn: 0.1550930	total: 1m 46s	remaining: 8.65s
# 925:	learn: 0.1550310	total: 1m 46s	remaining: 8.54s
# 926:	learn: 0.1549617	total: 1m 46s	remaining: 8.42s
# 927:	learn: 0.1548990	total: 1m 47s	remaining: 8.31s
# 928:	learn: 0.1548448	total: 1m 47s	remaining: 8.19s
# 929:	learn: 0.1548004	total: 1m 47s	remaining: 8.08s
# 930:	learn: 0.1547506	total: 1m 47s	remaining: 7.96s
# 931:	learn: 0.1546902	total: 1m 47s	remaining: 7.85s
# 932:	learn: 0.1546356	total: 1m 47s	remaining: 7.73s
# 933:	learn: 0.1545747	total: 1m 47s	remaining: 7.62s
# 934:	learn: 0.1545453	total: 1m 47s	remaining: 7.5s
# 935:	learn: 0.1544795	total: 1m 48s	remaining: 7.38s
# 936:	learn: 0.1544358	total: 1m 48s	remaining: 7.27s
# 937:	learn: 0.1543684	total: 1m 48s	remaining: 7.15s
# 938:	learn: 0.1543067	total: 1m 48s	remaining: 7.04s
# 939:	learn: 0.1542501	total: 1m 48s	remaining: 6.92s
# 940:	learn: 0.1541904	total: 1m 48s	remaining: 6.81s
# 941:	learn: 0.1541192	total: 1m 48s	remaining: 6.7s
# 942:	learn: 0.1540537	total: 1m 49s	remaining: 6.59s
# 943:	learn: 0.1539932	total: 1m 49s	remaining: 6.48s
# 944:	learn: 0.1539316	total: 1m 49s	remaining: 6.37s
# 945:	learn: 0.1538812	total: 1m 49s	remaining: 6.25s
# 946:	learn: 0.1538196	total: 1m 49s	remaining: 6.13s
# 947:	learn: 0.1537632	total: 1m 49s	remaining: 6.02s
# 948:	learn: 0.1536894	total: 1m 49s	remaining: 5.9s
# 949:	learn: 0.1536373	total: 1m 49s	remaining: 5.79s
# 950:	learn: 0.1535960	total: 1m 50s	remaining: 5.67s
# 951:	learn: 0.1535361	total: 1m 50s	remaining: 5.55s
# 952:	learn: 0.1534782	total: 1m 50s	remaining: 5.44s
# 953:	learn: 0.1534171	total: 1m 50s	remaining: 5.32s
# 954:	learn: 0.1533736	total: 1m 50s	remaining: 5.21s
# 955:	learn: 0.1533090	total: 1m 50s	remaining: 5.09s
# 956:	learn: 0.1532551	total: 1m 50s	remaining: 4.98s
# 957:	learn: 0.1532023	total: 1m 51s	remaining: 4.87s
# 958:	learn: 0.1531462	total: 1m 51s	remaining: 4.75s
# 959:	learn: 0.1530840	total: 1m 51s	remaining: 4.63s
# 960:	learn: 0.1530205	total: 1m 51s	remaining: 4.52s
# 961:	learn: 0.1529491	total: 1m 51s	remaining: 4.4s
# 962:	learn: 0.1529031	total: 1m 51s	remaining: 4.29s
# 963:	learn: 0.1528653	total: 1m 51s	remaining: 4.17s
# 964:	learn: 0.1528072	total: 1m 51s	remaining: 4.05s
# 965:	learn: 0.1527541	total: 1m 51s	remaining: 3.94s
# 966:	learn: 0.1527165	total: 1m 52s	remaining: 3.82s
# 967:	learn: 0.1526516	total: 1m 52s	remaining: 3.71s
# 968:	learn: 0.1526012	total: 1m 52s	remaining: 3.59s
# 969:	learn: 0.1525284	total: 1m 52s	remaining: 3.47s
# 970:	learn: 0.1524616	total: 1m 52s	remaining: 3.36s
# 971:	learn: 0.1523979	total: 1m 52s	remaining: 3.24s
# 972:	learn: 0.1523378	total: 1m 52s	remaining: 3.13s
# 973:	learn: 0.1522864	total: 1m 52s	remaining: 3.01s
# 974:	learn: 0.1522389	total: 1m 52s	remaining: 2.89s
# 975:	learn: 0.1521706	total: 1m 53s	remaining: 2.78s
# 976:	learn: 0.1521107	total: 1m 53s	remaining: 2.67s
# 977:	learn: 0.1520420	total: 1m 53s	remaining: 2.55s
# 978:	learn: 0.1519854	total: 1m 53s	remaining: 2.43s
# 979:	learn: 0.1519223	total: 1m 53s	remaining: 2.32s
# 980:	learn: 0.1518608	total: 1m 53s	remaining: 2.2s
# 981:	learn: 0.1518160	total: 1m 53s	remaining: 2.08s
# 982:	learn: 0.1517525	total: 1m 53s	remaining: 1.97s
# 983:	learn: 0.1517007	total: 1m 53s	remaining: 1.85s
# 984:	learn: 0.1516524	total: 1m 54s	remaining: 1.74s
# 985:	learn: 0.1516070	total: 1m 54s	remaining: 1.62s
# 986:	learn: 0.1515546	total: 1m 54s	remaining: 1.5s
# 987:	learn: 0.1514997	total: 1m 54s	remaining: 1.39s
# 988:	learn: 0.1514283	total: 1m 54s	remaining: 1.27s
# 989:	learn: 0.1513641	total: 1m 54s	remaining: 1.16s
# 990:	learn: 0.1512948	total: 1m 54s	remaining: 1.04s
# 991:	learn: 0.1512356	total: 1m 54s	remaining: 926ms
# 992:	learn: 0.1511842	total: 1m 54s	remaining: 810ms
# 993:	learn: 0.1511245	total: 1m 55s	remaining: 694ms
# 994:	learn: 0.1510753	total: 1m 55s	remaining: 578ms
# 995:	learn: 0.1510222	total: 1m 55s	remaining: 463ms
# 996:	learn: 0.1509601	total: 1m 55s	remaining: 347ms
# 997:	learn: 0.1509099	total: 1m 55s	remaining: 231ms
# 998:	learn: 0.1508510	total: 1m 55s	remaining: 116ms
# 999:	learn: 0.1507940	total: 1m 55s	remaining: 0us
#    Undersampling Technique                Model   ROC-AUC    PR-AUC
# 0                   random  Logistic Regression  0.857540  0.494507
# 1                   random             LightGBM  0.863440  0.499011
# 2                   random             CatBoost  0.888497  0.576395
# 3                      ncr  Logistic Regression  0.858739  0.498557
# 4                      ncr             LightGBM  0.862781  0.508598
# 5                      ncr             CatBoost  0.893958  0.592104
# 6                      enn  Logistic Regression  0.858747  0.498822
# 7                      enn             LightGBM  0.863523  0.512163
# 8                      enn             CatBoost  0.893906  0.592826
# 9                     renn  Logistic Regression  0.858724  0.498744
# 10                    renn             LightGBM  0.863945  0.509786
# 11                    renn             CatBoost  0.894112  0.591983
# 12                     nm1  Logistic Regression  0.856994  0.493583
# 13                     nm1             LightGBM  0.864912  0.505903
# 14                     nm1             CatBoost  0.877002  0.551184
# 15                   tomek  Logistic Regression  0.858826  0.498919
# 16                   tomek             LightGBM  0.864771  0.510729
# 17                   tomek             CatBoost  0.893994  0.591643
# 18                     oss  Logistic Regression  0.858822  0.498916
# 19                     oss             LightGBM  0.865372  0.507399
# 20                     oss             CatBoost  0.893818  0.592434

# %% [markdown]
# ### Export classification metrics

# %%
# Concatenate df_results_1 and df_results_2 horisontally
df_combined_results = pd.concat([df_results_2, df_results_1], axis=1)

# Export results to CSV files
df_combined_results.to_csv('4_evaluation_results_undersampling.csv', index=False)
