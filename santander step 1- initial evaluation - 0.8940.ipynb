# %% [markdown]
# # Santander

# %% [markdown]
# ## Contents
# - [0. Theory notes](#0-Theory-notes)
# - [1. Import Libraries](#1-Import-Libraries)
# - [2. Get Data](#2-Get-Data)
#     - [2.1 Read Data](#21-Read-Data)
#     - [2.2 Drop an unneeded column](#22-Drop-an-unneeded-column)
#     - [2.3 Split 70/30](#23-Split-7030)
# - [3. Baseline: Predict the Majority Class](#3-Baseline-Predict-the-Majority-Class)
# - [4. Train ML Models](#4-Train-ML-Models)
#     - [4.1 Random Forest Classifier](#41-Random-Forest-Classifier)
#     - [4.2 Logistic Regression](#42-Logistic-Regression)
#     - [4.3 XGBoost Classifier](#43-XGBoost-Classifier)
#     - [4.4 LightGBM Classifier](#44-LightGBM-Classifier)
#     - [4.5 CatBoost Classifier](#45-CatBoost-Classifier)
# - [5. Evaluation](#5-Evaluation)
#     - [5.1 Metrics which Require Predict Method](#51-Metrics-which-Require-Predict-Method)
#         - [5.1.1 Classification metrics](#511-Classification-metrics)
#         - [5.1.2 Confusion Matrix](#512-Confusion-Matrix)
#     - [5.2 Metrics which Require Predict_Proba Method](#52-Metrics-which-Require-Predict_Proba-Method)
# - [6. Export Classification Metrics](#6-Export-Classification-Metrics)

# %% [markdown]
# ### 0. Theory Notes
# [top](#Contents)

# %% [markdown]
# While **predict_proba** is useful for many classification tasks, there are certain scenarios where you might choose not to use it:
#
# - **Binary Classification with Balanced Classes**: When the classes are balanced and you only care about the final classification (not the confidence of predictions), using **predict** to get class labels might be sufficient.
# - **Efficiency and Performance**: Calculating probabilities can be computationally more expensive than just predicting class labels. In real-time systems where speed is critical, you might prefer using **predict** to get the class labels directly.
# - **Certain Metrics**: Metrics like accuracy, precision, recall, and F1 score do not require probability estimates and can be computed directly from class labels.
# - **Simple Decision Making**: When a simple yes/no decision is needed without considering the probability or confidence level.
# dence level.

# %% [markdown]
# # 1. Import libs
# [top](#Contents)

# %%
# pandas and numpy imports
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

import warnings
# Suppress the specific warning
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn.metrics')

# %%
# pip install -U imbalanced-learn

# %% [markdown]
# # 2. Get data
# [top](#Contents)

# %% [markdown]
# #### Read data
# [top](#Contents)

# %%
bank_ds = pd.read_csv('train.csv')

# %%
bank_test_ds = pd.read_csv('test.csv')

# %%
bank_ds.head(1)
# Out:
#    ID_code  target   var_0   var_1    var_2  var_3    var_4   var_5   var_6  \
# 0  train_0       0  8.9255 -6.7863  11.9081  5.093  11.4607 -9.2834  5.1187
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364    1.691  18.5227  -2.3978
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
#
# [1 rows x 202 columns]

# %%
bank_test_ds.head(1)
# Out:
#   ID_code    var_0   var_1    var_2   var_3    var_4   var_5   var_6    var_7  \
# 0  test_0  11.0656  7.7798  12.9536  9.4292  11.4327 -2.3805  5.8493  18.2675
#
#     var_8  ...  var_190  var_191  var_192  var_193  var_194  var_195  var_196  \
# 0  2.1337  ...  -2.1556  11.8495    -1.43   2.4508  13.7112   2.4669   4.3654
#
#    var_197  var_198  var_199
# 0    10.72  15.4722  -8.7197
#
# [1 rows x 201 columns]

# %% [markdown]
# #### Drop an unneeded column

# %%
# Assuming 'column_to_drop' is the name of the column you want to drop
column_to_drop = 'ID_code'

# Drop the column from bank_ds
bank_ds.drop(column_to_drop, axis=1, inplace=True)

# %% [markdown]
# ### Split 70/30

# %%
# separate dataset into train and test

X_train, X_test, y_train, y_test = train_test_split(
    bank_ds.drop(labels=['target'], axis=1),  # drop the target
    bank_ds['target'],  # just the target
    test_size=0.3,
    random_state=42)

X_train.shape, X_test.shape
# Out:
# ((140000, 200), (60000, 200))

# %% [markdown]
# ### Baseline: predict the majority class

# %%
# Baseline prediction: predict the majority class

y_train_base = pd.Series(np.zeros(len(y_train)))
y_test_base = pd.Series(np.zeros(len(y_test)))

# %% [markdown]
# ## Train ML models
# ### Random Forests

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=2, n_jobs=4)

rf.fit(X_train, y_train)

y_train_rf = rf.predict_proba(X_train)[:,1]
y_test_rf = rf.predict_proba(X_test)[:,1]

# %% [markdown]
# ### Logistic Regression

# %%
logit = LogisticRegression(random_state=42,  max_iter=2000)

logit.fit(X_train, y_train)

y_train_logit = logit.predict_proba(X_train)[:,1]
y_test_logit = logit.predict_proba(X_test)[:,1]
# Out:
# C:\Users\dziya\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### XGB Classifier

# %%
import xgboost as xgb
from xgboost import XGBClassifier

xgb_model = XGBClassifier(random_state=42, use_label_encoder=False)

xgb_model.fit(X_train, y_train)

y_train_xgb = xgb_model.predict_proba(X_train)[:, 1]
y_test_xgb = xgb_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### Light GBM

# %%
import lightgbm as lgb
from lightgbm import LGBMClassifier

lgb_model = LGBMClassifier(random_state=42)

lgb_model.fit(X_train, y_train)

y_train_lgb = lgb_model.predict_proba(X_train)[:, 1]
y_test_lgb = lgb_model.predict_proba(X_test)[:, 1]
# Out:
# [LightGBM] [Info] Number of positive: 13954, number of negative: 126046
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.189911 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 140000, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.099671 -> initscore=-2.200881
# [LightGBM] [Info] Start training from score -2.200881

# %%
# pip install lightgbm

# %% [markdown]
# ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

adaboost_model = AdaBoostClassifier(random_state=42)

adaboost_model.fit(X_train, y_train)

# Predict probabilities for the training and test sets
y_train_adaboost = adaboost_model.predict_proba(X_train)[:, 1]
y_test_adaboost = adaboost_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### CatBoost

# %%
from catboost import CatBoostClassifier

catboost_model = CatBoostClassifier(random_state=42)

catboost_model.fit(X_train, y_train)

# Predict probabilities for the training and test sets
y_train_catboost = catboost_model.predict_proba(X_train)[:, 1]
y_test_catboost = catboost_model.predict_proba(X_test)[:, 1]
# Out:
# Learning rate set to 0.084983
# 0:	learn: 0.6217063	total: 279ms	remaining: 4m 38s
# 1:	learn: 0.5642701	total: 396ms	remaining: 3m 17s
# 2:	learn: 0.5172629	total: 510ms	remaining: 2m 49s
# 3:	learn: 0.4801122	total: 615ms	remaining: 2m 33s
# 4:	learn: 0.4489135	total: 731ms	remaining: 2m 25s
# 5:	learn: 0.4244753	total: 839ms	remaining: 2m 18s
# 6:	learn: 0.4032821	total: 935ms	remaining: 2m 12s
# 7:	learn: 0.3864991	total: 1.04s	remaining: 2m 8s
# 8:	learn: 0.3720655	total: 1.14s	remaining: 2m 6s
# 9:	learn: 0.3599100	total: 1.24s	remaining: 2m 2s
# 10:	learn: 0.3503661	total: 1.34s	remaining: 2m
# 11:	learn: 0.3423601	total: 1.45s	remaining: 1m 59s
# 12:	learn: 0.3354061	total: 1.54s	remaining: 1m 57s
# 13:	learn: 0.3297183	total: 1.63s	remaining: 1m 55s
# 14:	learn: 0.3245210	total: 1.73s	remaining: 1m 53s
# 15:	learn: 0.3203170	total: 1.82s	remaining: 1m 51s
# 16:	learn: 0.3165151	total: 1.91s	remaining: 1m 50s
# 17:	learn: 0.3132907	total: 2s	remaining: 1m 49s
# 18:	learn: 0.3103479	total: 2.09s	remaining: 1m 47s
# 19:	learn: 0.3079070	total: 2.18s	remaining: 1m 46s
# 20:	learn: 0.3057319	total: 2.27s	remaining: 1m 45s
# 21:	learn: 0.3037173	total: 2.35s	remaining: 1m 44s
# 22:	learn: 0.3020044	total: 2.45s	remaining: 1m 44s
# 23:	learn: 0.3002461	total: 2.54s	remaining: 1m 43s
# 24:	learn: 0.2987393	total: 2.63s	remaining: 1m 42s
# 25:	learn: 0.2973669	total: 2.73s	remaining: 1m 42s
# 26:	learn: 0.2960448	total: 2.83s	remaining: 1m 41s
# 27:	learn: 0.2948316	total: 2.91s	remaining: 1m 41s
# 28:	learn: 0.2937327	total: 3s	remaining: 1m 40s
# 29:	learn: 0.2925743	total: 3.1s	remaining: 1m 40s
# 30:	learn: 0.2915310	total: 3.19s	remaining: 1m 39s
# 31:	learn: 0.2905480	total: 3.29s	remaining: 1m 39s
# 32:	learn: 0.2895704	total: 3.38s	remaining: 1m 39s
# 33:	learn: 0.2886726	total: 3.47s	remaining: 1m 38s
# 34:	learn: 0.2877658	total: 3.57s	remaining: 1m 38s
# 35:	learn: 0.2868690	total: 3.67s	remaining: 1m 38s
# 36:	learn: 0.2860003	total: 3.76s	remaining: 1m 37s
# 37:	learn: 0.2851504	total: 3.85s	remaining: 1m 37s
# 38:	learn: 0.2843678	total: 3.95s	remaining: 1m 37s
# 39:	learn: 0.2835873	total: 4.04s	remaining: 1m 36s
# 40:	learn: 0.2828035	total: 4.12s	remaining: 1m 36s
# 41:	learn: 0.2820814	total: 4.21s	remaining: 1m 35s
# 42:	learn: 0.2813773	total: 4.29s	remaining: 1m 35s
# 43:	learn: 0.2806746	total: 4.37s	remaining: 1m 35s
# 44:	learn: 0.2799480	total: 4.46s	remaining: 1m 34s
# 45:	learn: 0.2792303	total: 4.56s	remaining: 1m 34s
# 46:	learn: 0.2785835	total: 4.65s	remaining: 1m 34s
# 47:	learn: 0.2779348	total: 4.73s	remaining: 1m 33s
# 48:	learn: 0.2772360	total: 4.82s	remaining: 1m 33s
# 49:	learn: 0.2765253	total: 4.92s	remaining: 1m 33s
# 50:	learn: 0.2758744	total: 5.01s	remaining: 1m 33s
# 51:	learn: 0.2752164	total: 5.12s	remaining: 1m 33s
# 52:	learn: 0.2745832	total: 5.21s	remaining: 1m 33s
# 53:	learn: 0.2739425	total: 5.3s	remaining: 1m 32s
# 54:	learn: 0.2733701	total: 5.39s	remaining: 1m 32s
# 55:	learn: 0.2727782	total: 5.49s	remaining: 1m 32s
# 56:	learn: 0.2721985	total: 5.58s	remaining: 1m 32s
# 57:	learn: 0.2715845	total: 5.68s	remaining: 1m 32s
# 58:	learn: 0.2710128	total: 5.77s	remaining: 1m 31s
# 59:	learn: 0.2705148	total: 5.86s	remaining: 1m 31s
# 60:	learn: 0.2699155	total: 5.95s	remaining: 1m 31s
# 61:	learn: 0.2693808	total: 6.04s	remaining: 1m 31s
# 62:	learn: 0.2688300	total: 6.14s	remaining: 1m 31s
# 63:	learn: 0.2682816	total: 6.23s	remaining: 1m 31s
# 64:	learn: 0.2677281	total: 6.32s	remaining: 1m 30s
# 65:	learn: 0.2671422	total: 6.43s	remaining: 1m 30s
# 66:	learn: 0.2665944	total: 6.52s	remaining: 1m 30s
# 67:	learn: 0.2660595	total: 6.61s	remaining: 1m 30s
# 68:	learn: 0.2655810	total: 6.7s	remaining: 1m 30s
# 69:	learn: 0.2650817	total: 6.79s	remaining: 1m 30s
# 70:	learn: 0.2645870	total: 6.89s	remaining: 1m 30s
# 71:	learn: 0.2640585	total: 6.99s	remaining: 1m 30s
# 72:	learn: 0.2635259	total: 7.08s	remaining: 1m 29s
# 73:	learn: 0.2630541	total: 7.18s	remaining: 1m 29s
# 74:	learn: 0.2625826	total: 7.28s	remaining: 1m 29s
# 75:	learn: 0.2620649	total: 7.39s	remaining: 1m 29s
# 76:	learn: 0.2615776	total: 7.49s	remaining: 1m 29s
# 77:	learn: 0.2611102	total: 7.59s	remaining: 1m 29s
# 78:	learn: 0.2606231	total: 7.68s	remaining: 1m 29s
# 79:	learn: 0.2601849	total: 7.77s	remaining: 1m 29s
# 80:	learn: 0.2597752	total: 7.87s	remaining: 1m 29s
# 81:	learn: 0.2593380	total: 7.96s	remaining: 1m 29s
# 82:	learn: 0.2589023	total: 8.04s	remaining: 1m 28s
# 83:	learn: 0.2584515	total: 8.13s	remaining: 1m 28s
# 84:	learn: 0.2580007	total: 8.23s	remaining: 1m 28s
# 85:	learn: 0.2575499	total: 8.32s	remaining: 1m 28s
# 86:	learn: 0.2571357	total: 8.4s	remaining: 1m 28s
# 87:	learn: 0.2567603	total: 8.49s	remaining: 1m 28s
# 88:	learn: 0.2563546	total: 8.61s	remaining: 1m 28s
# 89:	learn: 0.2559443	total: 8.71s	remaining: 1m 28s
# 90:	learn: 0.2555614	total: 8.8s	remaining: 1m 27s
# 91:	learn: 0.2551956	total: 8.89s	remaining: 1m 27s
# 92:	learn: 0.2548208	total: 9.06s	remaining: 1m 28s
# 93:	learn: 0.2544745	total: 9.16s	remaining: 1m 28s
# 94:	learn: 0.2541071	total: 9.24s	remaining: 1m 28s
# 95:	learn: 0.2537367	total: 9.33s	remaining: 1m 27s
# 96:	learn: 0.2533790	total: 9.44s	remaining: 1m 27s
# 97:	learn: 0.2529496	total: 9.53s	remaining: 1m 27s
# 98:	learn: 0.2525863	total: 9.63s	remaining: 1m 27s
# 99:	learn: 0.2522249	total: 9.71s	remaining: 1m 27s
# 100:	learn: 0.2518792	total: 9.8s	remaining: 1m 27s
# 101:	learn: 0.2514671	total: 9.91s	remaining: 1m 27s
# 102:	learn: 0.2510920	total: 10s	remaining: 1m 27s
# 103:	learn: 0.2507412	total: 10.1s	remaining: 1m 26s
# 104:	learn: 0.2503896	total: 10.2s	remaining: 1m 27s
# 105:	learn: 0.2499989	total: 10.3s	remaining: 1m 26s
# 106:	learn: 0.2496513	total: 10.4s	remaining: 1m 26s
# 107:	learn: 0.2493123	total: 10.5s	remaining: 1m 26s
# 108:	learn: 0.2489545	total: 10.6s	remaining: 1m 26s
# 109:	learn: 0.2486119	total: 10.7s	remaining: 1m 26s
# 110:	learn: 0.2482819	total: 10.8s	remaining: 1m 26s
# 111:	learn: 0.2479258	total: 10.9s	remaining: 1m 26s
# 112:	learn: 0.2475714	total: 11s	remaining: 1m 26s
# 113:	learn: 0.2472516	total: 11.1s	remaining: 1m 26s
# 114:	learn: 0.2469466	total: 11.2s	remaining: 1m 26s
# 115:	learn: 0.2466299	total: 11.3s	remaining: 1m 25s
# 116:	learn: 0.2463287	total: 11.4s	remaining: 1m 25s
# 117:	learn: 0.2459904	total: 11.5s	remaining: 1m 25s
# 118:	learn: 0.2456789	total: 11.6s	remaining: 1m 25s
# 119:	learn: 0.2453551	total: 11.7s	remaining: 1m 25s
# 120:	learn: 0.2450509	total: 11.7s	remaining: 1m 25s
# 121:	learn: 0.2447652	total: 11.8s	remaining: 1m 25s
# 122:	learn: 0.2444713	total: 11.9s	remaining: 1m 25s
# 123:	learn: 0.2441573	total: 12s	remaining: 1m 25s
# 124:	learn: 0.2438681	total: 12.1s	remaining: 1m 24s
# 125:	learn: 0.2435757	total: 12.2s	remaining: 1m 24s
# 126:	learn: 0.2432650	total: 12.3s	remaining: 1m 24s
# 127:	learn: 0.2429417	total: 12.4s	remaining: 1m 24s
# 128:	learn: 0.2426213	total: 12.5s	remaining: 1m 24s
# 129:	learn: 0.2423260	total: 12.6s	remaining: 1m 24s
# 130:	learn: 0.2419740	total: 12.7s	remaining: 1m 24s
# 131:	learn: 0.2416946	total: 12.8s	remaining: 1m 24s
# 132:	learn: 0.2414421	total: 12.9s	remaining: 1m 23s
# 133:	learn: 0.2411573	total: 13s	remaining: 1m 23s
# 134:	learn: 0.2408226	total: 13.1s	remaining: 1m 23s
# 135:	learn: 0.2405480	total: 13.1s	remaining: 1m 23s
# 136:	learn: 0.2402714	total: 13.2s	remaining: 1m 23s
# 137:	learn: 0.2400022	total: 13.3s	remaining: 1m 23s
# 138:	learn: 0.2397168	total: 13.4s	remaining: 1m 23s
# 139:	learn: 0.2394674	total: 13.5s	remaining: 1m 22s
# 140:	learn: 0.2391813	total: 13.6s	remaining: 1m 22s
# 141:	learn: 0.2388676	total: 13.7s	remaining: 1m 22s
# 142:	learn: 0.2385764	total: 13.8s	remaining: 1m 22s
# 143:	learn: 0.2382928	total: 13.9s	remaining: 1m 22s
# 144:	learn: 0.2380439	total: 14s	remaining: 1m 22s
# 145:	learn: 0.2377722	total: 14.1s	remaining: 1m 22s
# 146:	learn: 0.2374756	total: 14.2s	remaining: 1m 22s
# 147:	learn: 0.2371978	total: 14.3s	remaining: 1m 22s
# 148:	learn: 0.2369417	total: 14.4s	remaining: 1m 22s
# 149:	learn: 0.2366721	total: 14.5s	remaining: 1m 21s
# 150:	learn: 0.2364135	total: 14.5s	remaining: 1m 21s
# 151:	learn: 0.2361272	total: 14.6s	remaining: 1m 21s
# 152:	learn: 0.2358866	total: 14.7s	remaining: 1m 21s
# 153:	learn: 0.2355939	total: 14.8s	remaining: 1m 21s
# 154:	learn: 0.2353331	total: 14.9s	remaining: 1m 21s
# 155:	learn: 0.2350794	total: 15s	remaining: 1m 21s
# 156:	learn: 0.2348267	total: 15.1s	remaining: 1m 21s
# 157:	learn: 0.2345537	total: 15.2s	remaining: 1m 20s
# 158:	learn: 0.2343090	total: 15.3s	remaining: 1m 20s
# 159:	learn: 0.2340663	total: 15.4s	remaining: 1m 20s
# 160:	learn: 0.2338172	total: 15.5s	remaining: 1m 20s
# 161:	learn: 0.2335514	total: 15.6s	remaining: 1m 20s
# 162:	learn: 0.2332871	total: 15.6s	remaining: 1m 20s
# 163:	learn: 0.2330348	total: 15.7s	remaining: 1m 20s
# 164:	learn: 0.2327677	total: 15.8s	remaining: 1m 20s
# 165:	learn: 0.2325287	total: 15.9s	remaining: 1m 19s
# 166:	learn: 0.2322794	total: 16s	remaining: 1m 19s
# 167:	learn: 0.2320291	total: 16.1s	remaining: 1m 19s
# 168:	learn: 0.2317595	total: 16.2s	remaining: 1m 19s
# 169:	learn: 0.2315145	total: 16.3s	remaining: 1m 19s
# 170:	learn: 0.2312709	total: 16.3s	remaining: 1m 19s
# 171:	learn: 0.2310322	total: 16.4s	remaining: 1m 19s
# 172:	learn: 0.2307757	total: 16.5s	remaining: 1m 19s
# 173:	learn: 0.2305194	total: 16.6s	remaining: 1m 18s
# 174:	learn: 0.2302565	total: 16.7s	remaining: 1m 18s
# 175:	learn: 0.2300310	total: 16.8s	remaining: 1m 18s
# 176:	learn: 0.2297760	total: 16.9s	remaining: 1m 18s
# 177:	learn: 0.2295476	total: 17s	remaining: 1m 18s
# 178:	learn: 0.2293139	total: 17.1s	remaining: 1m 18s
# 179:	learn: 0.2290708	total: 17.2s	remaining: 1m 18s
# 180:	learn: 0.2288235	total: 17.3s	remaining: 1m 18s
# 181:	learn: 0.2285893	total: 17.3s	remaining: 1m 17s
# 182:	learn: 0.2283599	total: 17.4s	remaining: 1m 17s
# 183:	learn: 0.2281322	total: 17.5s	remaining: 1m 17s
# 184:	learn: 0.2278911	total: 17.6s	remaining: 1m 17s
# 185:	learn: 0.2276825	total: 17.7s	remaining: 1m 17s
# 186:	learn: 0.2274524	total: 17.8s	remaining: 1m 17s
# 187:	learn: 0.2272274	total: 17.9s	remaining: 1m 17s
# 188:	learn: 0.2270097	total: 18s	remaining: 1m 17s
# 189:	learn: 0.2267583	total: 18.1s	remaining: 1m 16s
# 190:	learn: 0.2265243	total: 18.1s	remaining: 1m 16s
# 191:	learn: 0.2262966	total: 18.2s	remaining: 1m 16s
# 192:	learn: 0.2260795	total: 18.3s	remaining: 1m 16s
# 193:	learn: 0.2258573	total: 18.4s	remaining: 1m 16s
# 194:	learn: 0.2256506	total: 18.5s	remaining: 1m 16s
# 195:	learn: 0.2254241	total: 18.6s	remaining: 1m 16s
# 196:	learn: 0.2252148	total: 18.7s	remaining: 1m 16s
# 197:	learn: 0.2249901	total: 18.8s	remaining: 1m 15s
# 198:	learn: 0.2247720	total: 18.9s	remaining: 1m 15s
# 199:	learn: 0.2245620	total: 19s	remaining: 1m 15s
# 200:	learn: 0.2243570	total: 19s	remaining: 1m 15s
# 201:	learn: 0.2241575	total: 19.1s	remaining: 1m 15s
# 202:	learn: 0.2239511	total: 19.2s	remaining: 1m 15s
# 203:	learn: 0.2237267	total: 19.3s	remaining: 1m 15s
# 204:	learn: 0.2235127	total: 19.4s	remaining: 1m 15s
# 205:	learn: 0.2233105	total: 19.5s	remaining: 1m 15s
# 206:	learn: 0.2231160	total: 19.6s	remaining: 1m 15s
# 207:	learn: 0.2229062	total: 19.7s	remaining: 1m 15s
# 208:	learn: 0.2226977	total: 19.8s	remaining: 1m 14s
# 209:	learn: 0.2225058	total: 19.9s	remaining: 1m 14s
# 210:	learn: 0.2223176	total: 20s	remaining: 1m 14s
# 211:	learn: 0.2221048	total: 20.1s	remaining: 1m 14s
# 212:	learn: 0.2218952	total: 20.2s	remaining: 1m 14s
# 213:	learn: 0.2216890	total: 20.3s	remaining: 1m 14s
# 214:	learn: 0.2214820	total: 20.4s	remaining: 1m 14s
# 215:	learn: 0.2212924	total: 20.5s	remaining: 1m 14s
# 216:	learn: 0.2210947	total: 20.6s	remaining: 1m 14s
# 217:	learn: 0.2209014	total: 20.7s	remaining: 1m 14s
# 218:	learn: 0.2207038	total: 20.8s	remaining: 1m 14s
# 219:	learn: 0.2205051	total: 20.9s	remaining: 1m 13s
# 220:	learn: 0.2202959	total: 20.9s	remaining: 1m 13s
# 221:	learn: 0.2201077	total: 21s	remaining: 1m 13s
# 222:	learn: 0.2199031	total: 21.1s	remaining: 1m 13s
# 223:	learn: 0.2197093	total: 21.2s	remaining: 1m 13s
# 224:	learn: 0.2195010	total: 21.3s	remaining: 1m 13s
# 225:	learn: 0.2193099	total: 21.4s	remaining: 1m 13s
# 226:	learn: 0.2191234	total: 21.5s	remaining: 1m 13s
# 227:	learn: 0.2189134	total: 21.6s	remaining: 1m 13s
# 228:	learn: 0.2187263	total: 21.7s	remaining: 1m 13s
# 229:	learn: 0.2185332	total: 21.8s	remaining: 1m 12s
# 230:	learn: 0.2183436	total: 21.9s	remaining: 1m 12s
# 231:	learn: 0.2181532	total: 22s	remaining: 1m 12s
# 232:	learn: 0.2179634	total: 22.1s	remaining: 1m 12s
# 233:	learn: 0.2177744	total: 22.2s	remaining: 1m 12s
# 234:	learn: 0.2175707	total: 22.3s	remaining: 1m 12s
# 235:	learn: 0.2173663	total: 22.4s	remaining: 1m 12s
# 236:	learn: 0.2171616	total: 22.5s	remaining: 1m 12s
# 237:	learn: 0.2169598	total: 22.6s	remaining: 1m 12s
# 238:	learn: 0.2167732	total: 22.6s	remaining: 1m 12s
# 239:	learn: 0.2165909	total: 22.7s	remaining: 1m 11s
# 240:	learn: 0.2164298	total: 22.8s	remaining: 1m 11s
# 241:	learn: 0.2162252	total: 22.9s	remaining: 1m 11s
# 242:	learn: 0.2160415	total: 23s	remaining: 1m 11s
# 243:	learn: 0.2158564	total: 23.1s	remaining: 1m 11s
# 244:	learn: 0.2156693	total: 23.2s	remaining: 1m 11s
# 245:	learn: 0.2154787	total: 23.3s	remaining: 1m 11s
# 246:	learn: 0.2153021	total: 23.4s	remaining: 1m 11s
# 247:	learn: 0.2151272	total: 23.5s	remaining: 1m 11s
# 248:	learn: 0.2149445	total: 23.6s	remaining: 1m 11s
# 249:	learn: 0.2147727	total: 23.8s	remaining: 1m 11s
# 250:	learn: 0.2145968	total: 23.9s	remaining: 1m 11s
# 251:	learn: 0.2144186	total: 24s	remaining: 1m 11s
# 252:	learn: 0.2142394	total: 24.1s	remaining: 1m 11s
# 253:	learn: 0.2140683	total: 24.2s	remaining: 1m 11s
# 254:	learn: 0.2139011	total: 24.3s	remaining: 1m 10s
# 255:	learn: 0.2137453	total: 24.4s	remaining: 1m 10s
# 256:	learn: 0.2135857	total: 24.4s	remaining: 1m 10s
# 257:	learn: 0.2134156	total: 24.5s	remaining: 1m 10s
# 258:	learn: 0.2132425	total: 24.6s	remaining: 1m 10s
# 259:	learn: 0.2130817	total: 24.7s	remaining: 1m 10s
# 260:	learn: 0.2129207	total: 24.8s	remaining: 1m 10s
# 261:	learn: 0.2127710	total: 24.9s	remaining: 1m 10s
# 262:	learn: 0.2125994	total: 25s	remaining: 1m 10s
# 263:	learn: 0.2124307	total: 25.1s	remaining: 1m 9s
# 264:	learn: 0.2122525	total: 25.2s	remaining: 1m 9s
# 265:	learn: 0.2120683	total: 25.3s	remaining: 1m 9s
# 266:	learn: 0.2119071	total: 25.4s	remaining: 1m 9s
# 267:	learn: 0.2117424	total: 25.5s	remaining: 1m 9s
# 268:	learn: 0.2115791	total: 25.6s	remaining: 1m 9s
# 269:	learn: 0.2114253	total: 25.7s	remaining: 1m 9s
# 270:	learn: 0.2112612	total: 25.8s	remaining: 1m 9s
# 271:	learn: 0.2110971	total: 25.9s	remaining: 1m 9s
# 272:	learn: 0.2109340	total: 26s	remaining: 1m 9s
# 273:	learn: 0.2107758	total: 26.1s	remaining: 1m 9s
# 274:	learn: 0.2106070	total: 26.2s	remaining: 1m 9s
# 275:	learn: 0.2104380	total: 26.3s	remaining: 1m 8s
# 276:	learn: 0.2102892	total: 26.4s	remaining: 1m 8s
# 277:	learn: 0.2101256	total: 26.5s	remaining: 1m 8s
# 278:	learn: 0.2099685	total: 26.6s	remaining: 1m 8s
# 279:	learn: 0.2098029	total: 26.7s	remaining: 1m 8s
# 280:	learn: 0.2096501	total: 26.8s	remaining: 1m 8s
# 281:	learn: 0.2095033	total: 26.9s	remaining: 1m 8s
# 282:	learn: 0.2093507	total: 27s	remaining: 1m 8s
# 283:	learn: 0.2092031	total: 27.1s	remaining: 1m 8s
# 284:	learn: 0.2090396	total: 27.2s	remaining: 1m 8s
# 285:	learn: 0.2088770	total: 27.3s	remaining: 1m 8s
# 286:	learn: 0.2087290	total: 27.4s	remaining: 1m 8s
# 287:	learn: 0.2085806	total: 27.5s	remaining: 1m 7s
# 288:	learn: 0.2084060	total: 27.6s	remaining: 1m 7s
# 289:	learn: 0.2082391	total: 27.7s	remaining: 1m 7s
# 290:	learn: 0.2080874	total: 27.8s	remaining: 1m 7s
# 291:	learn: 0.2079368	total: 27.9s	remaining: 1m 7s
# 292:	learn: 0.2077735	total: 28s	remaining: 1m 7s
# 293:	learn: 0.2076383	total: 28.1s	remaining: 1m 7s
# 294:	learn: 0.2074810	total: 28.2s	remaining: 1m 7s
# 295:	learn: 0.2073299	total: 28.3s	remaining: 1m 7s
# 296:	learn: 0.2071733	total: 28.4s	remaining: 1m 7s
# 297:	learn: 0.2070281	total: 28.5s	remaining: 1m 7s
# 298:	learn: 0.2068814	total: 28.6s	remaining: 1m 7s
# 299:	learn: 0.2067548	total: 28.7s	remaining: 1m 6s
# 300:	learn: 0.2066103	total: 28.8s	remaining: 1m 6s
# 301:	learn: 0.2064706	total: 28.9s	remaining: 1m 6s
# 302:	learn: 0.2063361	total: 29s	remaining: 1m 6s
# 303:	learn: 0.2062074	total: 29s	remaining: 1m 6s
# 304:	learn: 0.2060601	total: 29.1s	remaining: 1m 6s
# 305:	learn: 0.2059023	total: 29.2s	remaining: 1m 6s
# 306:	learn: 0.2057538	total: 29.3s	remaining: 1m 6s
# 307:	learn: 0.2055978	total: 29.4s	remaining: 1m 6s
# 308:	learn: 0.2054509	total: 29.5s	remaining: 1m 6s
# 309:	learn: 0.2052917	total: 29.6s	remaining: 1m 5s
# 310:	learn: 0.2051573	total: 29.7s	remaining: 1m 5s
# 311:	learn: 0.2050188	total: 29.8s	remaining: 1m 5s
# 312:	learn: 0.2048643	total: 29.9s	remaining: 1m 5s
# 313:	learn: 0.2047254	total: 30s	remaining: 1m 5s
# 314:	learn: 0.2045888	total: 30.1s	remaining: 1m 5s
# 315:	learn: 0.2044458	total: 30.2s	remaining: 1m 5s
# 316:	learn: 0.2043102	total: 30.3s	remaining: 1m 5s
# 317:	learn: 0.2041642	total: 30.4s	remaining: 1m 5s
# 318:	learn: 0.2040434	total: 30.5s	remaining: 1m 5s
# 319:	learn: 0.2039062	total: 30.6s	remaining: 1m 5s
# 320:	learn: 0.2037535	total: 30.7s	remaining: 1m 4s
# 321:	learn: 0.2036231	total: 30.8s	remaining: 1m 4s
# 322:	learn: 0.2035040	total: 30.9s	remaining: 1m 4s
# 323:	learn: 0.2033637	total: 31s	remaining: 1m 4s
# 324:	learn: 0.2032189	total: 31.1s	remaining: 1m 4s
# 325:	learn: 0.2030855	total: 31.1s	remaining: 1m 4s
# 326:	learn: 0.2029501	total: 31.2s	remaining: 1m 4s
# 327:	learn: 0.2028172	total: 31.3s	remaining: 1m 4s
# 328:	learn: 0.2026846	total: 31.4s	remaining: 1m 4s
# 329:	learn: 0.2025577	total: 31.5s	remaining: 1m 3s
# 330:	learn: 0.2024391	total: 31.6s	remaining: 1m 3s
# 331:	learn: 0.2022977	total: 31.7s	remaining: 1m 3s
# 332:	learn: 0.2021657	total: 31.8s	remaining: 1m 3s
# 333:	learn: 0.2020361	total: 31.9s	remaining: 1m 3s
# 334:	learn: 0.2019034	total: 32s	remaining: 1m 3s
# 335:	learn: 0.2017713	total: 32s	remaining: 1m 3s
# 336:	learn: 0.2016279	total: 32.1s	remaining: 1m 3s
# 337:	learn: 0.2014949	total: 32.2s	remaining: 1m 3s
# 338:	learn: 0.2013635	total: 32.3s	remaining: 1m 3s
# 339:	learn: 0.2012447	total: 32.5s	remaining: 1m 3s
# 340:	learn: 0.2011230	total: 32.6s	remaining: 1m 3s
# 341:	learn: 0.2009820	total: 32.7s	remaining: 1m 2s
# 342:	learn: 0.2008418	total: 32.8s	remaining: 1m 2s
# 343:	learn: 0.2007076	total: 32.9s	remaining: 1m 2s
# 344:	learn: 0.2005579	total: 33s	remaining: 1m 2s
# 345:	learn: 0.2004159	total: 33.1s	remaining: 1m 2s
# 346:	learn: 0.2002865	total: 33.2s	remaining: 1m 2s
# 347:	learn: 0.2001600	total: 33.3s	remaining: 1m 2s
# 348:	learn: 0.2000358	total: 33.4s	remaining: 1m 2s
# 349:	learn: 0.1999090	total: 33.5s	remaining: 1m 2s
# 350:	learn: 0.1997730	total: 33.6s	remaining: 1m 2s
# 351:	learn: 0.1996629	total: 33.7s	remaining: 1m 2s
# 352:	learn: 0.1995426	total: 33.8s	remaining: 1m 1s
# 353:	learn: 0.1994167	total: 33.9s	remaining: 1m 1s
# 354:	learn: 0.1992920	total: 34s	remaining: 1m 1s
# 355:	learn: 0.1991672	total: 34.1s	remaining: 1m 1s
# 356:	learn: 0.1990449	total: 34.2s	remaining: 1m 1s
# 357:	learn: 0.1989221	total: 34.3s	remaining: 1m 1s
# 358:	learn: 0.1987974	total: 34.4s	remaining: 1m 1s
# 359:	learn: 0.1986682	total: 34.5s	remaining: 1m 1s
# 360:	learn: 0.1985444	total: 34.6s	remaining: 1m 1s
# 361:	learn: 0.1984275	total: 34.7s	remaining: 1m 1s
# 362:	learn: 0.1983119	total: 34.8s	remaining: 1m 1s
# 363:	learn: 0.1982030	total: 34.9s	remaining: 1m
# 364:	learn: 0.1980730	total: 35s	remaining: 1m
# 365:	learn: 0.1979528	total: 35.1s	remaining: 1m
# 366:	learn: 0.1978389	total: 35.2s	remaining: 1m
# 367:	learn: 0.1977241	total: 35.3s	remaining: 1m
# 368:	learn: 0.1975962	total: 35.4s	remaining: 1m
# 369:	learn: 0.1974869	total: 35.5s	remaining: 1m
# 370:	learn: 0.1973637	total: 35.6s	remaining: 1m
# 371:	learn: 0.1972552	total: 35.7s	remaining: 1m
# 372:	learn: 0.1971252	total: 35.9s	remaining: 1m
# 373:	learn: 0.1969998	total: 36s	remaining: 1m
# 374:	learn: 0.1968765	total: 36.1s	remaining: 1m
# 375:	learn: 0.1967503	total: 36.2s	remaining: 1m
# 376:	learn: 0.1966438	total: 36.3s	remaining: 59.9s
# 377:	learn: 0.1965204	total: 36.3s	remaining: 59.8s
# 378:	learn: 0.1963977	total: 36.4s	remaining: 59.7s
# 379:	learn: 0.1962824	total: 36.5s	remaining: 59.6s
# 380:	learn: 0.1961467	total: 36.6s	remaining: 59.5s
# 381:	learn: 0.1960416	total: 36.7s	remaining: 59.4s
# 382:	learn: 0.1959232	total: 36.8s	remaining: 59.3s
# 383:	learn: 0.1958000	total: 36.9s	remaining: 59.2s
# 384:	learn: 0.1956884	total: 37s	remaining: 59.1s
# 385:	learn: 0.1955712	total: 37.1s	remaining: 59s
# 386:	learn: 0.1954716	total: 37.2s	remaining: 58.9s
# 387:	learn: 0.1953546	total: 37.3s	remaining: 58.9s
# 388:	learn: 0.1952479	total: 37.4s	remaining: 58.7s
# 389:	learn: 0.1951370	total: 37.5s	remaining: 58.6s
# 390:	learn: 0.1950258	total: 37.6s	remaining: 58.5s
# 391:	learn: 0.1949110	total: 37.7s	remaining: 58.4s
# 392:	learn: 0.1947956	total: 37.8s	remaining: 58.3s
# 393:	learn: 0.1946807	total: 37.9s	remaining: 58.2s
# 394:	learn: 0.1945705	total: 37.9s	remaining: 58.1s
# 395:	learn: 0.1944631	total: 38s	remaining: 58s
# 396:	learn: 0.1943480	total: 38.1s	remaining: 57.9s
# 397:	learn: 0.1942259	total: 38.2s	remaining: 57.8s
# 398:	learn: 0.1941232	total: 38.3s	remaining: 57.7s
# 399:	learn: 0.1940069	total: 38.4s	remaining: 57.6s
# 400:	learn: 0.1939039	total: 38.5s	remaining: 57.5s
# 401:	learn: 0.1937891	total: 38.6s	remaining: 57.4s
# 402:	learn: 0.1936686	total: 38.7s	remaining: 57.3s
# 403:	learn: 0.1935646	total: 38.8s	remaining: 57.2s
# 404:	learn: 0.1934575	total: 38.9s	remaining: 57.1s
# 405:	learn: 0.1933418	total: 39s	remaining: 57s
# 406:	learn: 0.1932303	total: 39.1s	remaining: 56.9s
# 407:	learn: 0.1931236	total: 39.1s	remaining: 56.8s
# 408:	learn: 0.1930140	total: 39.3s	remaining: 56.7s
# 409:	learn: 0.1928931	total: 39.4s	remaining: 56.6s
# 410:	learn: 0.1927746	total: 39.5s	remaining: 56.5s
# 411:	learn: 0.1926601	total: 39.6s	remaining: 56.5s
# 412:	learn: 0.1925309	total: 39.7s	remaining: 56.5s
# 413:	learn: 0.1924260	total: 39.9s	remaining: 56.4s
# 414:	learn: 0.1923131	total: 40s	remaining: 56.3s
# 415:	learn: 0.1922088	total: 40s	remaining: 56.2s
# 416:	learn: 0.1921012	total: 40.1s	remaining: 56.1s
# 417:	learn: 0.1919990	total: 40.3s	remaining: 56.1s
# 418:	learn: 0.1918832	total: 40.4s	remaining: 56s
# 419:	learn: 0.1917710	total: 40.5s	remaining: 55.9s
# 420:	learn: 0.1916448	total: 40.6s	remaining: 55.8s
# 421:	learn: 0.1915376	total: 40.7s	remaining: 55.7s
# 422:	learn: 0.1914292	total: 40.7s	remaining: 55.6s
# 423:	learn: 0.1913152	total: 40.8s	remaining: 55.5s
# 424:	learn: 0.1911853	total: 40.9s	remaining: 55.4s
# 425:	learn: 0.1910776	total: 41s	remaining: 55.3s
# 426:	learn: 0.1909760	total: 41.1s	remaining: 55.2s
# 427:	learn: 0.1908767	total: 41.2s	remaining: 55.1s
# 428:	learn: 0.1907742	total: 41.3s	remaining: 55s
# 429:	learn: 0.1906624	total: 41.4s	remaining: 54.9s
# 430:	learn: 0.1905628	total: 41.5s	remaining: 54.8s
# 431:	learn: 0.1904477	total: 41.6s	remaining: 54.7s
# 432:	learn: 0.1903375	total: 41.7s	remaining: 54.6s
# 433:	learn: 0.1902291	total: 41.8s	remaining: 54.5s
# 434:	learn: 0.1901405	total: 41.9s	remaining: 54.4s
# 435:	learn: 0.1900378	total: 42s	remaining: 54.3s
# 436:	learn: 0.1899272	total: 42.1s	remaining: 54.2s
# 437:	learn: 0.1898208	total: 42.2s	remaining: 54.1s
# 438:	learn: 0.1897093	total: 42.3s	remaining: 54s
# 439:	learn: 0.1896193	total: 42.4s	remaining: 53.9s
# 440:	learn: 0.1895145	total: 42.5s	remaining: 53.8s
# 441:	learn: 0.1894070	total: 42.6s	remaining: 53.7s
# 442:	learn: 0.1893107	total: 42.7s	remaining: 53.6s
# 443:	learn: 0.1892042	total: 42.8s	remaining: 53.6s
# 444:	learn: 0.1890935	total: 42.9s	remaining: 53.5s
# 445:	learn: 0.1890045	total: 43s	remaining: 53.4s
# 446:	learn: 0.1888979	total: 43.1s	remaining: 53.3s
# 447:	learn: 0.1888031	total: 43.2s	remaining: 53.2s
# 448:	learn: 0.1887060	total: 43.3s	remaining: 53.1s
# 449:	learn: 0.1885999	total: 43.4s	remaining: 53s
# 450:	learn: 0.1884951	total: 43.5s	remaining: 52.9s
# 451:	learn: 0.1883932	total: 43.6s	remaining: 52.8s
# 452:	learn: 0.1882906	total: 43.7s	remaining: 52.7s
# 453:	learn: 0.1881855	total: 43.8s	remaining: 52.6s
# 454:	learn: 0.1880798	total: 43.9s	remaining: 52.5s
# 455:	learn: 0.1879685	total: 44s	remaining: 52.4s
# 456:	learn: 0.1878571	total: 44.1s	remaining: 52.4s
# 457:	learn: 0.1877689	total: 44.2s	remaining: 52.3s
# 458:	learn: 0.1876801	total: 44.3s	remaining: 52.2s
# 459:	learn: 0.1875777	total: 44.4s	remaining: 52.1s
# 460:	learn: 0.1874638	total: 44.5s	remaining: 52s
# 461:	learn: 0.1873641	total: 44.6s	remaining: 51.9s
# 462:	learn: 0.1872630	total: 44.7s	remaining: 51.8s
# 463:	learn: 0.1871712	total: 44.7s	remaining: 51.7s
# 464:	learn: 0.1870592	total: 44.8s	remaining: 51.6s
# 465:	learn: 0.1869664	total: 44.9s	remaining: 51.5s
# 466:	learn: 0.1868650	total: 45s	remaining: 51.4s
# 467:	learn: 0.1867711	total: 45.1s	remaining: 51.3s
# 468:	learn: 0.1866661	total: 45.2s	remaining: 51.2s
# 469:	learn: 0.1865575	total: 45.3s	remaining: 51.1s
# 470:	learn: 0.1864479	total: 45.5s	remaining: 51.1s
# 471:	learn: 0.1863470	total: 45.6s	remaining: 51s
# 472:	learn: 0.1862491	total: 45.7s	remaining: 50.9s
# 473:	learn: 0.1861434	total: 45.8s	remaining: 50.8s
# 474:	learn: 0.1860305	total: 45.9s	remaining: 50.8s
# 475:	learn: 0.1859353	total: 46s	remaining: 50.7s
# 476:	learn: 0.1858369	total: 46.1s	remaining: 50.6s
# 477:	learn: 0.1857608	total: 46.2s	remaining: 50.5s
# 478:	learn: 0.1856834	total: 46.3s	remaining: 50.4s
# 479:	learn: 0.1855947	total: 46.4s	remaining: 50.3s
# 480:	learn: 0.1855011	total: 46.5s	remaining: 50.2s
# 481:	learn: 0.1854152	total: 46.6s	remaining: 50.1s
# 482:	learn: 0.1853326	total: 46.7s	remaining: 50s
# 483:	learn: 0.1852408	total: 46.8s	remaining: 49.9s
# 484:	learn: 0.1851378	total: 46.9s	remaining: 49.8s
# 485:	learn: 0.1850678	total: 47s	remaining: 49.7s
# 486:	learn: 0.1849650	total: 47.1s	remaining: 49.6s
# 487:	learn: 0.1848878	total: 47.2s	remaining: 49.5s
# 488:	learn: 0.1847894	total: 47.3s	remaining: 49.4s
# 489:	learn: 0.1846904	total: 47.4s	remaining: 49.3s
# 490:	learn: 0.1845929	total: 47.5s	remaining: 49.2s
# 491:	learn: 0.1845138	total: 47.6s	remaining: 49.1s
# 492:	learn: 0.1844339	total: 47.6s	remaining: 49s
# 493:	learn: 0.1843406	total: 47.8s	remaining: 48.9s
# 494:	learn: 0.1842384	total: 47.9s	remaining: 48.8s
# 495:	learn: 0.1841432	total: 48s	remaining: 48.7s
# 496:	learn: 0.1840390	total: 48.1s	remaining: 48.7s
# 497:	learn: 0.1839375	total: 48.2s	remaining: 48.6s
# 498:	learn: 0.1838451	total: 48.3s	remaining: 48.5s
# 499:	learn: 0.1837506	total: 48.4s	remaining: 48.4s
# 500:	learn: 0.1836506	total: 48.5s	remaining: 48.3s
# 501:	learn: 0.1835540	total: 48.5s	remaining: 48.2s
# 502:	learn: 0.1834549	total: 48.6s	remaining: 48.1s
# 503:	learn: 0.1833525	total: 48.8s	remaining: 48s
# 504:	learn: 0.1832571	total: 48.9s	remaining: 47.9s
# 505:	learn: 0.1831680	total: 49s	remaining: 47.8s
# 506:	learn: 0.1830905	total: 49.1s	remaining: 47.7s
# 507:	learn: 0.1829915	total: 49.2s	remaining: 47.6s
# 508:	learn: 0.1828990	total: 49.3s	remaining: 47.5s
# 509:	learn: 0.1828156	total: 49.4s	remaining: 47.4s
# 510:	learn: 0.1827226	total: 49.5s	remaining: 47.4s
# 511:	learn: 0.1826426	total: 49.6s	remaining: 47.3s
# 512:	learn: 0.1825549	total: 49.7s	remaining: 47.2s
# 513:	learn: 0.1824674	total: 49.8s	remaining: 47.1s
# 514:	learn: 0.1823730	total: 49.9s	remaining: 47s
# 515:	learn: 0.1822748	total: 50s	remaining: 46.9s
# 516:	learn: 0.1821779	total: 50.1s	remaining: 46.8s
# 517:	learn: 0.1820981	total: 50.2s	remaining: 46.7s
# 518:	learn: 0.1820182	total: 50.3s	remaining: 46.6s
# 519:	learn: 0.1819312	total: 50.4s	remaining: 46.6s
# 520:	learn: 0.1818388	total: 50.5s	remaining: 46.5s
# 521:	learn: 0.1817457	total: 50.7s	remaining: 46.4s
# 522:	learn: 0.1816609	total: 50.8s	remaining: 46.3s
# 523:	learn: 0.1815832	total: 50.9s	remaining: 46.2s
# 524:	learn: 0.1814975	total: 51.1s	remaining: 46.2s
# 525:	learn: 0.1814000	total: 51.2s	remaining: 46.1s
# 526:	learn: 0.1813249	total: 51.3s	remaining: 46s
# 527:	learn: 0.1812384	total: 51.4s	remaining: 46s
# 528:	learn: 0.1811632	total: 51.5s	remaining: 45.8s
# 529:	learn: 0.1810635	total: 51.6s	remaining: 45.7s
# 530:	learn: 0.1809734	total: 51.7s	remaining: 45.7s
# 531:	learn: 0.1808843	total: 51.8s	remaining: 45.6s
# 532:	learn: 0.1808078	total: 51.9s	remaining: 45.5s
# 533:	learn: 0.1807233	total: 52s	remaining: 45.4s
# 534:	learn: 0.1806381	total: 52.1s	remaining: 45.3s
# 535:	learn: 0.1805422	total: 52.2s	remaining: 45.2s
# 536:	learn: 0.1804553	total: 52.3s	remaining: 45.1s
# 537:	learn: 0.1803688	total: 52.4s	remaining: 45s
# 538:	learn: 0.1802802	total: 52.5s	remaining: 44.9s
# 539:	learn: 0.1801854	total: 52.6s	remaining: 44.8s
# 540:	learn: 0.1801059	total: 52.7s	remaining: 44.7s
# 541:	learn: 0.1800209	total: 52.8s	remaining: 44.6s
# 542:	learn: 0.1799322	total: 52.9s	remaining: 44.5s
# 543:	learn: 0.1798294	total: 53s	remaining: 44.4s
# 544:	learn: 0.1797345	total: 53s	remaining: 44.3s
# 545:	learn: 0.1796544	total: 53.1s	remaining: 44.2s
# 546:	learn: 0.1795666	total: 53.2s	remaining: 44.1s
# 547:	learn: 0.1794714	total: 53.3s	remaining: 44s
# 548:	learn: 0.1793835	total: 53.4s	remaining: 43.9s
# 549:	learn: 0.1792928	total: 53.5s	remaining: 43.8s
# 550:	learn: 0.1792011	total: 53.6s	remaining: 43.7s
# 551:	learn: 0.1791225	total: 53.7s	remaining: 43.6s
# 552:	learn: 0.1790460	total: 53.8s	remaining: 43.5s
# 553:	learn: 0.1789503	total: 53.9s	remaining: 43.4s
# 554:	learn: 0.1788728	total: 54s	remaining: 43.3s
# 555:	learn: 0.1787852	total: 54.1s	remaining: 43.2s
# 556:	learn: 0.1786970	total: 54.2s	remaining: 43.1s
# 557:	learn: 0.1786001	total: 54.3s	remaining: 43s
# 558:	learn: 0.1785028	total: 54.4s	remaining: 42.9s
# 559:	learn: 0.1784158	total: 54.5s	remaining: 42.8s
# 560:	learn: 0.1783337	total: 54.6s	remaining: 42.7s
# 561:	learn: 0.1782405	total: 54.7s	remaining: 42.6s
# 562:	learn: 0.1781581	total: 54.7s	remaining: 42.5s
# 563:	learn: 0.1780724	total: 54.8s	remaining: 42.4s
# 564:	learn: 0.1779825	total: 54.9s	remaining: 42.3s
# 565:	learn: 0.1779022	total: 55s	remaining: 42.2s
# 566:	learn: 0.1778249	total: 55.1s	remaining: 42.1s
# 567:	learn: 0.1777272	total: 55.2s	remaining: 42s
# 568:	learn: 0.1776446	total: 55.3s	remaining: 41.9s
# 569:	learn: 0.1775619	total: 55.4s	remaining: 41.8s
# 570:	learn: 0.1774710	total: 55.5s	remaining: 41.7s
# 571:	learn: 0.1774085	total: 55.6s	remaining: 41.6s
# 572:	learn: 0.1773182	total: 55.7s	remaining: 41.5s
# 573:	learn: 0.1772277	total: 55.8s	remaining: 41.4s
# 574:	learn: 0.1771467	total: 55.9s	remaining: 41.3s
# 575:	learn: 0.1770515	total: 56s	remaining: 41.2s
# 576:	learn: 0.1769670	total: 56.2s	remaining: 41.2s
# 577:	learn: 0.1768758	total: 56.3s	remaining: 41.1s
# 578:	learn: 0.1767880	total: 56.4s	remaining: 41s
# 579:	learn: 0.1767139	total: 56.5s	remaining: 40.9s
# 580:	learn: 0.1766240	total: 56.6s	remaining: 40.8s
# 581:	learn: 0.1765421	total: 56.7s	remaining: 40.7s
# 582:	learn: 0.1764553	total: 56.8s	remaining: 40.6s
# 583:	learn: 0.1763789	total: 56.9s	remaining: 40.5s
# 584:	learn: 0.1762952	total: 57s	remaining: 40.4s
# 585:	learn: 0.1762084	total: 57s	remaining: 40.3s
# 586:	learn: 0.1761239	total: 57.1s	remaining: 40.2s
# 587:	learn: 0.1760402	total: 57.3s	remaining: 40.1s
# 588:	learn: 0.1759681	total: 57.3s	remaining: 40s
# 589:	learn: 0.1758759	total: 57.4s	remaining: 39.9s
# 590:	learn: 0.1758017	total: 57.6s	remaining: 39.8s
# 591:	learn: 0.1757205	total: 57.7s	remaining: 39.8s
# 592:	learn: 0.1756241	total: 57.8s	remaining: 39.7s
# 593:	learn: 0.1755466	total: 57.9s	remaining: 39.6s
# 594:	learn: 0.1754670	total: 58s	remaining: 39.5s
# 595:	learn: 0.1754014	total: 58.1s	remaining: 39.4s
# 596:	learn: 0.1753235	total: 58.2s	remaining: 39.3s
# 597:	learn: 0.1752447	total: 58.3s	remaining: 39.2s
# 598:	learn: 0.1751639	total: 58.4s	remaining: 39.1s
# 599:	learn: 0.1751043	total: 58.5s	remaining: 39s
# 600:	learn: 0.1750331	total: 58.6s	remaining: 38.9s
# 601:	learn: 0.1749512	total: 58.7s	remaining: 38.8s
# 602:	learn: 0.1748630	total: 58.8s	remaining: 38.7s
# 603:	learn: 0.1748028	total: 58.9s	remaining: 38.6s
# 604:	learn: 0.1747257	total: 59s	remaining: 38.5s
# 605:	learn: 0.1746322	total: 59.1s	remaining: 38.4s
# 606:	learn: 0.1745537	total: 59.2s	remaining: 38.3s
# 607:	learn: 0.1744720	total: 59.3s	remaining: 38.2s
# 608:	learn: 0.1744081	total: 59.4s	remaining: 38.1s
# 609:	learn: 0.1743438	total: 59.4s	remaining: 38s
# 610:	learn: 0.1742564	total: 59.5s	remaining: 37.9s
# 611:	learn: 0.1741641	total: 59.6s	remaining: 37.8s
# 612:	learn: 0.1740832	total: 59.7s	remaining: 37.7s
# 613:	learn: 0.1739965	total: 59.9s	remaining: 37.6s
# 614:	learn: 0.1739214	total: 60s	remaining: 37.5s
# 615:	learn: 0.1738581	total: 1m	remaining: 37.4s
# 616:	learn: 0.1737716	total: 1m	remaining: 37.3s
# 617:	learn: 0.1736880	total: 1m	remaining: 37.2s
# 618:	learn: 0.1736066	total: 1m	remaining: 37.2s
# 619:	learn: 0.1735178	total: 1m	remaining: 37.1s
# 620:	learn: 0.1734568	total: 1m	remaining: 37s
# 621:	learn: 0.1733756	total: 1m	remaining: 37s
# 622:	learn: 0.1732997	total: 1m	remaining: 36.9s
# 623:	learn: 0.1732175	total: 1m 1s	remaining: 36.8s
# 624:	learn: 0.1731297	total: 1m 1s	remaining: 36.7s
# 625:	learn: 0.1730533	total: 1m 1s	remaining: 36.6s
# 626:	learn: 0.1729792	total: 1m 1s	remaining: 36.5s
# 627:	learn: 0.1729095	total: 1m 1s	remaining: 36.4s
# 628:	learn: 0.1728270	total: 1m 1s	remaining: 36.3s
# 629:	learn: 0.1727437	total: 1m 1s	remaining: 36.2s
# 630:	learn: 0.1726748	total: 1m 1s	remaining: 36.1s
# 631:	learn: 0.1725866	total: 1m 1s	remaining: 36s
# 632:	learn: 0.1725153	total: 1m 1s	remaining: 35.9s
# 633:	learn: 0.1724304	total: 1m 2s	remaining: 35.8s
# 634:	learn: 0.1723507	total: 1m 2s	remaining: 35.7s
# 635:	learn: 0.1722874	total: 1m 2s	remaining: 35.6s
# 636:	learn: 0.1721986	total: 1m 2s	remaining: 35.5s
# 637:	learn: 0.1721107	total: 1m 2s	remaining: 35.5s
# 638:	learn: 0.1720246	total: 1m 2s	remaining: 35.4s
# 639:	learn: 0.1719585	total: 1m 2s	remaining: 35.3s
# 640:	learn: 0.1718836	total: 1m 2s	remaining: 35.2s
# 641:	learn: 0.1718022	total: 1m 2s	remaining: 35.1s
# 642:	learn: 0.1717290	total: 1m 3s	remaining: 35s
# 643:	learn: 0.1716588	total: 1m 3s	remaining: 34.9s
# 644:	learn: 0.1715865	total: 1m 3s	remaining: 34.8s
# 645:	learn: 0.1715108	total: 1m 3s	remaining: 34.7s
# 646:	learn: 0.1714353	total: 1m 3s	remaining: 34.6s
# 647:	learn: 0.1713450	total: 1m 3s	remaining: 34.5s
# 648:	learn: 0.1712781	total: 1m 3s	remaining: 34.4s
# 649:	learn: 0.1711929	total: 1m 3s	remaining: 34.3s
# 650:	learn: 0.1710954	total: 1m 3s	remaining: 34.2s
# 651:	learn: 0.1710147	total: 1m 3s	remaining: 34.2s
# 652:	learn: 0.1709381	total: 1m 4s	remaining: 34.1s
# 653:	learn: 0.1708667	total: 1m 4s	remaining: 34s
# 654:	learn: 0.1707942	total: 1m 4s	remaining: 33.9s
# 655:	learn: 0.1707267	total: 1m 4s	remaining: 33.8s
# 656:	learn: 0.1706565	total: 1m 4s	remaining: 33.8s
# 657:	learn: 0.1705877	total: 1m 4s	remaining: 33.7s
# 658:	learn: 0.1705072	total: 1m 4s	remaining: 33.6s
# 659:	learn: 0.1704518	total: 1m 4s	remaining: 33.5s
# 660:	learn: 0.1703686	total: 1m 5s	remaining: 33.4s
# 661:	learn: 0.1702956	total: 1m 5s	remaining: 33.3s
# 662:	learn: 0.1702154	total: 1m 5s	remaining: 33.2s
# 663:	learn: 0.1701529	total: 1m 5s	remaining: 33.1s
# 664:	learn: 0.1700907	total: 1m 5s	remaining: 33s
# 665:	learn: 0.1700156	total: 1m 5s	remaining: 32.9s
# 666:	learn: 0.1699360	total: 1m 5s	remaining: 32.8s
# 667:	learn: 0.1698651	total: 1m 5s	remaining: 32.7s
# 668:	learn: 0.1697847	total: 1m 5s	remaining: 32.6s
# 669:	learn: 0.1696949	total: 1m 6s	remaining: 32.5s
# 670:	learn: 0.1696112	total: 1m 6s	remaining: 32.4s
# 671:	learn: 0.1695322	total: 1m 6s	remaining: 32.4s
# 672:	learn: 0.1694465	total: 1m 6s	remaining: 32.3s
# 673:	learn: 0.1693775	total: 1m 6s	remaining: 32.2s
# 674:	learn: 0.1692976	total: 1m 6s	remaining: 32.1s
# 675:	learn: 0.1692068	total: 1m 6s	remaining: 32s
# 676:	learn: 0.1691331	total: 1m 6s	remaining: 31.9s
# 677:	learn: 0.1690673	total: 1m 6s	remaining: 31.8s
# 678:	learn: 0.1689918	total: 1m 7s	remaining: 31.7s
# 679:	learn: 0.1689094	total: 1m 7s	remaining: 31.6s
# 680:	learn: 0.1688405	total: 1m 7s	remaining: 31.5s
# 681:	learn: 0.1687676	total: 1m 7s	remaining: 31.4s
# 682:	learn: 0.1686908	total: 1m 7s	remaining: 31.3s
# 683:	learn: 0.1686120	total: 1m 7s	remaining: 31.2s
# 684:	learn: 0.1685322	total: 1m 7s	remaining: 31.1s
# 685:	learn: 0.1684563	total: 1m 7s	remaining: 31s
# 686:	learn: 0.1683920	total: 1m 7s	remaining: 30.9s
# 687:	learn: 0.1683257	total: 1m 8s	remaining: 30.9s
# 688:	learn: 0.1682499	total: 1m 8s	remaining: 30.8s
# 689:	learn: 0.1681739	total: 1m 8s	remaining: 30.7s
# 690:	learn: 0.1681081	total: 1m 8s	remaining: 30.6s
# 691:	learn: 0.1680348	total: 1m 8s	remaining: 30.5s
# 692:	learn: 0.1679664	total: 1m 8s	remaining: 30.5s
# 693:	learn: 0.1678959	total: 1m 8s	remaining: 30.4s
# 694:	learn: 0.1678164	total: 1m 8s	remaining: 30.3s
# 695:	learn: 0.1677486	total: 1m 9s	remaining: 30.2s
# 696:	learn: 0.1676875	total: 1m 9s	remaining: 30.1s
# 697:	learn: 0.1676208	total: 1m 9s	remaining: 30s
# 698:	learn: 0.1675400	total: 1m 9s	remaining: 29.9s
# 699:	learn: 0.1674645	total: 1m 9s	remaining: 29.8s
# 700:	learn: 0.1674040	total: 1m 9s	remaining: 29.7s
# 701:	learn: 0.1673362	total: 1m 9s	remaining: 29.6s
# 702:	learn: 0.1672594	total: 1m 9s	remaining: 29.5s
# 703:	learn: 0.1671894	total: 1m 9s	remaining: 29.4s
# 704:	learn: 0.1671267	total: 1m 10s	remaining: 29.3s
# 705:	learn: 0.1670629	total: 1m 10s	remaining: 29.2s
# 706:	learn: 0.1669904	total: 1m 10s	remaining: 29.1s
# 707:	learn: 0.1669156	total: 1m 10s	remaining: 29s
# 708:	learn: 0.1668551	total: 1m 10s	remaining: 28.9s
# 709:	learn: 0.1667987	total: 1m 10s	remaining: 28.8s
# 710:	learn: 0.1667218	total: 1m 10s	remaining: 28.7s
# 711:	learn: 0.1666553	total: 1m 10s	remaining: 28.6s
# 712:	learn: 0.1665830	total: 1m 10s	remaining: 28.5s
# 713:	learn: 0.1665090	total: 1m 10s	remaining: 28.4s
# 714:	learn: 0.1664524	total: 1m 11s	remaining: 28.3s
# 715:	learn: 0.1663994	total: 1m 11s	remaining: 28.2s
# 716:	learn: 0.1663252	total: 1m 11s	remaining: 28.1s
# 717:	learn: 0.1662544	total: 1m 11s	remaining: 28s
# 718:	learn: 0.1661769	total: 1m 11s	remaining: 27.9s
# 719:	learn: 0.1661036	total: 1m 11s	remaining: 27.8s
# 720:	learn: 0.1660360	total: 1m 11s	remaining: 27.7s
# 721:	learn: 0.1659631	total: 1m 11s	remaining: 27.6s
# 722:	learn: 0.1658858	total: 1m 11s	remaining: 27.5s
# 723:	learn: 0.1658034	total: 1m 11s	remaining: 27.4s
# 724:	learn: 0.1657243	total: 1m 12s	remaining: 27.3s
# 725:	learn: 0.1656507	total: 1m 12s	remaining: 27.2s
# 726:	learn: 0.1655784	total: 1m 12s	remaining: 27.2s
# 727:	learn: 0.1655103	total: 1m 12s	remaining: 27.1s
# 728:	learn: 0.1654326	total: 1m 12s	remaining: 27s
# 729:	learn: 0.1653691	total: 1m 12s	remaining: 26.9s
# 730:	learn: 0.1653009	total: 1m 12s	remaining: 26.8s
# 731:	learn: 0.1652241	total: 1m 12s	remaining: 26.7s
# 732:	learn: 0.1651553	total: 1m 13s	remaining: 26.6s
# 733:	learn: 0.1650829	total: 1m 13s	remaining: 26.5s
# 734:	learn: 0.1650048	total: 1m 13s	remaining: 26.4s
# 735:	learn: 0.1649356	total: 1m 13s	remaining: 26.3s
# 736:	learn: 0.1648711	total: 1m 13s	remaining: 26.2s
# 737:	learn: 0.1648078	total: 1m 13s	remaining: 26.1s
# 738:	learn: 0.1647314	total: 1m 13s	remaining: 26s
# 739:	learn: 0.1646685	total: 1m 13s	remaining: 25.9s
# 740:	learn: 0.1645914	total: 1m 13s	remaining: 25.8s
# 741:	learn: 0.1645178	total: 1m 13s	remaining: 25.7s
# 742:	learn: 0.1644568	total: 1m 14s	remaining: 25.6s
# 743:	learn: 0.1643874	total: 1m 14s	remaining: 25.5s
# 744:	learn: 0.1643181	total: 1m 14s	remaining: 25.4s
# 745:	learn: 0.1642657	total: 1m 14s	remaining: 25.3s
# 746:	learn: 0.1641991	total: 1m 14s	remaining: 25.2s
# 747:	learn: 0.1641322	total: 1m 14s	remaining: 25.1s
# 748:	learn: 0.1640604	total: 1m 14s	remaining: 25s
# 749:	learn: 0.1639873	total: 1m 14s	remaining: 24.9s
# 750:	learn: 0.1639217	total: 1m 14s	remaining: 24.8s
# 751:	learn: 0.1638435	total: 1m 14s	remaining: 24.7s
# 752:	learn: 0.1637694	total: 1m 15s	remaining: 24.6s
# 753:	learn: 0.1637051	total: 1m 15s	remaining: 24.5s
# 754:	learn: 0.1636470	total: 1m 15s	remaining: 24.4s
# 755:	learn: 0.1635723	total: 1m 15s	remaining: 24.3s
# 756:	learn: 0.1634964	total: 1m 15s	remaining: 24.2s
# 757:	learn: 0.1634368	total: 1m 15s	remaining: 24.1s
# 758:	learn: 0.1633574	total: 1m 15s	remaining: 24.1s
# 759:	learn: 0.1632933	total: 1m 15s	remaining: 24s
# 760:	learn: 0.1632335	total: 1m 16s	remaining: 23.9s
# 761:	learn: 0.1631633	total: 1m 16s	remaining: 23.8s
# 762:	learn: 0.1631032	total: 1m 16s	remaining: 23.7s
# 763:	learn: 0.1630387	total: 1m 16s	remaining: 23.6s
# 764:	learn: 0.1629872	total: 1m 16s	remaining: 23.5s
# 765:	learn: 0.1629211	total: 1m 16s	remaining: 23.4s
# 766:	learn: 0.1628575	total: 1m 16s	remaining: 23.3s
# 767:	learn: 0.1628027	total: 1m 16s	remaining: 23.2s
# 768:	learn: 0.1627437	total: 1m 16s	remaining: 23.1s
# 769:	learn: 0.1626999	total: 1m 16s	remaining: 23s
# 770:	learn: 0.1626462	total: 1m 17s	remaining: 22.9s
# 771:	learn: 0.1625884	total: 1m 17s	remaining: 22.8s
# 772:	learn: 0.1625212	total: 1m 17s	remaining: 22.7s
# 773:	learn: 0.1624479	total: 1m 17s	remaining: 22.6s
# 774:	learn: 0.1623814	total: 1m 17s	remaining: 22.5s
# 775:	learn: 0.1623187	total: 1m 17s	remaining: 22.4s
# 776:	learn: 0.1622547	total: 1m 17s	remaining: 22.3s
# 777:	learn: 0.1621983	total: 1m 17s	remaining: 22.2s
# 778:	learn: 0.1621317	total: 1m 17s	remaining: 22.1s
# 779:	learn: 0.1620608	total: 1m 17s	remaining: 22s
# 780:	learn: 0.1619839	total: 1m 18s	remaining: 21.9s
# 781:	learn: 0.1619100	total: 1m 18s	remaining: 21.8s
# 782:	learn: 0.1618533	total: 1m 18s	remaining: 21.7s
# 783:	learn: 0.1617996	total: 1m 18s	remaining: 21.6s
# 784:	learn: 0.1617312	total: 1m 18s	remaining: 21.5s
# 785:	learn: 0.1616655	total: 1m 18s	remaining: 21.4s
# 786:	learn: 0.1615908	total: 1m 18s	remaining: 21.3s
# 787:	learn: 0.1615218	total: 1m 18s	remaining: 21.2s
# 788:	learn: 0.1614669	total: 1m 18s	remaining: 21.1s
# 789:	learn: 0.1614042	total: 1m 19s	remaining: 21s
# 790:	learn: 0.1613347	total: 1m 19s	remaining: 20.9s
# 791:	learn: 0.1612638	total: 1m 19s	remaining: 20.8s
# 792:	learn: 0.1612022	total: 1m 19s	remaining: 20.7s
# 793:	learn: 0.1611142	total: 1m 19s	remaining: 20.6s
# 794:	learn: 0.1610400	total: 1m 19s	remaining: 20.5s
# 795:	learn: 0.1609698	total: 1m 19s	remaining: 20.5s
# 796:	learn: 0.1609128	total: 1m 19s	remaining: 20.4s
# 797:	learn: 0.1608506	total: 1m 20s	remaining: 20.3s
# 798:	learn: 0.1607970	total: 1m 20s	remaining: 20.2s
# 799:	learn: 0.1607483	total: 1m 20s	remaining: 20.1s
# 800:	learn: 0.1606839	total: 1m 20s	remaining: 20s
# 801:	learn: 0.1606149	total: 1m 20s	remaining: 19.9s
# 802:	learn: 0.1605612	total: 1m 20s	remaining: 19.8s
# 803:	learn: 0.1604928	total: 1m 20s	remaining: 19.7s
# 804:	learn: 0.1604311	total: 1m 20s	remaining: 19.6s
# 805:	learn: 0.1603640	total: 1m 20s	remaining: 19.5s
# 806:	learn: 0.1602947	total: 1m 20s	remaining: 19.4s
# 807:	learn: 0.1602460	total: 1m 21s	remaining: 19.3s
# 808:	learn: 0.1601912	total: 1m 21s	remaining: 19.2s
# 809:	learn: 0.1601339	total: 1m 21s	remaining: 19.1s
# 810:	learn: 0.1600891	total: 1m 21s	remaining: 19s
# 811:	learn: 0.1600229	total: 1m 21s	remaining: 18.9s
# 812:	learn: 0.1599805	total: 1m 21s	remaining: 18.8s
# 813:	learn: 0.1599194	total: 1m 21s	remaining: 18.7s
# 814:	learn: 0.1598584	total: 1m 21s	remaining: 18.6s
# 815:	learn: 0.1598003	total: 1m 21s	remaining: 18.5s
# 816:	learn: 0.1597352	total: 1m 21s	remaining: 18.4s
# 817:	learn: 0.1596760	total: 1m 22s	remaining: 18.3s
# 818:	learn: 0.1596154	total: 1m 22s	remaining: 18.2s
# 819:	learn: 0.1595405	total: 1m 22s	remaining: 18.1s
# 820:	learn: 0.1594799	total: 1m 22s	remaining: 18s
# 821:	learn: 0.1594174	total: 1m 22s	remaining: 17.9s
# 822:	learn: 0.1593448	total: 1m 22s	remaining: 17.8s
# 823:	learn: 0.1592710	total: 1m 22s	remaining: 17.7s
# 824:	learn: 0.1592098	total: 1m 23s	remaining: 17.6s
# 825:	learn: 0.1591424	total: 1m 23s	remaining: 17.5s
# 826:	learn: 0.1590647	total: 1m 23s	remaining: 17.4s
# 827:	learn: 0.1590020	total: 1m 23s	remaining: 17.3s
# 828:	learn: 0.1589363	total: 1m 23s	remaining: 17.2s
# 829:	learn: 0.1588763	total: 1m 23s	remaining: 17.1s
# 830:	learn: 0.1588341	total: 1m 23s	remaining: 17s
# 831:	learn: 0.1587758	total: 1m 23s	remaining: 16.9s
# 832:	learn: 0.1587200	total: 1m 23s	remaining: 16.8s
# 833:	learn: 0.1586616	total: 1m 23s	remaining: 16.7s
# 834:	learn: 0.1585887	total: 1m 24s	remaining: 16.6s
# 835:	learn: 0.1585292	total: 1m 24s	remaining: 16.5s
# 836:	learn: 0.1584733	total: 1m 24s	remaining: 16.4s
# 837:	learn: 0.1584048	total: 1m 24s	remaining: 16.3s
# 838:	learn: 0.1583476	total: 1m 24s	remaining: 16.2s
# 839:	learn: 0.1582706	total: 1m 24s	remaining: 16.1s
# 840:	learn: 0.1582074	total: 1m 24s	remaining: 16s
# 841:	learn: 0.1581399	total: 1m 24s	remaining: 15.9s
# 842:	learn: 0.1580657	total: 1m 24s	remaining: 15.8s
# 843:	learn: 0.1580236	total: 1m 24s	remaining: 15.7s
# 844:	learn: 0.1579673	total: 1m 24s	remaining: 15.6s
# 845:	learn: 0.1579041	total: 1m 25s	remaining: 15.5s
# 846:	learn: 0.1578466	total: 1m 25s	remaining: 15.4s
# 847:	learn: 0.1577812	total: 1m 25s	remaining: 15.3s
# 848:	learn: 0.1577429	total: 1m 25s	remaining: 15.2s
# 849:	learn: 0.1576770	total: 1m 25s	remaining: 15.1s
# 850:	learn: 0.1576193	total: 1m 25s	remaining: 15s
# 851:	learn: 0.1575680	total: 1m 25s	remaining: 14.9s
# 852:	learn: 0.1575158	total: 1m 25s	remaining: 14.8s
# 853:	learn: 0.1574428	total: 1m 26s	remaining: 14.7s
# 854:	learn: 0.1573813	total: 1m 26s	remaining: 14.6s
# 855:	learn: 0.1573129	total: 1m 26s	remaining: 14.5s
# 856:	learn: 0.1572658	total: 1m 26s	remaining: 14.4s
# 857:	learn: 0.1572080	total: 1m 26s	remaining: 14.3s
# 858:	learn: 0.1571440	total: 1m 26s	remaining: 14.2s
# 859:	learn: 0.1570957	total: 1m 26s	remaining: 14.1s
# 860:	learn: 0.1570217	total: 1m 26s	remaining: 14s
# 861:	learn: 0.1569436	total: 1m 26s	remaining: 13.9s
# 862:	learn: 0.1568761	total: 1m 26s	remaining: 13.8s
# 863:	learn: 0.1568152	total: 1m 27s	remaining: 13.7s
# 864:	learn: 0.1567685	total: 1m 27s	remaining: 13.6s
# 865:	learn: 0.1567201	total: 1m 27s	remaining: 13.5s
# 866:	learn: 0.1566620	total: 1m 27s	remaining: 13.4s
# 867:	learn: 0.1566074	total: 1m 27s	remaining: 13.3s
# 868:	learn: 0.1565355	total: 1m 27s	remaining: 13.2s
# 869:	learn: 0.1564733	total: 1m 27s	remaining: 13.1s
# 870:	learn: 0.1564130	total: 1m 27s	remaining: 13s
# 871:	learn: 0.1563425	total: 1m 27s	remaining: 12.9s
# 872:	learn: 0.1563091	total: 1m 27s	remaining: 12.8s
# 873:	learn: 0.1562437	total: 1m 27s	remaining: 12.7s
# 874:	learn: 0.1561797	total: 1m 28s	remaining: 12.6s
# 875:	learn: 0.1561140	total: 1m 28s	remaining: 12.5s
# 876:	learn: 0.1560526	total: 1m 28s	remaining: 12.4s
# 877:	learn: 0.1559927	total: 1m 28s	remaining: 12.3s
# 878:	learn: 0.1559402	total: 1m 28s	remaining: 12.2s
# 879:	learn: 0.1558866	total: 1m 28s	remaining: 12.1s
# 880:	learn: 0.1558429	total: 1m 28s	remaining: 12s
# 881:	learn: 0.1557667	total: 1m 28s	remaining: 11.9s
# 882:	learn: 0.1556974	total: 1m 28s	remaining: 11.8s
# 883:	learn: 0.1556321	total: 1m 28s	remaining: 11.7s
# 884:	learn: 0.1555785	total: 1m 29s	remaining: 11.6s
# 885:	learn: 0.1555222	total: 1m 29s	remaining: 11.5s
# 886:	learn: 0.1554766	total: 1m 29s	remaining: 11.4s
# 887:	learn: 0.1554122	total: 1m 29s	remaining: 11.3s
# 888:	learn: 0.1553453	total: 1m 29s	remaining: 11.2s
# 889:	learn: 0.1552978	total: 1m 29s	remaining: 11.1s
# 890:	learn: 0.1552301	total: 1m 29s	remaining: 11s
# 891:	learn: 0.1551743	total: 1m 29s	remaining: 10.9s
# 892:	learn: 0.1551165	total: 1m 29s	remaining: 10.8s
# 893:	learn: 0.1550594	total: 1m 30s	remaining: 10.7s
# 894:	learn: 0.1550088	total: 1m 30s	remaining: 10.6s
# 895:	learn: 0.1549376	total: 1m 30s	remaining: 10.5s
# 896:	learn: 0.1548645	total: 1m 30s	remaining: 10.4s
# 897:	learn: 0.1547902	total: 1m 30s	remaining: 10.3s
# 898:	learn: 0.1547320	total: 1m 30s	remaining: 10.2s
# 899:	learn: 0.1546630	total: 1m 30s	remaining: 10.1s
# 900:	learn: 0.1545991	total: 1m 30s	remaining: 9.97s
# 901:	learn: 0.1545284	total: 1m 30s	remaining: 9.88s
# 902:	learn: 0.1544706	total: 1m 31s	remaining: 9.78s
# 903:	learn: 0.1544118	total: 1m 31s	remaining: 9.67s
# 904:	learn: 0.1543583	total: 1m 31s	remaining: 9.57s
# 905:	learn: 0.1543065	total: 1m 31s	remaining: 9.47s
# 906:	learn: 0.1542619	total: 1m 31s	remaining: 9.38s
# 907:	learn: 0.1542004	total: 1m 31s	remaining: 9.28s
# 908:	learn: 0.1541285	total: 1m 31s	remaining: 9.18s
# 909:	learn: 0.1540569	total: 1m 31s	remaining: 9.07s
# 910:	learn: 0.1540010	total: 1m 31s	remaining: 8.98s
# 911:	learn: 0.1539315	total: 1m 32s	remaining: 8.88s
# 912:	learn: 0.1538676	total: 1m 32s	remaining: 8.79s
# 913:	learn: 0.1538237	total: 1m 32s	remaining: 8.69s
# 914:	learn: 0.1537724	total: 1m 32s	remaining: 8.59s
# 915:	learn: 0.1537132	total: 1m 32s	remaining: 8.49s
# 916:	learn: 0.1536668	total: 1m 32s	remaining: 8.39s
# 917:	learn: 0.1536068	total: 1m 32s	remaining: 8.29s
# 918:	learn: 0.1535601	total: 1m 32s	remaining: 8.19s
# 919:	learn: 0.1534991	total: 1m 32s	remaining: 8.08s
# 920:	learn: 0.1534385	total: 1m 33s	remaining: 7.98s
# 921:	learn: 0.1533818	total: 1m 33s	remaining: 7.88s
# 922:	learn: 0.1533185	total: 1m 33s	remaining: 7.78s
# 923:	learn: 0.1532660	total: 1m 33s	remaining: 7.68s
# 924:	learn: 0.1532081	total: 1m 33s	remaining: 7.58s
# 925:	learn: 0.1531514	total: 1m 33s	remaining: 7.48s
# 926:	learn: 0.1530881	total: 1m 33s	remaining: 7.38s
# 927:	learn: 0.1530205	total: 1m 33s	remaining: 7.28s
# 928:	learn: 0.1529527	total: 1m 33s	remaining: 7.18s
# 929:	learn: 0.1528977	total: 1m 34s	remaining: 7.08s
# 930:	learn: 0.1528349	total: 1m 34s	remaining: 6.98s
# 931:	learn: 0.1527766	total: 1m 34s	remaining: 6.88s
# 932:	learn: 0.1527258	total: 1m 34s	remaining: 6.78s
# 933:	learn: 0.1526710	total: 1m 34s	remaining: 6.68s
# 934:	learn: 0.1526057	total: 1m 34s	remaining: 6.58s
# 935:	learn: 0.1525472	total: 1m 34s	remaining: 6.48s
# 936:	learn: 0.1524984	total: 1m 34s	remaining: 6.38s
# 937:	learn: 0.1524307	total: 1m 34s	remaining: 6.28s
# 938:	learn: 0.1523660	total: 1m 35s	remaining: 6.19s
# 939:	learn: 0.1523055	total: 1m 35s	remaining: 6.09s
# 940:	learn: 0.1522378	total: 1m 35s	remaining: 5.99s
# 941:	learn: 0.1521872	total: 1m 35s	remaining: 5.88s
# 942:	learn: 0.1521191	total: 1m 35s	remaining: 5.78s
# 943:	learn: 0.1520708	total: 1m 35s	remaining: 5.68s
# 944:	learn: 0.1520073	total: 1m 35s	remaining: 5.58s
# 945:	learn: 0.1519666	total: 1m 35s	remaining: 5.48s
# 946:	learn: 0.1519021	total: 1m 36s	remaining: 5.38s
# 947:	learn: 0.1518502	total: 1m 36s	remaining: 5.28s
# 948:	learn: 0.1517979	total: 1m 36s	remaining: 5.18s
# 949:	learn: 0.1517423	total: 1m 36s	remaining: 5.08s
# 950:	learn: 0.1516925	total: 1m 36s	remaining: 4.97s
# 951:	learn: 0.1516411	total: 1m 36s	remaining: 4.87s
# 952:	learn: 0.1515827	total: 1m 36s	remaining: 4.77s
# 953:	learn: 0.1515113	total: 1m 36s	remaining: 4.67s
# 954:	learn: 0.1514567	total: 1m 36s	remaining: 4.57s
# 955:	learn: 0.1513974	total: 1m 37s	remaining: 4.47s
# 956:	learn: 0.1513259	total: 1m 37s	remaining: 4.37s
# 957:	learn: 0.1512720	total: 1m 37s	remaining: 4.26s
# 958:	learn: 0.1512173	total: 1m 37s	remaining: 4.16s
# 959:	learn: 0.1511617	total: 1m 37s	remaining: 4.06s
# 960:	learn: 0.1510862	total: 1m 37s	remaining: 3.97s
# 961:	learn: 0.1510260	total: 1m 37s	remaining: 3.87s
# 962:	learn: 0.1509736	total: 1m 38s	remaining: 3.77s
# 963:	learn: 0.1509083	total: 1m 38s	remaining: 3.66s
# 964:	learn: 0.1508504	total: 1m 38s	remaining: 3.56s
# 965:	learn: 0.1508003	total: 1m 38s	remaining: 3.46s
# 966:	learn: 0.1507456	total: 1m 38s	remaining: 3.36s
# 967:	learn: 0.1506985	total: 1m 38s	remaining: 3.26s
# 968:	learn: 0.1506292	total: 1m 38s	remaining: 3.16s
# 969:	learn: 0.1505655	total: 1m 38s	remaining: 3.05s
# 970:	learn: 0.1505148	total: 1m 38s	remaining: 2.95s
# 971:	learn: 0.1504581	total: 1m 38s	remaining: 2.85s
# 972:	learn: 0.1504123	total: 1m 39s	remaining: 2.75s
# 973:	learn: 0.1503512	total: 1m 39s	remaining: 2.65s
# 974:	learn: 0.1502965	total: 1m 39s	remaining: 2.54s
# 975:	learn: 0.1502321	total: 1m 39s	remaining: 2.44s
# 976:	learn: 0.1501849	total: 1m 39s	remaining: 2.34s
# 977:	learn: 0.1501150	total: 1m 39s	remaining: 2.24s
# 978:	learn: 0.1500619	total: 1m 39s	remaining: 2.14s
# 979:	learn: 0.1500075	total: 1m 39s	remaining: 2.04s
# 980:	learn: 0.1499645	total: 1m 39s	remaining: 1.93s
# 981:	learn: 0.1499041	total: 1m 39s	remaining: 1.83s
# 982:	learn: 0.1498620	total: 1m 40s	remaining: 1.73s
# 983:	learn: 0.1497922	total: 1m 40s	remaining: 1.63s
# 984:	learn: 0.1497475	total: 1m 40s	remaining: 1.53s
# 985:	learn: 0.1496892	total: 1m 40s	remaining: 1.42s
# 986:	learn: 0.1496308	total: 1m 40s	remaining: 1.32s
# 987:	learn: 0.1495891	total: 1m 40s	remaining: 1.22s
# 988:	learn: 0.1495376	total: 1m 40s	remaining: 1.12s
# 989:	learn: 0.1494821	total: 1m 40s	remaining: 1.02s
# 990:	learn: 0.1494230	total: 1m 41s	remaining: 917ms
# 991:	learn: 0.1493537	total: 1m 41s	remaining: 816ms
# 992:	learn: 0.1493261	total: 1m 41s	remaining: 714ms
# 993:	learn: 0.1492588	total: 1m 41s	remaining: 612ms
# 994:	learn: 0.1491935	total: 1m 41s	remaining: 510ms
# 995:	learn: 0.1491481	total: 1m 41s	remaining: 408ms
# 996:	learn: 0.1490991	total: 1m 41s	remaining: 306ms
# 997:	learn: 0.1490591	total: 1m 41s	remaining: 204ms
# 998:	learn: 0.1490054	total: 1m 41s	remaining: 102ms
# 999:	learn: 0.1489477	total: 1m 42s	remaining: 0us

# %%
#!pip install catboost

# %% [markdown]
# ## Evaluation

# %% [markdown]
# #### Metrics which require predict method

# %% [markdown]
# ##### Confusion matrix
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html
#
# TN | FP
#
# FN | TP

# %% [markdown]
# #### Confusion matrix, Recall, Precision, F1-score, G-mean, etc

# %%
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    recall_score,
    precision_score,
    f1_score,
    classification_report,
    confusion_matrix
)

# require scaling
from imblearn.metrics import (
    geometric_mean_score,
    make_index_balanced_accuracy,
)

def dominance(y_true, y_pred):
    tpr = recall_score(y_test, y_pred, pos_label=1)
    tnr = recall_score(y_test, y_pred, pos_label=0)
    return tpr - tnr

# Function to get classification metrics
def get_classification_metrics(y_true, y_pred):
    report = classification_report(y_true, y_pred, output_dict=True)
    accuracy          = accuracy_score(y_test, y_pred)
    balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
    
    # Adding possible averages to recall, precision, and f1-score calculations
    # Default average is None - scores are returned for each class individually rather than being averaged
    recall_weighted    = recall_score(y_test, y_pred, average='weighted')
    precision_weighted = precision_score(y_test, y_pred, average='weighted') 
    f1_weighted        = f1_score(y_test, y_pred, average='weighted')

    recall_micro       = recall_score(y_test, y_pred, average='micro')
    precision_micro    = precision_score(y_test, y_pred, average='micro')
    f1_micro           = f1_score(y_test, y_pred, average='micro')
    
    recall_macro       = recall_score(y_test, y_pred, average='macro')
    precision_macro    = precision_score(y_test, y_pred, average='macro')
    f1_macro           = f1_score(y_test, y_pred, average='macro')

    # Adding possible averages to G-mean
    # If the average parameter is not specified, it defaults to average='binary'.
    g_mean_binary      = geometric_mean_score(y_test, y_pred, average='binary')
    g_mean_weighted    = geometric_mean_score(y_test, y_pred, average='weighted')
    g_mean_micro       = geometric_mean_score(y_test, y_pred, average='micro')
    g_mean_macro       = geometric_mean_score(y_test, y_pred, average='macro')

    # A lower alpha gives more weight to sensitivity (TPR), while a higher alpha gives more weight to specificity (TNR). 
    # In other words,in case of a lower alpha more emphasis is placed on correctly identifying positive instances
    gmean = make_index_balanced_accuracy(alpha=0.5, squared=True)(geometric_mean_score) 
    corrected_g_mean  = gmean(y_test, y_pred)
    # specifying an average might not be necessary or meaningful. Leaving for the time being
    corrected_g_mean_binary  = gmean(y_test, y_pred,average='binary')
    corrected_g_mean_weighted  = gmean(y_test, y_pred,average='weighted')
    corrected_g_mean_micro  = gmean(y_test, y_pred,average='micro')
    corrected_g_mean_macro  = gmean(y_test, y_pred,average='macro')
    
    dominance_score   = dominance(y_test, y_pred) 

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
    FPR = fp / (tn + fp)
    FNR = fn / (tp + fn)
    # TPR = tp / (tp + fn) # recallminority
    # TNR = tn / (tn + fp) # recall majority
    
    return {
        'Accuracy': accuracy,
        'Recall Majority (TNR)': report['0']['recall'],
        'Recall Minority (TPR)': report['1']['recall'],
        'Balanced Accuracy': balanced_accuracy,
        'FPR': FPR,
        'FNR': FNR,
        
        'Precision Majority': report['0']['precision'],
        'Precision Minority': report['1']['precision'],
        'F1-Score Majority': report['0']['f1-score'],
        'F1-Score Minority': report['1']['f1-score'], 
        
        # Weighted average (Use 'weighted' if you want to take class imbalance into account)
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,

        # Micro average (Use 'micro' if you want a metric that gives equal weight to every individual prediction)
        'Micro Precision': precision_micro,
        'Micro Recall': recall_micro,
        'Micro F1-Score': f1_micro,
        
        # Macro average (Use 'macro' if you want to treat each class equally)
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,

        # Geometric average (a suitable metric when you want to balance the trade-off between detecting the minority class 
        # and avoiding false positives from the majority class)
        'G-mean-binary': g_mean_binary, # (compute two geometric means for each class, then the arithmetic mean of these G-means)
        'G-mean-weighted': g_mean_weighted, # calculates the geometric mean for each class and then computes the weighted arithmetic mean of these G-means
        'G-mean-micro': g_mean_micro, # treats all classes equally, regardless of their size
        'G-mean-macro': g_mean_macro, # use when you want to weight each instance equally, regardless of their class

        # Corrected G-means
        'Corrected G-mean': corrected_g_mean,
        'Corrected G-mean-binary': corrected_g_mean_binary,
        'Corrected G-mean-weighted': corrected_g_mean_weighted,
        'Corrected G-mean-micro': corrected_g_mean_micro,
        'Corrected G-mean-macro': corrected_g_mean_macro,
        
        'Dominance': dominance_score
    }

models = {
    'Baseline': y_test_base,
    'Random Forest': rf.predict(X_test),
    'Logistic Regression': logit.predict(X_test),
    'XGBoost': xgb_model.predict(X_test),
    'LightGBM': lgb_model.predict(X_test),
    'AdaBoost': adaboost_model.predict(X_test),
    'CatBoost': catboost_model.predict(X_test)
}

# Collecting results
results = []
confusion_matricies = []
for model_name, y_pred in models.items():
    metrics           = get_classification_metrics(y_test, y_pred)
    conf_matrix       = confusion_matrix(y_test, y_pred)
    results.append({
        'Model': model_name,
        **metrics,
    })
    confusion_matricies.append({
        'Model': model_name,
        'Confusion matrix': conf_matrix
    })

# Create a DataFrame from the results
df_results_1 = pd.DataFrame(results)
df_confusion_matricies = pd.DataFrame(confusion_matricies)

# Print the DataFrame as a table
print(df_results_1)
print(df_confusion_matricies)
# Out:
#                  Model  Accuracy  Recall Majority (TNR)  \
# 0             Baseline  0.897600               1.000000
# 1        Random Forest  0.897600               1.000000
# 2  Logistic Regression  0.912817               0.986612
# 3              XGBoost  0.911717               0.986650
# 4             LightGBM  0.906350               0.997995
# 5             AdaBoost  0.905017               0.989268
# 6             CatBoost  0.922533               0.990159
#
#    Recall Minority (TPR)  Balanced Accuracy       FPR       FNR  \
# 0               0.000000           0.500000  0.000000  1.000000
# 1               0.000000           0.500000  0.000000  1.000000
# 2               0.265951           0.626281  0.013388  0.734049
# 3               0.254883           0.620766  0.013350  0.745117
# 4               0.103027           0.550511  0.002005  0.896973
# 5               0.166504           0.577886  0.010732  0.833496
# 6               0.329753           0.659956  0.009841  0.670247
#
#    Precision Majority  Precision Minority  F1-Score Majority  ...  \
# 0            0.897600            0.000000           0.946037  ...
# 1            0.897600            0.000000           0.946037  ...
# 2            0.921763            0.693843           0.953086  ...
# 3            0.920679            0.685339           0.952524  ...
# 4            0.907001            0.854251           0.950325  ...
# 5            0.912310            0.638976           0.949232  ...
# 6            0.928313            0.792645           0.958239  ...
#
#    G-mean-binary  G-mean-weighted  G-mean-micro  G-mean-macro  \
# 0       0.000000         0.303174      0.897600      0.500000
# 1       0.000000         0.303174      0.897600      0.500000
# 2       0.512240         0.556890      0.912817      0.626281
# 3       0.501478         0.548360      0.911717      0.620766
# 4       0.320657         0.420049      0.906350      0.550511
# 5       0.405853         0.476379      0.905017      0.577886
# 6       0.571408         0.605471      0.922533      0.659956
#
#    Corrected G-mean  Corrected G-mean-binary  Corrected G-mean-weighted  \
# 0          0.000000                 0.000000                   0.128459
# 1          0.000000                 0.000000                   0.128459
# 2          0.262390                 0.167843                   0.398988
# 3          0.251480                 0.159468                   0.388187
# 4          0.102821                 0.056810                   0.239226
# 5          0.164717                 0.096955                   0.301176
# 6          0.326507                 0.218694                   0.462854
#
#    Corrected G-mean-micro  Corrected G-mean-macro  Dominance
# 0                0.805686                0.250000  -1.000000
# 1                0.805686                0.250000  -1.000000
# 2                0.833234                0.392228  -0.720662
# 3                0.831227                0.385351  -0.731767
# 4                0.821470                0.303062  -0.894967
# 5                0.819055                0.333952  -0.822764
# 6                0.851068                0.435542  -0.660406
#
# [7 rows x 30 columns]
#                  Model              Confusion matrix
# 0             Baseline       [[53856, 0], [6144, 0]]
# 1        Random Forest       [[53856, 0], [6144, 0]]
# 2  Logistic Regression  [[53135, 721], [4510, 1634]]
# 3              XGBoost  [[53137, 719], [4578, 1566]]
# 4             LightGBM   [[53748, 108], [5511, 633]]
# 5             AdaBoost  [[53278, 578], [5121, 1023]]
# 6             CatBoost  [[53326, 530], [4118, 2026]]

# %% [markdown]
# #### Metrics which require predict_proba method
# The ROC AUC score is calculated based on the predicted probabilities for each class, which are obtained using the predict_proba method. This method provides the probability estimates for each class, which are necessary to compute the ROC curve and subsequently the AUC (Area Under the Curve).

# %%
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score
)

models = {
    'Baseline': y_test_base,
    'Random Forest': rf.predict_proba(X_test)[:,1],
    'Logistic Regression': logit.predict_proba(X_test)[:,1],
    'XGBoost': xgb_model.predict_proba(X_test)[:,1],
    'LightGBM': lgb_model.predict_proba(X_test)[:,1],
    'AdaBoost': adaboost_model.predict_proba(X_test)[:,1],
    'CatBoost': catboost_model.predict_proba(X_test)[:,1]
}

# Collecting results
results = []
for model_name, y_pred in models.items():
    roc_auc   = roc_auc_score(y_test, y_pred) 
    pr_auc = average_precision_score(y_test, y_pred)
    results.append({
        'Model': model_name,
        'ROC-AUC': roc_auc,
        'PR-AUC': pr_auc
    })

# Create a DataFrame from the results
df_results_2 = pd.DataFrame(results)

# Print the DataFrame as a table
print(df_results_2)
# Out:
#                  Model   ROC-AUC    PR-AUC
# 0             Baseline  0.500000  0.102400
# 1        Random Forest  0.747842  0.289410
# 2  Logistic Regression  0.860041  0.510377
# 3              XGBoost  0.857861  0.497970
# 4             LightGBM  0.862282  0.517279
# 5             AdaBoost  0.803598  0.401087
# 6             CatBoost  0.893987  0.606566

# %% [markdown]
# ### Export classification metrics

# %%
# Concatenate df_results_1 and df_results_2 horisontally
df_combined_results = pd.concat([df_results_2, df_results_1], axis=1)

# Export results to CSV files
df_combined_results.to_csv('1_evaluation_results.csv', index=False)
df_confusion_matricies.to_csv('1_confusion_matricies.csv', index=False)
