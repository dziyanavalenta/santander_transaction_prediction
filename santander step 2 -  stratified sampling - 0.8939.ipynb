# %% [markdown]
# # Santander

# %% [markdown]
# ## Contents
# - [1. Import Libraries](#1-Import-Libraries)
# - [2. Get Data](#2-Get-Data)
#     - [2.1 Read Data](#21-Read-Data)
#     - [2.2 Drop an unneeded column](#22-Drop-an-unneeded-column)
#     - [2.3 Split 70/30 (stratified sampling)](#23-Split-7030-stratified-sampling)
# - [3. Baseline: Predict the Majority Class](#3-Baseline-Predict-the-Majority-Class)
# - [4. Train ML Models](#4-Train-ML-Models)
#     - [4.1 Random Forest Classifier](#41-Random-Forest-Classifier)
#     - [4.2 Logistic Regression](#42-Logistic-Regression)
#     - [4.3 XGBoost Classifier](#43-XGBoost-Classifier)
#     - [4.4 LightGBM Classifier](#44-LightGBM-Classifier)
#     - [4.5 CatBoost Classifier](#45-CatBoost-Classifier)
# - [5. Evaluation](#5-Evaluation)
#     - [5.1 Metrics which Require Predict Method](#51-Metrics-which-Require-Predict-Method)
#         - [5.1.1 Classification metrics](#511-Classification-metrics)
#         - [5.1.2 Confusion Matrix](#512-Confusion-Matrix)
#     - [5.2 Metrics which Require Predict_Proba Method](#52-Metrics-which-Require-Predict_Proba-Method)
# - [6. Export Classification Metrics](#6-Export-Classification-Metrics)
# - [7. Theory notes](#7-Theory-notes)

# %%
# 1. Import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import warnings
import xgboost as xgb
from xgboost import XGBClassifier
import lightgbm as lgb
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    recall_score,
    precision_score,
    f1_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
    average_precision_score
)
from imblearn.metrics import (
    geometric_mean_score,
    make_index_balanced_accuracy,
)

# Suppress the specific warning
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn.metrics')

# 2. Get Data

# 2.1 Read Data
bank_ds = pd.read_csv('train.csv')
bank_test_ds = pd.read_csv('test.csv')

# 2.2 Drop an unneeded column
column_to_drop = 'ID_code'
bank_ds.drop(column_to_drop, axis=1, inplace=True)

# 2.3 Split 70/30 (stratified sampling)
target = bank_ds['target']
X_train, X_test, y_train, y_test = train_test_split(
    bank_ds.drop(labels=['target'], axis=1),
    bank_ds['target'],
    test_size=0.3,
    stratify=target,
    random_state=42
)
print(X_train.shape, X_test.shape)

# 3. Baseline: Predict the Majority Class
y_train_base = pd.Series(np.zeros(len(y_train)))
y_test_base = pd.Series(np.zeros(len(y_test)))

# 4. Train ML Models

# 4.1 Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=2, n_jobs=4)
rf.fit(X_train, y_train)
y_train_rf = rf.predict_proba(X_train)[:, 1]
y_test_rf = rf.predict_proba(X_test)[:, 1]

# 4.2 Logistic Regression
logit = LogisticRegression(random_state=42, max_iter=2000)
logit.fit(X_train, y_train)
y_train_logit = logit.predict_proba(X_train)[:, 1]
y_test_logit = logit.predict_proba(X_test)[:, 1]

# 4.3 XGB Classifier
xgb_model = XGBClassifier(random_state=42, use_label_encoder=False)
xgb_model.fit(X_train, y_train)
y_train_xgb = xgb_model.predict_proba(X_train)[:, 1]
y_test_xgb = xgb_model.predict_proba(X_test)[:, 1]

# 4.4 Light GBM
lgb_model = LGBMClassifier(random_state=42)
lgb_model.fit(X_train, y_train)
y_train_lgb = lgb_model.predict_proba(X_train)[:, 1]
y_test_lgb = lgb_model.predict_proba(X_test)[:, 1]

# 4.5 Cat Boost
catboost_model = CatBoostClassifier(random_state=42)
catboost_model.fit(X_train, y_train)
y_train_catboost = catboost_model.predict_proba(X_train)[:, 1]
y_test_catboost = catboost_model.predict_proba(X_test)[:, 1]

# 5. Evaluation

# 5.1 Metrics which Require Predict Method

# 5.1.1 Classification metrics
def dominance(y_true, y_pred):
    tpr = recall_score(y_test, y_pred, pos_label=1)
    tnr = recall_score(y_test, y_pred, pos_label=0)
    return tpr - tnr

def get_classification_metrics(y_true, y_pred):
    report = classification_report(y_true, y_pred, output_dict=True)
    accuracy = accuracy_score(y_test, y_pred)
    balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
    recall_weighted = recall_score(y_test, y_pred, average='weighted')
    precision_weighted = precision_score(y_test, y_pred, average='weighted')
    f1_weighted = f1_score(y_test, y_pred, average='weighted')
    recall_micro = recall_score(y_test, y_pred, average='micro')
    precision_micro = precision_score(y_test, y_pred, average='micro')
    f1_micro = f1_score(y_test, y_pred, average='micro')
    recall_macro = recall_score(y_test, y_pred, average='macro')
    precision_macro = precision_score(y_test, y_pred, average='macro')
    f1_macro = f1_score(y_test, y_pred, average='macro')
    g_mean_binary = geometric_mean_score(y_test, y_pred, average='binary')
    g_mean_weighted = geometric_mean_score(y_test, y_pred, average='weighted')
    g_mean_micro = geometric_mean_score(y_test, y_pred, average='micro')
    g_mean_macro = geometric_mean_score(y_test, y_pred, average='macro')
    gmean = make_index_balanced_accuracy(alpha=0.5, squared=True)(geometric_mean_score)
    corrected_g_mean = gmean(y_test, y_pred)
    corrected_g_mean_binary = gmean(y_test, y_pred, average='binary')
    corrected_g_mean_weighted = gmean(y_test, y_pred, average='weighted')
    corrected_g_mean_micro = gmean(y_test, y_pred, average='micro')
    corrected_g_mean_macro = gmean(y_test, y_pred, average='macro')
    dominance_score = dominance(y_test, y_pred)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
    FPR = fp / (tn + fp)
    FNR = fn / (tp + fn)
    return {
        'Accuracy': accuracy,
        'Recall Majority (TNR)': report['0']['recall'],
        'Recall Minority (TPR)': report['1']['recall'],
        'Balanced Accuracy': balanced_accuracy,
        'FPR': FPR,
        'FNR': FNR,
        'Precision Majority': report['0']['precision'],
        'Precision Minority': report['1']['precision'],
        'F1-Score Majority': report['0']['f1-score'],
        'F1-Score Minority': report['1']['f1-score'],
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,
        'Micro Precision': precision_micro,
        'Micro Recall': recall_micro,
        'Micro F1-Score': f1_micro,
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,
        'G-mean-binary': g_mean_binary,
        'G-mean-weighted': g_mean_weighted,
        'G-mean-micro': g_mean_micro,
        'G-mean-macro': g_mean_macro,
        'Corrected G-mean': corrected_g_mean,
        'Corrected G-mean-binary': corrected_g_mean_binary,
        'Corrected G-mean-weighted': corrected_g_mean_weighted,
        'Corrected G-mean-micro': corrected_g_mean_micro,
        'Corrected G-mean-macro': corrected_g_mean_macro,
        'Dominance': dominance_score
    }
results = []   
models = {
    'Baseline': y_test_base,
    'Random Forest': rf.predict(X_test),
    'Logistic Regression': logit.predict(X_test),
    'XGBoost': xgb_model.predict(X_test),
    'LightGBM': lgb_model.predict(X_test),
    'CatBoost': catboost_model.predict(X_test)
}


confusion_matrices = []
for model_name, y_pred in models.items():
    metrics = get_classification_metrics(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    results.append({
        'Model': model_name,
        **metrics,
    })
    confusion_matrices.append({
        'Model': model_name,
        'Confusion matrix': conf_matrix
    })
df_results_1 = pd.DataFrame(results)
print(df_results_1)
# Out:
# (140000, 200) (60000, 200)
# C:\Users\dziya\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [LightGBM] [Info] Number of positive: 14069, number of negative: 125931
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.158759 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 140000, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.100493 -> initscore=-2.191760
# [LightGBM] [Info] Start training from score -2.191760
# Learning rate set to 0.084983
# 0:	learn: 0.6221520	total: 94.6ms	remaining: 1m 34s
# 1:	learn: 0.5650402	total: 183ms	remaining: 1m 31s
# 2:	learn: 0.5182997	total: 268ms	remaining: 1m 28s
# 3:	learn: 0.4813299	total: 352ms	remaining: 1m 27s
# 4:	learn: 0.4505648	total: 441ms	remaining: 1m 27s
# 5:	learn: 0.4262857	total: 528ms	remaining: 1m 27s
# 6:	learn: 0.4043163	total: 605ms	remaining: 1m 25s
# 7:	learn: 0.3868582	total: 684ms	remaining: 1m 24s
# 8:	learn: 0.3728083	total: 762ms	remaining: 1m 23s
# 9:	learn: 0.3609445	total: 839ms	remaining: 1m 23s
# 10:	learn: 0.3514371	total: 920ms	remaining: 1m 22s
# 11:	learn: 0.3431504	total: 996ms	remaining: 1m 22s
# 12:	learn: 0.3365540	total: 1.07s	remaining: 1m 21s
# 13:	learn: 0.3305926	total: 1.15s	remaining: 1m 21s
# 14:	learn: 0.3257795	total: 1.23s	remaining: 1m 20s
# 15:	learn: 0.3216045	total: 1.3s	remaining: 1m 20s
# 16:	learn: 0.3178594	total: 1.39s	remaining: 1m 20s
# 17:	learn: 0.3146868	total: 1.46s	remaining: 1m 19s
# 18:	learn: 0.3118125	total: 1.54s	remaining: 1m 19s
# 19:	learn: 0.3091812	total: 1.61s	remaining: 1m 19s
# 20:	learn: 0.3069867	total: 1.69s	remaining: 1m 18s
# 21:	learn: 0.3050307	total: 1.76s	remaining: 1m 18s
# 22:	learn: 0.3032448	total: 1.84s	remaining: 1m 18s
# 23:	learn: 0.3015805	total: 1.92s	remaining: 1m 18s
# 24:	learn: 0.2999786	total: 2s	remaining: 1m 17s
# 25:	learn: 0.2986313	total: 2.07s	remaining: 1m 17s
# 26:	learn: 0.2974256	total: 2.15s	remaining: 1m 17s
# 27:	learn: 0.2961247	total: 2.22s	remaining: 1m 17s
# 28:	learn: 0.2949316	total: 2.3s	remaining: 1m 17s
# 29:	learn: 0.2937849	total: 2.38s	remaining: 1m 16s
# 30:	learn: 0.2927666	total: 2.46s	remaining: 1m 16s
# 31:	learn: 0.2916738	total: 2.53s	remaining: 1m 16s
# 32:	learn: 0.2906593	total: 2.6s	remaining: 1m 16s
# 79:	learn: 0.2616129	total: 6.3s	remaining: 1m 12s
# 80:	learn: 0.2611629	total: 6.38s	remaining: 1m 12s
# 81:	learn: 0.2607133	total: 6.47s	remaining: 1m 12s
# 82:	learn: 0.2602256	total: 6.55s	remaining: 1m 12s
# 83:	learn: 0.2597248	total: 6.63s	remaining: 1m 12s
# 84:	learn: 0.2593187	total: 6.71s	remaining: 1m 12s
# 85:	learn: 0.2589141	total: 6.78s	remaining: 1m 12s
# 86:	learn: 0.2584502	total: 6.86s	remaining: 1m 11s
# 87:	learn: 0.2580250	total: 6.93s	remaining: 1m 11s
# 88:	learn: 0.2576278	total: 7.01s	remaining: 1m 11s
# 89:	learn: 0.2572007	total: 7.09s	remaining: 1m 11s
# 90:	learn: 0.2567840	total: 7.17s	remaining: 1m 11s
# 91:	learn: 0.2563899	total: 7.25s	remaining: 1m 11s
# 92:	learn: 0.2559988	total: 7.33s	remaining: 1m 11s
# 93:	learn: 0.2555940	total: 7.42s	remaining: 1m 11s
# 94:	learn: 0.2552309	total: 7.5s	remaining: 1m 11s
# 95:	learn: 0.2548146	total: 7.58s	remaining: 1m 11s
# 96:	learn: 0.2544149	total: 7.66s	remaining: 1m 11s
# 97:	learn: 0.2540205	total: 7.73s	remaining: 1m 11s
# 98:	learn: 0.2536411	total: 7.82s	remaining: 1m 11s
# 99:	learn: 0.2532555	total: 7.9s	remaining: 1m 11s
# 100:	learn: 0.2529173	total: 7.97s	remaining: 1m 10s
# 101:	learn: 0.2525499	total: 8.06s	remaining: 1m 10s
# 102:	learn: 0.2521918	total: 8.14s	remaining: 1m 10s
# 103:	learn: 0.2518260	total: 8.21s	remaining: 1m 10s
# 104:	learn: 0.2514631	total: 8.3s	remaining: 1m 10s
# 105:	learn: 0.2511016	total: 8.38s	remaining: 1m 10s
# 106:	learn: 0.2507435	total: 8.46s	remaining: 1m 10s
# 107:	learn: 0.2504145	total: 8.55s	remaining: 1m 10s
# 108:	learn: 0.2500678	total: 8.64s	remaining: 1m 10s
# 109:	learn: 0.2497187	total: 8.72s	remaining: 1m 10s
# 110:	learn: 0.2493944	total: 8.81s	remaining: 1m 10s
# 111:	learn: 0.2490500	total: 8.89s	remaining: 1m 10s
# 112:	learn: 0.2487276	total: 8.97s	remaining: 1m 10s
# 113:	learn: 0.2484199	total: 9.05s	remaining: 1m 10s
# 114:	learn: 0.2480668	total: 9.14s	remaining: 1m 10s
# 115:	learn: 0.2477549	total: 9.22s	remaining: 1m 10s
# 116:	learn: 0.2474404	total: 9.3s	remaining: 1m 10s
# 117:	learn: 0.2471257	total: 9.38s	remaining: 1m 10s
# 118:	learn: 0.2467851	total: 9.47s	remaining: 1m 10s
# 119:	learn: 0.2464514	total: 9.54s	remaining: 1m 9s
# 120:	learn: 0.2461380	total: 9.62s	remaining: 1m 9s
# 121:	learn: 0.2458264	total: 9.71s	remaining: 1m 9s
# 122:	learn: 0.2454631	total: 9.8s	remaining: 1m 9s
# 123:	learn: 0.2451416	total: 9.88s	remaining: 1m 9s
# 124:	learn: 0.2448372	total: 9.96s	remaining: 1m 9s
# 125:	learn: 0.2445436	total: 10s	remaining: 1m 9s
# 126:	learn: 0.2442234	total: 10.1s	remaining: 1m 9s
# 127:	learn: 0.2439378	total: 10.2s	remaining: 1m 9s
# 128:	learn: 0.2436497	total: 10.3s	remaining: 1m 9s
# 129:	learn: 0.2433498	total: 10.4s	remaining: 1m 9s
# 130:	learn: 0.2430333	total: 10.4s	remaining: 1m 9s
# 131:	learn: 0.2427541	total: 10.5s	remaining: 1m 9s
# 132:	learn: 0.2424450	total: 10.6s	remaining: 1m 9s
# 133:	learn: 0.2421613	total: 10.7s	remaining: 1m 9s
# 134:	learn: 0.2418524	total: 10.8s	remaining: 1m 8s
# 135:	learn: 0.2415763	total: 10.8s	remaining: 1m 8s
# 136:	learn: 0.2412889	total: 10.9s	remaining: 1m 8s
# 137:	learn: 0.2410142	total: 11s	remaining: 1m 8s
# 138:	learn: 0.2407235	total: 11.1s	remaining: 1m 8s
# 139:	learn: 0.2404703	total: 11.2s	remaining: 1m 8s
# 140:	learn: 0.2401929	total: 11.2s	remaining: 1m 8s
# 141:	learn: 0.2399171	total: 11.3s	remaining: 1m 8s
# 142:	learn: 0.2396136	total: 11.4s	remaining: 1m 8s
# 143:	learn: 0.2393040	total: 11.5s	remaining: 1m 8s
# 144:	learn: 0.2390517	total: 11.6s	remaining: 1m 8s
# 145:	learn: 0.2387558	total: 11.6s	remaining: 1m 8s
# 146:	learn: 0.2384795	total: 11.7s	remaining: 1m 8s
# 147:	learn: 0.2381892	total: 11.8s	remaining: 1m 7s
# 148:	learn: 0.2379104	total: 11.9s	remaining: 1m 7s
# 149:	learn: 0.2376565	total: 12s	remaining: 1m 7s
# 150:	learn: 0.2373539	total: 12s	remaining: 1m 7s
# 151:	learn: 0.2370928	total: 12.1s	remaining: 1m 7s
# 152:	learn: 0.2367907	total: 12.2s	remaining: 1m 7s
# 153:	learn: 0.2365270	total: 12.3s	remaining: 1m 7s
# 154:	learn: 0.2362757	total: 12.4s	remaining: 1m 7s
# 155:	learn: 0.2360196	total: 12.5s	remaining: 1m 7s
# 156:	learn: 0.2357412	total: 12.5s	remaining: 1m 7s
# 157:	learn: 0.2354869	total: 12.6s	remaining: 1m 7s
# 158:	learn: 0.2352228	total: 12.7s	remaining: 1m 7s
# 159:	learn: 0.2349544	total: 12.8s	remaining: 1m 7s
# 160:	learn: 0.2347144	total: 12.9s	remaining: 1m 6s
# 161:	learn: 0.2344442	total: 12.9s	remaining: 1m 6s
# 162:	learn: 0.2341900	total: 13s	remaining: 1m 6s
# 163:	learn: 0.2339340	total: 13.1s	remaining: 1m 6s
# 164:	learn: 0.2336845	total: 13.2s	remaining: 1m 6s
# 165:	learn: 0.2334356	total: 13.2s	remaining: 1m 6s
# 166:	learn: 0.2331861	total: 13.3s	remaining: 1m 6s
# 167:	learn: 0.2329134	total: 13.4s	remaining: 1m 6s
# 168:	learn: 0.2326656	total: 13.5s	remaining: 1m 6s
# 169:	learn: 0.2323913	total: 13.6s	remaining: 1m 6s
# 170:	learn: 0.2321533	total: 13.7s	remaining: 1m 6s
# 745:	learn: 0.1650035	total: 1m	remaining: 20.7s
# 746:	learn: 0.1649410	total: 1m	remaining: 20.6s
# 747:	learn: 0.1648752	total: 1m	remaining: 20.5s
# 748:	learn: 0.1648080	total: 1m 1s	remaining: 20.4s
# 749:	learn: 0.1647357	total: 1m 1s	remaining: 20.4s
# 750:	learn: 0.1646672	total: 1m 1s	remaining: 20.3s
# 751:	learn: 0.1645871	total: 1m 1s	remaining: 20.2s
# 752:	learn: 0.1645190	total: 1m 1s	remaining: 20.1s
# 753:	learn: 0.1644362	total: 1m 1s	remaining: 20s
# 754:	learn: 0.1643652	total: 1m 1s	remaining: 20s
# 755:	learn: 0.1643049	total: 1m 1s	remaining: 19.9s
# 756:	learn: 0.1642263	total: 1m 1s	remaining: 19.8s
# 757:	learn: 0.1641645	total: 1m 1s	remaining: 19.7s
# 758:	learn: 0.1640936	total: 1m 1s	remaining: 19.6s
# 759:	learn: 0.1640335	total: 1m 1s	remaining: 19.6s
# 760:	learn: 0.1639501	total: 1m 2s	remaining: 19.5s
# 761:	learn: 0.1638637	total: 1m 2s	remaining: 19.4s
# 762:	learn: 0.1637844	total: 1m 2s	remaining: 19.3s
# 763:	learn: 0.1637360	total: 1m 2s	remaining: 19.2s
# 764:	learn: 0.1636726	total: 1m 2s	remaining: 19.2s
# 765:	learn: 0.1636177	total: 1m 2s	remaining: 19.1s
# 766:	learn: 0.1635518	total: 1m 2s	remaining: 19s
# 767:	learn: 0.1634868	total: 1m 2s	remaining: 18.9s
# 768:	learn: 0.1634172	total: 1m 2s	remaining: 18.8s
# 769:	learn: 0.1633456	total: 1m 2s	remaining: 18.7s
# 770:	learn: 0.1632726	total: 1m 2s	remaining: 18.7s
# 771:	learn: 0.1632031	total: 1m 2s	remaining: 18.6s
# 772:	learn: 0.1631387	total: 1m 3s	remaining: 18.5s
# 773:	learn: 0.1630736	total: 1m 3s	remaining: 18.4s
# 774:	learn: 0.1630188	total: 1m 3s	remaining: 18.3s
# 775:	learn: 0.1629594	total: 1m 3s	remaining: 18.3s
# 776:	learn: 0.1628941	total: 1m 3s	remaining: 18.2s
# 777:	learn: 0.1628399	total: 1m 3s	remaining: 18.1s
# 778:	learn: 0.1627668	total: 1m 3s	remaining: 18s
# 779:	learn: 0.1626977	total: 1m 3s	remaining: 17.9s
# 780:	learn: 0.1626386	total: 1m 3s	remaining: 17.8s
# 781:	learn: 0.1625715	total: 1m 3s	remaining: 17.8s
# 782:	learn: 0.1625030	total: 1m 3s	remaining: 17.7s
# 783:	learn: 0.1624497	total: 1m 3s	remaining: 17.6s
# 784:	learn: 0.1624046	total: 1m 3s	remaining: 17.5s
# 785:	learn: 0.1623510	total: 1m 4s	remaining: 17.4s
# 786:	learn: 0.1622795	total: 1m 4s	remaining: 17.4s
# 787:	learn: 0.1622111	total: 1m 4s	remaining: 17.3s
# 788:	learn: 0.1621690	total: 1m 4s	remaining: 17.2s
# 789:	learn: 0.1620914	total: 1m 4s	remaining: 17.1s
# 790:	learn: 0.1620431	total: 1m 4s	remaining: 17s
# 791:	learn: 0.1619739	total: 1m 4s	remaining: 16.9s
# 976:	learn: 0.1508908	total: 1m 19s	remaining: 1.87s
# 977:	learn: 0.1508302	total: 1m 19s	remaining: 1.79s
# 978:	learn: 0.1507821	total: 1m 19s	remaining: 1.71s
# 979:	learn: 0.1507283	total: 1m 19s	remaining: 1.63s
# 980:	learn: 0.1506727	total: 1m 19s	remaining: 1.55s
# 981:	learn: 0.1506263	total: 1m 19s	remaining: 1.47s
# 982:	learn: 0.1505818	total: 1m 20s	remaining: 1.38s
# 983:	learn: 0.1505236	total: 1m 20s	remaining: 1.3s
# 984:	learn: 0.1504577	total: 1m 20s	remaining: 1.22s
# 985:	learn: 0.1504136	total: 1m 20s	remaining: 1.14s
# 986:	learn: 0.1503506	total: 1m 20s	remaining: 1.06s
# 987:	learn: 0.1502929	total: 1m 20s	remaining: 977ms
# 988:	learn: 0.1502495	total: 1m 20s	remaining: 896ms
# 989:	learn: 0.1501747	total: 1m 20s	remaining: 814ms
# 990:	learn: 0.1501073	total: 1m 20s	remaining: 733ms
# 991:	learn: 0.1500553	total: 1m 20s	remaining: 651ms
# 992:	learn: 0.1499939	total: 1m 20s	remaining: 570ms
# 993:	learn: 0.1499349	total: 1m 20s	remaining: 489ms
# 994:	learn: 0.1498908	total: 1m 21s	remaining: 407ms
# 995:	learn: 0.1498403	total: 1m 21s	remaining: 326ms
# 996:	learn: 0.1497732	total: 1m 21s	remaining: 244ms
# 997:	learn: 0.1497134	total: 1m 21s	remaining: 163ms
# 998:	learn: 0.1496509	total: 1m 21s	remaining: 81.4ms
# 999:	learn: 0.1495981	total: 1m 21s	remaining: 0us
#                  Model  Accuracy  Recall Majority (TNR)  \
# 0             Baseline  0.899517               1.000000
# 1        Random Forest  0.899517               1.000000
# 2  Logistic Regression  0.913250               0.985807
# 3              XGBoost  0.913183               0.987660
# 4             LightGBM  0.907650               0.998240
# 5             CatBoost  0.920667               0.989420
#
#    Recall Minority (TPR)  Balanced Accuracy       FPR       FNR  \
# 0               0.000000           0.500000  0.000000  1.000000
# 1               0.000000           0.500000  0.000000  1.000000
# 2               0.263725           0.624766  0.014193  0.736275
# 3               0.246475           0.617068  0.012340  0.753525
# 4               0.096699           0.547470  0.001760  0.903301
# 5               0.305192           0.647306  0.010580  0.694808
#
#    Precision Majority  Precision Minority  F1-Score Majority  ...  \
# 0            0.899517            0.000000           0.947101  ...
# 1            0.899517            0.000000           0.947101  ...
# 2            0.922993            0.674873           0.953366  ...
# 3            0.921467            0.690520           0.953416  ...
# 4            0.908196            0.859882           0.951091  ...
# 5            0.927260            0.763169           0.957332  ...
#
#    G-mean-binary  G-mean-weighted  G-mean-micro  G-mean-macro  \
# 0       0.000000         0.300643      0.899517      0.500000
# 1       0.000000         0.300643      0.899517      0.500000
# 2       0.509885         0.554175      0.913250      0.624766
# 3       0.493390         0.541376      0.913183      0.617068
# 4       0.310691         0.412302      0.907650      0.547470
# 5       0.549511         0.586753      0.920667      0.647306
#
#    Corrected G-mean  Corrected G-mean-binary  Corrected G-mean-weighted  \
# 0          0.000000                 0.000000                   0.126497
# 1          0.000000                 0.000000                   0.126497
# 2          0.259982                 0.166118                   0.395706
# 3          0.243434                 0.153219                   0.379876
# 4          0.096529                 0.053017                   0.231221
# 5          0.301963                 0.198657                   0.438391
#
#    Corrected G-mean-micro  Corrected G-mean-macro  Dominance
# 0                0.809130                0.250000  -1.000000
# 1                0.809130                0.250000  -1.000000
# 2                0.834026                0.390333  -0.722082
# 3                0.833904                0.380773  -0.741185
# 4                0.823829                0.299723  -0.901541
# 5                0.847627                0.419005  -0.684229
#
# [6 rows x 30 columns]

# %%
# 5.1.2 Confusion Matrix
df_confusion_matrices = pd.DataFrame(confusion_matrices)

print(df_confusion_matrices)
# Out:
#                  Model              Confusion matrix
# 0             Baseline       [[53971, 0], [6029, 0]]
# 1        Random Forest       [[53971, 0], [6029, 0]]
# 2  Logistic Regression  [[53205, 766], [4439, 1590]]
# 3              XGBoost  [[53305, 666], [4543, 1486]]
# 4             LightGBM    [[53876, 95], [5446, 583]]
# 5             CatBoost  [[53400, 571], [4189, 1840]]

# %%
# 5.2 Metrics which Require Predict_Proba Method
models = {
    'Baseline': y_test_base,
    'Random Forest': rf.predict_proba(X_test)[:, 1],
    'Logistic Regression': logit.predict_proba(X_test)[:, 1],
    'XGBoost': xgb_model.predict_proba(X_test)[:, 1],
    'LightGBM': lgb_model.predict_proba(X_test)[:, 1],
    'CatBoost': catboost_model.predict_proba(X_test)[:, 1]
}

results = []
for model_name, y_pred in models.items():
    roc_auc = roc_auc_score(y_test, y_pred)
    pr_auc = average_precision_score(y_test, y_pred)
    results.append({
        'Model': model_name,
        'ROC-AUC': roc_auc,
        'PR-AUC': pr_auc
    })

df_results_2 = pd.DataFrame(results)

print(df_results_2)

# 6. Export Classification Metrics
df_combined_results = pd.concat([df_results_2, df_results_1], axis=1)
df_combined_results.to_csv('2_evaluation_results_stratify_sampling.csv', index=False)
df_confusion_matrices.to_csv('2_confusion_matrices_stratify_sampling.csv', index=False)
# Out:
#                  Model   ROC-AUC    PR-AUC
# 0             Baseline  0.500000  0.100483
# 1        Random Forest  0.748211  0.277832
# 2  Logistic Regression  0.858369  0.497739
# 3              XGBoost  0.854883  0.488493
# 4             LightGBM  0.863721  0.507548
# 5             CatBoost  0.893907  0.592283

# %% [markdown]
# ## 7. Theory notes
#
# While **predict_proba** is useful for many classification tasks, there are certain scenarios where you might choose not to use it:
#
# - **Binary Classification with Balanced Classes**: When the classes are balanced and you only care about the final classification (not the confidence of predictions), using **predict** to get class labels might be sufficient.
# - **Efficiency and Performance**: Calculating probabilities can be computationally more expensive than just predicting class labels. In real-time systems where speed is critical, you might prefer using **predict** to get the class labels directly.
# - **Certain Metrics**: Metrics like accuracy, precision, recall, and F1 score do not require probability estimates and can be computed directly from class labels.
# - **Simple Decision Making**: When a simple yes/no decision is needed without considering the probability or confidence level.

# %% [markdown]
# ##### Confusion matrix
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html
#
# TN | FP
#
# FN | TP

# %% [markdown]
# **Metrics which require predict_proba method**
# - The ROC AUC score is calculated based on the predicted probabilities for each class, which are obtained using the predict_proba method. This method - provides the probability estimates for each class, which are necessary to compute the ROC curve and subsequently the AUC (Area Under the Curve).
