# %% [markdown]
# # Santander

# %% [markdown]
# ## Contents
# - [1. Import Libraries](#1-Import-Libraries)
# - [2. Get Data](#2-Get-Data)
#     - [2.1 Read Data](#21-Read-Data)
#     - [2.2 Drop an unneeded column](#22-Drop-an-unneeded-column)
#     - [2.3 Split 70/30 (stratified sampling)](#23-Split-7030-stratified-sampling)
#     - [2.4 Scaling](#24-Scaling)
# - [3. Baseline: Predict the Majority Class](#3-Baseline-Predict-the-Majority-Class)
# - [4. Train ML Models](#4-Train-ML-Models)
#     - [4.1 Random Forest Classifier](#41-Random-Forest-Classifier)
#     - [4.2 Logistic Regression](#42-Logistic-Regression)
#     - [4.3 XGB Classifier](#43-XGB-Classifier)
#     - [4.4 Light GBM](#44-Light-GBM)
#     - [4.5 CatBoost](#45-CatBoost)
# - [5. Evaluation](#5-Evaluation)
#     - [5.1 Metrics which Require Predict Method](#51-Metrics-which-Require-Predict-Method)
#         - [5.1.1 Classification metrics](#511-Classification-metrics)
#         - [5.1.2 Confusion Matrix](#512-Confusion-Matrix)
#     - [5.2 Metrics which Require Predict_Proba Method](#52-Metrics-which-Require-Predict_Proba-Method)
# - [6. Export Classification Metrics](#6-Export-Classification-Metrics)
# - [7. Theory notes](#7-Theory-notes)

# %% [markdown]
# # 1. Import libs
# [top](#Contents)

# %%
# pandas and numpy imports
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

import warnings
# Suppress the specific warning
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn.metrics')

# %%
# pip install -U imbalanced-learn

# %% [markdown]
# # 2. Get data
# [top](#Contents)

# %% [markdown]
# #### Read data
# [top](#Contents)

# %%
bank_ds = pd.read_csv('train.csv')

# %%
bank_test_ds = pd.read_csv('test.csv')

# %% [markdown]
# #### Drop an unneeded column

# %%
# Assuming 'column_to_drop' is the name of the column you want to drop
column_to_drop = 'ID_code'

# Drop the column from bank_ds
bank_ds.drop(column_to_drop, axis=1, inplace=True)

# %% [markdown]
# ### Split 70/30 (stratified sampling)

# %%
target = bank_ds['target']

# %%
# separate dataset into train and test

X_train, X_test, y_train, y_test = train_test_split(
    bank_ds.drop(labels=['target'], axis=1),  # drop the target
    bank_ds['target'],  # just the target
    test_size=0.3,
    stratify=target,
    random_state=42)

X_train.shape, X_test.shape
# Out:
# ((140000, 200), (60000, 200))

# %% [markdown]
# ### Scaling

# %% [markdown]
# Models like Logistic Regression require scaling for better performance. Tree-based models like Random Forest, XGBoost, and LightGBM do not inherently require scaling but scaling can still be beneficial (can improve performance and convergence in some cases).

# %%
from sklearn.preprocessing import MinMaxScaler
# we put the variables in the same scale
scaler = MinMaxScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Baseline: predict the majority class

# %%
# Baseline prediction: predict the majority class

y_train_base = pd.Series(np.zeros(len(y_train)))
y_test_base = pd.Series(np.zeros(len(y_test)))

# %% [markdown]
# ## Train ML models
# ### Random Forests

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=2, n_jobs=4)

rf.fit(X_train, y_train)

y_train_rf = rf.predict_proba(X_train)[:,1]
y_test_rf = rf.predict_proba(X_test)[:,1]

# %% [markdown]
# ### Logistic Regression

# %%
logit = LogisticRegression(random_state=42,  max_iter=2000)

logit.fit(X_train, y_train)

y_train_logit = logit.predict_proba(X_train)[:,1]
y_test_logit = logit.predict_proba(X_test)[:,1]

# %% [markdown]
# ### XGB Classifier

# %%
import xgboost as xgb
from xgboost import XGBClassifier

xgb_model = XGBClassifier(random_state=42, use_label_encoder=False)

xgb_model.fit(X_train, y_train)

y_train_xgb = xgb_model.predict_proba(X_train)[:, 1]
y_test_xgb = xgb_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### Light GBM

# %%
import lightgbm as lgb
from lightgbm import LGBMClassifier

lgb_model = LGBMClassifier(random_state=42)

lgb_model.fit(X_train, y_train)

y_train_lgb = lgb_model.predict_proba(X_train)[:, 1]
y_test_lgb = lgb_model.predict_proba(X_test)[:, 1]
# Out:
# [LightGBM] [Info] Number of positive: 14069, number of negative: 125931
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.257812 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 140000, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.100493 -> initscore=-2.191760
# [LightGBM] [Info] Start training from score -2.191760

# %% [markdown]
# ### CatBoost

# %%
from catboost import CatBoostClassifier

catboost_model = CatBoostClassifier(random_state=42)

catboost_model.fit(X_train, y_train)

# Predict probabilities for the training and test sets
y_train_catboost = catboost_model.predict_proba(X_train)[:, 1]
y_test_catboost = catboost_model.predict_proba(X_test)[:, 1]
# Out:
# Learning rate set to 0.084983
# 0:	learn: 0.6221526	total: 301ms	remaining: 5m 1s
# 1:	learn: 0.5650405	total: 408ms	remaining: 3m 23s
# 2:	learn: 0.5183000	total: 524ms	remaining: 2m 54s
# 3:	learn: 0.4813300	total: 648ms	remaining: 2m 41s
# 4:	learn: 0.4505646	total: 795ms	remaining: 2m 38s
# 5:	learn: 0.4262856	total: 939ms	remaining: 2m 35s
# 6:	learn: 0.4043164	total: 1.06s	remaining: 2m 30s
# 7:	learn: 0.3868581	total: 1.18s	remaining: 2m 26s
# 8:	learn: 0.3728083	total: 1.31s	remaining: 2m 24s
# 9:	learn: 0.3609445	total: 1.43s	remaining: 2m 21s
# 10:	learn: 0.3514370	total: 1.56s	remaining: 2m 20s
# 11:	learn: 0.3431505	total: 1.7s	remaining: 2m 19s
# 12:	learn: 0.3365540	total: 1.82s	remaining: 2m 18s
# 13:	learn: 0.3305925	total: 1.94s	remaining: 2m 16s
# 14:	learn: 0.3257796	total: 2.06s	remaining: 2m 15s
# 15:	learn: 0.3216046	total: 2.17s	remaining: 2m 13s
# 16:	learn: 0.3178592	total: 2.29s	remaining: 2m 12s
# 17:	learn: 0.3146867	total: 2.4s	remaining: 2m 11s
# 18:	learn: 0.3118125	total: 2.52s	remaining: 2m 10s
# 19:	learn: 0.3091812	total: 2.63s	remaining: 2m 8s
# 20:	learn: 0.3069866	total: 2.75s	remaining: 2m 8s
# 21:	learn: 0.3050306	total: 2.87s	remaining: 2m 7s
# 22:	learn: 0.3032449	total: 2.98s	remaining: 2m 6s
# 23:	learn: 0.3015804	total: 3.08s	remaining: 2m 5s
# 24:	learn: 0.2999785	total: 3.18s	remaining: 2m 3s
# 25:	learn: 0.2986313	total: 3.26s	remaining: 2m 2s
# 26:	learn: 0.2974256	total: 3.35s	remaining: 2m
# 27:	learn: 0.2961247	total: 3.44s	remaining: 1m 59s
# 28:	learn: 0.2949316	total: 3.54s	remaining: 1m 58s
# 29:	learn: 0.2937849	total: 3.63s	remaining: 1m 57s
# 30:	learn: 0.2927667	total: 3.72s	remaining: 1m 56s
# 31:	learn: 0.2916739	total: 3.81s	remaining: 1m 55s
# 32:	learn: 0.2906592	total: 3.9s	remaining: 1m 54s
# 33:	learn: 0.2897173	total: 4.01s	remaining: 1m 53s
# 34:	learn: 0.2887478	total: 4.12s	remaining: 1m 53s
# 35:	learn: 0.2878750	total: 4.24s	remaining: 1m 53s
# 36:	learn: 0.2870279	total: 4.33s	remaining: 1m 52s
# 37:	learn: 0.2861845	total: 4.42s	remaining: 1m 52s
# 38:	learn: 0.2854006	total: 4.52s	remaining: 1m 51s
# 39:	learn: 0.2846293	total: 4.63s	remaining: 1m 51s
# 40:	learn: 0.2839054	total: 4.78s	remaining: 1m 51s
# 41:	learn: 0.2831302	total: 4.92s	remaining: 1m 52s
# 42:	learn: 0.2824401	total: 5.02s	remaining: 1m 51s
# 43:	learn: 0.2817306	total: 5.13s	remaining: 1m 51s
# 44:	learn: 0.2809724	total: 5.25s	remaining: 1m 51s
# 45:	learn: 0.2802893	total: 5.35s	remaining: 1m 50s
# 46:	learn: 0.2796130	total: 5.47s	remaining: 1m 50s
# 47:	learn: 0.2789197	total: 5.58s	remaining: 1m 50s
# 48:	learn: 0.2782905	total: 5.68s	remaining: 1m 50s
# 49:	learn: 0.2776176	total: 5.79s	remaining: 1m 50s
# 50:	learn: 0.2769521	total: 5.91s	remaining: 1m 49s
# 51:	learn: 0.2763425	total: 6.02s	remaining: 1m 49s
# 52:	learn: 0.2756696	total: 6.17s	remaining: 1m 50s
# 53:	learn: 0.2750566	total: 6.29s	remaining: 1m 50s
# 54:	learn: 0.2744384	total: 6.39s	remaining: 1m 49s
# 55:	learn: 0.2738640	total: 6.49s	remaining: 1m 49s
# 56:	learn: 0.2733043	total: 6.6s	remaining: 1m 49s
# 57:	learn: 0.2727532	total: 6.7s	remaining: 1m 48s
# 58:	learn: 0.2721711	total: 6.8s	remaining: 1m 48s
# 59:	learn: 0.2716461	total: 6.91s	remaining: 1m 48s
# 60:	learn: 0.2710902	total: 7s	remaining: 1m 47s
# 61:	learn: 0.2705629	total: 7.1s	remaining: 1m 47s
# 62:	learn: 0.2700092	total: 7.21s	remaining: 1m 47s
# 63:	learn: 0.2694810	total: 7.31s	remaining: 1m 46s
# 64:	learn: 0.2689573	total: 7.42s	remaining: 1m 46s
# 65:	learn: 0.2684527	total: 7.53s	remaining: 1m 46s
# 66:	learn: 0.2678629	total: 7.65s	remaining: 1m 46s
# 67:	learn: 0.2673702	total: 7.75s	remaining: 1m 46s
# 68:	learn: 0.2668328	total: 7.92s	remaining: 1m 46s
# 69:	learn: 0.2663568	total: 8.03s	remaining: 1m 46s
# 70:	learn: 0.2658680	total: 8.14s	remaining: 1m 46s
# 71:	learn: 0.2653625	total: 8.24s	remaining: 1m 46s
# 72:	learn: 0.2649158	total: 8.34s	remaining: 1m 45s
# 73:	learn: 0.2644094	total: 8.46s	remaining: 1m 45s
# 74:	learn: 0.2638885	total: 8.57s	remaining: 1m 45s
# 75:	learn: 0.2634785	total: 8.67s	remaining: 1m 45s
# 76:	learn: 0.2629853	total: 8.79s	remaining: 1m 45s
# 77:	learn: 0.2625604	total: 8.88s	remaining: 1m 45s
# 78:	learn: 0.2620789	total: 8.99s	remaining: 1m 44s
# 79:	learn: 0.2616129	total: 9.1s	remaining: 1m 44s
# 80:	learn: 0.2611629	total: 9.2s	remaining: 1m 44s
# 81:	learn: 0.2607132	total: 9.33s	remaining: 1m 44s
# 82:	learn: 0.2602257	total: 9.45s	remaining: 1m 44s
# 83:	learn: 0.2597249	total: 9.57s	remaining: 1m 44s
# 84:	learn: 0.2593187	total: 9.69s	remaining: 1m 44s
# 85:	learn: 0.2589140	total: 9.79s	remaining: 1m 44s
# 86:	learn: 0.2584503	total: 9.91s	remaining: 1m 44s
# 87:	learn: 0.2580250	total: 10s	remaining: 1m 43s
# 88:	learn: 0.2576278	total: 10.1s	remaining: 1m 43s
# 89:	learn: 0.2572007	total: 10.3s	remaining: 1m 43s
# 90:	learn: 0.2567841	total: 10.4s	remaining: 1m 43s
# 91:	learn: 0.2563898	total: 10.5s	remaining: 1m 43s
# 92:	learn: 0.2559988	total: 10.6s	remaining: 1m 43s
# 93:	learn: 0.2555940	total: 10.7s	remaining: 1m 42s
# 94:	learn: 0.2552309	total: 10.8s	remaining: 1m 42s
# 95:	learn: 0.2548146	total: 10.9s	remaining: 1m 42s
# 96:	learn: 0.2544149	total: 11s	remaining: 1m 42s
# 97:	learn: 0.2540205	total: 11.1s	remaining: 1m 41s
# 98:	learn: 0.2536411	total: 11.2s	remaining: 1m 41s
# 99:	learn: 0.2532556	total: 11.3s	remaining: 1m 41s
# 100:	learn: 0.2529172	total: 11.3s	remaining: 1m 41s
# 101:	learn: 0.2525499	total: 11.4s	remaining: 1m 40s
# 102:	learn: 0.2521918	total: 11.5s	remaining: 1m 40s
# 103:	learn: 0.2518259	total: 11.6s	remaining: 1m 40s
# 104:	learn: 0.2514631	total: 11.7s	remaining: 1m 39s
# 105:	learn: 0.2511016	total: 11.8s	remaining: 1m 39s
# 106:	learn: 0.2507435	total: 11.9s	remaining: 1m 39s
# 107:	learn: 0.2504145	total: 12s	remaining: 1m 39s
# 108:	learn: 0.2500677	total: 12.1s	remaining: 1m 38s
# 109:	learn: 0.2497186	total: 12.2s	remaining: 1m 38s
# 110:	learn: 0.2493943	total: 12.3s	remaining: 1m 38s
# 111:	learn: 0.2490500	total: 12.4s	remaining: 1m 38s
# 112:	learn: 0.2487276	total: 12.5s	remaining: 1m 37s
# 113:	learn: 0.2484199	total: 12.6s	remaining: 1m 37s
# 114:	learn: 0.2480668	total: 12.7s	remaining: 1m 37s
# 115:	learn: 0.2477549	total: 12.8s	remaining: 1m 37s
# 116:	learn: 0.2474404	total: 12.8s	remaining: 1m 36s
# 117:	learn: 0.2471257	total: 12.9s	remaining: 1m 36s
# 118:	learn: 0.2467850	total: 13s	remaining: 1m 36s
# 119:	learn: 0.2464515	total: 13.1s	remaining: 1m 36s
# 120:	learn: 0.2461380	total: 13.2s	remaining: 1m 35s
# 121:	learn: 0.2458264	total: 13.3s	remaining: 1m 35s
# 122:	learn: 0.2454631	total: 13.4s	remaining: 1m 35s
# 123:	learn: 0.2451416	total: 13.5s	remaining: 1m 35s
# 124:	learn: 0.2448372	total: 13.6s	remaining: 1m 35s
# 125:	learn: 0.2445436	total: 13.7s	remaining: 1m 35s
# 126:	learn: 0.2442234	total: 13.8s	remaining: 1m 35s
# 127:	learn: 0.2439378	total: 13.9s	remaining: 1m 34s
# 128:	learn: 0.2436497	total: 14s	remaining: 1m 34s
# 129:	learn: 0.2433498	total: 14.1s	remaining: 1m 34s
# 130:	learn: 0.2430333	total: 14.3s	remaining: 1m 34s
# 131:	learn: 0.2427541	total: 14.3s	remaining: 1m 34s
# 132:	learn: 0.2424450	total: 14.5s	remaining: 1m 34s
# 133:	learn: 0.2421614	total: 14.6s	remaining: 1m 34s
# 134:	learn: 0.2418524	total: 14.7s	remaining: 1m 33s
# 135:	learn: 0.2415763	total: 14.7s	remaining: 1m 33s
# 136:	learn: 0.2412889	total: 14.8s	remaining: 1m 33s
# 137:	learn: 0.2410143	total: 15s	remaining: 1m 33s
# 138:	learn: 0.2407235	total: 15.1s	remaining: 1m 33s
# 139:	learn: 0.2404703	total: 15.2s	remaining: 1m 33s
# 140:	learn: 0.2401929	total: 15.3s	remaining: 1m 32s
# 141:	learn: 0.2399171	total: 15.4s	remaining: 1m 32s
# 142:	learn: 0.2396137	total: 15.5s	remaining: 1m 32s
# 143:	learn: 0.2393040	total: 15.6s	remaining: 1m 32s
# 144:	learn: 0.2390516	total: 15.7s	remaining: 1m 32s
# 145:	learn: 0.2387558	total: 15.8s	remaining: 1m 32s
# 146:	learn: 0.2384795	total: 15.9s	remaining: 1m 32s
# 147:	learn: 0.2381892	total: 16s	remaining: 1m 32s
# 148:	learn: 0.2379104	total: 16.1s	remaining: 1m 31s
# 149:	learn: 0.2376564	total: 16.2s	remaining: 1m 31s
# 150:	learn: 0.2373539	total: 16.3s	remaining: 1m 31s
# 151:	learn: 0.2370928	total: 16.4s	remaining: 1m 31s
# 152:	learn: 0.2367907	total: 16.5s	remaining: 1m 31s
# 153:	learn: 0.2365270	total: 16.6s	remaining: 1m 31s
# 154:	learn: 0.2362757	total: 16.7s	remaining: 1m 31s
# 155:	learn: 0.2360196	total: 16.8s	remaining: 1m 31s
# 156:	learn: 0.2357412	total: 16.9s	remaining: 1m 30s
# 157:	learn: 0.2354869	total: 17s	remaining: 1m 30s
# 158:	learn: 0.2352228	total: 17.1s	remaining: 1m 30s
# 159:	learn: 0.2349544	total: 17.2s	remaining: 1m 30s
# 160:	learn: 0.2347143	total: 17.3s	remaining: 1m 30s
# 161:	learn: 0.2344442	total: 17.4s	remaining: 1m 30s
# 162:	learn: 0.2341900	total: 17.5s	remaining: 1m 29s
# 163:	learn: 0.2339341	total: 17.6s	remaining: 1m 29s
# 164:	learn: 0.2336845	total: 17.7s	remaining: 1m 29s
# 165:	learn: 0.2334356	total: 17.8s	remaining: 1m 29s
# 166:	learn: 0.2331860	total: 17.9s	remaining: 1m 29s
# 167:	learn: 0.2329133	total: 18s	remaining: 1m 29s
# 168:	learn: 0.2326656	total: 18.1s	remaining: 1m 29s
# 169:	learn: 0.2323913	total: 18.2s	remaining: 1m 29s
# 170:	learn: 0.2321533	total: 18.4s	remaining: 1m 28s
# 171:	learn: 0.2319303	total: 18.4s	remaining: 1m 28s
# 172:	learn: 0.2316964	total: 18.6s	remaining: 1m 28s
# 173:	learn: 0.2314617	total: 18.7s	remaining: 1m 28s
# 174:	learn: 0.2312276	total: 18.8s	remaining: 1m 28s
# 175:	learn: 0.2309817	total: 18.9s	remaining: 1m 28s
# 176:	learn: 0.2307351	total: 19s	remaining: 1m 28s
# 177:	learn: 0.2305169	total: 19.1s	remaining: 1m 27s
# 178:	learn: 0.2302782	total: 19.2s	remaining: 1m 27s
# 179:	learn: 0.2300351	total: 19.3s	remaining: 1m 27s
# 180:	learn: 0.2298007	total: 19.4s	remaining: 1m 27s
# 181:	learn: 0.2295537	total: 19.5s	remaining: 1m 27s
# 182:	learn: 0.2293054	total: 19.6s	remaining: 1m 27s
# 183:	learn: 0.2290799	total: 19.7s	remaining: 1m 27s
# 184:	learn: 0.2288391	total: 19.8s	remaining: 1m 27s
# 185:	learn: 0.2286030	total: 19.9s	remaining: 1m 26s
# 186:	learn: 0.2283606	total: 20s	remaining: 1m 26s
# 187:	learn: 0.2281116	total: 20.1s	remaining: 1m 26s
# 188:	learn: 0.2278886	total: 20.2s	remaining: 1m 26s
# 189:	learn: 0.2276370	total: 20.3s	remaining: 1m 26s
# 190:	learn: 0.2274106	total: 20.4s	remaining: 1m 26s
# 191:	learn: 0.2271922	total: 20.5s	remaining: 1m 26s
# 192:	learn: 0.2269797	total: 20.6s	remaining: 1m 26s
# 193:	learn: 0.2267440	total: 20.8s	remaining: 1m 26s
# 194:	learn: 0.2265236	total: 20.9s	remaining: 1m 26s
# 195:	learn: 0.2263030	total: 21s	remaining: 1m 26s
# 196:	learn: 0.2260950	total: 21.1s	remaining: 1m 26s
# 197:	learn: 0.2258990	total: 21.2s	remaining: 1m 25s
# 198:	learn: 0.2256824	total: 21.3s	remaining: 1m 25s
# 199:	learn: 0.2254749	total: 21.5s	remaining: 1m 25s
# 200:	learn: 0.2252671	total: 21.6s	remaining: 1m 25s
# 201:	learn: 0.2250558	total: 21.7s	remaining: 1m 25s
# 202:	learn: 0.2248408	total: 21.9s	remaining: 1m 25s
# 203:	learn: 0.2246392	total: 22s	remaining: 1m 25s
# 204:	learn: 0.2244325	total: 22.1s	remaining: 1m 25s
# 205:	learn: 0.2242192	total: 22.2s	remaining: 1m 25s
# 206:	learn: 0.2240028	total: 22.4s	remaining: 1m 25s
# 207:	learn: 0.2237909	total: 22.5s	remaining: 1m 25s
# 208:	learn: 0.2235734	total: 22.6s	remaining: 1m 25s
# 209:	learn: 0.2233653	total: 22.7s	remaining: 1m 25s
# 210:	learn: 0.2231608	total: 22.8s	remaining: 1m 25s
# 211:	learn: 0.2229611	total: 22.9s	remaining: 1m 25s
# 212:	learn: 0.2227600	total: 23s	remaining: 1m 25s
# 213:	learn: 0.2225449	total: 23.2s	remaining: 1m 25s
# 214:	learn: 0.2223352	total: 23.3s	remaining: 1m 24s
# 215:	learn: 0.2221397	total: 23.4s	remaining: 1m 24s
# 216:	learn: 0.2219470	total: 23.5s	remaining: 1m 24s
# 217:	learn: 0.2217508	total: 23.6s	remaining: 1m 24s
# 218:	learn: 0.2215401	total: 23.7s	remaining: 1m 24s
# 219:	learn: 0.2213205	total: 23.9s	remaining: 1m 24s
# 220:	learn: 0.2211167	total: 24s	remaining: 1m 24s
# 221:	learn: 0.2209211	total: 24.1s	remaining: 1m 24s
# 222:	learn: 0.2207317	total: 24.2s	remaining: 1m 24s
# 223:	learn: 0.2205196	total: 24.3s	remaining: 1m 24s
# 224:	learn: 0.2203189	total: 24.4s	remaining: 1m 24s
# 225:	learn: 0.2201308	total: 24.5s	remaining: 1m 23s
# 226:	learn: 0.2199348	total: 24.7s	remaining: 1m 23s
# 227:	learn: 0.2197394	total: 24.8s	remaining: 1m 23s
# 228:	learn: 0.2195569	total: 24.9s	remaining: 1m 23s
# 229:	learn: 0.2193748	total: 25.1s	remaining: 1m 23s
# 230:	learn: 0.2191890	total: 25.2s	remaining: 1m 23s
# 231:	learn: 0.2190172	total: 25.3s	remaining: 1m 23s
# 232:	learn: 0.2188301	total: 25.4s	remaining: 1m 23s
# 233:	learn: 0.2186416	total: 25.6s	remaining: 1m 23s
# 234:	learn: 0.2184503	total: 25.7s	remaining: 1m 23s
# 235:	learn: 0.2182642	total: 25.9s	remaining: 1m 23s
# 236:	learn: 0.2180767	total: 26s	remaining: 1m 23s
# 237:	learn: 0.2178746	total: 26.1s	remaining: 1m 23s
# 238:	learn: 0.2176799	total: 26.3s	remaining: 1m 23s
# 239:	learn: 0.2175215	total: 26.4s	remaining: 1m 23s
# 240:	learn: 0.2173330	total: 26.5s	remaining: 1m 23s
# 241:	learn: 0.2171590	total: 26.6s	remaining: 1m 23s
# 242:	learn: 0.2169815	total: 26.7s	remaining: 1m 23s
# 243:	learn: 0.2168082	total: 26.9s	remaining: 1m 23s
# 244:	learn: 0.2166308	total: 27s	remaining: 1m 23s
# 245:	learn: 0.2164770	total: 27.1s	remaining: 1m 23s
# 246:	learn: 0.2162971	total: 27.2s	remaining: 1m 23s
# 247:	learn: 0.2161291	total: 27.4s	remaining: 1m 22s
# 248:	learn: 0.2159485	total: 27.5s	remaining: 1m 22s
# 249:	learn: 0.2157676	total: 27.6s	remaining: 1m 22s
# 250:	learn: 0.2155830	total: 27.8s	remaining: 1m 23s
# 251:	learn: 0.2154030	total: 28s	remaining: 1m 22s
# 252:	learn: 0.2152235	total: 28.1s	remaining: 1m 22s
# 253:	learn: 0.2150362	total: 28.2s	remaining: 1m 22s
# 254:	learn: 0.2148704	total: 28.3s	remaining: 1m 22s
# 255:	learn: 0.2146959	total: 28.4s	remaining: 1m 22s
# 256:	learn: 0.2145253	total: 28.5s	remaining: 1m 22s
# 257:	learn: 0.2143602	total: 28.6s	remaining: 1m 22s
# 258:	learn: 0.2141975	total: 28.7s	remaining: 1m 22s
# 259:	learn: 0.2140218	total: 28.8s	remaining: 1m 21s
# 260:	learn: 0.2138457	total: 28.9s	remaining: 1m 21s
# 261:	learn: 0.2136554	total: 29s	remaining: 1m 21s
# 262:	learn: 0.2134829	total: 29.1s	remaining: 1m 21s
# 263:	learn: 0.2133198	total: 29.2s	remaining: 1m 21s
# 264:	learn: 0.2131462	total: 29.3s	remaining: 1m 21s
# 265:	learn: 0.2129727	total: 29.4s	remaining: 1m 21s
# 266:	learn: 0.2128053	total: 29.5s	remaining: 1m 20s
# 267:	learn: 0.2126302	total: 29.6s	remaining: 1m 20s
# 268:	learn: 0.2124616	total: 29.7s	remaining: 1m 20s
# 269:	learn: 0.2122937	total: 29.8s	remaining: 1m 20s
# 270:	learn: 0.2121472	total: 29.9s	remaining: 1m 20s
# 271:	learn: 0.2119902	total: 30s	remaining: 1m 20s
# 272:	learn: 0.2118380	total: 30s	remaining: 1m 20s
# 273:	learn: 0.2116759	total: 30.1s	remaining: 1m 19s
# 274:	learn: 0.2115265	total: 30.2s	remaining: 1m 19s
# 275:	learn: 0.2113796	total: 30.3s	remaining: 1m 19s
# 276:	learn: 0.2112274	total: 30.4s	remaining: 1m 19s
# 277:	learn: 0.2110626	total: 30.5s	remaining: 1m 19s
# 278:	learn: 0.2109216	total: 30.6s	remaining: 1m 19s
# 279:	learn: 0.2107635	total: 30.7s	remaining: 1m 19s
# 280:	learn: 0.2105997	total: 30.8s	remaining: 1m 18s
# 281:	learn: 0.2104511	total: 31s	remaining: 1m 18s
# 282:	learn: 0.2102995	total: 31.1s	remaining: 1m 18s
# 283:	learn: 0.2101440	total: 31.2s	remaining: 1m 18s
# 284:	learn: 0.2099910	total: 31.3s	remaining: 1m 18s
# 285:	learn: 0.2098245	total: 31.4s	remaining: 1m 18s
# 286:	learn: 0.2096810	total: 31.5s	remaining: 1m 18s
# 287:	learn: 0.2095184	total: 31.6s	remaining: 1m 18s
# 288:	learn: 0.2093670	total: 31.7s	remaining: 1m 17s
# 289:	learn: 0.2092056	total: 31.8s	remaining: 1m 17s
# 290:	learn: 0.2090671	total: 31.9s	remaining: 1m 17s
# 291:	learn: 0.2089049	total: 32s	remaining: 1m 17s
# 292:	learn: 0.2087484	total: 32.1s	remaining: 1m 17s
# 293:	learn: 0.2085961	total: 32.2s	remaining: 1m 17s
# 294:	learn: 0.2084587	total: 32.3s	remaining: 1m 17s
# 295:	learn: 0.2083149	total: 32.4s	remaining: 1m 17s
# 296:	learn: 0.2081440	total: 32.5s	remaining: 1m 16s
# 297:	learn: 0.2080002	total: 32.6s	remaining: 1m 16s
# 298:	learn: 0.2078516	total: 32.7s	remaining: 1m 16s
# 299:	learn: 0.2076969	total: 32.9s	remaining: 1m 16s
# 300:	learn: 0.2075547	total: 33s	remaining: 1m 16s
# 301:	learn: 0.2074106	total: 33.1s	remaining: 1m 16s
# 302:	learn: 0.2072808	total: 33.2s	remaining: 1m 16s
# 303:	learn: 0.2071598	total: 33.3s	remaining: 1m 16s
# 304:	learn: 0.2070131	total: 33.4s	remaining: 1m 16s
# 305:	learn: 0.2068778	total: 33.5s	remaining: 1m 16s
# 306:	learn: 0.2067311	total: 33.6s	remaining: 1m 15s
# 307:	learn: 0.2065776	total: 33.8s	remaining: 1m 15s
# 308:	learn: 0.2064356	total: 33.9s	remaining: 1m 15s
# 309:	learn: 0.2062902	total: 34s	remaining: 1m 15s
# 310:	learn: 0.2061468	total: 34.1s	remaining: 1m 15s
# 311:	learn: 0.2060093	total: 34.2s	remaining: 1m 15s
# 312:	learn: 0.2058641	total: 34.3s	remaining: 1m 15s
# 313:	learn: 0.2057184	total: 34.4s	remaining: 1m 15s
# 314:	learn: 0.2055763	total: 34.5s	remaining: 1m 15s
# 315:	learn: 0.2054326	total: 34.6s	remaining: 1m 14s
# 316:	learn: 0.2052953	total: 34.7s	remaining: 1m 14s
# 317:	learn: 0.2051579	total: 34.8s	remaining: 1m 14s
# 318:	learn: 0.2050249	total: 34.9s	remaining: 1m 14s
# 319:	learn: 0.2048920	total: 35s	remaining: 1m 14s
# 320:	learn: 0.2047518	total: 35.2s	remaining: 1m 14s
# 321:	learn: 0.2046102	total: 35.3s	remaining: 1m 14s
# 322:	learn: 0.2044781	total: 35.4s	remaining: 1m 14s
# 323:	learn: 0.2043363	total: 35.5s	remaining: 1m 14s
# 324:	learn: 0.2041921	total: 35.6s	remaining: 1m 14s
# 325:	learn: 0.2040514	total: 35.8s	remaining: 1m 13s
# 326:	learn: 0.2039163	total: 35.9s	remaining: 1m 13s
# 327:	learn: 0.2037857	total: 36s	remaining: 1m 13s
# 328:	learn: 0.2036402	total: 36.1s	remaining: 1m 13s
# 329:	learn: 0.2035140	total: 36.2s	remaining: 1m 13s
# 330:	learn: 0.2033597	total: 36.3s	remaining: 1m 13s
# 331:	learn: 0.2032279	total: 36.4s	remaining: 1m 13s
# 332:	learn: 0.2030891	total: 36.5s	remaining: 1m 13s
# 333:	learn: 0.2029589	total: 36.6s	remaining: 1m 13s
# 334:	learn: 0.2028209	total: 36.8s	remaining: 1m 12s
# 335:	learn: 0.2026752	total: 36.9s	remaining: 1m 12s
# 336:	learn: 0.2025415	total: 37s	remaining: 1m 12s
# 337:	learn: 0.2023994	total: 37.1s	remaining: 1m 12s
# 338:	learn: 0.2022835	total: 37.2s	remaining: 1m 12s
# 339:	learn: 0.2021577	total: 37.3s	remaining: 1m 12s
# 340:	learn: 0.2020181	total: 37.5s	remaining: 1m 12s
# 341:	learn: 0.2018832	total: 37.6s	remaining: 1m 12s
# 342:	learn: 0.2017468	total: 37.7s	remaining: 1m 12s
# 343:	learn: 0.2016095	total: 37.8s	remaining: 1m 12s
# 344:	learn: 0.2014724	total: 37.9s	remaining: 1m 11s
# 345:	learn: 0.2013356	total: 38.1s	remaining: 1m 11s
# 346:	learn: 0.2012154	total: 38.2s	remaining: 1m 11s
# 347:	learn: 0.2010700	total: 38.3s	remaining: 1m 11s
# 348:	learn: 0.2009503	total: 38.4s	remaining: 1m 11s
# 349:	learn: 0.2008079	total: 38.6s	remaining: 1m 11s
# 350:	learn: 0.2006802	total: 38.7s	remaining: 1m 11s
# 351:	learn: 0.2005530	total: 38.8s	remaining: 1m 11s
# 352:	learn: 0.2004386	total: 39s	remaining: 1m 11s
# 353:	learn: 0.2003040	total: 39.1s	remaining: 1m 11s
# 354:	learn: 0.2001830	total: 39.2s	remaining: 1m 11s
# 355:	learn: 0.2000524	total: 39.3s	remaining: 1m 11s
# 356:	learn: 0.1999306	total: 39.5s	remaining: 1m 11s
# 357:	learn: 0.1997981	total: 39.6s	remaining: 1m 11s
# 358:	learn: 0.1996643	total: 39.8s	remaining: 1m 10s
# 359:	learn: 0.1995568	total: 39.9s	remaining: 1m 10s
# 360:	learn: 0.1994379	total: 40s	remaining: 1m 10s
# 361:	learn: 0.1993173	total: 40.1s	remaining: 1m 10s
# 362:	learn: 0.1991915	total: 40.2s	remaining: 1m 10s
# 363:	learn: 0.1990813	total: 40.4s	remaining: 1m 10s
# 364:	learn: 0.1989584	total: 40.5s	remaining: 1m 10s
# 365:	learn: 0.1988491	total: 40.6s	remaining: 1m 10s
# 366:	learn: 0.1987353	total: 40.8s	remaining: 1m 10s
# 367:	learn: 0.1986123	total: 40.9s	remaining: 1m 10s
# 368:	learn: 0.1984992	total: 41s	remaining: 1m 10s
# 369:	learn: 0.1983737	total: 41.1s	remaining: 1m 9s
# 370:	learn: 0.1982550	total: 41.2s	remaining: 1m 9s
# 371:	learn: 0.1981366	total: 41.3s	remaining: 1m 9s
# 372:	learn: 0.1980142	total: 41.5s	remaining: 1m 9s
# 373:	learn: 0.1978957	total: 41.6s	remaining: 1m 9s
# 374:	learn: 0.1977752	total: 41.7s	remaining: 1m 9s
# 375:	learn: 0.1976646	total: 41.8s	remaining: 1m 9s
# 376:	learn: 0.1975390	total: 42s	remaining: 1m 9s
# 377:	learn: 0.1974186	total: 42.1s	remaining: 1m 9s
# 378:	learn: 0.1972939	total: 42.2s	remaining: 1m 9s
# 379:	learn: 0.1971673	total: 42.3s	remaining: 1m 9s
# 380:	learn: 0.1970511	total: 42.5s	remaining: 1m 8s
# 381:	learn: 0.1969295	total: 42.6s	remaining: 1m 8s
# 382:	learn: 0.1968042	total: 42.7s	remaining: 1m 8s
# 383:	learn: 0.1966906	total: 42.8s	remaining: 1m 8s
# 384:	learn: 0.1965840	total: 42.9s	remaining: 1m 8s
# 385:	learn: 0.1964666	total: 43.1s	remaining: 1m 8s
# 386:	learn: 0.1963502	total: 43.2s	remaining: 1m 8s
# 387:	learn: 0.1962280	total: 43.3s	remaining: 1m 8s
# 388:	learn: 0.1961077	total: 43.5s	remaining: 1m 8s
# 389:	learn: 0.1959915	total: 43.6s	remaining: 1m 8s
# 390:	learn: 0.1958730	total: 43.7s	remaining: 1m 8s
# 391:	learn: 0.1957596	total: 43.8s	remaining: 1m 7s
# 392:	learn: 0.1956464	total: 43.9s	remaining: 1m 7s
# 393:	learn: 0.1955288	total: 44.1s	remaining: 1m 7s
# 394:	learn: 0.1954121	total: 44.2s	remaining: 1m 7s
# 395:	learn: 0.1953122	total: 44.3s	remaining: 1m 7s
# 396:	learn: 0.1951980	total: 44.4s	remaining: 1m 7s
# 397:	learn: 0.1950774	total: 44.5s	remaining: 1m 7s
# 398:	learn: 0.1949572	total: 44.6s	remaining: 1m 7s
# 399:	learn: 0.1948356	total: 44.7s	remaining: 1m 7s
# 400:	learn: 0.1947205	total: 44.8s	remaining: 1m 6s
# 401:	learn: 0.1946006	total: 44.9s	remaining: 1m 6s
# 402:	learn: 0.1944888	total: 45s	remaining: 1m 6s
# 403:	learn: 0.1943720	total: 45.1s	remaining: 1m 6s
# 404:	learn: 0.1942556	total: 45.2s	remaining: 1m 6s
# 405:	learn: 0.1941455	total: 45.3s	remaining: 1m 6s
# 406:	learn: 0.1940263	total: 45.4s	remaining: 1m 6s
# 407:	learn: 0.1939082	total: 45.5s	remaining: 1m 6s
# 408:	learn: 0.1938018	total: 45.6s	remaining: 1m 5s
# 409:	learn: 0.1936895	total: 45.7s	remaining: 1m 5s
# 410:	learn: 0.1935819	total: 45.9s	remaining: 1m 5s
# 411:	learn: 0.1934742	total: 46s	remaining: 1m 5s
# 412:	learn: 0.1933699	total: 46.1s	remaining: 1m 5s
# 413:	learn: 0.1932554	total: 46.2s	remaining: 1m 5s
# 414:	learn: 0.1931418	total: 46.3s	remaining: 1m 5s
# 415:	learn: 0.1930258	total: 46.4s	remaining: 1m 5s
# 416:	learn: 0.1929184	total: 46.5s	remaining: 1m 5s
# 417:	learn: 0.1928069	total: 46.6s	remaining: 1m 4s
# 418:	learn: 0.1927003	total: 46.7s	remaining: 1m 4s
# 419:	learn: 0.1925904	total: 46.8s	remaining: 1m 4s
# 420:	learn: 0.1924828	total: 47s	remaining: 1m 4s
# 421:	learn: 0.1923676	total: 47.1s	remaining: 1m 4s
# 422:	learn: 0.1922631	total: 47.2s	remaining: 1m 4s
# 423:	learn: 0.1921722	total: 47.3s	remaining: 1m 4s
# 424:	learn: 0.1920764	total: 47.4s	remaining: 1m 4s
# 425:	learn: 0.1919738	total: 47.5s	remaining: 1m 3s
# 426:	learn: 0.1918855	total: 47.6s	remaining: 1m 3s
# 427:	learn: 0.1917777	total: 47.7s	remaining: 1m 3s
# 428:	learn: 0.1916724	total: 47.8s	remaining: 1m 3s
# 429:	learn: 0.1915739	total: 47.9s	remaining: 1m 3s
# 430:	learn: 0.1914541	total: 48s	remaining: 1m 3s
# 431:	learn: 0.1913575	total: 48.1s	remaining: 1m 3s
# 432:	learn: 0.1912447	total: 48.2s	remaining: 1m 3s
# 433:	learn: 0.1911320	total: 48.3s	remaining: 1m 3s
# 434:	learn: 0.1910289	total: 48.4s	remaining: 1m 2s
# 435:	learn: 0.1909251	total: 48.5s	remaining: 1m 2s
# 436:	learn: 0.1908274	total: 48.6s	remaining: 1m 2s
# 437:	learn: 0.1907193	total: 48.7s	remaining: 1m 2s
# 438:	learn: 0.1906135	total: 48.8s	remaining: 1m 2s
# 439:	learn: 0.1905038	total: 48.9s	remaining: 1m 2s
# 440:	learn: 0.1903933	total: 49s	remaining: 1m 2s
# 441:	learn: 0.1902960	total: 49.1s	remaining: 1m 2s
# 442:	learn: 0.1901923	total: 49.2s	remaining: 1m 1s
# 443:	learn: 0.1901063	total: 49.4s	remaining: 1m 1s
# 444:	learn: 0.1899950	total: 49.5s	remaining: 1m 1s
# 445:	learn: 0.1898871	total: 49.6s	remaining: 1m 1s
# 446:	learn: 0.1897781	total: 49.7s	remaining: 1m 1s
# 447:	learn: 0.1896825	total: 49.8s	remaining: 1m 1s
# 448:	learn: 0.1895709	total: 49.9s	remaining: 1m 1s
# 449:	learn: 0.1894679	total: 50s	remaining: 1m 1s
# 450:	learn: 0.1893587	total: 50.1s	remaining: 1m
# 451:	learn: 0.1892484	total: 50.2s	remaining: 1m
# 452:	learn: 0.1891430	total: 50.3s	remaining: 1m
# 453:	learn: 0.1890293	total: 50.4s	remaining: 1m
# 454:	learn: 0.1889360	total: 50.5s	remaining: 1m
# 455:	learn: 0.1888433	total: 50.7s	remaining: 1m
# 456:	learn: 0.1887316	total: 50.8s	remaining: 1m
# 457:	learn: 0.1886327	total: 50.9s	remaining: 1m
# 458:	learn: 0.1885464	total: 51s	remaining: 1m
# 459:	learn: 0.1884623	total: 51.1s	remaining: 1m
# 460:	learn: 0.1883629	total: 51.3s	remaining: 60s
# 461:	learn: 0.1882677	total: 51.4s	remaining: 59.9s
# 462:	learn: 0.1881678	total: 51.5s	remaining: 59.8s
# 463:	learn: 0.1880786	total: 51.6s	remaining: 59.7s
# 464:	learn: 0.1879879	total: 51.8s	remaining: 59.5s
# 465:	learn: 0.1878867	total: 51.9s	remaining: 59.4s
# 466:	learn: 0.1877862	total: 51.9s	remaining: 59.3s
# 467:	learn: 0.1876929	total: 52s	remaining: 59.2s
# 468:	learn: 0.1875960	total: 52.1s	remaining: 59s
# 469:	learn: 0.1874937	total: 52.2s	remaining: 58.9s
# 470:	learn: 0.1873910	total: 52.4s	remaining: 58.8s
# 471:	learn: 0.1873036	total: 52.5s	remaining: 58.7s
# 472:	learn: 0.1872055	total: 52.6s	remaining: 58.6s
# 473:	learn: 0.1871004	total: 52.7s	remaining: 58.5s
# 474:	learn: 0.1869926	total: 52.8s	remaining: 58.4s
# 475:	learn: 0.1869091	total: 52.9s	remaining: 58.3s
# 476:	learn: 0.1868131	total: 53s	remaining: 58.1s
# 477:	learn: 0.1867145	total: 53.1s	remaining: 58s
# 478:	learn: 0.1866177	total: 53.3s	remaining: 57.9s
# 479:	learn: 0.1865171	total: 53.4s	remaining: 57.8s
# 480:	learn: 0.1864078	total: 53.5s	remaining: 57.7s
# 481:	learn: 0.1863194	total: 53.6s	remaining: 57.6s
# 482:	learn: 0.1862328	total: 53.7s	remaining: 57.5s
# 483:	learn: 0.1861296	total: 53.8s	remaining: 57.4s
# 484:	learn: 0.1860245	total: 53.9s	remaining: 57.2s
# 485:	learn: 0.1859253	total: 54s	remaining: 57.1s
# 486:	learn: 0.1858235	total: 54.1s	remaining: 57s
# 487:	learn: 0.1857161	total: 54.2s	remaining: 56.9s
# 488:	learn: 0.1856236	total: 54.4s	remaining: 56.8s
# 489:	learn: 0.1855251	total: 54.5s	remaining: 56.7s
# 490:	learn: 0.1854246	total: 54.6s	remaining: 56.6s
# 491:	learn: 0.1853348	total: 54.7s	remaining: 56.5s
# 492:	learn: 0.1852231	total: 54.8s	remaining: 56.4s
# 493:	learn: 0.1851259	total: 54.9s	remaining: 56.3s
# 494:	learn: 0.1850436	total: 55s	remaining: 56.2s
# 495:	learn: 0.1849532	total: 55.2s	remaining: 56.1s
# 496:	learn: 0.1848494	total: 55.3s	remaining: 56s
# 497:	learn: 0.1847469	total: 55.4s	remaining: 55.9s
# 498:	learn: 0.1846561	total: 55.6s	remaining: 55.8s
# 499:	learn: 0.1845573	total: 55.7s	remaining: 55.7s
# 500:	learn: 0.1844547	total: 55.8s	remaining: 55.5s
# 501:	learn: 0.1843700	total: 55.9s	remaining: 55.4s
# 502:	learn: 0.1842636	total: 56s	remaining: 55.3s
# 503:	learn: 0.1841749	total: 56.1s	remaining: 55.2s
# 504:	learn: 0.1840813	total: 56.2s	remaining: 55.1s
# 505:	learn: 0.1839912	total: 56.3s	remaining: 55s
# 506:	learn: 0.1838949	total: 56.5s	remaining: 54.9s
# 507:	learn: 0.1837998	total: 56.6s	remaining: 54.8s
# 508:	learn: 0.1837015	total: 56.7s	remaining: 54.7s
# 509:	learn: 0.1836282	total: 56.8s	remaining: 54.6s
# 510:	learn: 0.1835452	total: 56.9s	remaining: 54.5s
# 511:	learn: 0.1834596	total: 57s	remaining: 54.4s
# 512:	learn: 0.1833593	total: 57.1s	remaining: 54.3s
# 513:	learn: 0.1832811	total: 57.3s	remaining: 54.1s
# 514:	learn: 0.1831958	total: 57.4s	remaining: 54s
# 515:	learn: 0.1831099	total: 57.5s	remaining: 53.9s
# 516:	learn: 0.1830243	total: 57.6s	remaining: 53.8s
# 517:	learn: 0.1829295	total: 57.7s	remaining: 53.7s
# 518:	learn: 0.1828388	total: 57.8s	remaining: 53.6s
# 519:	learn: 0.1827497	total: 57.9s	remaining: 53.5s
# 520:	learn: 0.1826635	total: 58.1s	remaining: 53.4s
# 521:	learn: 0.1825591	total: 58.2s	remaining: 53.3s
# 522:	learn: 0.1824636	total: 58.4s	remaining: 53.3s
# 523:	learn: 0.1823704	total: 58.5s	remaining: 53.2s
# 524:	learn: 0.1822802	total: 58.6s	remaining: 53.1s
# 525:	learn: 0.1822040	total: 58.8s	remaining: 52.9s
# 526:	learn: 0.1821134	total: 58.9s	remaining: 52.8s
# 527:	learn: 0.1820226	total: 59s	remaining: 52.8s
# 528:	learn: 0.1819243	total: 59.1s	remaining: 52.7s
# 529:	learn: 0.1818317	total: 59.3s	remaining: 52.5s
# 530:	learn: 0.1817424	total: 59.4s	remaining: 52.4s
# 531:	learn: 0.1816660	total: 59.5s	remaining: 52.3s
# 532:	learn: 0.1815764	total: 59.6s	remaining: 52.2s
# 533:	learn: 0.1814767	total: 59.7s	remaining: 52.1s
# 534:	learn: 0.1813823	total: 59.8s	remaining: 52s
# 535:	learn: 0.1812835	total: 60s	remaining: 51.9s
# 536:	learn: 0.1811872	total: 1m	remaining: 51.8s
# 537:	learn: 0.1810940	total: 1m	remaining: 51.7s
# 538:	learn: 0.1810065	total: 1m	remaining: 51.5s
# 539:	learn: 0.1809332	total: 1m	remaining: 51.4s
# 540:	learn: 0.1808536	total: 1m	remaining: 51.3s
# 541:	learn: 0.1807646	total: 1m	remaining: 51.1s
# 542:	learn: 0.1806702	total: 1m	remaining: 51s
# 543:	learn: 0.1805776	total: 1m	remaining: 50.9s
# 544:	learn: 0.1804915	total: 1m	remaining: 50.8s
# 545:	learn: 0.1803960	total: 1m	remaining: 50.7s
# 546:	learn: 0.1802910	total: 1m 1s	remaining: 50.5s
# 547:	learn: 0.1802025	total: 1m 1s	remaining: 50.4s
# 548:	learn: 0.1801029	total: 1m 1s	remaining: 50.3s
# 549:	learn: 0.1800065	total: 1m 1s	remaining: 50.2s
# 550:	learn: 0.1799280	total: 1m 1s	remaining: 50s
# 551:	learn: 0.1798366	total: 1m 1s	remaining: 49.9s
# 552:	learn: 0.1797582	total: 1m 1s	remaining: 49.8s
# 553:	learn: 0.1796795	total: 1m 1s	remaining: 49.7s
# 554:	learn: 0.1795982	total: 1m 1s	remaining: 49.6s
# 555:	learn: 0.1795251	total: 1m 1s	remaining: 49.4s
# 556:	learn: 0.1794458	total: 1m 2s	remaining: 49.3s
# 557:	learn: 0.1793606	total: 1m 2s	remaining: 49.2s
# 558:	learn: 0.1792791	total: 1m 2s	remaining: 49.1s
# 559:	learn: 0.1792042	total: 1m 2s	remaining: 49s
# 560:	learn: 0.1791216	total: 1m 2s	remaining: 48.8s
# 561:	learn: 0.1790399	total: 1m 2s	remaining: 48.7s
# 562:	learn: 0.1789618	total: 1m 2s	remaining: 48.7s
# 563:	learn: 0.1788800	total: 1m 2s	remaining: 48.7s
# 564:	learn: 0.1787867	total: 1m 3s	remaining: 48.6s
# 565:	learn: 0.1787121	total: 1m 3s	remaining: 48.5s
# 566:	learn: 0.1786237	total: 1m 3s	remaining: 48.4s
# 567:	learn: 0.1785489	total: 1m 3s	remaining: 48.3s
# 568:	learn: 0.1784622	total: 1m 3s	remaining: 48.2s
# 569:	learn: 0.1783970	total: 1m 3s	remaining: 48s
# 570:	learn: 0.1783104	total: 1m 3s	remaining: 47.9s
# 571:	learn: 0.1782212	total: 1m 3s	remaining: 47.8s
# 572:	learn: 0.1781357	total: 1m 3s	remaining: 47.7s
# 573:	learn: 0.1780507	total: 1m 4s	remaining: 47.6s
# 574:	learn: 0.1779606	total: 1m 4s	remaining: 47.5s
# 575:	learn: 0.1778795	total: 1m 4s	remaining: 47.4s
# 576:	learn: 0.1778150	total: 1m 4s	remaining: 47.3s
# 577:	learn: 0.1777192	total: 1m 4s	remaining: 47.2s
# 578:	learn: 0.1776402	total: 1m 4s	remaining: 47.1s
# 579:	learn: 0.1775619	total: 1m 4s	remaining: 47s
# 580:	learn: 0.1774886	total: 1m 4s	remaining: 46.9s
# 581:	learn: 0.1773951	total: 1m 5s	remaining: 46.7s
# 582:	learn: 0.1773176	total: 1m 5s	remaining: 46.6s
# 583:	learn: 0.1772311	total: 1m 5s	remaining: 46.5s
# 584:	learn: 0.1771637	total: 1m 5s	remaining: 46.4s
# 585:	learn: 0.1770775	total: 1m 5s	remaining: 46.3s
# 586:	learn: 0.1770097	total: 1m 5s	remaining: 46.2s
# 587:	learn: 0.1769216	total: 1m 6s	remaining: 46.3s
# 588:	learn: 0.1768422	total: 1m 6s	remaining: 46.2s
# 589:	learn: 0.1767590	total: 1m 6s	remaining: 46.1s
# 590:	learn: 0.1766730	total: 1m 6s	remaining: 46s
# 591:	learn: 0.1765816	total: 1m 6s	remaining: 45.9s
# 592:	learn: 0.1764928	total: 1m 6s	remaining: 45.8s
# 593:	learn: 0.1764026	total: 1m 6s	remaining: 45.6s
# 594:	learn: 0.1763290	total: 1m 6s	remaining: 45.5s
# 595:	learn: 0.1762565	total: 1m 6s	remaining: 45.4s
# 596:	learn: 0.1761970	total: 1m 7s	remaining: 45.3s
# 597:	learn: 0.1761079	total: 1m 7s	remaining: 45.2s
# 598:	learn: 0.1760392	total: 1m 7s	remaining: 45s
# 599:	learn: 0.1759485	total: 1m 7s	remaining: 44.9s
# 600:	learn: 0.1758601	total: 1m 7s	remaining: 44.8s
# 601:	learn: 0.1757754	total: 1m 7s	remaining: 44.7s
# 602:	learn: 0.1757099	total: 1m 7s	remaining: 44.5s
# 603:	learn: 0.1756270	total: 1m 7s	remaining: 44.4s
# 604:	learn: 0.1755375	total: 1m 7s	remaining: 44.3s
# 605:	learn: 0.1754550	total: 1m 7s	remaining: 44.2s
# 606:	learn: 0.1753701	total: 1m 8s	remaining: 44.1s
# 607:	learn: 0.1752830	total: 1m 8s	remaining: 43.9s
# 608:	learn: 0.1752210	total: 1m 8s	remaining: 43.8s
# 609:	learn: 0.1751414	total: 1m 8s	remaining: 43.7s
# 610:	learn: 0.1750633	total: 1m 8s	remaining: 43.6s
# 611:	learn: 0.1749853	total: 1m 8s	remaining: 43.5s
# 612:	learn: 0.1748966	total: 1m 8s	remaining: 43.3s
# 613:	learn: 0.1747959	total: 1m 8s	remaining: 43.2s
# 614:	learn: 0.1747325	total: 1m 8s	remaining: 43.1s
# 615:	learn: 0.1746401	total: 1m 8s	remaining: 43s
# 616:	learn: 0.1745594	total: 1m 9s	remaining: 42.9s
# 617:	learn: 0.1744674	total: 1m 9s	remaining: 42.8s
# 618:	learn: 0.1743948	total: 1m 9s	remaining: 42.6s
# 619:	learn: 0.1743159	total: 1m 9s	remaining: 42.5s
# 620:	learn: 0.1742405	total: 1m 9s	remaining: 42.4s
# 621:	learn: 0.1741706	total: 1m 9s	remaining: 42.3s
# 622:	learn: 0.1740984	total: 1m 9s	remaining: 42.2s
# 623:	learn: 0.1740380	total: 1m 9s	remaining: 42.1s
# 624:	learn: 0.1739507	total: 1m 9s	remaining: 42s
# 625:	learn: 0.1738790	total: 1m 10s	remaining: 41.8s
# 626:	learn: 0.1738160	total: 1m 10s	remaining: 41.7s
# 627:	learn: 0.1737355	total: 1m 10s	remaining: 41.6s
# 628:	learn: 0.1736568	total: 1m 10s	remaining: 41.5s
# 629:	learn: 0.1735690	total: 1m 10s	remaining: 41.4s
# 630:	learn: 0.1734833	total: 1m 10s	remaining: 41.3s
# 631:	learn: 0.1733967	total: 1m 10s	remaining: 41.1s
# 632:	learn: 0.1733225	total: 1m 10s	remaining: 41s
# 633:	learn: 0.1732346	total: 1m 10s	remaining: 40.9s
# 634:	learn: 0.1731594	total: 1m 10s	remaining: 40.8s
# 635:	learn: 0.1730778	total: 1m 11s	remaining: 40.7s
# 636:	learn: 0.1730024	total: 1m 11s	remaining: 40.6s
# 637:	learn: 0.1729177	total: 1m 11s	remaining: 40.5s
# 638:	learn: 0.1728338	total: 1m 11s	remaining: 40.3s
# 639:	learn: 0.1727627	total: 1m 11s	remaining: 40.2s
# 640:	learn: 0.1726811	total: 1m 11s	remaining: 40.1s
# 641:	learn: 0.1725932	total: 1m 11s	remaining: 40s
# 642:	learn: 0.1725226	total: 1m 11s	remaining: 39.9s
# 643:	learn: 0.1724546	total: 1m 11s	remaining: 39.8s
# 644:	learn: 0.1723730	total: 1m 12s	remaining: 39.7s
# 645:	learn: 0.1723047	total: 1m 12s	remaining: 39.5s
# 646:	learn: 0.1722251	total: 1m 12s	remaining: 39.4s
# 647:	learn: 0.1721465	total: 1m 12s	remaining: 39.3s
# 648:	learn: 0.1720808	total: 1m 12s	remaining: 39.2s
# 649:	learn: 0.1720019	total: 1m 12s	remaining: 39.1s
# 650:	learn: 0.1719146	total: 1m 12s	remaining: 39s
# 651:	learn: 0.1718281	total: 1m 12s	remaining: 38.9s
# 652:	learn: 0.1717394	total: 1m 12s	remaining: 38.8s
# 653:	learn: 0.1716791	total: 1m 13s	remaining: 38.6s
# 654:	learn: 0.1716165	total: 1m 13s	remaining: 38.5s
# 655:	learn: 0.1715548	total: 1m 13s	remaining: 38.4s
# 656:	learn: 0.1714787	total: 1m 13s	remaining: 38.3s
# 657:	learn: 0.1714026	total: 1m 13s	remaining: 38.2s
# 658:	learn: 0.1713162	total: 1m 13s	remaining: 38.1s
# 659:	learn: 0.1712527	total: 1m 13s	remaining: 37.9s
# 660:	learn: 0.1711855	total: 1m 13s	remaining: 37.8s
# 661:	learn: 0.1711077	total: 1m 13s	remaining: 37.7s
# 662:	learn: 0.1710302	total: 1m 13s	remaining: 37.6s
# 663:	learn: 0.1709406	total: 1m 14s	remaining: 37.5s
# 664:	learn: 0.1708726	total: 1m 14s	remaining: 37.4s
# 665:	learn: 0.1707903	total: 1m 14s	remaining: 37.3s
# 666:	learn: 0.1707120	total: 1m 14s	remaining: 37.2s
# 667:	learn: 0.1706239	total: 1m 14s	remaining: 37.1s
# 668:	learn: 0.1705552	total: 1m 14s	remaining: 36.9s
# 669:	learn: 0.1704763	total: 1m 14s	remaining: 36.8s
# 670:	learn: 0.1703937	total: 1m 14s	remaining: 36.7s
# 671:	learn: 0.1703192	total: 1m 14s	remaining: 36.6s
# 672:	learn: 0.1702321	total: 1m 15s	remaining: 36.5s
# 673:	learn: 0.1701537	total: 1m 15s	remaining: 36.4s
# 674:	learn: 0.1700801	total: 1m 15s	remaining: 36.2s
# 675:	learn: 0.1699983	total: 1m 15s	remaining: 36.1s
# 676:	learn: 0.1699403	total: 1m 15s	remaining: 36s
# 677:	learn: 0.1698597	total: 1m 15s	remaining: 35.9s
# 678:	learn: 0.1697958	total: 1m 15s	remaining: 35.8s
# 679:	learn: 0.1697278	total: 1m 15s	remaining: 35.7s
# 680:	learn: 0.1696585	total: 1m 15s	remaining: 35.5s
# 681:	learn: 0.1695814	total: 1m 15s	remaining: 35.4s
# 682:	learn: 0.1695104	total: 1m 16s	remaining: 35.3s
# 683:	learn: 0.1694352	total: 1m 16s	remaining: 35.2s
# 684:	learn: 0.1693609	total: 1m 16s	remaining: 35.1s
# 685:	learn: 0.1692780	total: 1m 16s	remaining: 35s
# 686:	learn: 0.1692175	total: 1m 16s	remaining: 34.9s
# 687:	learn: 0.1691587	total: 1m 16s	remaining: 34.8s
# 688:	learn: 0.1690785	total: 1m 16s	remaining: 34.6s
# 689:	learn: 0.1689943	total: 1m 16s	remaining: 34.5s
# 690:	learn: 0.1689067	total: 1m 17s	remaining: 34.4s
# 691:	learn: 0.1688360	total: 1m 17s	remaining: 34.3s
# 692:	learn: 0.1687512	total: 1m 17s	remaining: 34.2s
# 693:	learn: 0.1686746	total: 1m 17s	remaining: 34.1s
# 694:	learn: 0.1686021	total: 1m 17s	remaining: 34s
# 695:	learn: 0.1685377	total: 1m 17s	remaining: 33.9s
# 696:	learn: 0.1684763	total: 1m 17s	remaining: 33.8s
# 697:	learn: 0.1684090	total: 1m 17s	remaining: 33.7s
# 698:	learn: 0.1683335	total: 1m 17s	remaining: 33.5s
# 699:	learn: 0.1682550	total: 1m 18s	remaining: 33.4s
# 700:	learn: 0.1681828	total: 1m 18s	remaining: 33.3s
# 701:	learn: 0.1681174	total: 1m 18s	remaining: 33.2s
# 702:	learn: 0.1680473	total: 1m 18s	remaining: 33.1s
# 703:	learn: 0.1679673	total: 1m 18s	remaining: 33s
# 704:	learn: 0.1678980	total: 1m 18s	remaining: 32.9s
# 705:	learn: 0.1678245	total: 1m 18s	remaining: 32.8s
# 706:	learn: 0.1677415	total: 1m 18s	remaining: 32.6s
# 707:	learn: 0.1676729	total: 1m 18s	remaining: 32.5s
# 708:	learn: 0.1676094	total: 1m 18s	remaining: 32.4s
# 709:	learn: 0.1675545	total: 1m 19s	remaining: 32.3s
# 710:	learn: 0.1674681	total: 1m 19s	remaining: 32.2s
# 711:	learn: 0.1674032	total: 1m 19s	remaining: 32.1s
# 712:	learn: 0.1673229	total: 1m 19s	remaining: 32s
# 713:	learn: 0.1672565	total: 1m 19s	remaining: 31.8s
# 714:	learn: 0.1671784	total: 1m 19s	remaining: 31.7s
# 715:	learn: 0.1671077	total: 1m 19s	remaining: 31.6s
# 716:	learn: 0.1670283	total: 1m 19s	remaining: 31.5s
# 717:	learn: 0.1669742	total: 1m 19s	remaining: 31.4s
# 718:	learn: 0.1669074	total: 1m 19s	remaining: 31.3s
# 719:	learn: 0.1668399	total: 1m 20s	remaining: 31.1s
# 720:	learn: 0.1667681	total: 1m 20s	remaining: 31s
# 721:	learn: 0.1666879	total: 1m 20s	remaining: 30.9s
# 722:	learn: 0.1666062	total: 1m 20s	remaining: 30.8s
# 723:	learn: 0.1665383	total: 1m 20s	remaining: 30.7s
# 724:	learn: 0.1664611	total: 1m 20s	remaining: 30.6s
# 725:	learn: 0.1663875	total: 1m 20s	remaining: 30.5s
# 726:	learn: 0.1663176	total: 1m 20s	remaining: 30.4s
# 727:	learn: 0.1662484	total: 1m 20s	remaining: 30.2s
# 728:	learn: 0.1661779	total: 1m 21s	remaining: 30.1s
# 729:	learn: 0.1661027	total: 1m 21s	remaining: 30s
# 730:	learn: 0.1660468	total: 1m 21s	remaining: 29.9s
# 731:	learn: 0.1659749	total: 1m 21s	remaining: 29.8s
# 732:	learn: 0.1659169	total: 1m 21s	remaining: 29.7s
# 733:	learn: 0.1658517	total: 1m 21s	remaining: 29.5s
# 734:	learn: 0.1657746	total: 1m 21s	remaining: 29.4s
# 735:	learn: 0.1657072	total: 1m 21s	remaining: 29.3s
# 736:	learn: 0.1656447	total: 1m 21s	remaining: 29.2s
# 737:	learn: 0.1655835	total: 1m 21s	remaining: 29.1s
# 738:	learn: 0.1655087	total: 1m 21s	remaining: 29s
# 739:	learn: 0.1654299	total: 1m 22s	remaining: 28.8s
# 740:	learn: 0.1653621	total: 1m 22s	remaining: 28.7s
# 741:	learn: 0.1652840	total: 1m 22s	remaining: 28.6s
# 742:	learn: 0.1652071	total: 1m 22s	remaining: 28.5s
# 743:	learn: 0.1651272	total: 1m 22s	remaining: 28.4s
# 744:	learn: 0.1650589	total: 1m 22s	remaining: 28.3s
# 745:	learn: 0.1650036	total: 1m 22s	remaining: 28.2s
# 746:	learn: 0.1649410	total: 1m 22s	remaining: 28.1s
# 747:	learn: 0.1648752	total: 1m 22s	remaining: 27.9s
# 748:	learn: 0.1648079	total: 1m 23s	remaining: 27.8s
# 749:	learn: 0.1647357	total: 1m 23s	remaining: 27.7s
# 750:	learn: 0.1646672	total: 1m 23s	remaining: 27.6s
# 751:	learn: 0.1645871	total: 1m 23s	remaining: 27.5s
# 752:	learn: 0.1645190	total: 1m 23s	remaining: 27.4s
# 753:	learn: 0.1644362	total: 1m 23s	remaining: 27.3s
# 754:	learn: 0.1643652	total: 1m 23s	remaining: 27.2s
# 755:	learn: 0.1643049	total: 1m 23s	remaining: 27s
# 756:	learn: 0.1642263	total: 1m 23s	remaining: 26.9s
# 757:	learn: 0.1641645	total: 1m 23s	remaining: 26.8s
# 758:	learn: 0.1640937	total: 1m 24s	remaining: 26.7s
# 759:	learn: 0.1640335	total: 1m 24s	remaining: 26.6s
# 760:	learn: 0.1639501	total: 1m 24s	remaining: 26.5s
# 761:	learn: 0.1638637	total: 1m 24s	remaining: 26.4s
# 762:	learn: 0.1637845	total: 1m 24s	remaining: 26.2s
# 763:	learn: 0.1637360	total: 1m 24s	remaining: 26.1s
# 764:	learn: 0.1636726	total: 1m 24s	remaining: 26s
# 765:	learn: 0.1636177	total: 1m 24s	remaining: 25.9s
# 766:	learn: 0.1635519	total: 1m 24s	remaining: 25.8s
# 767:	learn: 0.1634869	total: 1m 25s	remaining: 25.7s
# 768:	learn: 0.1634173	total: 1m 25s	remaining: 25.6s
# 769:	learn: 0.1633456	total: 1m 25s	remaining: 25.5s
# 770:	learn: 0.1632727	total: 1m 25s	remaining: 25.4s
# 771:	learn: 0.1632031	total: 1m 25s	remaining: 25.3s
# 772:	learn: 0.1631387	total: 1m 25s	remaining: 25.2s
# 773:	learn: 0.1630736	total: 1m 25s	remaining: 25s
# 774:	learn: 0.1630188	total: 1m 25s	remaining: 24.9s
# 775:	learn: 0.1629594	total: 1m 26s	remaining: 24.8s
# 776:	learn: 0.1628941	total: 1m 26s	remaining: 24.7s
# 777:	learn: 0.1628399	total: 1m 26s	remaining: 24.6s
# 778:	learn: 0.1627668	total: 1m 26s	remaining: 24.5s
# 779:	learn: 0.1626977	total: 1m 26s	remaining: 24.4s
# 780:	learn: 0.1626386	total: 1m 26s	remaining: 24.3s
# 781:	learn: 0.1625715	total: 1m 26s	remaining: 24.2s
# 782:	learn: 0.1625030	total: 1m 26s	remaining: 24.1s
# 783:	learn: 0.1624497	total: 1m 27s	remaining: 24s
# 784:	learn: 0.1624046	total: 1m 27s	remaining: 23.9s
# 785:	learn: 0.1623510	total: 1m 27s	remaining: 23.8s
# 786:	learn: 0.1622795	total: 1m 27s	remaining: 23.6s
# 787:	learn: 0.1622111	total: 1m 27s	remaining: 23.5s
# 788:	learn: 0.1621690	total: 1m 27s	remaining: 23.4s
# 789:	learn: 0.1620914	total: 1m 27s	remaining: 23.3s
# 790:	learn: 0.1620431	total: 1m 27s	remaining: 23.2s
# 791:	learn: 0.1619738	total: 1m 27s	remaining: 23.1s
# 792:	learn: 0.1618987	total: 1m 28s	remaining: 23s
# 793:	learn: 0.1618371	total: 1m 28s	remaining: 22.9s
# 794:	learn: 0.1617722	total: 1m 28s	remaining: 22.8s
# 795:	learn: 0.1616963	total: 1m 28s	remaining: 22.7s
# 796:	learn: 0.1616249	total: 1m 28s	remaining: 22.6s
# 797:	learn: 0.1615749	total: 1m 28s	remaining: 22.4s
# 798:	learn: 0.1615173	total: 1m 28s	remaining: 22.3s
# 799:	learn: 0.1614636	total: 1m 28s	remaining: 22.2s
# 800:	learn: 0.1613952	total: 1m 29s	remaining: 22.1s
# 801:	learn: 0.1613234	total: 1m 29s	remaining: 22s
# 802:	learn: 0.1612699	total: 1m 29s	remaining: 21.9s
# 803:	learn: 0.1612080	total: 1m 29s	remaining: 21.8s
# 804:	learn: 0.1611420	total: 1m 29s	remaining: 21.7s
# 805:	learn: 0.1610720	total: 1m 29s	remaining: 21.6s
# 806:	learn: 0.1610184	total: 1m 29s	remaining: 21.5s
# 807:	learn: 0.1609334	total: 1m 29s	remaining: 21.4s
# 808:	learn: 0.1608755	total: 1m 30s	remaining: 21.2s
# 809:	learn: 0.1608271	total: 1m 30s	remaining: 21.1s
# 810:	learn: 0.1607571	total: 1m 30s	remaining: 21s
# 811:	learn: 0.1607070	total: 1m 30s	remaining: 20.9s
# 812:	learn: 0.1606430	total: 1m 30s	remaining: 20.8s
# 813:	learn: 0.1605718	total: 1m 30s	remaining: 20.7s
# 814:	learn: 0.1605121	total: 1m 30s	remaining: 20.6s
# 815:	learn: 0.1604426	total: 1m 30s	remaining: 20.5s
# 816:	learn: 0.1603725	total: 1m 30s	remaining: 20.4s
# 817:	learn: 0.1603154	total: 1m 31s	remaining: 20.3s
# 818:	learn: 0.1602430	total: 1m 31s	remaining: 20.1s
# 819:	learn: 0.1601735	total: 1m 31s	remaining: 20s
# 820:	learn: 0.1601147	total: 1m 31s	remaining: 19.9s
# 821:	learn: 0.1600702	total: 1m 31s	remaining: 19.8s
# 822:	learn: 0.1600125	total: 1m 31s	remaining: 19.7s
# 823:	learn: 0.1599532	total: 1m 31s	remaining: 19.6s
# 824:	learn: 0.1598783	total: 1m 31s	remaining: 19.5s
# 825:	learn: 0.1598003	total: 1m 31s	remaining: 19.4s
# 826:	learn: 0.1597276	total: 1m 32s	remaining: 19.3s
# 827:	learn: 0.1596690	total: 1m 32s	remaining: 19.1s
# 828:	learn: 0.1596005	total: 1m 32s	remaining: 19s
# 829:	learn: 0.1595398	total: 1m 32s	remaining: 18.9s
# 830:	learn: 0.1594705	total: 1m 32s	remaining: 18.8s
# 831:	learn: 0.1593936	total: 1m 32s	remaining: 18.7s
# 832:	learn: 0.1593445	total: 1m 32s	remaining: 18.6s
# 833:	learn: 0.1592953	total: 1m 32s	remaining: 18.5s
# 834:	learn: 0.1592342	total: 1m 32s	remaining: 18.3s
# 835:	learn: 0.1591816	total: 1m 32s	remaining: 18.2s
# 836:	learn: 0.1591165	total: 1m 33s	remaining: 18.1s
# 837:	learn: 0.1590678	total: 1m 33s	remaining: 18s
# 838:	learn: 0.1590044	total: 1m 33s	remaining: 17.9s
# 839:	learn: 0.1589488	total: 1m 33s	remaining: 17.8s
# 840:	learn: 0.1588800	total: 1m 33s	remaining: 17.7s
# 841:	learn: 0.1588211	total: 1m 33s	remaining: 17.6s
# 842:	learn: 0.1587603	total: 1m 33s	remaining: 17.5s
# 843:	learn: 0.1586948	total: 1m 33s	remaining: 17.3s
# 844:	learn: 0.1586255	total: 1m 33s	remaining: 17.2s
# 845:	learn: 0.1585626	total: 1m 34s	remaining: 17.1s
# 846:	learn: 0.1585005	total: 1m 34s	remaining: 17s
# 847:	learn: 0.1584294	total: 1m 34s	remaining: 16.9s
# 848:	learn: 0.1583615	total: 1m 34s	remaining: 16.8s
# 849:	learn: 0.1582956	total: 1m 34s	remaining: 16.7s
# 850:	learn: 0.1582094	total: 1m 34s	remaining: 16.6s
# 851:	learn: 0.1581501	total: 1m 34s	remaining: 16.4s
# 852:	learn: 0.1580900	total: 1m 34s	remaining: 16.3s
# 853:	learn: 0.1580308	total: 1m 34s	remaining: 16.2s
# 854:	learn: 0.1579746	total: 1m 35s	remaining: 16.1s
# 855:	learn: 0.1579121	total: 1m 35s	remaining: 16s
# 856:	learn: 0.1578500	total: 1m 35s	remaining: 15.9s
# 857:	learn: 0.1577831	total: 1m 35s	remaining: 15.8s
# 858:	learn: 0.1577189	total: 1m 35s	remaining: 15.7s
# 859:	learn: 0.1576502	total: 1m 35s	remaining: 15.6s
# 860:	learn: 0.1576026	total: 1m 35s	remaining: 15.4s
# 861:	learn: 0.1575540	total: 1m 35s	remaining: 15.3s
# 862:	learn: 0.1575035	total: 1m 35s	remaining: 15.2s
# 863:	learn: 0.1574294	total: 1m 35s	remaining: 15.1s
# 864:	learn: 0.1573742	total: 1m 36s	remaining: 15s
# 865:	learn: 0.1573116	total: 1m 36s	remaining: 14.9s
# 866:	learn: 0.1572486	total: 1m 36s	remaining: 14.8s
# 867:	learn: 0.1571954	total: 1m 36s	remaining: 14.7s
# 868:	learn: 0.1571378	total: 1m 36s	remaining: 14.5s
# 869:	learn: 0.1570878	total: 1m 36s	remaining: 14.4s
# 870:	learn: 0.1570265	total: 1m 36s	remaining: 14.3s
# 871:	learn: 0.1569511	total: 1m 36s	remaining: 14.2s
# 872:	learn: 0.1568944	total: 1m 36s	remaining: 14.1s
# 873:	learn: 0.1568356	total: 1m 36s	remaining: 14s
# 874:	learn: 0.1567812	total: 1m 37s	remaining: 13.9s
# 875:	learn: 0.1567189	total: 1m 37s	remaining: 13.8s
# 876:	learn: 0.1566536	total: 1m 37s	remaining: 13.6s
# 877:	learn: 0.1566039	total: 1m 37s	remaining: 13.5s
# 878:	learn: 0.1565380	total: 1m 37s	remaining: 13.4s
# 879:	learn: 0.1564876	total: 1m 37s	remaining: 13.3s
# 880:	learn: 0.1564246	total: 1m 37s	remaining: 13.2s
# 881:	learn: 0.1563623	total: 1m 37s	remaining: 13.1s
# 882:	learn: 0.1563006	total: 1m 37s	remaining: 13s
# 883:	learn: 0.1562203	total: 1m 38s	remaining: 12.9s
# 884:	learn: 0.1561636	total: 1m 38s	remaining: 12.8s
# 885:	learn: 0.1560971	total: 1m 38s	remaining: 12.7s
# 886:	learn: 0.1560281	total: 1m 38s	remaining: 12.5s
# 887:	learn: 0.1559610	total: 1m 38s	remaining: 12.4s
# 888:	learn: 0.1558962	total: 1m 38s	remaining: 12.3s
# 889:	learn: 0.1558349	total: 1m 38s	remaining: 12.2s
# 890:	learn: 0.1557904	total: 1m 38s	remaining: 12.1s
# 891:	learn: 0.1557242	total: 1m 39s	remaining: 12s
# 892:	learn: 0.1556539	total: 1m 39s	remaining: 11.9s
# 893:	learn: 0.1555905	total: 1m 39s	remaining: 11.8s
# 894:	learn: 0.1555368	total: 1m 39s	remaining: 11.7s
# 895:	learn: 0.1554749	total: 1m 39s	remaining: 11.5s
# 896:	learn: 0.1554084	total: 1m 39s	remaining: 11.4s
# 897:	learn: 0.1553452	total: 1m 39s	remaining: 11.3s
# 898:	learn: 0.1553042	total: 1m 39s	remaining: 11.2s
# 899:	learn: 0.1552414	total: 1m 39s	remaining: 11.1s
# 900:	learn: 0.1551786	total: 1m 39s	remaining: 11s
# 901:	learn: 0.1551234	total: 1m 40s	remaining: 10.9s
# 902:	learn: 0.1550607	total: 1m 40s	remaining: 10.8s
# 903:	learn: 0.1550026	total: 1m 40s	remaining: 10.7s
# 904:	learn: 0.1549433	total: 1m 40s	remaining: 10.5s
# 905:	learn: 0.1548887	total: 1m 40s	remaining: 10.4s
# 906:	learn: 0.1548407	total: 1m 40s	remaining: 10.3s
# 907:	learn: 0.1547769	total: 1m 40s	remaining: 10.2s
# 908:	learn: 0.1547243	total: 1m 40s	remaining: 10.1s
# 909:	learn: 0.1546582	total: 1m 40s	remaining: 9.98s
# 910:	learn: 0.1546024	total: 1m 41s	remaining: 9.87s
# 911:	learn: 0.1545435	total: 1m 41s	remaining: 9.76s
# 912:	learn: 0.1545010	total: 1m 41s	remaining: 9.65s
# 913:	learn: 0.1544411	total: 1m 41s	remaining: 9.54s
# 914:	learn: 0.1543907	total: 1m 41s	remaining: 9.43s
# 915:	learn: 0.1543332	total: 1m 41s	remaining: 9.32s
# 916:	learn: 0.1542795	total: 1m 41s	remaining: 9.21s
# 917:	learn: 0.1542114	total: 1m 41s	remaining: 9.09s
# 918:	learn: 0.1541557	total: 1m 41s	remaining: 8.98s
# 919:	learn: 0.1541065	total: 1m 42s	remaining: 8.87s
# 920:	learn: 0.1540498	total: 1m 42s	remaining: 8.76s
# 921:	learn: 0.1539925	total: 1m 42s	remaining: 8.65s
# 922:	learn: 0.1539289	total: 1m 42s	remaining: 8.54s
# 923:	learn: 0.1538805	total: 1m 42s	remaining: 8.43s
# 924:	learn: 0.1538177	total: 1m 42s	remaining: 8.32s
# 925:	learn: 0.1537787	total: 1m 42s	remaining: 8.21s
# 926:	learn: 0.1537180	total: 1m 42s	remaining: 8.1s
# 927:	learn: 0.1536571	total: 1m 42s	remaining: 7.99s
# 928:	learn: 0.1535925	total: 1m 43s	remaining: 7.87s
# 929:	learn: 0.1535193	total: 1m 43s	remaining: 7.76s
# 930:	learn: 0.1534569	total: 1m 43s	remaining: 7.65s
# 931:	learn: 0.1533969	total: 1m 43s	remaining: 7.54s
# 932:	learn: 0.1533367	total: 1m 43s	remaining: 7.43s
# 933:	learn: 0.1532752	total: 1m 43s	remaining: 7.32s
# 934:	learn: 0.1532181	total: 1m 43s	remaining: 7.21s
# 935:	learn: 0.1531694	total: 1m 43s	remaining: 7.1s
# 936:	learn: 0.1531298	total: 1m 43s	remaining: 6.99s
# 937:	learn: 0.1530689	total: 1m 44s	remaining: 6.88s
# 938:	learn: 0.1530066	total: 1m 44s	remaining: 6.77s
# 939:	learn: 0.1529419	total: 1m 44s	remaining: 6.66s
# 940:	learn: 0.1528810	total: 1m 44s	remaining: 6.55s
# 941:	learn: 0.1528447	total: 1m 44s	remaining: 6.44s
# 942:	learn: 0.1527958	total: 1m 44s	remaining: 6.33s
# 943:	learn: 0.1527401	total: 1m 44s	remaining: 6.22s
# 944:	learn: 0.1526766	total: 1m 44s	remaining: 6.11s
# 945:	learn: 0.1526137	total: 1m 45s	remaining: 6s
# 946:	learn: 0.1525424	total: 1m 45s	remaining: 5.89s
# 947:	learn: 0.1524899	total: 1m 45s	remaining: 5.78s
# 948:	learn: 0.1524317	total: 1m 45s	remaining: 5.67s
# 949:	learn: 0.1523734	total: 1m 45s	remaining: 5.56s
# 950:	learn: 0.1523093	total: 1m 45s	remaining: 5.45s
# 951:	learn: 0.1522715	total: 1m 45s	remaining: 5.34s
# 952:	learn: 0.1522239	total: 1m 46s	remaining: 5.23s
# 953:	learn: 0.1521615	total: 1m 46s	remaining: 5.12s
# 954:	learn: 0.1521003	total: 1m 46s	remaining: 5.01s
# 955:	learn: 0.1520532	total: 1m 46s	remaining: 4.9s
# 956:	learn: 0.1520136	total: 1m 46s	remaining: 4.79s
# 957:	learn: 0.1519453	total: 1m 46s	remaining: 4.67s
# 958:	learn: 0.1518883	total: 1m 46s	remaining: 4.56s
# 959:	learn: 0.1518323	total: 1m 46s	remaining: 4.45s
# 960:	learn: 0.1517860	total: 1m 47s	remaining: 4.34s
# 961:	learn: 0.1517219	total: 1m 47s	remaining: 4.23s
# 962:	learn: 0.1516723	total: 1m 47s	remaining: 4.12s
# 963:	learn: 0.1516226	total: 1m 47s	remaining: 4.01s
# 964:	learn: 0.1515670	total: 1m 47s	remaining: 3.9s
# 965:	learn: 0.1515142	total: 1m 47s	remaining: 3.79s
# 966:	learn: 0.1514710	total: 1m 47s	remaining: 3.68s
# 967:	learn: 0.1514093	total: 1m 47s	remaining: 3.57s
# 968:	learn: 0.1513528	total: 1m 48s	remaining: 3.46s
# 969:	learn: 0.1512959	total: 1m 48s	remaining: 3.35s
# 970:	learn: 0.1512415	total: 1m 48s	remaining: 3.23s
# 971:	learn: 0.1511801	total: 1m 48s	remaining: 3.12s
# 972:	learn: 0.1511263	total: 1m 48s	remaining: 3.01s
# 973:	learn: 0.1510600	total: 1m 48s	remaining: 2.9s
# 974:	learn: 0.1510045	total: 1m 48s	remaining: 2.79s
# 975:	learn: 0.1509609	total: 1m 48s	remaining: 2.68s
# 976:	learn: 0.1508908	total: 1m 49s	remaining: 2.57s
# 977:	learn: 0.1508302	total: 1m 49s	remaining: 2.46s
# 978:	learn: 0.1507821	total: 1m 49s	remaining: 2.35s
# 979:	learn: 0.1507283	total: 1m 49s	remaining: 2.23s
# 980:	learn: 0.1506727	total: 1m 49s	remaining: 2.13s
# 981:	learn: 0.1506263	total: 1m 49s	remaining: 2.01s
# 982:	learn: 0.1505818	total: 1m 50s	remaining: 1.9s
# 983:	learn: 0.1505237	total: 1m 50s	remaining: 1.79s
# 984:	learn: 0.1504578	total: 1m 50s	remaining: 1.68s
# 985:	learn: 0.1504136	total: 1m 50s	remaining: 1.57s
# 986:	learn: 0.1503506	total: 1m 50s	remaining: 1.46s
# 987:	learn: 0.1502929	total: 1m 50s	remaining: 1.34s
# 988:	learn: 0.1502495	total: 1m 50s	remaining: 1.23s
# 989:	learn: 0.1501748	total: 1m 50s	remaining: 1.12s
# 990:	learn: 0.1501073	total: 1m 51s	remaining: 1.01s
# 991:	learn: 0.1500554	total: 1m 51s	remaining: 896ms
# 992:	learn: 0.1499940	total: 1m 51s	remaining: 784ms
# 993:	learn: 0.1499349	total: 1m 51s	remaining: 672ms
# 994:	learn: 0.1498908	total: 1m 51s	remaining: 560ms
# 995:	learn: 0.1498403	total: 1m 51s	remaining: 448ms
# 996:	learn: 0.1497732	total: 1m 51s	remaining: 336ms
# 997:	learn: 0.1497134	total: 1m 51s	remaining: 224ms
# 998:	learn: 0.1496509	total: 1m 51s	remaining: 112ms
# 999:	learn: 0.1495981	total: 1m 51s	remaining: 0us

# %% [markdown]
# ## Evaluation

# %% [markdown]
# #### Metrics which require predict method

# %% [markdown]
# ##### Confusion matrix
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html
#
# TN | FP
#
# FN | TP

# %% [markdown]
# #### Confusion matrix, Recall, Precision, F1-score, G-mean, etc

# %%
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    recall_score,
    precision_score,
    f1_score,
    classification_report,
    confusion_matrix
)

# require scaling
from imblearn.metrics import (
    geometric_mean_score,
    make_index_balanced_accuracy,
)

def dominance(y_true, y_pred):
    tpr = recall_score(y_test, y_pred, pos_label=1)
    tnr = recall_score(y_test, y_pred, pos_label=0)
    return tpr - tnr

# Function to get classification metrics
def get_classification_metrics(y_true, y_pred):
    report = classification_report(y_true, y_pred, output_dict=True)
    accuracy          = accuracy_score(y_test, y_pred)
    balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
    
    # Adding possible averages to recall, precision, and f1-score calculations
    # Default average is None - scores are returned for each class individually rather than being averaged
    recall_weighted    = recall_score(y_test, y_pred, average='weighted')
    precision_weighted = precision_score(y_test, y_pred, average='weighted') 
    f1_weighted        = f1_score(y_test, y_pred, average='weighted')

    recall_micro       = recall_score(y_test, y_pred, average='micro')
    precision_micro    = precision_score(y_test, y_pred, average='micro')
    f1_micro           = f1_score(y_test, y_pred, average='micro')
    
    recall_macro       = recall_score(y_test, y_pred, average='macro')
    precision_macro    = precision_score(y_test, y_pred, average='macro')
    f1_macro           = f1_score(y_test, y_pred, average='macro')

    # Adding possible averages to G-mean
    # If the average parameter is not specified, it defaults to average='binary'.
    g_mean_binary      = geometric_mean_score(y_test, y_pred, average='binary')
    g_mean_weighted    = geometric_mean_score(y_test, y_pred, average='weighted')
    g_mean_micro       = geometric_mean_score(y_test, y_pred, average='micro')
    g_mean_macro       = geometric_mean_score(y_test, y_pred, average='macro')

    # A lower alpha gives more weight to sensitivity (TPR), while a higher alpha gives more weight to specificity (TNR). 
    # In other words,in case of a lower alpha more emphasis is placed on correctly identifying positive instances
    gmean = make_index_balanced_accuracy(alpha=0.5, squared=True)(geometric_mean_score) 
    corrected_g_mean  = gmean(y_test, y_pred)
    # specifying an average might not be necessary or meaningful. Leaving for the time being
    corrected_g_mean_binary  = gmean(y_test, y_pred,average='binary')
    corrected_g_mean_weighted  = gmean(y_test, y_pred,average='weighted')
    corrected_g_mean_micro  = gmean(y_test, y_pred,average='micro')
    corrected_g_mean_macro  = gmean(y_test, y_pred,average='macro')
    
    dominance_score   = dominance(y_test, y_pred) 

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
    FPR = fp / (tn + fp)
    FNR = fn / (tp + fn)
    # TPR = tp / (tp + fn) # recallminority
    # TNR = tn / (tn + fp) # recall majority
    
    return {
        'Accuracy': accuracy,
        'Recall Majority (TNR)': report['0']['recall'],
        'Recall Minority (TPR)': report['1']['recall'],
        'Balanced Accuracy': balanced_accuracy,
        'FPR': FPR,
        'FNR': FNR,
        
        'Precision Majority': report['0']['precision'],
        'Precision Minority': report['1']['precision'],
        'F1-Score Majority': report['0']['f1-score'],
        'F1-Score Minority': report['1']['f1-score'], 
        
        # Weighted average (Use 'weighted' if you want to take class imbalance into account)
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,

        # Micro average (Use 'micro' if you want a metric that gives equal weight to every individual prediction)
        'Micro Precision': precision_micro,
        'Micro Recall': recall_micro,
        'Micro F1-Score': f1_micro,
        
        # Macro average (Use 'macro' if you want to treat each class equally)
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,

        # Geometric average (a suitable metric when you want to balance the trade-off between detecting the minority class 
        # and avoiding false positives from the majority class)
        'G-mean-binary': g_mean_binary, # (compute two geometric means for each class, then the arithmetic mean of these G-means)
        'G-mean-weighted': g_mean_weighted, # calculates the geometric mean for each class and then computes the weighted arithmetic mean of these G-means
        'G-mean-micro': g_mean_micro, # treats all classes equally, regardless of their size
        'G-mean-macro': g_mean_macro, # use when you want to weight each instance equally, regardless of their class

        # Corrected G-means
        'Corrected G-mean': corrected_g_mean,
        'Corrected G-mean-binary': corrected_g_mean_binary,
        'Corrected G-mean-weighted': corrected_g_mean_weighted,
        'Corrected G-mean-micro': corrected_g_mean_micro,
        'Corrected G-mean-macro': corrected_g_mean_macro,
        
        'Dominance': dominance_score
    }

models = {
    'Baseline': y_test_base,
    'Random Forest': rf.predict(X_test),
    'Logistic Regression': logit.predict(X_test),
    'XGBoost': xgb_model.predict(X_test),
    'LightGBM': lgb_model.predict(X_test),
    'CatBoost': catboost_model.predict(X_test)
}

# Collecting results
results = []
confusion_matricies = []
for model_name, y_pred in models.items():
    metrics           = get_classification_metrics(y_test, y_pred)
    conf_matrix       = confusion_matrix(y_test, y_pred)
    results.append({
        'Model': model_name,
        **metrics,
    })
    confusion_matricies.append({
        'Model': model_name,
        'Confusion matrix': conf_matrix
    })

# Create a DataFrame from the results
df_results_1 = pd.DataFrame(results)
df_confusion_matricies = pd.DataFrame(confusion_matricies)

# Print the DataFrame as a table
print(df_results_1)
print(df_confusion_matricies)
# Out:
#                  Model  Accuracy  Recall Majority (TNR)  \
# 0             Baseline  0.899517               1.000000
# 1        Random Forest  0.899517               1.000000
# 2  Logistic Regression  0.913517               0.986085
# 3              XGBoost  0.913183               0.987660
# 4             LightGBM  0.907283               0.998295
#
#    Recall Minority (TPR)  Balanced Accuracy       FPR       FNR  \
# 0               0.000000           0.500000  0.000000  1.000000
# 1               0.000000           0.500000  0.000000  1.000000
# 2               0.263891           0.624988  0.013915  0.736109
# 3               0.246475           0.617068  0.012340  0.753525
# 4               0.092553           0.545424  0.001705  0.907447
#
#    Precision Majority  Precision Minority  F1-Score Majority  ...  \
# 0            0.899517            0.000000           0.947101  ...
# 1            0.899517            0.000000           0.947101  ...
# 2            0.923029            0.679334           0.953516  ...
# 3            0.921467            0.690520           0.953416  ...
# 4            0.907818            0.858462           0.950909  ...
#
#    G-mean-binary  G-mean-weighted  G-mean-micro  G-mean-macro  \
# 0       0.000000         0.300643      0.899517      0.500000
# 1       0.000000         0.300643      0.899517      0.500000
# 2       0.510117         0.554402      0.913517      0.624988
# 3       0.493390         0.541376      0.913183      0.617068
# 4       0.303965         0.408099      0.907283      0.545424
#
#    Corrected G-mean  Corrected G-mean-binary  Corrected G-mean-weighted  \
# 0          0.000000                 0.000000                   0.126497
# 1          0.000000                 0.000000                   0.126497
# 2          0.260219                 0.166255                   0.396044
# 3          0.243434                 0.153219                   0.379876
# 4          0.092395                 0.050552                   0.226811
#
#    Corrected G-mean-micro  Corrected G-mean-macro  Dominance
# 0                0.809130                0.250000  -1.000000
# 1                0.809130                0.250000  -1.000000
# 2                0.834513                0.390610  -0.722194
# 3                0.833904                0.380773  -0.741185
# 4                0.823163                0.297487  -0.905743
#
# [5 rows x 30 columns]
#                  Model              Confusion matrix
# 0             Baseline       [[53971, 0], [6029, 0]]
# 1        Random Forest       [[53971, 0], [6029, 0]]
# 2  Logistic Regression  [[53220, 751], [4438, 1591]]
# 3              XGBoost  [[53305, 666], [4543, 1486]]
# 4             LightGBM    [[53879, 92], [5471, 558]]

# %% [markdown]
# #### Metrics which require predict_proba method
# The ROC AUC score is calculated based on the predicted probabilities for each class, which are obtained using the predict_proba method. This method provides the probability estimates for each class, which are necessary to compute the ROC curve and subsequently the AUC (Area Under the Curve).

# %%
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score
)

models = {
    'Baseline': y_test_base,
    'Random Forest': rf.predict_proba(X_test)[:,1],
    'Logistic Regression': logit.predict_proba(X_test)[:,1],
    'XGBoost': xgb_model.predict_proba(X_test)[:,1],
    'LightGBM': lgb_model.predict_proba(X_test)[:,1],
    'CatBoost': catboost_model.predict_proba(X_test)[:,1]
}

# Collecting results
results = []
for model_name, y_pred in models.items():
    roc_auc   = roc_auc_score(y_test, y_pred) 
    pr_auc = average_precision_score(y_test, y_pred)
    results.append({
        'Model': model_name,
        'ROC-AUC': roc_auc,
        'PR-AUC': pr_auc
    })

# Create a DataFrame from the results
df_results_2 = pd.DataFrame(results)

# Print the DataFrame as a table
print(df_results_2)
# Out:
#                  Model   ROC-AUC    PR-AUC
# 0             Baseline  0.500000  0.100483
# 1        Random Forest  0.748215  0.277840
# 2  Logistic Regression  0.858844  0.498939
# 3              XGBoost  0.854883  0.488493
# 4             LightGBM  0.863880  0.511203
# 5             CatBoost  0.893906  0.592294

# %% [markdown]
# ### Export classification metrics

# %%
# Concatenate df_results_1 and df_results_2 horisontally
df_combined_results = pd.concat([df_results_2, df_results_1], axis=1)

# Export results to CSV files
df_combined_results.to_csv('3_evaluation_results_scaling.csv', index=False)
df_confusion_matricies.to_csv('3_confusion_matricies_scaling.csv', index=False)
