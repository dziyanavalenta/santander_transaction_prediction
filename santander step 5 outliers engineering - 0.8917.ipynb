# %% [markdown]
# # Santander

# %% [markdown]
# ### Readme
# The focus of this notebook was on detecting and handling outliers in the dataset to improve model training. Key steps included:
#
# - **Outlier Detection**: Used the IQR method to identify outliers in each feature.
# - **Outlier Analysis**: Counted outliers in each target class to understand their distribution.
# - **Data Cleaning**: Removed outliers from the majority class (target == 0) while retaining all samples from the minority class (target == 1).
# - **Dataset Comparison**: Compared the shapes and target distributions of the original and cleaned datasets to ensure data quality and class balance.
# - **Preparation for Training**: Prepared cleaned training data and retained the test data for further model training.
# This process aimed to enhance the model's performance by reducing noise and potential bias introduced by outliers.

# %% [markdown]
# # 1. Import libs
# [top](#Contents)

# %%
# pandas and numpy imports
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

import warnings
# Suppress the specific warning
warnings.filterwarnings("ignore", category=UserWarning, module='sklearn.metrics')

# %%
# pip install -U imbalanced-learn

# %% [markdown]
# # 2. Get data
# [top](#Contents)

# %% [markdown]
# #### Read data
# [top](#Contents)

# %%
bank_ds = pd.read_csv('train.csv')

# %%
bank_test_ds = pd.read_csv('test.csv')

# %% [markdown]
# #### Drop an unneeded column

# %%
# Assuming 'column_to_drop' is the name of the column you want to drop
column_to_drop = 'ID_code'

# Drop the column from bank_ds
bank_ds.drop(column_to_drop, axis=1, inplace=True)

# %% [markdown]
# ### Split 70/30 (stratified sampling)

# %%
target = bank_ds['target']

# %%
# separate dataset into train and test

X_train, X_test, y_train, y_test = train_test_split(
    bank_ds.drop(labels=['target'], axis=1),  # drop the target
    bank_ds['target'],  # just the target
    test_size=0.3,
    stratify=target,
    random_state=42)

X_train.shape, X_test.shape
# Out:
# ((140000, 200), (60000, 200))

# %% [markdown]
# ### Scaling

# %% [markdown]
# Models like Logistic Regression require scaling for better performance. Tree-based models like Random Forest, XGBoost, and LightGBM do not inherently require scaling but scaling can still be beneficial (can improve performance and convergence in some cases).

# %%
from sklearn.preprocessing import MinMaxScaler
# we put the variables in the same scale
scaler = MinMaxScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Outliers Engineering

# %% [markdown]
# #### Count the number of outliers in each class

# %%
import pandas as pd
import numpy as np

# Separate the features and target
features = bank_ds.drop(columns='target')
target = bank_ds['target']

# Define a function to detect outliers using IQR
def detect_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    is_outlier = ((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR)))
    return is_outlier

# Detect outliers in each feature
outliers = features.apply(detect_outliers_iqr)

# Sum outliers for each sample
outliers['is_outlier'] = outliers.sum(axis=1) > 0

# Add target column back to the outliers DataFrame
outliers['target'] = target

# Count outliers in each class
outliers_count = outliers[outliers['is_outlier']].groupby('target').size()

# Print the results
print(outliers_count)
# Out:
# target
# 0    21903
# 1     2993
# dtype: int64

# %%
import pandas as pd
import numpy as np

# Convert X_train to a pandas DataFrame
X_train_df = pd.DataFrame(X_train, columns=bank_ds.drop(labels=['target'], axis=1).columns)

# Separate the features and target
features = X_train_df
target = y_train

# Define a function to detect outliers using IQR
def detect_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    is_outlier = ((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR)))
    return is_outlier

# Detect outliers in each feature
outliers = features.apply(detect_outliers_iqr)

# Sum outliers for each sample
outliers['is_outlier'] = outliers.sum(axis=1) > 0

# Add target column back to the outliers DataFrame
outliers['target'] = target

# Count outliers in each class
outliers_count = outliers[outliers['is_outlier']].groupby('target').size()

# Print the results
print(outliers_count)
# Out:
# target
# 0.0    11063
# 1.0     1287
# dtype: int64

# %% [markdown]
# ##### Remove outliers from majority class, but not minority

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Assuming bank_ds is your dataset and has been defined earlier in your code
# Separate the dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(
    bank_ds.drop(labels=['target'], axis=1),  # drop the target
    bank_ds['target'],  # just the target
    test_size=0.3,
    stratify=bank_ds['target'],
    random_state=42)

# Convert X_train to a pandas DataFrame
X_train_df = pd.DataFrame(X_train, columns=bank_ds.drop(labels=['target'], axis=1).columns)

# Ensure y_train is a pandas Series with aligned indices
y_train = y_train.reset_index(drop=True)
X_train_df = X_train_df.reset_index(drop=True)

# Separate the features and target
features = X_train_df
target = y_train

# Separate majority and minority classes
majority_class = features[target == 0]
minority_class = features[target == 1]

# Define a function to detect outliers using IQR
def detect_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    is_outlier = ((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR)))
    return is_outlier

# Detect outliers in the majority class
outliers_majority = majority_class.apply(detect_outliers_iqr)

# Sum outliers for each sample
outliers_majority['is_outlier'] = outliers_majority.sum(axis=1) > 0

# Keep only non-outliers in the majority class
cleaned_majority_class = majority_class[~outliers_majority['is_outlier']]

# Align the indices of the target and cleaned_majority_class
cleaned_majority_class_target = target.loc[cleaned_majority_class.index]

# Combine cleaned majority class with minority class
cleaned_data = pd.concat([cleaned_majority_class, minority_class])
cleaned_target = pd.concat([cleaned_majority_class_target, target[target == 1]])

# Ensure the target is properly aligned
cleaned_data = cleaned_data.reset_index(drop=True)
cleaned_target = cleaned_target.reset_index(drop=True)

# Print the shapes of the original and cleaned datasets
print("Original dataset shape:", X_train_df.shape)
print("Cleaned dataset shape:", cleaned_data.shape)

# Print the target distribution before and after cleaning
print("Original target distribution:\n", y_train.value_counts())
print("Cleaned target distribution:\n", cleaned_target.value_counts())

# Optionally, you can return the cleaned training data and test data as follows:
X_train_cleaned = cleaned_data
y_train_cleaned = cleaned_target

# The test set remains unchanged:
X_test_df = pd.DataFrame(X_test, columns=bank_ds.drop(labels=['target'], axis=1).columns)
# Out:
# Original dataset shape: (140000, 200)
# Cleaned dataset shape: (123320, 200)
# Original target distribution:
#  target
# 0    125931
# 1     14069
# Name: count, dtype: int64
# Cleaned target distribution:
#  target
# 0    109251
# 1     14069
# Name: count, dtype: int64

# %% [markdown]
# ##### Renaming

# %%
X_train = X_train_cleaned
y_train = y_train_cleaned
X_test = X_test_df

# %% [markdown]
# ## Train ML models
# ### Random Forests

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42, max_depth=2, n_jobs=4)

rf.fit(X_train, y_train)

y_train_rf = rf.predict_proba(X_train)[:,1]
y_test_rf = rf.predict_proba(X_test)[:,1]

# %% [markdown]
# ### Logistic Regression

# %%
logit = LogisticRegression(random_state=42,  max_iter=2000)

logit.fit(X_train, y_train)

y_train_logit = logit.predict_proba(X_train)[:,1]
y_test_logit = logit.predict_proba(X_test)[:,1]
# Out:
# C:\Users\dziya\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### XGB Classifier

# %%
import xgboost as xgb
from xgboost import XGBClassifier

xgb_model = XGBClassifier(random_state=42, use_label_encoder=False)

xgb_model.fit(X_train, y_train)

y_train_xgb = xgb_model.predict_proba(X_train)[:, 1]
y_test_xgb = xgb_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### Light GBM

# %%
import lightgbm as lgb
from lightgbm import LGBMClassifier

lgb_model = LGBMClassifier(random_state=42)

lgb_model.fit(X_train, y_train)

y_train_lgb = lgb_model.predict_proba(X_train)[:, 1]
y_test_lgb = lgb_model.predict_proba(X_test)[:, 1]
# Out:
# [LightGBM] [Info] Number of positive: 14069, number of negative: 109251
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.137303 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 123320, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.114085 -> initscore=-2.049674
# [LightGBM] [Info] Start training from score -2.049674

# %% [markdown]
# ### CatBoost

# %%
from catboost import CatBoostClassifier

catboost_model = CatBoostClassifier(random_state=42)

catboost_model.fit(X_train, y_train)

# Predict probabilities for the training and test sets
y_train_catboost = catboost_model.predict_proba(X_train)[:, 1]
y_test_catboost = catboost_model.predict_proba(X_test)[:, 1]
# Out:
# Learning rate set to 0.080502
# 0:	learn: 0.6319535	total: 302ms	remaining: 5m 1s
# 1:	learn: 0.5810590	total: 442ms	remaining: 3m 40s
# 2:	learn: 0.5394485	total: 579ms	remaining: 3m 12s
# 3:	learn: 0.5046726	total: 712ms	remaining: 2m 57s
# 4:	learn: 0.4766759	total: 872ms	remaining: 2m 53s
# 5:	learn: 0.4535324	total: 1.01s	remaining: 2m 46s
# 6:	learn: 0.4334646	total: 1.13s	remaining: 2m 40s
# 7:	learn: 0.4162499	total: 1.24s	remaining: 2m 33s
# 8:	learn: 0.4030335	total: 1.38s	remaining: 2m 32s
# 9:	learn: 0.3907472	total: 1.51s	remaining: 2m 29s
# 10:	learn: 0.3809563	total: 1.66s	remaining: 2m 29s
# 11:	learn: 0.3722892	total: 1.8s	remaining: 2m 27s
# 12:	learn: 0.3648129	total: 1.91s	remaining: 2m 24s
# 13:	learn: 0.3586594	total: 2.03s	remaining: 2m 23s
# 14:	learn: 0.3532511	total: 2.15s	remaining: 2m 20s
# 15:	learn: 0.3486108	total: 2.25s	remaining: 2m 18s
# 16:	learn: 0.3445799	total: 2.35s	remaining: 2m 16s
# 17:	learn: 0.3411927	total: 2.46s	remaining: 2m 14s
# 18:	learn: 0.3382288	total: 2.58s	remaining: 2m 13s
# 19:	learn: 0.3355161	total: 2.7s	remaining: 2m 12s
# 20:	learn: 0.3331142	total: 2.82s	remaining: 2m 11s
# 21:	learn: 0.3309042	total: 2.92s	remaining: 2m 9s
# 22:	learn: 0.3288382	total: 3.03s	remaining: 2m 8s
# 23:	learn: 0.3270698	total: 3.14s	remaining: 2m 7s
# 24:	learn: 0.3253601	total: 3.25s	remaining: 2m 6s
# 25:	learn: 0.3238370	total: 3.36s	remaining: 2m 5s
# 26:	learn: 0.3223658	total: 3.48s	remaining: 2m 5s
# 27:	learn: 0.3209644	total: 3.59s	remaining: 2m 4s
# 28:	learn: 0.3195885	total: 3.71s	remaining: 2m 4s
# 29:	learn: 0.3184342	total: 3.84s	remaining: 2m 4s
# 30:	learn: 0.3172820	total: 3.97s	remaining: 2m 4s
# 31:	learn: 0.3160958	total: 4.1s	remaining: 2m 3s
# 32:	learn: 0.3149470	total: 4.22s	remaining: 2m 3s
# 33:	learn: 0.3138796	total: 4.33s	remaining: 2m 3s
# 34:	learn: 0.3128471	total: 4.45s	remaining: 2m 2s
# 35:	learn: 0.3118628	total: 4.57s	remaining: 2m 2s
# 36:	learn: 0.3109425	total: 4.69s	remaining: 2m 2s
# 37:	learn: 0.3099965	total: 4.82s	remaining: 2m 2s
# 38:	learn: 0.3091532	total: 4.92s	remaining: 2m 1s
# 39:	learn: 0.3082870	total: 5.03s	remaining: 2m
# 40:	learn: 0.3074585	total: 5.13s	remaining: 2m
# 41:	learn: 0.3066367	total: 5.24s	remaining: 1m 59s
# 42:	learn: 0.3058172	total: 5.35s	remaining: 1m 59s
# 43:	learn: 0.3050377	total: 5.46s	remaining: 1m 58s
# 182:	learn: 0.2478054	total: 17.7s	remaining: 1m 19s
# 183:	learn: 0.2475558	total: 17.8s	remaining: 1m 18s
# 184:	learn: 0.2472989	total: 17.9s	remaining: 1m 18s
# 185:	learn: 0.2470277	total: 18s	remaining: 1m 18s
# 186:	learn: 0.2467886	total: 18s	remaining: 1m 18s
# 187:	learn: 0.2465500	total: 18.1s	remaining: 1m 18s
# 188:	learn: 0.2463232	total: 18.2s	remaining: 1m 18s
# 189:	learn: 0.2460817	total: 18.3s	remaining: 1m 17s
# 190:	learn: 0.2458326	total: 18.4s	remaining: 1m 17s
# 191:	learn: 0.2455656	total: 18.5s	remaining: 1m 17s
# 192:	learn: 0.2453384	total: 18.5s	remaining: 1m 17s
# 193:	learn: 0.2450655	total: 18.6s	remaining: 1m 17s
# 194:	learn: 0.2448235	total: 18.7s	remaining: 1m 17s
# 195:	learn: 0.2445803	total: 18.8s	remaining: 1m 17s
# 196:	learn: 0.2443592	total: 18.9s	remaining: 1m 16s
# 197:	learn: 0.2441458	total: 19s	remaining: 1m 16s
# 198:	learn: 0.2439014	total: 19s	remaining: 1m 16s
# 199:	learn: 0.2436682	total: 19.1s	remaining: 1m 16s
# 200:	learn: 0.2434298	total: 19.2s	remaining: 1m 16s
# 201:	learn: 0.2431731	total: 19.3s	remaining: 1m 16s
# 202:	learn: 0.2429350	total: 19.4s	remaining: 1m 16s
# 203:	learn: 0.2426717	total: 19.5s	remaining: 1m 15s
# 204:	learn: 0.2424196	total: 19.6s	remaining: 1m 15s
# 205:	learn: 0.2422074	total: 19.6s	remaining: 1m 15s
# 206:	learn: 0.2419835	total: 19.7s	remaining: 1m 15s
# 207:	learn: 0.2417483	total: 19.8s	remaining: 1m 15s
# 208:	learn: 0.2415613	total: 19.9s	remaining: 1m 15s
# 209:	learn: 0.2413451	total: 20s	remaining: 1m 15s
# 210:	learn: 0.2411173	total: 20.1s	remaining: 1m 15s
# 211:	learn: 0.2409137	total: 20.2s	remaining: 1m 15s
# 212:	learn: 0.2406972	total: 20.4s	remaining: 1m 15s
# 213:	learn: 0.2404628	total: 20.6s	remaining: 1m 15s
# 214:	learn: 0.2402597	total: 20.7s	remaining: 1m 15s
# 215:	learn: 0.2400089	total: 20.9s	remaining: 1m 15s
# 216:	learn: 0.2397981	total: 21.1s	remaining: 1m 16s
# 217:	learn: 0.2395641	total: 21.2s	remaining: 1m 16s
# 218:	learn: 0.2393318	total: 21.3s	remaining: 1m 16s
# 219:	learn: 0.2391017	total: 21.4s	remaining: 1m 15s
# 220:	learn: 0.2388865	total: 21.5s	remaining: 1m 15s
# 221:	learn: 0.2386740	total: 21.6s	remaining: 1m 15s
# 222:	learn: 0.2384995	total: 21.7s	remaining: 1m 15s
# 223:	learn: 0.2382990	total: 21.8s	remaining: 1m 15s
# 224:	learn: 0.2380869	total: 21.8s	remaining: 1m 15s
# 225:	learn: 0.2378896	total: 21.9s	remaining: 1m 15s
# 226:	learn: 0.2377061	total: 22s	remaining: 1m 14s
# 227:	learn: 0.2374950	total: 22.1s	remaining: 1m 14s
# 274:	learn: 0.2285538	total: 26.4s	remaining: 1m 9s
# 275:	learn: 0.2283770	total: 26.5s	remaining: 1m 9s
# 276:	learn: 0.2281925	total: 26.6s	remaining: 1m 9s
# 277:	learn: 0.2280408	total: 26.7s	remaining: 1m 9s
# 278:	learn: 0.2278596	total: 26.8s	remaining: 1m 9s
# 279:	learn: 0.2276983	total: 26.9s	remaining: 1m 9s
# 280:	learn: 0.2275404	total: 27s	remaining: 1m 9s
# 281:	learn: 0.2273691	total: 27.1s	remaining: 1m 8s
# 282:	learn: 0.2271823	total: 27.2s	remaining: 1m 8s
# 283:	learn: 0.2269994	total: 27.3s	remaining: 1m 8s
# 284:	learn: 0.2268443	total: 27.4s	remaining: 1m 8s
# 285:	learn: 0.2266727	total: 27.5s	remaining: 1m 8s
# 286:	learn: 0.2265221	total: 27.6s	remaining: 1m 8s
# 287:	learn: 0.2263722	total: 27.6s	remaining: 1m 8s
# 288:	learn: 0.2262073	total: 27.7s	remaining: 1m 8s
# 289:	learn: 0.2260370	total: 27.8s	remaining: 1m 8s
# 290:	learn: 0.2258733	total: 27.9s	remaining: 1m 8s
# 291:	learn: 0.2257079	total: 28s	remaining: 1m 7s
# 292:	learn: 0.2255457	total: 28.1s	remaining: 1m 7s
# 293:	learn: 0.2253948	total: 28.2s	remaining: 1m 7s
# 294:	learn: 0.2252278	total: 28.3s	remaining: 1m 7s
# 295:	learn: 0.2250653	total: 28.3s	remaining: 1m 7s
# 296:	learn: 0.2249051	total: 28.4s	remaining: 1m 7s
# 297:	learn: 0.2247412	total: 28.5s	remaining: 1m 7s
# 298:	learn: 0.2245721	total: 28.6s	remaining: 1m 7s
# 299:	learn: 0.2244037	total: 28.7s	remaining: 1m 6s
# 300:	learn: 0.2242430	total: 28.8s	remaining: 1m 6s
# 301:	learn: 0.2240668	total: 28.9s	remaining: 1m 6s
# 302:	learn: 0.2239072	total: 29s	remaining: 1m 6s
# 303:	learn: 0.2237527	total: 29s	remaining: 1m 6s
# 304:	learn: 0.2235864	total: 29.1s	remaining: 1m 6s
# 305:	learn: 0.2234278	total: 29.2s	remaining: 1m 6s
# 306:	learn: 0.2232878	total: 29.3s	remaining: 1m 6s
# 307:	learn: 0.2231315	total: 29.4s	remaining: 1m 6s
# 308:	learn: 0.2229775	total: 29.5s	remaining: 1m 5s
# 309:	learn: 0.2228259	total: 29.6s	remaining: 1m 5s
# 310:	learn: 0.2226859	total: 29.7s	remaining: 1m 5s
# 311:	learn: 0.2225308	total: 29.8s	remaining: 1m 5s
# 312:	learn: 0.2223879	total: 29.8s	remaining: 1m 5s
# 313:	learn: 0.2222506	total: 29.9s	remaining: 1m 5s
# 314:	learn: 0.2220905	total: 30s	remaining: 1m 5s
# 315:	learn: 0.2219350	total: 30.1s	remaining: 1m 5s
# 316:	learn: 0.2217777	total: 30.2s	remaining: 1m 5s
# 317:	learn: 0.2216294	total: 30.3s	remaining: 1m 4s
# 318:	learn: 0.2214887	total: 30.4s	remaining: 1m 4s
# 319:	learn: 0.2213435	total: 30.5s	remaining: 1m 4s
# 655:	learn: 0.1845811	total: 1m 3s	remaining: 33.5s
# 656:	learn: 0.1845033	total: 1m 3s	remaining: 33.4s
# 657:	learn: 0.1844396	total: 1m 4s	remaining: 33.3s
# 658:	learn: 0.1843561	total: 1m 4s	remaining: 33.2s
# 659:	learn: 0.1842780	total: 1m 4s	remaining: 33.1s
# 660:	learn: 0.1841954	total: 1m 4s	remaining: 33s
# 661:	learn: 0.1840977	total: 1m 4s	remaining: 32.9s
# 662:	learn: 0.1840306	total: 1m 4s	remaining: 32.8s
# 663:	learn: 0.1839428	total: 1m 4s	remaining: 32.7s
# 664:	learn: 0.1838559	total: 1m 4s	remaining: 32.6s
# 665:	learn: 0.1837833	total: 1m 4s	remaining: 32.5s
# 666:	learn: 0.1837112	total: 1m 4s	remaining: 32.4s
# 667:	learn: 0.1836231	total: 1m 5s	remaining: 32.3s
# 668:	learn: 0.1835310	total: 1m 5s	remaining: 32.2s
# 669:	learn: 0.1834605	total: 1m 5s	remaining: 32.1s
# 670:	learn: 0.1833876	total: 1m 5s	remaining: 32s
# 671:	learn: 0.1833139	total: 1m 5s	remaining: 31.9s
# 672:	learn: 0.1832334	total: 1m 5s	remaining: 31.8s
# 673:	learn: 0.1831417	total: 1m 5s	remaining: 31.8s
# 674:	learn: 0.1830689	total: 1m 5s	remaining: 31.7s
# 675:	learn: 0.1830064	total: 1m 5s	remaining: 31.6s
# 676:	learn: 0.1829256	total: 1m 5s	remaining: 31.5s
# 677:	learn: 0.1828468	total: 1m 6s	remaining: 31.4s
# 678:	learn: 0.1827529	total: 1m 6s	remaining: 31.3s
# 679:	learn: 0.1826682	total: 1m 6s	remaining: 31.2s
# 680:	learn: 0.1825736	total: 1m 6s	remaining: 31.1s
# 681:	learn: 0.1824862	total: 1m 6s	remaining: 31s
# 682:	learn: 0.1824223	total: 1m 6s	remaining: 30.9s
# 683:	learn: 0.1823585	total: 1m 6s	remaining: 30.8s
# 684:	learn: 0.1822929	total: 1m 6s	remaining: 30.7s
# 685:	learn: 0.1822091	total: 1m 6s	remaining: 30.6s
# 686:	learn: 0.1821337	total: 1m 6s	remaining: 30.5s
# 687:	learn: 0.1820533	total: 1m 7s	remaining: 30.4s
# 688:	learn: 0.1819809	total: 1m 7s	remaining: 30.3s
# 689:	learn: 0.1818891	total: 1m 7s	remaining: 30.2s
# 690:	learn: 0.1818017	total: 1m 7s	remaining: 30.1s
# 691:	learn: 0.1817220	total: 1m 7s	remaining: 30s
# 692:	learn: 0.1816449	total: 1m 7s	remaining: 29.9s
# 693:	learn: 0.1815778	total: 1m 7s	remaining: 29.8s
# 694:	learn: 0.1815008	total: 1m 7s	remaining: 29.7s
# 695:	learn: 0.1814232	total: 1m 7s	remaining: 29.6s
# 696:	learn: 0.1813641	total: 1m 7s	remaining: 29.5s
# 697:	learn: 0.1813019	total: 1m 7s	remaining: 29.4s
# 698:	learn: 0.1812180	total: 1m 8s	remaining: 29.3s
# 699:	learn: 0.1811425	total: 1m 8s	remaining: 29.2s
# 700:	learn: 0.1810683	total: 1m 8s	remaining: 29.1s
# 885:	learn: 0.1680189	total: 1m 25s	remaining: 11s
# 886:	learn: 0.1679481	total: 1m 25s	remaining: 10.9s
# 887:	learn: 0.1678875	total: 1m 25s	remaining: 10.8s
# 888:	learn: 0.1678310	total: 1m 26s	remaining: 10.7s
# 889:	learn: 0.1677477	total: 1m 26s	remaining: 10.6s
# 890:	learn: 0.1676747	total: 1m 26s	remaining: 10.6s
# 891:	learn: 0.1676013	total: 1m 26s	remaining: 10.5s
# 892:	learn: 0.1675164	total: 1m 26s	remaining: 10.4s
# 893:	learn: 0.1674522	total: 1m 26s	remaining: 10.3s
# 894:	learn: 0.1673786	total: 1m 26s	remaining: 10.2s
# 895:	learn: 0.1673103	total: 1m 26s	remaining: 10.1s
# 896:	learn: 0.1672442	total: 1m 26s	remaining: 9.97s
# 897:	learn: 0.1671952	total: 1m 26s	remaining: 9.87s
# 898:	learn: 0.1671298	total: 1m 27s	remaining: 9.78s
# 899:	learn: 0.1670759	total: 1m 27s	remaining: 9.68s
# 900:	learn: 0.1670229	total: 1m 27s	remaining: 9.58s
# 901:	learn: 0.1669636	total: 1m 27s	remaining: 9.48s
# 902:	learn: 0.1668931	total: 1m 27s	remaining: 9.38s
# 903:	learn: 0.1668378	total: 1m 27s	remaining: 9.29s
# 904:	learn: 0.1667739	total: 1m 27s	remaining: 9.19s
# 905:	learn: 0.1667291	total: 1m 27s	remaining: 9.09s
# 906:	learn: 0.1666740	total: 1m 27s	remaining: 8.99s
# 907:	learn: 0.1666087	total: 1m 27s	remaining: 8.9s
# 908:	learn: 0.1665570	total: 1m 27s	remaining: 8.8s
# 909:	learn: 0.1664980	total: 1m 27s	remaining: 8.7s
# 910:	learn: 0.1664273	total: 1m 28s	remaining: 8.61s
# 911:	learn: 0.1663727	total: 1m 28s	remaining: 8.51s
# 912:	learn: 0.1663087	total: 1m 28s	remaining: 8.41s
# 913:	learn: 0.1662626	total: 1m 28s	remaining: 8.31s
# 914:	learn: 0.1662012	total: 1m 28s	remaining: 8.21s
# 915:	learn: 0.1661299	total: 1m 28s	remaining: 8.12s
# 916:	learn: 0.1660558	total: 1m 28s	remaining: 8.02s
# 917:	learn: 0.1659866	total: 1m 28s	remaining: 7.92s
# 918:	learn: 0.1659244	total: 1m 28s	remaining: 7.83s
# 919:	learn: 0.1658720	total: 1m 28s	remaining: 7.73s
# 920:	learn: 0.1658049	total: 1m 28s	remaining: 7.63s
# 921:	learn: 0.1657440	total: 1m 29s	remaining: 7.54s
# 922:	learn: 0.1656832	total: 1m 29s	remaining: 7.44s
# 923:	learn: 0.1656233	total: 1m 29s	remaining: 7.34s
# 924:	learn: 0.1655566	total: 1m 29s	remaining: 7.25s
# 925:	learn: 0.1654755	total: 1m 29s	remaining: 7.15s
# 926:	learn: 0.1654263	total: 1m 29s	remaining: 7.05s
# 927:	learn: 0.1653717	total: 1m 29s	remaining: 6.96s
# 928:	learn: 0.1653106	total: 1m 29s	remaining: 6.86s
# 929:	learn: 0.1652395	total: 1m 29s	remaining: 6.77s
# 930:	learn: 0.1651673	total: 1m 30s	remaining: 6.67s
# 977:	learn: 0.1623149	total: 1m 34s	remaining: 2.13s
# 978:	learn: 0.1622685	total: 1m 34s	remaining: 2.03s
# 979:	learn: 0.1622097	total: 1m 34s	remaining: 1.94s
# 980:	learn: 0.1621711	total: 1m 35s	remaining: 1.84s
# 981:	learn: 0.1621083	total: 1m 35s	remaining: 1.74s
# 982:	learn: 0.1620475	total: 1m 35s	remaining: 1.65s
# 983:	learn: 0.1619830	total: 1m 35s	remaining: 1.55s
# 984:	learn: 0.1619283	total: 1m 35s	remaining: 1.45s
# 985:	learn: 0.1618647	total: 1m 35s	remaining: 1.36s
# 986:	learn: 0.1618115	total: 1m 35s	remaining: 1.26s
# 987:	learn: 0.1617629	total: 1m 35s	remaining: 1.16s
# 988:	learn: 0.1616894	total: 1m 35s	remaining: 1.06s
# 989:	learn: 0.1616210	total: 1m 35s	remaining: 968ms
# 990:	learn: 0.1615554	total: 1m 35s	remaining: 871ms
# 991:	learn: 0.1614878	total: 1m 36s	remaining: 775ms
# 992:	learn: 0.1614256	total: 1m 36s	remaining: 678ms
# 993:	learn: 0.1613527	total: 1m 36s	remaining: 581ms
# 994:	learn: 0.1612875	total: 1m 36s	remaining: 484ms
# 995:	learn: 0.1612468	total: 1m 36s	remaining: 387ms
# 996:	learn: 0.1611803	total: 1m 36s	remaining: 290ms
# 997:	learn: 0.1611302	total: 1m 36s	remaining: 194ms
# 998:	learn: 0.1610690	total: 1m 36s	remaining: 96.8ms
# 999:	learn: 0.1610172	total: 1m 36s	remaining: 0us

# %% [markdown]
# ## Evaluation

# %% [markdown]
# #### Metrics which require predict method

# %% [markdown]
# ##### Confusion matrix
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html
#
# TN | FP
#
# FN | TP

# %% [markdown]
# #### Confusion matrix, Recall, Precision, F1-score, G-mean, etc

# %%
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    recall_score,
    precision_score,
    f1_score,
    classification_report,
    confusion_matrix
)

from imblearn.metrics import (
    geometric_mean_score,
    make_index_balanced_accuracy,
)

# %%
# Helper functions


def dominance(y_true, y_pred):
    tpr = recall_score(y_test, y_pred, pos_label=1)
    tnr = recall_score(y_test, y_pred, pos_label=0)
    return tpr - tnr

# Function to get classification metrics
def get_classification_metrics(y_true, y_pred):
    report = classification_report(y_true, y_pred, output_dict=True)
    accuracy          = accuracy_score(y_test, y_pred)
    balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
    
    # Adding possible averages to recall, precision, and f1-score calculations
    # Default average is None - scores are returned for each class individually rather than being averaged
    recall_weighted    = recall_score(y_test, y_pred, average='weighted')
    precision_weighted = precision_score(y_test, y_pred, average='weighted') 
    f1_weighted        = f1_score(y_test, y_pred, average='weighted')

    recall_micro       = recall_score(y_test, y_pred, average='micro')
    precision_micro    = precision_score(y_test, y_pred, average='micro')
    f1_micro           = f1_score(y_test, y_pred, average='micro')
    
    recall_macro       = recall_score(y_test, y_pred, average='macro')
    precision_macro    = precision_score(y_test, y_pred, average='macro')
    f1_macro           = f1_score(y_test, y_pred, average='macro')

    # Adding possible averages to G-mean
    # If the average parameter is not specified, it defaults to average='binary'.
    g_mean_binary      = geometric_mean_score(y_test, y_pred, average='binary')
    g_mean_weighted    = geometric_mean_score(y_test, y_pred, average='weighted')
    g_mean_micro       = geometric_mean_score(y_test, y_pred, average='micro')
    g_mean_macro       = geometric_mean_score(y_test, y_pred, average='macro')

    # A lower alpha gives more weight to sensitivity (TPR), while a higher alpha gives more weight to specificity (TNR). 
    # In other words,in case of a lower alpha more emphasis is placed on correctly identifying positive instances
    gmean = make_index_balanced_accuracy(alpha=0.5, squared=True)(geometric_mean_score) 
    corrected_g_mean  = gmean(y_test, y_pred)
    # specifying an average might not be necessary or meaningful. Leaving for the time being
    corrected_g_mean_binary  = gmean(y_test, y_pred,average='binary')
    corrected_g_mean_weighted  = gmean(y_test, y_pred,average='weighted')
    corrected_g_mean_micro  = gmean(y_test, y_pred,average='micro')
    corrected_g_mean_macro  = gmean(y_test, y_pred,average='macro')
    
    dominance_score   = dominance(y_test, y_pred) 

    tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
    FPR = fp / (tn + fp)
    FNR = fn / (tp + fn)
    # TPR = tp / (tp + fn) # recallminority
    # TNR = tn / (tn + fp) # recall majority
    
    return {
        'Accuracy': accuracy,
        'Recall Majority (TNR)': report['0']['recall'],
        'Recall Minority (TPR)': report['1']['recall'],
        'Balanced Accuracy': balanced_accuracy,
        'FPR': FPR,
        'FNR': FNR,
        
        'Precision Majority': report['0']['precision'],
        'Precision Minority': report['1']['precision'],
        'F1-Score Majority': report['0']['f1-score'],
        'F1-Score Minority': report['1']['f1-score'], 
        
        # Weighted average (Use 'weighted' if you want to take class imbalance into account)
        'Weighted Precision': precision_weighted,
        'Weighted Recall': recall_weighted,
        'Weighted F1-Score': f1_weighted,

        # Micro average (Use 'micro' if you want a metric that gives equal weight to every individual prediction)
        'Micro Precision': precision_micro,
        'Micro Recall': recall_micro,
        'Micro F1-Score': f1_micro,
        
        # Macro average (Use 'macro' if you want to treat each class equally)
        'Macro Precision': precision_macro,
        'Macro Recall': recall_macro,
        'Macro F1-Score': f1_macro,

        # Geometric average (a suitable metric when you want to balance the trade-off between detecting the minority class 
        # and avoiding false positives from the majority class)
        'G-mean-binary': g_mean_binary, # (compute two geometric means for each class, then the arithmetic mean of these G-means)
        'G-mean-weighted': g_mean_weighted, # calculates the geometric mean for each class and then computes the weighted arithmetic mean of these G-means
        'G-mean-micro': g_mean_micro, # treats all classes equally, regardless of their size
        'G-mean-macro': g_mean_macro, # use when you want to weight each instance equally, regardless of their class

        # Corrected G-means
        'Corrected G-mean': corrected_g_mean,
        'Corrected G-mean-binary': corrected_g_mean_binary,
        'Corrected G-mean-weighted': corrected_g_mean_weighted,
        'Corrected G-mean-micro': corrected_g_mean_micro,
        'Corrected G-mean-macro': corrected_g_mean_macro,
        
        'Dominance': dominance_score
    }

# %%
models = {
    'Random Forest': rf.predict(X_test),
    'Logistic Regression': logit.predict(X_test),
    'XGBoost': xgb_model.predict(X_test),
    'LightGBM': lgb_model.predict(X_test),
    'CatBoost': catboost_model.predict(X_test)
}

# Collecting results
results = []
confusion_matricies = []
for model_name, y_pred in models.items():
    metrics           = get_classification_metrics(y_test, y_pred)
    conf_matrix       = confusion_matrix(y_test, y_pred)
    results.append({
        'Model': model_name,
        **metrics,
    })
    confusion_matricies.append({
        'Model': model_name,
        'Confusion matrix': conf_matrix
    })

# Create a DataFrame from the results
df_results_1 = pd.DataFrame(results)
df_confusion_matricies = pd.DataFrame(confusion_matricies)

# Print the DataFrame as a table
print(df_results_1)
print(df_confusion_matricies)
# Out:
#                  Model  Accuracy  Recall Majority (TNR)  \
# 0        Random Forest  0.899517               1.000000
# 1  Logistic Regression  0.912850               0.981953
# 2              XGBoost  0.912117               0.982639
# 3             LightGBM  0.909450               0.996146
#
#    Recall Minority (TPR)  Balanced Accuracy       FPR       FNR  \
# 0               0.000000           0.500000  0.000000  1.000000
# 1               0.294244           0.638099  0.018047  0.705756
# 2               0.280809           0.631724  0.017361  0.719191
# 3               0.133355           0.564751  0.003854  0.866645
#
#    Precision Majority  Precision Minority  F1-Score Majority  ...  \
# 0            0.899517            0.000000           0.947101  ...
# 1            0.925679            0.645560           0.952986  ...
# 2            0.924420            0.643726           0.952641  ...
# 3            0.911423            0.794466           0.951903  ...
#
#    G-mean-binary  G-mean-weighted  G-mean-micro  G-mean-macro  \
# 0       0.000000         0.300643      0.899517      0.500000
# 1       0.537526         0.575918      0.912850      0.638099
# 2       0.525294         0.566088      0.912117      0.631724
# 3       0.364474         0.447354      0.909450      0.564751
#
#    Corrected G-mean  Corrected G-mean-binary  Corrected G-mean-weighted  \
# 0          0.000000                 0.000000                   0.126497
# 1          0.288934                 0.189583                   0.422812
# 2          0.275934                 0.179105                   0.410309
# 3          0.132842                 0.075534                   0.269109
#
#    Corrected G-mean-micro  Corrected G-mean-macro  Dominance
# 0                0.809130                0.250000  -1.000000
# 1                0.833295                0.407170  -0.687709
# 2                0.831957                0.399075  -0.701829
# 3                0.827099                0.318943  -0.862791
#
# [4 rows x 30 columns]
#                  Model              Confusion matrix
# 0        Random Forest       [[53971, 0], [6029, 0]]
# 1  Logistic Regression  [[52997, 974], [4255, 1774]]
# 2              XGBoost  [[53034, 937], [4336, 1693]]
# 3             LightGBM   [[53763, 208], [5225, 804]]

# %% [markdown]
# #### Metrics which require predict_proba method
# The ROC AUC score is calculated based on the predicted probabilities for each class, which are obtained using the predict_proba method. This method provides the probability estimates for each class, which are necessary to compute the ROC curve and subsequently the AUC (Area Under the Curve).

# %%
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score
)

models = {
    'Random Forest': rf.predict_proba(X_test)[:,1],
    'Logistic Regression': logit.predict_proba(X_test)[:,1],
    'XGBoost': xgb_model.predict_proba(X_test)[:,1],
    'LightGBM': lgb_model.predict_proba(X_test)[:,1],
    'CatBoost': catboost_model.predict_proba(X_test)[:,1]
}

# Collecting results
results = []
for model_name, y_pred in models.items():
    roc_auc   = roc_auc_score(y_test, y_pred) 
    pr_auc = average_precision_score(y_test, y_pred)
    results.append({
        'Model': model_name,
        'ROC-AUC': roc_auc,
        'PR-AUC': pr_auc
    })

# Create a DataFrame from the results
df_results_2 = pd.DataFrame(results)

# Print the DataFrame as a table
print(df_results_2)
# Out:
#                  Model   ROC-AUC    PR-AUC
# 0        Random Forest  0.736037  0.224972
# 1  Logistic Regression  0.858266  0.497735
# 2              XGBoost  0.855851  0.483367
# 3             LightGBM  0.861808  0.499206
# 4             CatBoost  0.891671  0.577059

# %% [markdown]
# ### Export classification metrics

# %%
# Concatenate df_results_1 and df_results_2 horisontally
df_combined_results = pd.concat([df_results_2, df_results_1], axis=1)

# Export results to CSV files
df_combined_results.to_csv('5_evaluation_results_outliers.csv', index=False)
df_confusion_matricies.to_csv('5_confusion_matricies_outliers.csv', index=False)
